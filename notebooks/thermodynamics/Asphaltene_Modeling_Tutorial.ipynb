# %% [markdown]
# # Asphaltene screening and phase-behaviour modeling with NeqSim
#
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/thermodynamics/Asphaltene_Modeling_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Asphaltene deposition can restrict wells, pipelines, valves, and separators. This tutorial
# combines transparent screening calculations with NeqSim's current
# `PedersenAsphalteneCharacterization` workflow. It keeps screening, equilibrium prediction,
# and laboratory calibration clearly separated.
#
# ## Learning objectives
#
# After completing the notebook, you can:
#
# 1. calculate and interpret SARA-based stability indicators;
# 2. use a qualitative pressure-density risk map without treating it as a calibrated model;
# 3. characterize a heavy asphaltene pseudo-component with the Pedersen correlations;
# 4. add that component to SRK and CPA systems and run phase-aware flashes;
# 5. inspect every phase instead of assuming a fixed phase index;
# 6. perform depletion, molecular-weight, temperature, and interaction-parameter studies;
# 7. verify phase-fraction and component closure; and
# 8. define the laboratory data needed before using the model for design decisions.

# %%
import subprocess
import sys

if "google.colab" in sys.modules:
    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--no-cache-dir",
            "neqsim",
        ]
    )
else:
    print("Using the validated local NeqSim environment.")
# Out:
# Using the validated local NeqSim environment.

# %% [markdown]
# ## 1. Engineering context and terminology
#
# Asphaltenes are operationally defined as the fraction of crude oil that is insoluble in a
# specified light paraffinic solvent, commonly $n$-heptane or $n$-pentane, but soluble in an
# aromatic solvent such as toluene. They are not one pure chemical species.
#
# SARA fractionation groups an oil into saturates, aromatics, resins, and asphaltenes. Pressure,
# temperature, composition, gas injection, and mixing can change the solvent quality of the oil.
# An unstable asphaltene-rich phase can then appear and may deposit after additional transport,
# aggregation, and surface-attachment steps.
#
# The modeling hierarchy used here is:
#
# - **screening:** dimensionless indicators used to prioritize samples;
# - **equilibrium:** a cubic equation of state represents an asphaltene-rich liquid split;
# - **calibration:** pseudo-component properties and binary interaction parameters are fitted to
#   measured onset and precipitation data;
# - **deposition:** a separate kinetic and transport problem, not predicted by equilibrium alone.
#
# All fluids and measurements in this notebook are synthetic and public. Results are teaching
# examples, not a field-fluid design basis.

# %% [markdown]
# ## 2. Setup NeqSim with direct Java access
#
# The Python package starts the NeqSim Java engine through JPype. Direct Java access is useful here
# because the asphaltene characterization class exposes its full current API: pseudo-component
# characterization, addition to a thermodynamic system, interaction-parameter application,
# phase-aware TP flash, and solvency screening.

# %%
from importlib.metadata import version

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display

from neqsim import jneqsim


SystemSrkEos = jneqsim.thermo.system.SystemSrkEos
SystemSrkCPAstatoil = jneqsim.thermo.system.SystemSrkCPAstatoil
ThermodynamicOperations = (
    jneqsim.thermodynamicoperations.ThermodynamicOperations
)
PedersenAsphalteneCharacterization = (
    jneqsim.thermo.characterization.PedersenAsphalteneCharacterization
)

NEQSIM_VERSION = version("neqsim")
COLORS = {
    "blue": "#0072B2",
    "orange": "#E69F00",
    "green": "#009E73",
    "red": "#D55E00",
    "purple": "#CC79A7",
    "sky": "#56B4E9",
}

print(f"NeqSim version: {NEQSIM_VERSION}")
# Out:
# NeqSim version: 3.16.0

# %% [markdown]
# ## 10. Practical end-to-end NeqSim workflow
#
# The final application connects the notebook's pieces into a reusable workflow:
#
# $$
# \text{fluid data}
# \longrightarrow
# \text{pseudo-component}
# \longrightarrow
# \text{mixing rule and } k_{ij}
# \longrightarrow
# \text{TP flash}
# \longrightarrow
# \text{phase validation}
# $$
#
# The synthetic base case is 50 °C and 150 bar. Every sensitivity point is rebuilt from the same
# feed rather than inheriting a previous flash state. This cold-case construction makes the study
# reproducible and exposes isolated convergence gaps instead of hiding them in a warm-start path.

# %%
figure, axis = plt.subplots(figsize=(13.5, 3.7))
axis.set_xlim(0.0, 13.5)
axis.set_ylim(0.0, 2.7)
axis.axis("off")

workflow_steps = [
    ("SARA + live oil", COLORS["sky"]),
    ("Pedersen\npseudo-component", COLORS["blue"]),
    ("SRK / CPA\n+ kij", COLORS["orange"]),
    ("Multiphase TP flash", COLORS["green"]),
    ("Closure +\nsensitivity", COLORS["purple"]),
]
x_positions = np.linspace(1.3, 12.2, len(workflow_steps))
for index, ((label, color), x_position) in enumerate(
    zip(workflow_steps, x_positions)
):
    axis.text(
        x_position,
        1.35,
        label,
        ha="center",
        va="center",
        color="white",
        fontsize=9,
        bbox={
            "boxstyle": "round,pad=0.45",
            "facecolor": color,
            "edgecolor": "black",
        },
    )
    if index < len(workflow_steps) - 1:
        axis.annotate(
            "",
            xy=(x_positions[index + 1] - 1.05, 1.35),
            xytext=(x_position + 1.05, 1.35),
            arrowprops={
                "arrowstyle": "->",
                "color": "black",
                "lw": 1.8,
            },
        )

axis.set_title(
    "Asphaltene screening-to-validation workflow",
    fontsize=14,
)
figure.tight_layout()
plt.show()

# %% [markdown]
# The overview separates measurements and screening from the thermodynamic calculation. Its final
# validation block is deliberately explicit: a converged TP flash is only usable after phase
# identity, physical properties, and component closure have been checked.

# %% [markdown]
# ## 3. SARA analysis and stability indicators
#
# For mass fractions $w_i$, a commonly used colloidal-instability index is
#
# $$
# \mathrm{CII} =
# \frac{w_{\mathrm{sat}} + w_{\mathrm{asp}}}
# {w_{\mathrm{aro}} + w_{\mathrm{res}}}
# $$
#
# The resin-to-asphaltene ratio is
#
# $$
# R/A = \frac{w_{\mathrm{res}}}{w_{\mathrm{asp}}}
# $$
#
# These ratios are empirical screens, not thermodynamic state functions. Their thresholds depend on
# the analytical method and crude-oil population. They do not replace measured onset pressure or a
# calibrated phase-equilibrium model.

# %%
def calculate_stability_indicators(
    saturates,
    aromatics,
    resins,
    asphaltenes,
):
    fractions = np.array(
        [saturates, aromatics, resins, asphaltenes],
        dtype=float,
    )
    if np.any(fractions < 0.0):
        raise ValueError("SARA fractions must be non-negative.")
    if not np.isclose(fractions.sum(), 1.0, atol=1.0e-10):
        raise ValueError("SARA fractions must sum to one.")

    denominator = aromatics + resins
    if denominator <= 0.0 or asphaltenes <= 0.0:
        raise ValueError("Aromatics + resins and asphaltenes must be positive.")

    cii = (saturates + asphaltenes) / denominator
    resin_asphaltene_ratio = resins / asphaltenes

    if cii < 0.7:
        category = "lower empirical risk"
    elif cii < 0.9:
        category = "intermediate empirical risk"
    else:
        category = "higher empirical risk"

    return cii, resin_asphaltene_ratio, category


sara_samples = pd.DataFrame(
    [
        ["Synthetic light oil", 0.60, 0.25, 0.10, 0.05],
        ["Aromatic-rich oil", 0.42, 0.38, 0.15, 0.05],
        ["Resin-stabilized oil", 0.48, 0.27, 0.20, 0.05],
    ],
    columns=[
        "Sample",
        "Saturates",
        "Aromatics",
        "Resins",
        "Asphaltenes",
    ],
)

indicator_rows = []
for row in sara_samples.itertuples(index=False):
    cii, ratio, category = calculate_stability_indicators(
        row.Saturates,
        row.Aromatics,
        row.Resins,
        row.Asphaltenes,
    )
    indicator_rows.append(
        {
            "Sample": row.Sample,
            "CII [-]": cii,
            "R/A [-]": ratio,
            "Interpretation": category,
        }
    )

sara_results = pd.DataFrame(indicator_rows)
display(sara_results.round(3))
# Out:
#                  Sample  CII [-]  R/A [-]               Interpretation
# 0   Synthetic light oil    1.857      2.0        higher empirical risk
# 1     Aromatic-rich oil    0.887      3.0  intermediate empirical risk
# 2  Resin-stabilized oil    1.128      4.0        higher empirical risk

# %% [markdown]
# ## 4. Pressure-density screening
#
# De Boer and co-workers related field observations to reservoir undersaturation and in-situ oil
# density. This notebook preserves the original pressure-density example as a **qualitative teaching
# map**. The score below is deliberately transparent and dimensionless; it is not presented as the
# published De Boer correlation and must not be used as a quantitative acceptance criterion.
#
# Reservoir undersaturation is
#
# $$
# \Delta P = P_{\mathrm{res}} - P_{\mathrm{b}}
# $$
#
# where $P_{\mathrm{res}}$ and $P_{\mathrm{b}}$ are reservoir and bubble-point pressure in bar. A
# larger pressure change and a lighter live oil receive a higher illustrative screening score.

# %%
def pressure_density_screen(
    reservoir_pressure_bar,
    bubble_pressure_bar,
    live_oil_density_kg_m3,
):
    pressure_margin_bar = reservoir_pressure_bar - bubble_pressure_bar
    if pressure_margin_bar < 0.0:
        raise ValueError("Reservoir pressure must be at or above bubble pressure.")
    if not 600.0 <= live_oil_density_kg_m3 <= 950.0:
        raise ValueError("Live-oil density is outside the screening range.")

    pressure_score = np.clip(pressure_margin_bar / 300.0, 0.0, 1.0)
    density_score = np.clip(
        (850.0 - live_oil_density_kg_m3) / 200.0,
        0.0,
        1.0,
    )
    illustrative_score = 0.65 * pressure_score + 0.35 * density_score

    if illustrative_score < 0.33:
        category = "lower screen"
    elif illustrative_score < 0.66:
        category = "intermediate screen"
    else:
        category = "higher screen"

    return pressure_margin_bar, illustrative_score, category


screening_cases = pd.DataFrame(
    [
        ["Field A", 350.0, 150.0, 720.0],
        ["Field B", 280.0, 180.0, 780.0],
        ["Field C", 400.0, 120.0, 690.0],
    ],
    columns=[
        "Case",
        "Reservoir pressure [bar]",
        "Bubble pressure [bar]",
        "Live-oil density [kg/m³]",
    ],
)

screen_rows = []
for row in screening_cases.itertuples(index=False):
    pressure_margin, score, category = pressure_density_screen(
        row[1],
        row[2],
        row[3],
    )
    screen_rows.append(
        {
            "Case": row.Case,
            "Undersaturation [bar]": pressure_margin,
            "Illustrative score [-]": score,
            "Category": category,
            "Density [kg/m³]": row[3],
        }
    )

pressure_density_results = pd.DataFrame(screen_rows)
display(pressure_density_results.round(3))

figure, axis = plt.subplots(figsize=(8.5, 5.2))
for row in pressure_density_results.itertuples(index=False):
    axis.scatter(
        row[1],
        row[4],
        s=170,
        label=f"{row.Case}: {row[3]}",
    )
    axis.annotate(
        row.Case,
        (row[1], row[4]),
        xytext=(7, 7),
        textcoords="offset points",
    )
axis.set_title("Qualitative pressure-density screening map")
axis.set_xlabel("Reservoir undersaturation, ΔP [bar]")
axis.set_ylabel("Live-oil density [kg/m³]")
axis.grid(True, alpha=0.3)
axis.legend(title="Illustrative category")
figure.tight_layout()
plt.show()
# Out:
#       Case  Undersaturation [bar]  ...             Category Density [kg/m³]
# 0  Field A                  200.0  ...        higher screen           720.0
# 1  Field B                  100.0  ...  intermediate screen           780.0
# 2  Field C                  280.0  ...        higher screen           690.0
#
# [3 rows x 5 columns]

# %% [markdown]
# The pressure-density map ranks Field C highest because it combines the largest undersaturation
# with the lightest oil. That conclusion is only a prioritization signal. It does not predict an
# onset pressure or deposited mass.

# %% [markdown]
# ## 5. Pedersen classical cubic-EOS method
#
# NeqSim represents the asphaltene fraction as a characterized heavy pseudo-component. A classical
# SRK or PR equation of state can then represent precipitation as liquid-liquid equilibrium: an
# asphaltene-lean liquid and an asphaltene-rich liquid.
#
# The SRK pressure relation is
#
# $$
# P =
# \frac{RT}{v-b}
# -
# \frac{a\alpha}{v(v+b)}
# $$
#
# NeqSim derives pseudo-critical properties from molecular weight $M$ in g/mol and density
# $\rho_{\mathrm{asp}}$ in g/cm³. Binary interaction parameters $k_{ij}$ influence the cross-energy
# term:
#
# $$
# a_{ij} =
# \sqrt{a_i a_j}
# \left(1-k_{ij}\right)
# $$
#
# The exact implementation uses a mixing-rule matrix; this compact expression only shows why
# $k_{ij}$ is a calibration parameter. Laboratory onset and precipitation data are essential.

# %%
def build_pedersen_oil(
    pressure_bar=150.0,
    temperature_k=323.15,
    asphaltene_mw_g_mol=750.0,
    asphaltene_density_g_cm3=1.10,
    base_kij=0.0,
    system_class=SystemSrkEos,
):
    fluid = system_class(temperature_k, pressure_bar)
    base_composition = [
        ("methane", 0.30),
        ("n-pentane", 0.25),
        ("n-heptane", 0.20),
        ("nC10", 0.10),
        ("nC20", 0.05),
    ]
    for component_name, moles in base_composition:
        fluid.addComponent(component_name, moles)

    characterization = PedersenAsphalteneCharacterization()
    characterization.setAsphalteneMW(asphaltene_mw_g_mol)
    characterization.setAsphalteneDensity(asphaltene_density_g_cm3)
    component_name = characterization.addAsphalteneToSystem(
        fluid,
        0.10,
    )

    fluid.setMixingRule("classic")
    fluid.setMultiPhaseCheck(True)
    fluid.init(0)
    characterization.applyAsphalteneKij(fluid, base_kij)

    return fluid, characterization, str(component_name)


fluid, asphaltene_characterization, asphaltene_component_name = (
    build_pedersen_oil()
)

characterization_properties = pd.DataFrame(
    {
        "Property": [
            "Component name",
            "Molecular weight [g/mol]",
            "Density input [g/cm³]",
            "Critical temperature [K]",
            "Critical pressure [bar]",
            "Acentric factor [-]",
            "Normal boiling point [K]",
        ],
        "Value": [
            asphaltene_component_name,
            asphaltene_characterization.getAsphalteneMW(),
            asphaltene_characterization.getAsphalteneDensity(),
            asphaltene_characterization.getCriticalTemperature(),
            asphaltene_characterization.getCriticalPressure(),
            asphaltene_characterization.getAcentricFactor(),
            asphaltene_characterization.getBoilingPoint(),
        ],
    }
)
display(characterization_properties)
# Out:
#                    Property          Value
# 0            Component name  Asphaltene_PC
# 1  Molecular weight [g/mol]          750.0
# 2     Density input [g/cm³]            1.1
# 3  Critical temperature [K]     996.121998
# 4   Critical pressure [bar]      16.263452
# 5       Acentric factor [-]            2.5
# 6  Normal boiling point [K]     838.462437

# %%
def extract_phase_table(system):
    system.initProperties()
    rows = []
    for phase_index in range(system.getNumberOfPhases()):
        phase = system.getPhase(phase_index)
        density = float(phase.getDensity("kg/m3"))
        asphaltene_fraction = 0.0
        for component_index in range(phase.getNumberOfComponents()):
            component = phase.getComponent(component_index)
            if "asph" in str(component.getComponentName()).lower():
                asphaltene_fraction += float(component.getx())
        rows.append(
            {
                "Phase": phase_index,
                "Type before marking": str(phase.getPhaseTypeName()),
                "Beta [-]": float(phase.getBeta()),
                "Density [kg/m³]": density,
                "Asphaltene mole fraction [-]": asphaltene_fraction,
                "Asphaltene rich": bool(phase.isAsphalteneRich()),
            }
        )
    PedersenAsphalteneCharacterization.markAsphalteneRichLiquidPhases(
        system
    )
    for row in rows:
        row["Type after marking"] = str(
            system.getPhase(row["Phase"]).getPhaseTypeName()
        )
    return pd.DataFrame(rows)


has_asphaltene_rich_phase = (
    PedersenAsphalteneCharacterization.TPflash(fluid)
)
phase_results = extract_phase_table(fluid)

print(
    "Asphaltene-rich liquid detected:",
    has_asphaltene_rich_phase,
)
display(phase_results.round(6))
# Out:
# Asphaltene-rich liquid detected: True
#    Phase Type before marking  ...  Asphaltene rich  Type after marking
# 0      0                 oil  ...            False                 oil
# 1      1                 oil  ...             True   asphaltene liquid
#
# [2 rows x 7 columns]

# %%
def cold_pressure_case(pressure_bar, system_class=SystemSrkEos):
    case_fluid, case_characterization, _ = build_pedersen_oil(
        pressure_bar=float(pressure_bar),
        system_class=system_class,
    )
    detected = PedersenAsphalteneCharacterization.TPflash(case_fluid)
    rows = extract_phase_table(case_fluid)
    heavy_beta = rows.loc[
        rows["Asphaltene rich"],
        "Beta [-]",
    ].sum()
    gas_beta = rows.loc[
        rows["Type before marking"].str.contains(
            "gas",
            case=False,
        ),
        "Beta [-]",
    ].sum()
    return {
        "Pressure [bar]": float(pressure_bar),
        "Number of phases [-]": int(case_fluid.getNumberOfPhases()),
        "Asphaltene-rich beta [-]": float(heavy_beta),
        "Gas beta [-]": float(gas_beta),
        "Detected": bool(detected),
    }


depletion_pressures_bar = [
    250.0,
    225.0,
    200.0,
    175.0,
    150.0,
    125.0,
    100.0,
]
depletion_results = pd.DataFrame(
    [
        cold_pressure_case(pressure_bar)
        for pressure_bar in depletion_pressures_bar
    ]
)
display(depletion_results.round(6))

figure, axes = plt.subplots(1, 2, figsize=(12.0, 4.6))
axes[0].plot(
    depletion_results["Pressure [bar]"],
    depletion_results["Number of phases [-]"],
    marker="o",
    color=COLORS["blue"],
    label="Equilibrium phase count",
)
axes[0].set_title("Refreshed phase count during pressure depletion")
axes[0].set_xlabel("Pressure [bar]")
axes[0].set_ylabel("Number of phases [-]")
axes[0].grid(True, alpha=0.3)
axes[0].legend()

axes[1].plot(
    depletion_results["Pressure [bar]"],
    depletion_results["Asphaltene-rich beta [-]"],
    marker="s",
    color=COLORS["red"],
    label="Asphaltene-rich phase fraction",
)
axes[1].plot(
    depletion_results["Pressure [bar]"],
    depletion_results["Gas beta [-]"],
    marker="^",
    color=COLORS["green"],
    label="Gas phase fraction",
)
axes[1].set_title("Refreshed phase fractions during depletion")
axes[1].set_xlabel("Pressure [bar]")
axes[1].set_ylabel("Molar phase fraction, β [-]")
axes[1].grid(True, alpha=0.3)
axes[1].legend()

for axis in axes:
    axis.invert_xaxis()
figure.tight_layout()
plt.show()
# Out:
#    Pressure [bar]  Number of phases [-]  ...  Gas beta [-]  Detected
# 0           250.0                     2  ...      0.000000     False
# 1           225.0                     2  ...      0.000000      True
# 2           200.0                     1  ...      0.000000     False
# 3           175.0                     2  ...      0.000000      True
# 4           150.0                     2  ...      0.000000      True
# 5           125.0                     2  ...      0.021843     False
# 6           100.0                     2  ...      0.050309     False
#
# [7 rows x 5 columns]

# %% [markdown]
# The cold-case pressure scan predicts a significant asphaltene-rich phase around 150 bar for this
# unfitted synthetic fluid. Isolated topology changes at nearby pressures show why a coarse scan
# must be refined and checked for continuity before an onset is reported.

# %% [markdown]
# ## 6. Tuning Pedersen pseudo-component parameters
#
# Molecular weight and density determine the initial pseudo-critical properties. Tuning multipliers
# then alter $T_c$, $P_c$, and the acentric factor $\omega$. These are regression parameters, not
# independent physical measurements.
#
# For a measured property $y_m$ and model prediction $y_p$, a weighted least-squares objective may be
#
# $$
# J(\boldsymbol{\theta}) =
# \sum_m
# \left(
# \frac{y_{p,m}(\boldsymbol{\theta})-y_m}
# {\sigma_m}
# \right)^2
# $$
#
# where $\boldsymbol{\theta}$ contains selected pseudo-component and interaction parameters and
# $\sigma_m$ represents measurement uncertainty.

# %%
molecular_weights_g_mol = np.array(
    [600.0, 750.0, 1000.0, 1500.0]
)
critical_temperatures_k = []
critical_pressures_bar = []
acentric_factors = []

for molecular_weight in molecular_weights_g_mol:
    characterization = PedersenAsphalteneCharacterization()
    characterization.setAsphalteneMW(float(molecular_weight))
    characterization.setAsphalteneDensity(1.10)
    characterization.characterize()
    critical_temperatures_k.append(
        characterization.getCriticalTemperature()
    )
    critical_pressures_bar.append(
        characterization.getCriticalPressure()
    )
    acentric_factors.append(
        characterization.getAcentricFactor()
    )

figure, axes = plt.subplots(1, 3, figsize=(14.0, 4.3))
series = [
    (
        critical_temperatures_k,
        "Critical temperature [K]",
        "Pedersen critical temperature",
        COLORS["blue"],
    ),
    (
        critical_pressures_bar,
        "Critical pressure [bar]",
        "Pedersen critical pressure",
        COLORS["red"],
    ),
    (
        acentric_factors,
        "Acentric factor [-]",
        "Pedersen acentric factor",
        COLORS["green"],
    ),
]

for axis, (values, label, title, color) in zip(axes, series):
    axis.plot(
        molecular_weights_g_mol,
        values,
        marker="o",
        color=color,
        label="NeqSim characterization",
    )
    axis.set_xlabel("Asphaltene molecular weight [g/mol]")
    axis.set_ylabel(label)
    axis.set_title(title)
    axis.grid(True, alpha=0.3)
    axis.legend()

figure.tight_layout()
plt.show()

# %% [markdown]
# Increasing molecular weight changes all three characterized properties, but the response is
# correlation-driven. Molecular weight should therefore be fitted together with density and
# interaction parameters, not adjusted solely to obtain a visually preferred phase envelope.

# %%
tuned_characterization = PedersenAsphalteneCharacterization()
tuned_characterization.setAsphalteneMW(750.0)
tuned_characterization.setAsphalteneDensity(1.10)
tuned_characterization.characterize()

base_properties = {
    "Tc [K]": tuned_characterization.getCriticalTemperature(),
    "Pc [bar]": tuned_characterization.getCriticalPressure(),
    "Omega [-]": tuned_characterization.getAcentricFactor(),
}

tuned_characterization.setTuningParameters(
    1.05,
    0.95,
    1.02,
)
tuned_characterization.characterize()
tuned_properties = {
    "Tc [K]": tuned_characterization.getCriticalTemperature(),
    "Pc [bar]": tuned_characterization.getCriticalPressure(),
    "Omega [-]": tuned_characterization.getAcentricFactor(),
}

tuning_comparison = pd.DataFrame(
    {
        "Property": list(base_properties),
        "Base": list(base_properties.values()),
        "Tuned": list(tuned_properties.values()),
    }
)
tuning_comparison["Change [%]"] = (
    100.0
    * (
        tuning_comparison["Tuned"]
        - tuning_comparison["Base"]
    )
    / tuning_comparison["Base"]
)
display(tuning_comparison.round(4))
# Out:
#     Property      Base      Tuned  Change [%]
# 0     Tc [K]  996.1220  1045.9281         5.0
# 1   Pc [bar]   16.2635    15.4503        -5.0
# 2  Omega [-]    2.5000     2.5500         2.0

# %% [markdown]
# ## 7. CPA comparison
#
# The original notebook introduced a CPA example. It is retained as a model-form comparison, not as
# a claim that association physics alone predicts asphaltene precipitation. The same Pedersen
# pseudo-component and composition are used in SRK and `SystemSrkCPAstatoil`.
#
# CPA augments the cubic residual Helmholtz energy:
#
# $$
# A^{\mathrm{res}} =
# A^{\mathrm{cubic}}
# +
# A^{\mathrm{assoc}}
# $$
#
# For this hydrocarbon-only synthetic fluid, the comparison mainly demonstrates API portability.
# Water, glycol, or other associating compounds are where the association term is normally most
# important.

# %%
cpa_fluid, cpa_characterization, cpa_asphaltene_name = (
    build_pedersen_oil(
        pressure_bar=150.0,
        system_class=SystemSrkCPAstatoil,
    )
)

print(
    "CPA system created with component:",
    cpa_asphaltene_name,
)
print(
    "Total components:",
    cpa_fluid.getPhase(0).getNumberOfComponents(),
)
# Out:
# CPA system created with component: Asphaltene_PC
# Total components: 6

# %%
comparison_pressures_bar = [
    200.0,
    175.0,
    150.0,
    125.0,
    100.0,
]
model_rows = []

for model_name, system_class in [
    ("SRK", SystemSrkEos),
    ("SRK-CPA-Statoil", SystemSrkCPAstatoil),
]:
    for pressure_bar in comparison_pressures_bar:
        case = cold_pressure_case(
            pressure_bar,
            system_class=system_class,
        )
        case["Model"] = model_name
        model_rows.append(case)

model_comparison = pd.DataFrame(model_rows)
display(
    model_comparison[
        [
            "Model",
            "Pressure [bar]",
            "Number of phases [-]",
            "Asphaltene-rich beta [-]",
            "Gas beta [-]",
        ]
    ].round(6)
)

figure, axes = plt.subplots(1, 2, figsize=(12.0, 4.6))
for model_name, group in model_comparison.groupby("Model"):
    axes[0].plot(
        group["Pressure [bar]"],
        group["Number of phases [-]"],
        marker="o",
        label=model_name,
    )
    axes[1].plot(
        group["Pressure [bar]"],
        group["Asphaltene-rich beta [-]"],
        marker="s",
        label=model_name,
    )

axes[0].set_title("Original CPA example: refreshed phase count")
axes[0].set_ylabel("Number of phases [-]")
axes[1].set_title("Original CPA example: heavy-phase fraction")
axes[1].set_ylabel("Asphaltene-rich phase fraction, β [-]")
for axis in axes:
    axis.set_xlabel("Pressure [bar]")
    axis.invert_xaxis()
    axis.grid(True, alpha=0.3)
    axis.legend(title="Equation of state")
figure.tight_layout()
plt.show()
# Out:
#              Model  Pressure [bar]  ...  Asphaltene-rich beta [-]  Gas beta [-]
# 0              SRK           200.0  ...                  0.000000      0.000000
# 1              SRK           175.0  ...                  0.000000      0.000000
# 2              SRK           150.0  ...                  0.112894      0.000000
# 3              SRK           125.0  ...                  0.000000      0.021843
# 4              SRK           100.0  ...                  0.000000      0.050309
# 5  SRK-CPA-Statoil           200.0  ...                  0.121501      0.000000
# 6  SRK-CPA-Statoil           175.0  ...                  0.121099      0.000000
# 7  SRK-CPA-Statoil           150.0  ...                  0.120685      0.000000
# 8  SRK-CPA-Statoil           125.0  ...                  0.120260      0.000000
# 9  SRK-CPA-Statoil           100.0  ...                  0.119822      0.000000
#
# [10 rows x 5 columns]

# %% [markdown]
# SRK and CPA both complete the selected cold cases, but their heavy-phase fractions differ. This is
# model-form sensitivity, not evidence that one model is more accurate; laboratory data and the
# presence of genuinely associating components must guide the choice.

# %% [markdown]
# ## 8. Complete oil characterization with TBP fractions
#
# The original complete-oil example is retained. Defined components describe the light ends, while
# true-boiling-point (TBP) pseudo-components describe the heavy tail. The asphaltene
# pseudo-component is added last so the same Pedersen properties and phase-marking workflow can be
# used.

# %%
complete_oil = SystemSrkEos(373.15, 200.0)
complete_oil.getCharacterization().setTBPModel("PedersenSRK")

for component_name, moles in [
    ("nitrogen", 0.005),
    ("CO2", 0.020),
    ("methane", 0.350),
    ("ethane", 0.080),
    ("propane", 0.050),
    ("n-butane", 0.030),
    ("n-pentane", 0.020),
]:
    complete_oil.addComponent(component_name, moles)

for name, moles, molar_mass_kg_mol, density_g_cm3 in [
    ("C7", 0.100, 0.096, 0.738),
    ("C10", 0.080, 0.134, 0.792),
    ("C15", 0.050, 0.206, 0.836),
    ("C20+", 0.030, 0.350, 0.890),
]:
    complete_oil.addTBPfraction(
        name,
        moles,
        molar_mass_kg_mol,
        density_g_cm3,
    )

complete_oil_characterization = (
    PedersenAsphalteneCharacterization()
)
complete_oil_characterization.setAsphalteneMW(850.0)
complete_oil_characterization.setAsphalteneDensity(1.12)
complete_oil_asphaltene_name = (
    complete_oil_characterization.addAsphalteneToSystem(
        complete_oil,
        0.020,
    )
)

complete_oil.setMixingRule("classic")
complete_oil.setMultiPhaseCheck(True)
complete_oil.init(0)
complete_oil_characterization.applyAsphalteneKij(
    complete_oil,
    0.0,
)

print(
    "Total components:",
    complete_oil.getPhase(0).getNumberOfComponents(),
)
print("Asphaltene component:", complete_oil_asphaltene_name)
# Out:
# Total components: 12
# Asphaltene component: Asphaltene_PC

# %%
complete_oil_detected = (
    PedersenAsphalteneCharacterization.TPflash(complete_oil)
)
complete_oil_phase_table = extract_phase_table(complete_oil)

physical_phases = complete_oil_phase_table[
    complete_oil_phase_table["Beta [-]"] > 1.0e-8
].copy()
assert not physical_phases.empty
assert np.all(physical_phases["Density [kg/m³]"] > 0.0)

print(
    f"T = {complete_oil.getTemperature() - 273.15:.1f} °C, "
    f"P = {complete_oil.getPressure():.1f} bar"
)
print(
    "Asphaltene-rich liquid detected:",
    complete_oil_detected,
)
display(physical_phases.round(6))
# Out:
# T = 100.0 °C, P = 200.0 bar
# Asphaltene-rich liquid detected: True
#    Phase Type before marking  ...  Asphaltene rich  Type after marking
# 0      0                 gas  ...            False                 gas
# 1      1                 oil  ...            False                 oil
# 2      2                 oil  ...             True   asphaltene liquid
#
# [3 rows x 7 columns]

# %% [markdown]
# ## 9. Summary and best practices
#
# The six original examples are preserved and integrated:
#
# 1. SARA/CII screening now validates fraction closure and avoids universal threshold claims.
# 2. Pressure-density screening is explicitly a qualitative teaching map.
# 3. Pedersen characterization uses the current released NeqSim API.
# 4. The original pressure-depletion and molecular-weight figures are numerically refreshed.
# 5. The CPA example is a controlled model-form comparison.
# 6. The full TBP-oil example retrieves the physical liquid phase by properties rather than index.
#
# For engineering work, obtain SARA method details, live-oil composition, constant-composition
# expansion data, asphaltene-onset pressure, precipitated mass, and redissolution observations.
# Regress the fewest defensible parameters, validate against withheld measurements, and couple the
# equilibrium result to transport and deposition models only when the application requires it.

# %% [markdown]
# ### 10.1 Flash validity and material closure
#
# For overall mole fraction $z_i$, phase fraction $\beta_p$, and phase composition $x_{i,p}$,
# component closure requires
#
# $$
# z_i =
# \sum_p \beta_p x_{i,p}
# $$
#
# The check below uses every component and every calculated phase. A small residual proves internal
# flash closure; it does not prove that the selected pseudo-component or $k_{ij}$ is calibrated.

# %%
validation_fluid, validation_characterization, _ = (
    build_pedersen_oil(
        pressure_bar=150.0,
        temperature_k=323.15,
    )
)
validation_detected = (
    PedersenAsphalteneCharacterization.TPflash(
        validation_fluid
    )
)
validation_phase_table = extract_phase_table(validation_fluid)

component_residuals = []
phase_fraction_sum = 0.0
for phase_index in range(validation_fluid.getNumberOfPhases()):
    phase_fraction_sum += float(
        validation_fluid.getPhase(phase_index).getBeta()
    )

for component_index in range(
    validation_fluid.getPhase(0).getNumberOfComponents()
):
    reference_component = (
        validation_fluid.getPhase(0).getComponent(component_index)
    )
    overall_fraction = float(reference_component.getz())
    reconstructed_fraction = 0.0
    for phase_index in range(
        validation_fluid.getNumberOfPhases()
    ):
        phase = validation_fluid.getPhase(phase_index)
        reconstructed_fraction += (
            float(phase.getBeta())
            * float(phase.getComponent(component_index).getx())
        )
    component_residuals.append(
        {
            "Component": str(
                reference_component.getComponentName()
            ),
            "Overall z [-]": overall_fraction,
            "Reconstructed z [-]": reconstructed_fraction,
            "Residual [-]": (
                reconstructed_fraction - overall_fraction
            ),
        }
    )

closure_results = pd.DataFrame(component_residuals)
maximum_component_residual = float(
    closure_results["Residual [-]"].abs().max()
)

assert validation_detected
assert abs(phase_fraction_sum - 1.0) < 1.0e-10
assert maximum_component_residual < 1.0e-10
assert np.isfinite(
    validation_phase_table[
        [
            "Beta [-]",
            "Density [kg/m³]",
            "Asphaltene mole fraction [-]",
        ]
    ].to_numpy()
).all()

print(f"Phase-fraction sum: {phase_fraction_sum:.12f}")
print(
    "Maximum component residual: "
    f"{maximum_component_residual:.3e}"
)
display(closure_results)
# Out:
# Phase-fraction sum: 1.000000000000
# Maximum component residual: 2.531e-14
#        Component  Overall z [-]  Reconstructed z [-]  Residual [-]
# 0        methane           0.30                 0.30  7.716050e-15
# 1      n-pentane           0.25                 0.25  6.883383e-15
# 2      n-heptane           0.20                 0.20  6.050715e-15
# 3           nC10           0.10                 0.10  3.191891e-15
# 4           nC20           0.05                 0.05  1.616762e-15
# 5  Asphaltene_PC           0.10                 0.10 -2.531308e-14

# %% [markdown]
# ### 10.2 Native solubility-parameter screening
#
# NeqSim provides an asphaltene solubility-parameter estimate and a qualitative comparison with an
# oil-phase value. The Hildebrand parameter is
#
# $$
# \delta =
# \sqrt{\frac{E_{\mathrm{coh}}}{V_m}}
# $$
#
# and is reported in $\mathrm{MPa}^{1/2}$. Similar values imply stronger solvency. This screen is
# scenario ranking, but an oil solubility parameter should be measured or calculated with a
# documented method.

# %%
temperatures_c = np.arange(25.0, 101.0, 15.0)
asphaltene_delta = [
    float(
        asphaltene_characterization.calculateSolubilityParameter(
            temperature_c + 273.15
        )
    )
    for temperature_c in temperatures_c
]
oil_delta_values = np.array([16.0, 18.0, 20.0, 22.0])

stability_rows = []
for oil_delta in oil_delta_values:
    difference = abs(asphaltene_delta[0] - oil_delta)
    stability_rows.append(
        {
            "Oil δ [MPa^0.5]": oil_delta,
            "|Δδ| at 25 °C [MPa^0.5]": difference,
            "Native assessment": str(
                asphaltene_characterization.assessStability(
                    float(oil_delta)
                )
            )
            .split("Status:")[-1]
            .strip(),
        }
    )

solvency_results = pd.DataFrame(stability_rows)
display(solvency_results)

figure, axis = plt.subplots(figsize=(8.5, 5.0))
axis.plot(
    temperatures_c,
    asphaltene_delta,
    marker="o",
    color=COLORS["purple"],
    label="NeqSim asphaltene estimate",
)
for oil_delta in oil_delta_values:
    axis.axhline(
        oil_delta,
        linestyle="--",
        alpha=0.65,
        label=f"Oil scenario: {oil_delta:.0f} MPa$^{{1/2}}$",
    )
axis.set_title("Temperature and oil-solvency screening")
axis.set_xlabel("Temperature [°C]")
axis.set_ylabel("Solubility parameter, δ [MPa$^{1/2}$]")
axis.grid(True, alpha=0.3)
axis.legend(ncol=2)
figure.tight_layout()
plt.show()
# Out:
#    Oil δ [MPa^0.5]  ...                     Native assessment
# 0             16.0  ...    UNSTABLE - High precipitation risk
# 1             18.0  ...  MARGINAL - Monitor during operations
# 2             20.0  ...     STABLE - Good asphaltene solvency
# 3             22.0  ...  MARGINAL - Monitor during operations
#
# [4 rows x 3 columns]

# %% [markdown]
# The native asphaltene estimate decreases with temperature. Oil scenarios closest to that curve
# have the smallest solubility-parameter difference and therefore the stronger qualitative solvency
# screen. A measured or independently calculated oil value is still required.

# %% [markdown]
# ### 10.3 Interaction-parameter and temperature sensitivity
#
# The binary interaction parameter changes unlike-component attraction. It is not a generic
# "instability knob": the response must be fitted to laboratory data and checked for phase
# continuity. The sensitivity uses independently rebuilt cases and reports the equilibrium
# asphaltene-rich molar phase fraction.

# %%
kij_values = np.array(
    [0.00, 0.01, 0.02, 0.04, 0.05, 0.06, 0.08]
)
temperature_values_c = np.array(
    [40.0, 50.0, 70.0, 80.0]
)

kij_heavy_beta = []
for kij_value in kij_values:
    case_fluid, _, _ = build_pedersen_oil(
        pressure_bar=150.0,
        temperature_k=323.15,
        base_kij=float(kij_value),
    )
    PedersenAsphalteneCharacterization.TPflash(case_fluid)
    case_table = extract_phase_table(case_fluid)
    kij_heavy_beta.append(
        float(
            case_table.loc[
                case_table["Asphaltene rich"],
                "Beta [-]",
            ].sum()
        )
    )

temperature_heavy_beta = []
for temperature_c in temperature_values_c:
    case_fluid, _, _ = build_pedersen_oil(
        pressure_bar=150.0,
        temperature_k=float(temperature_c + 273.15),
    )
    PedersenAsphalteneCharacterization.TPflash(case_fluid)
    case_table = extract_phase_table(case_fluid)
    temperature_heavy_beta.append(
        float(
            case_table.loc[
                case_table["Asphaltene rich"],
                "Beta [-]",
            ].sum()
        )
    )

assert np.all(np.isfinite(kij_heavy_beta))
assert np.all(np.isfinite(temperature_heavy_beta))
assert np.all(np.asarray(kij_heavy_beta) > 0.0)
assert np.all(np.asarray(temperature_heavy_beta) > 0.0)

figure, axes = plt.subplots(1, 2, figsize=(12.0, 4.6))
axes[0].plot(
    kij_values,
    kij_heavy_beta,
    marker="o",
    color=COLORS["orange"],
    label="150 bar and 50 °C",
)
axes[0].set_title("Binary-interaction sensitivity")
axes[0].set_xlabel("Base asphaltene-light $k_{ij}$ [-]")
axes[0].set_ylabel("Asphaltene-rich phase fraction, β [-]")
axes[0].grid(True, alpha=0.3)
axes[0].legend()

axes[1].plot(
    temperature_values_c,
    temperature_heavy_beta,
    marker="s",
    color=COLORS["red"],
    label="150 bar and base $k_{ij}=0$",
)
axes[1].set_title("Temperature sensitivity")
axes[1].set_xlabel("Temperature [°C]")
axes[1].set_ylabel("Asphaltene-rich phase fraction, β [-]")
axes[1].grid(True, alpha=0.3)
axes[1].legend()

figure.tight_layout()
plt.show()

# %% [markdown]
# Within the validated points, the predicted heavy-phase fraction decreases as the selected base
# $k_{ij}$ increases and rises modestly with temperature. These are local responses for one
# synthetic composition; they must not be extrapolated beyond the calibrated range.

# %% [markdown]
# ## 11. Interpretation, limitations, and next steps
#
# The phase split is an equilibrium prediction. Deposition additionally requires aggregation,
# particle transport, surface attachment, and residence time. The synthetic pressure scan contains
# isolated phase-topology changes; that is a warning to calibrate against data and verify nearby
# cold-start and warm-start calculations before accepting an onset.
#
# Practical next steps:
#
# 1. replace the synthetic composition and SARA fractions with documented laboratory data;
# 2. regress molecular weight, density, and selected $k_{ij}$ values against onset and precipitated
#    mass while limiting parameter count;
# 3. validate against withheld depletion, gas-injection, and temperature measurements;
# 4. repeat the calculation with PR and justified mixing rules;
# 5. couple validated equilibrium results to a deposition or transport model only if needed.
#
# ### References
#
# - K. S. Pedersen, “The Mechanisms Behind Asphaltene Precipitation – Successfully Handled by a
#   Classical Cubic Equation of State,” SPE-224534-MS, 2025.
# - K. S. Pedersen and P. L. Christensen, *Phase Behavior of Petroleum Reservoir Fluids*, 2007.
# - R. B. de Boer et al., “Screening of Crude Oils for Asphalt Precipitation: Theory, Practice, and
#   the Selection of Inhibitors,” SPE Production & Facilities, 1995.
# - [Current NeqSim Pedersen asphaltene implementation](https://github.com/equinor/neqsim/blob/master/src/main/java/neqsim/thermo/characterization/PedersenAsphalteneCharacterization.java)
# - [NeqSim documentation](https://equinor.github.io/neqsimhome/)

# %%
engineering_checks = {
    "NeqSim package version recorded": NEQSIM_VERSION == "3.16.0",
    "SARA scenarios finite": np.isfinite(
        sara_results[["CII [-]", "R/A [-]"]].to_numpy()
    ).all(),
    "Screening scores bounded": pressure_density_results[
        "Illustrative score [-]"
    ].between(0.0, 1.0).all(),
    "Pedersen properties finite": np.isfinite(
        [
            asphaltene_characterization.getCriticalTemperature(),
            asphaltene_characterization.getCriticalPressure(),
            asphaltene_characterization.getAcentricFactor(),
            asphaltene_characterization.getBoilingPoint(),
        ]
    ).all(),
    "Critical temperature exceeds boiling point": (
        asphaltene_characterization.getCriticalTemperature()
        > asphaltene_characterization.getBoilingPoint()
    ),
    "Base flash has significant heavy phase": (
        validation_phase_table.loc[
            validation_phase_table["Asphaltene rich"],
            "Beta [-]",
        ].sum()
        > 0.05
    ),
    "Phase fractions close": abs(phase_fraction_sum - 1.0) < 1.0e-10,
    "Components close": maximum_component_residual < 1.0e-10,
    "Positive physical complete-oil densities": np.all(
        physical_phases["Density [kg/m³]"] > 0.0
    ),
    "Pressure cases finite": np.isfinite(
        depletion_results[
            [
                "Number of phases [-]",
                "Asphaltene-rich beta [-]",
                "Gas beta [-]",
            ]
        ].to_numpy()
    ).all(),
    "SRK and CPA cases completed": (
        model_comparison.groupby("Model").size().to_dict()
        == {"SRK": 5, "SRK-CPA-Statoil": 5}
    ),
    "Interaction sensitivity finite": np.isfinite(
        kij_heavy_beta
    ).all(),
    "Temperature sensitivity finite": np.isfinite(
        temperature_heavy_beta
    ).all(),
}

failed_checks = [
    name
    for name, passed in engineering_checks.items()
    if not bool(passed)
]
assert not failed_checks, failed_checks

print(
    f"Engineering checks passed: "
    f"{len(engineering_checks)}/{len(engineering_checks)}"
)
for check_name in engineering_checks:
    print(f"PASS - {check_name}")
# Out:
# Engineering checks passed: 13/13
# PASS - NeqSim package version recorded
# PASS - SARA scenarios finite
# PASS - Screening scores bounded
# PASS - Pedersen properties finite
# PASS - Critical temperature exceeds boiling point
# PASS - Base flash has significant heavy phase
# PASS - Phase fractions close
# PASS - Components close
# PASS - Positive physical complete-oil densities
# PASS - Pressure cases finite
# PASS - SRK and CPA cases completed
# PASS - Interaction sensitivity finite
# PASS - Temperature sensitivity finite
