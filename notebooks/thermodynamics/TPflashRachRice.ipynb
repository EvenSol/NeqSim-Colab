# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/TPflashRachRice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TP flash

# %%
#@title TP flash and Rachford Rice
#@markdown This video gives an intriduction to TP flash and Rachford Rice
from IPython.display import YouTubeVideo
YouTubeVideo('ACxOiXWq1SQ', width=600, height=400)
