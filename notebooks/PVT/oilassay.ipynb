# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/PVT/oilassay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Oil-assay cuts, pseudo-components, and fluid characterization
#
# This tutorial converts a compact synthetic oil assay into a compositional NeqSim fluid. It is
# intended for PVT, reservoir, production, and process engineers who need to understand how
# distillation cuts become equation-of-state pseudo-components.
#
# ## Prerequisites
#
# You should know mass fractions, density, boiling range, API gravity, and the purpose of a cubic
# equation of state. No local files or proprietary data are needed.
#
# ## Learning objectives
#
# You will learn to:
#
# - quality-check a mass-based boiling-point assay;
# - convert API gravity to density and independently verify the conversion;
# - create `AssayCut` records and apply `OilAssayCharacterisation`;
# - audit pseudo-component moles, molar masses, and total-mass closure;
# - compare volume-additive density with SRK and Peng--Robinson predictions;
# - study pressure, cut-resolution, and density-assumption sensitivities; and
# - identify limitations that require laboratory data or EOS calibration.

# %%
import importlib.util
import subprocess
import sys


if importlib.util.find_spec("neqsim") is None:
    subprocess.run(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--no-cache-dir",
            "neqsim",
        ],
        check=True,
    )

# %% [markdown]
# ## Engineering context and model boundary
#
# An oil assay reports broad fractions rather than every molecule. NeqSim represents each cut as a
# pseudo-component with resolved density, normal boiling point, and estimated molar mass. Those
# pseudo-components can be placed in the same `SystemInterface` as identified light components.
# This notebook isolates the assay portion so its bookkeeping remains transparent.
#
# We use cubic equations of state only for screening dense-liquid states at 50 degrees Celsius and
# 10--300 bara absolute. The assay is synthetic and has eight cuts from light naphtha to residue.
# It is not a crude-oil certificate, and the calculations do not predict viscosity, wax,
# asphaltenes, sulfur, metals, or product yields.

# %%
import platform
from importlib.metadata import version

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import jpype
from IPython.display import display
from neqsim import jneqsim


neqsim_version = version("neqsim")
python_version = platform.python_version()
java_version = str(jpype.java.lang.System.getProperty("java.version"))

print(f"NeqSim: {neqsim_version}")
print(f"Python: {python_version}")
print(f"Java: {java_version}")
# Out:
# NeqSim: 3.16.0
# Python: 3.12.13
# Java: 17.0.19

# %% [markdown]
# ## Synthetic assay and assumptions
#
# Each row gives a cut name, mass fraction $w_j$, API gravity, and average normal boiling point
# $T_{b,j}$ in degrees Celsius. Fractions are on a 1.000 kg assay basis. API gravity is a
# conventional dimensionless index, while NeqSim stores density in $\mathrm{g/cm^3}$ and boiling
# temperature in kelvin.
#
# The values are smooth, plausible training inputs rather than measurements from a named field.
# They are intentionally explicit so every transformation can be reproduced.

# %%
assay_data = pd.DataFrame(
    [
        ("Light naphtha", 0.06, 75.0, 80.0),
        ("Heavy naphtha", 0.10, 60.0, 140.0),
        ("Kerosene", 0.13, 47.0, 210.0),
        ("Light gas oil", 0.17, 36.0, 300.0),
        ("Heavy gas oil", 0.18, 27.0, 390.0),
        ("Vacuum gas oil", 0.16, 20.0, 480.0),
        ("Vacuum residue", 0.14, 12.0, 600.0),
        ("Heavy residue", 0.06, 7.0, 720.0),
    ],
    columns=[
        "cut",
        "mass fraction [-]",
        "API gravity [-]",
        "average boiling point [°C]",
    ],
)

mass_fraction_sum = float(assay_data["mass fraction [-]"].sum())
boiling_points_c = assay_data["average boiling point [°C]"].to_numpy()

display(assay_data)
print(f"Mass-fraction sum: {mass_fraction_sum:.12f}")
# Out:
#               cut  ...  average boiling point [°C]
# 0   Light naphtha  ...                        80.0
# 1   Heavy naphtha  ...                       140.0
# 2        Kerosene  ...                       210.0
# 3   Light gas oil  ...                       300.0
# 4   Heavy gas oil  ...                       390.0
# 5  Vacuum gas oil  ...                       480.0
# 6  Vacuum residue  ...                       600.0
# 7   Heavy residue  ...                       720.0
#
# [8 rows x 4 columns]
# Mass-fraction sum: 1.000000000000

# %% [markdown]
# ## API gravity and density
#
# At the 60 degrees Fahrenheit reference condition, API gravity and specific gravity are related by
#
# $$
# \mathrm{API} = \frac{141.5}{SG} - 131.5
# $$
#
# and the rearranged relation is
#
# $$
# SG = \frac{141.5}{\mathrm{API} + 131.5}
# $$
#
# Here $SG$ is specific gravity relative to water and API is the API-gravity index. We use
# $\rho_{w}=999.016\ \mathrm{kg/m^3}$ for water at 60 degrees Fahrenheit, giving cut density
# $\rho_j=SG_j\rho_w$. The chosen water density is an explicit conversion convention, not a fitted
# parameter.

# %%
WATER_DENSITY_60F_KG_M3 = 999.016


def api_to_density_kg_m3(api_gravity):
    specific_gravity = 141.5 / (api_gravity + 131.5)
    return specific_gravity * WATER_DENSITY_60F_KG_M3


def density_to_api(density_kg_m3):
    specific_gravity = density_kg_m3 / WATER_DENSITY_60F_KG_M3
    return 141.5 / specific_gravity - 131.5


assay_data["density from API [kg/m³]"] = api_to_density_kg_m3(
    assay_data["API gravity [-]"],
)
assay_data["API round trip [-]"] = density_to_api(
    assay_data["density from API [kg/m³]"],
)
maximum_api_round_trip_error = float(
    np.max(
        np.abs(
            assay_data["API round trip [-]"]
            - assay_data["API gravity [-]"]
        )
    )
)

display(assay_data)
print(f"Maximum API round-trip error: {maximum_api_round_trip_error:.3e}")
# Out:
#               cut  ...  API round trip [-]
# 0   Light naphtha  ...                75.0
# 1   Heavy naphtha  ...                60.0
# 2        Kerosene  ...                47.0
# 3   Light gas oil  ...                36.0
# 4   Heavy gas oil  ...                27.0
# 5  Vacuum gas oil  ...                20.0
# 6  Vacuum residue  ...                12.0
# 7   Heavy residue  ...                 7.0
#
# [8 rows x 6 columns]
# Maximum API round-trip error: 0.000e+00

# %% [markdown]
# ## NeqSim characterization workflow
#
# `AssayCut` stores the observed cut descriptors. `OilAssayCharacterisation` resolves missing
# molar mass, adds one pseudo-component per cut, and applies the selected assay mass to the fluid.
# The component list is finalized before the mixing rule is selected; this ordering lets NeqSim
# allocate interaction-parameter arrays for the complete system.
#
# The helper returns both the thermodynamic system and the resolved cut objects. It supports SRK
# and Peng--Robinson (PR) so model sensitivity can be shown without hidden mutation.

# %%
AssayCut = jneqsim.thermo.characterization.OilAssayCharacterisation.AssayCut
OilAssay = jneqsim.thermo.characterization.OilAssayCharacterisation
ThermodynamicOperations = jneqsim.thermodynamicoperations.ThermodynamicOperations


def build_assay_fluid(cut_frame, model="PR", total_assay_mass_kg=1.0):
    system_class = jneqsim.thermo.system.SystemPrEos
    if model == "SRK":
        system_class = jneqsim.thermo.system.SystemSrkEos

    fluid = system_class(323.15, 10.0)
    characterization = OilAssay(fluid)
    characterization.setTotalAssayMass(total_assay_mass_kg)
    cut_objects = []

    for row in cut_frame.itertuples(index=False):
        assay_cut = (
            AssayCut(row.cut)
            .withMassFraction(row[1])
            .withApiGravity(row[2])
            .withAverageBoilingPointCelsius(row[3])
        )
        characterization.addCut(assay_cut)
        cut_objects.append(assay_cut)

    characterization.apply()
    fluid.setMixingRule("classic")
    fluid.setMultiPhaseCheck(False)
    fluid.init(0)
    return fluid, characterization, cut_objects


def flash_dense_liquid(fluid, temperature_c, pressure_bara):
    state = fluid.clone()
    state.setTemperature(temperature_c, "C")
    state.setPressure(pressure_bara, "bara")
    ThermodynamicOperations(state).TPflash()
    state.initProperties()
    return state

# %% [markdown]
# ## Resolved cut properties
#
# The characterization correlation resolves density $\rho_j$, boiling temperature $T_{b,j}$,
# and molar mass $MW_j$. A resolved molar mass is a model estimate for a broad fraction, not a
# measured molecular identity. Monotonic increases across the assay are useful input-quality
# checks because heavier, higher-boiling cuts should generally have larger density and molar mass.

# %%
pr_fluid, pr_characterization, resolved_cuts = build_assay_fluid(assay_data)

resolved_rows = []
for cut_object in resolved_cuts:
    density_g_cm3 = float(cut_object.resolveDensity())
    boiling_point_k = float(cut_object.resolveAverageBoilingPoint())
    molar_mass_kg_kmol = float(
        cut_object.resolveMolarMass(density_g_cm3, boiling_point_k)
    )
    resolved_rows.append(
        {
            "cut": str(cut_object.getName()),
            "density [kg/m³]": 1000.0 * density_g_cm3,
            "boiling point [K]": boiling_point_k,
            "molar mass [kg/kmol]": molar_mass_kg_kmol,
        }
    )

resolved_properties = pd.DataFrame(resolved_rows)
display(resolved_properties)
# Out:
#               cut  density [kg/m³]  boiling point [K]  molar mass [kg/kmol]
# 0   Light naphtha       684.555758             353.15             94.638627
# 1   Heavy naphtha       738.176313             413.15            128.058141
# 2        Kerosene       791.937053             483.15            173.945232
# 3   Light gas oil       843.944860             573.15            245.986917
# 4   Heavy gas oil       891.866019             663.15            330.400432
# 5  Vacuum gas oil       933.074350             753.15            428.614751
# 6  Vacuum residue       985.092432             873.15            578.959005
# 7   Heavy residue      1020.655336             993.15            760.648669

# %% [markdown]
# ## Pseudo-component inventory and mass closure
#
# For a total assay mass $m_a$, cut $j$ receives mass $m_j=w_jm_a$. Its amount is
#
# $$
# n_j = \frac{m_j}{MW_j}
# $$
#
# where $n_j$ is in kmol when $m_j$ is in kg and $MW_j$ is in $\mathrm{kg/kmol}$. Reconstructing
# $n_jMW_j$ from the NeqSim system tests that the mass-basis assay was transferred correctly.

# %%
inventory_rows = []
for component_index in range(pr_fluid.getNumberOfComponents()):
    component = pr_fluid.getComponent(component_index)
    component_moles_kmol = float(component.getNumberOfmoles())
    component_molar_mass_kg_kmol = float(component.getMolarMass())
    reconstructed_mass_kg = (
        component_moles_kmol * component_molar_mass_kg_kmol
    )
    inventory_rows.append(
        {
            "component": str(component.getComponentName()),
            "amount [kmol]": component_moles_kmol,
            "molar mass [kg/kmol]": component_molar_mass_kg_kmol,
            "reconstructed mass [kg]": reconstructed_mass_kg,
        }
    )

component_inventory = pd.DataFrame(inventory_rows)
reconstructed_assay_mass_kg = float(
    component_inventory["reconstructed mass [kg]"].sum()
)
system_assay_mass_kg = float(pr_fluid.getMass("kg"))
mass_residual_kg = reconstructed_assay_mass_kg - system_assay_mass_kg

display(component_inventory)
print(f"System assay mass: {system_assay_mass_kg:.12f} kg")
print(f"Mass reconstruction residual: {mass_residual_kg:.3e} kg")
# Out:
#            component  ...  reconstructed mass [kg]
# 0   Light naphtha_PC  ...                     0.06
# 1   Heavy naphtha_PC  ...                     0.10
# 2        Kerosene_PC  ...                     0.13
# 3   Light gas oil_PC  ...                     0.17
# 4   Heavy gas oil_PC  ...                     0.18
# 5  Vacuum gas oil_PC  ...                     0.16
# 6  Vacuum residue_PC  ...                     0.14
# 7   Heavy residue_PC  ...                     0.06
#
# [8 rows x 4 columns]
# System assay mass: 1.000000000000 kg
# Mass reconstruction residual: 2.220e-16 kg

# %% [markdown]
# ## Volume-additive bulk density
#
# An independent first estimate assumes ideal volume additivity. The total volume is the sum of
# cut volumes $m_j/\rho_j$, so the bulk density is
#
# $$
# \rho_{\mathrm{bulk}} = \left(\sum_j \frac{w_j}{\rho_j}\right)^{-1}
# $$
#
# This estimate ignores excess volume, thermal expansion, and pressure effects. It is nevertheless
# a strong bookkeeping benchmark because it follows directly from the reported mass fractions and
# cut densities.

# %%
cut_densities_kg_m3 = resolved_properties["density [kg/m³]"].to_numpy()
cut_mass_fractions = assay_data["mass fraction [-]"].to_numpy()

volume_additive_density_kg_m3 = 1.0 / np.sum(
    cut_mass_fractions / cut_densities_kg_m3
)
arithmetic_density_kg_m3 = float(
    np.sum(cut_mass_fractions * cut_densities_kg_m3)
)
assay_volume_m3 = 1.0 / volume_additive_density_kg_m3

density_benchmarks = pd.DataFrame(
    [
        {
            "estimate": "volume-additive (harmonic)",
            "density [kg/m³]": volume_additive_density_kg_m3,
        },
        {
            "estimate": "mass-weighted arithmetic (not volume closure)",
            "density [kg/m³]": arithmetic_density_kg_m3,
        },
    ]
)

display(density_benchmarks)
print(f"Volume of 1.000 kg assay: {assay_volume_m3:.9f} m³")
# Out:
#                                         estimate  density [kg/m³]
# 0                     volume-additive (harmonic)       859.910968
# 1  mass-weighted arithmetic (not volume closure)       870.293460
# Volume of 1.000 kg assay: 0.001162911 m³

# %% [markdown]
# ## Assay distribution plot
#
# The cumulative mass curve answers how much of the assay lies below each average boiling point.
# The density overlay helps detect nonmonotonic inputs before characterization. Average boiling
# points are representative cut locations, so this is not a simulated ASTM D86 or true-boiling-
# point distillation curve.

# %%
cumulative_mass_percent = 100.0 * np.cumsum(cut_mass_fractions)

figure, left_axis = plt.subplots(figsize=(9, 5))
left_axis.step(
    boiling_points_c,
    cumulative_mass_percent,
    where="mid",
    linewidth=2.5,
    label="cumulative assay mass",
)
left_axis.set_xlabel("Average cut boiling point [°C]")
left_axis.set_ylabel("Cumulative mass [%]")
left_axis.set_ylim(0.0, 105.0)
left_axis.grid(alpha=0.25)

right_axis = left_axis.twinx()
right_axis.plot(
    boiling_points_c,
    cut_densities_kg_m3,
    marker="o",
    color="tab:red",
    label="resolved cut density",
)
right_axis.set_ylabel("Cut density [kg/m³]")

lines = left_axis.get_lines() + right_axis.get_lines()
left_axis.legend(lines, [line.get_label() for line in lines], loc="lower right")
figure.suptitle("Synthetic oil-assay distribution and density")
figure.tight_layout()
plt.show()

# %% [markdown]
# ## EOS density benchmark at one dense-liquid state
#
# We now flash the characterized assay at 50 degrees Celsius and 10 bara absolute. The state is a
# single dense oil for both models. PR and SRK share the same cut inputs but use different cubic-EOS
# volume translations and attractive terms, so their density difference is model-form evidence.
#
# The relative deviation from the volume-additive estimate is
#
# $$
# \delta_\rho = \frac{\rho_{\mathrm{EOS}}-\rho_{\mathrm{bulk}}}
# {\rho_{\mathrm{bulk}}}
# $$
#
# It should not be interpreted as error against laboratory data.

# %%
eos_rows = []
for eos_name in ["PR", "SRK"]:
    eos_fluid, _, _ = build_assay_fluid(assay_data, model=eos_name)
    eos_state = flash_dense_liquid(eos_fluid, 50.0, 10.0)
    eos_density_kg_m3 = float(eos_state.getPhase(0).getDensity("kg/m3"))
    relative_deviation_percent = 100.0 * (
        eos_density_kg_m3 - volume_additive_density_kg_m3
    ) / volume_additive_density_kg_m3
    eos_rows.append(
        {
            "EOS": eos_name,
            "temperature [°C]": 50.0,
            "pressure [bara]": 10.0,
            "density [kg/m³]": eos_density_kg_m3,
            "deviation from volume-additive [%]": relative_deviation_percent,
            "system mass [kg]": float(eos_state.getMass("kg")),
        }
    )

eos_comparison = pd.DataFrame(eos_rows)
pr_reference_density_kg_m3 = float(
    eos_comparison.loc[eos_comparison["EOS"] == "PR", "density [kg/m³]"].iloc[0]
)

display(eos_comparison)
# Out:
#    EOS  temperature [°C]  ...  deviation from volume-additive [%]  system mass [kg]
# 0   PR              50.0  ...                           -2.910080               1.0
# 1  SRK              50.0  ...                            6.318346               1.0
#
# [2 rows x 6 columns]

# %% [markdown]
# ## Pressure sensitivity and apparent compressibility
#
# At fixed temperature, a stable liquid should become denser as absolute pressure rises. The
# finite-difference apparent compressibility is estimated from the density change as
#
# $$
# c_\rho = \frac{1}{\rho}\frac{\Delta\rho}{\Delta P}
# $$
#
# where $c_\rho$ is in $\mathrm{Pa^{-1}}$, density is in $\mathrm{kg/m^3}$, and pressure is in
# pascal. This is a screening slope over a wide pressure interval, not an isothermal-compressibility
# measurement at a point.

# %%
pressure_grid_bara = np.array([10.0, 25.0, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0])
pressure_rows = []

for pressure_bara in pressure_grid_bara:
    pressure_state = flash_dense_liquid(pr_fluid, 50.0, pressure_bara)
    pressure_rows.append(
        {
            "pressure [bara]": pressure_bara,
            "density [kg/m³]": float(
                pressure_state.getPhase(0).getDensity("kg/m3")
            ),
            "system mass [kg]": float(pressure_state.getMass("kg")),
        }
    )

pressure_sensitivity = pd.DataFrame(pressure_rows)
pressure_span_pa = (
    pressure_sensitivity["pressure [bara]"].iloc[-1]
    - pressure_sensitivity["pressure [bara]"].iloc[0]
) * 1.0e5
density_change_kg_m3 = (
    pressure_sensitivity["density [kg/m³]"].iloc[-1]
    - pressure_sensitivity["density [kg/m³]"].iloc[0]
)
apparent_compressibility_pa_inverse = (
    density_change_kg_m3 / pr_reference_density_kg_m3 / pressure_span_pa
)

display(pressure_sensitivity)
print(
    "Apparent density compressibility: "
    f"{apparent_compressibility_pa_inverse:.3e} Pa⁻¹"
)
# Out:
#    pressure [bara]  density [kg/m³]  system mass [kg]
# 0             10.0       834.886871               1.0
# 1             25.0       845.094441               1.0
# 2             50.0       849.665684               1.0
# 3            100.0       852.355368               1.0
# 4            150.0       853.331333               1.0
# 5            200.0       853.836167               1.0
# 6            250.0       854.144693               1.0
# 7            300.0       854.352766               1.0
# Apparent density compressibility: 8.040e-10 Pa⁻¹

# %% [markdown]
# ## Pressure-response interpretation
#
# The curve should be monotonic and flatten at high pressure. A sudden discontinuity would suggest
# a phase change, unstable characterization, or a solver issue and would invalidate the simple
# liquid-compressibility interpretation. All calculations clone the same characterized fluid, so
# the sweep has no history dependence.

# %%
figure, axis = plt.subplots(figsize=(8, 4.8))
axis.plot(
    pressure_sensitivity["pressure [bara]"],
    pressure_sensitivity["density [kg/m³]"],
    marker="o",
    linewidth=2.2,
)
axis.axhline(
    volume_additive_density_kg_m3,
    color="tab:gray",
    linestyle="--",
    label="volume-additive benchmark",
)
axis.set_xlabel("Pressure [bara]")
axis.set_ylabel("PR density at 50°C [kg/m³]")
axis.set_title("Dense-liquid pressure response")
axis.grid(alpha=0.25)
axis.legend()
figure.tight_layout()
plt.show()

# %% [markdown]
# ## Cut-resolution sensitivity
#
# Laboratories often provide different numbers of fractions. We merge adjacent cuts in pairs while
# preserving total mass, volume-additive density, and mass-weighted boiling point. The merged-cut
# density is therefore computed from additive volumes before converting back to API gravity.
#
# This comparison isolates discretization: both fluids describe the same bulk mass and volume, but
# one uses eight pseudo-components and the other uses four.

# %%
def merge_adjacent_cuts(cut_frame):
    merged_rows = []
    for start_index in range(0, len(cut_frame), 2):
        pair = cut_frame.iloc[start_index : start_index + 2]
        pair_mass_fraction = float(pair["mass fraction [-]"].sum())
        normalized_weights = pair["mass fraction [-]"] / pair_mass_fraction
        pair_density_kg_m3 = 1.0 / np.sum(
            normalized_weights / pair["density from API [kg/m³]"]
        )
        pair_boiling_point_c = float(
            np.sum(
                normalized_weights * pair["average boiling point [°C]"]
            )
        )
        merged_rows.append(
            {
                "cut": " + ".join(pair["cut"]),
                "mass fraction [-]": pair_mass_fraction,
                "API gravity [-]": density_to_api(pair_density_kg_m3),
                "average boiling point [°C]": pair_boiling_point_c,
            }
        )
    return pd.DataFrame(merged_rows)


merged_assay_data = merge_adjacent_cuts(assay_data)
display(merged_assay_data)
# Out:
#                               cut  ...  average boiling point [°C]
# 0   Light naphtha + Heavy naphtha  ...                  117.500000
# 1        Kerosene + Light gas oil  ...                  261.000000
# 2  Heavy gas oil + Vacuum gas oil  ...                  432.352941
# 3  Vacuum residue + Heavy residue  ...                  636.000000
#
# [4 rows x 4 columns]

# %% [markdown]
# ## Resolution result
#
# The density difference quantifies sensitivity to cut discretization for this state and
# correlation. Small agreement supports using four cuts for rapid screening, but it does not prove
# that both descriptions predict the same bubble point, gas liberation, viscosity, or product
# yields. Those require validation against the intended calculation.

# %%
resolution_rows = []
for label, cut_frame in [
    ("eight original cuts", assay_data),
    ("four volume-preserving cuts", merged_assay_data),
]:
    resolution_fluid, _, _ = build_assay_fluid(cut_frame, model="PR")
    resolution_state = flash_dense_liquid(resolution_fluid, 50.0, 10.0)
    resolution_rows.append(
        {
            "representation": label,
            "number of cuts": len(cut_frame),
            "density [kg/m³]": float(
                resolution_state.getPhase(0).getDensity("kg/m3")
            ),
            "system mass [kg]": float(resolution_state.getMass("kg")),
        }
    )

resolution_sensitivity = pd.DataFrame(resolution_rows)
resolution_density_difference_percent = 100.0 * (
    resolution_sensitivity["density [kg/m³]"].iloc[1]
    - resolution_sensitivity["density [kg/m³]"].iloc[0]
) / resolution_sensitivity["density [kg/m³]"].iloc[0]

display(resolution_sensitivity)
print(
    "Four-cut density difference: "
    f"{resolution_density_difference_percent:.6f}%"
)
# Out:
#                 representation  ...  system mass [kg]
# 0          eight original cuts  ...               1.0
# 1  four volume-preserving cuts  ...               1.0
#
# [2 rows x 4 columns]
# Four-cut density difference: -0.181136%

# %% [markdown]
# ## Density-measurement scenario
#
# To test input sensitivity, every cut API gravity is shifted by -5, 0, or +5 API units while mass
# fractions and boiling points remain fixed. Higher API gravity means lower density. This is a
# deliberately broad scenario, not a statement about laboratory uncertainty; real assay errors are
# correlated and should be propagated from measurement certificates.

# %%
api_shift_rows = []
for api_shift in [-5.0, 0.0, 5.0]:
    shifted_assay = assay_data[
        [
            "cut",
            "mass fraction [-]",
            "API gravity [-]",
            "average boiling point [°C]",
        ]
    ].copy()
    shifted_assay["API gravity [-]"] += api_shift
    shifted_fluid, _, _ = build_assay_fluid(shifted_assay, model="PR")
    shifted_state = flash_dense_liquid(shifted_fluid, 50.0, 10.0)
    api_shift_rows.append(
        {
            "API shift [-]": api_shift,
            "density [kg/m³]": float(
                shifted_state.getPhase(0).getDensity("kg/m3")
            ),
            "system mass [kg]": float(shifted_state.getMass("kg")),
        }
    )

api_sensitivity = pd.DataFrame(api_shift_rows)
display(api_sensitivity)
# Out:
#    API shift [-]  density [kg/m³]  system mass [kg]
# 0           -5.0       864.184576               1.0
# 1            0.0       834.886871               1.0
# 2            5.0       807.724997               1.0

# %% [markdown]
# ## Scenario comparison
#
# The left panel makes the expected inverse API-density relationship visible. The right panel
# compares cut resolution at identical state conditions. These are sensitivity studies around one
# synthetic assay; neither is a substitute for regression to measured density and phase-equilibrium
# data.

# %%
figure, axes = plt.subplots(1, 2, figsize=(11, 4.5))

axes[0].plot(
    api_sensitivity["API shift [-]"],
    api_sensitivity["density [kg/m³]"],
    marker="o",
    linewidth=2.2,
)
axes[0].set_xlabel("Uniform API-gravity shift [-]")
axes[0].set_ylabel("PR density at 50°C and 10 bara [kg/m³]")
axes[0].set_title("Input-density sensitivity")
axes[0].grid(alpha=0.25)

axes[1].bar(
    resolution_sensitivity["representation"],
    resolution_sensitivity["density [kg/m³]"],
    color=["tab:blue", "tab:orange"],
)
axes[1].set_ylabel("PR density at 50°C and 10 bara [kg/m³]")
axes[1].set_title("Cut-resolution sensitivity")
axes[1].tick_params(axis="x", rotation=12)
axes[1].set_ylim(0.95 * resolution_sensitivity["density [kg/m³]"].min(), None)
axes[1].grid(axis="y", alpha=0.25)

figure.tight_layout()
plt.show()

# %% [markdown]
# ## Verification checks
#
# The checks below cover input closure, monotonic assay properties, exact mass transfer, finite
# state properties, expected pressure and API trends, and sensitivity reproducibility. They test
# the calculation implementation and physical direction of change. They do not certify the assay
# against laboratory observations.

# %%
checks = {
    "mass fractions sum to one": abs(mass_fraction_sum - 1.0) < 1.0e-12,
    "boiling points increase": bool(np.all(np.diff(boiling_points_c) > 0.0)),
    "API gravity decreases with boiling point": bool(
        np.all(np.diff(assay_data["API gravity [-]"]) < 0.0)
    ),
    "API conversion round trip closes": maximum_api_round_trip_error < 1.0e-12,
    "resolved density increases": bool(np.all(np.diff(cut_densities_kg_m3) > 0.0)),
    "resolved boiling point increases": bool(
        np.all(np.diff(resolved_properties["boiling point [K]"]) > 0.0)
    ),
    "resolved molar mass increases": bool(
        np.all(np.diff(resolved_properties["molar mass [kg/kmol]"]) > 0.0)
    ),
    "one pseudo-component per cut": pr_fluid.getNumberOfComponents() == len(assay_data),
    "system assay mass closes": abs(system_assay_mass_kg - 1.0) < 1.0e-12,
    "reconstructed mass closes": abs(mass_residual_kg) < 1.0e-12,
    "bulk density is finite": np.isfinite(volume_additive_density_kg_m3),
    "bulk density is plausible": 700.0 < volume_additive_density_kg_m3 < 1100.0,
    "EOS densities are finite": bool(
        np.isfinite(eos_comparison["density [kg/m³]"]).all()
    ),
    "EOS state masses close": bool(
        np.allclose(eos_comparison["system mass [kg]"], 1.0, atol=1.0e-12)
    ),
    "PR agrees with volume estimate": abs(
        pr_reference_density_kg_m3 - volume_additive_density_kg_m3
    ) / volume_additive_density_kg_m3 < 0.05,
    "pressure density is monotonic": bool(
        np.all(np.diff(pressure_sensitivity["density [kg/m³]"]) > 0.0)
    ),
    "pressure sweep mass closes": bool(
        np.allclose(pressure_sensitivity["system mass [kg]"], 1.0, atol=1.0e-12)
    ),
    "compressibility is positive": apparent_compressibility_pa_inverse > 0.0,
    "compressibility is plausible": (
        1.0e-11 < apparent_compressibility_pa_inverse < 5.0e-9
    ),
    "merged assay mass closes": abs(
        merged_assay_data["mass fraction [-]"].sum() - 1.0
    ) < 1.0e-12,
    "cut-resolution masses close": bool(
        np.allclose(resolution_sensitivity["system mass [kg]"], 1.0, atol=1.0e-12)
    ),
    "cut-resolution density is stable": abs(
        resolution_density_difference_percent
    ) < 3.0,
    "API scenario masses close": bool(
        np.allclose(api_sensitivity["system mass [kg]"], 1.0, atol=1.0e-12)
    ),
    "higher API lowers density": bool(
        np.all(np.diff(api_sensitivity["density [kg/m³]"]) < 0.0)
    ),
    "all displayed results are finite": bool(
        np.isfinite(
            np.concatenate(
                [
                    resolved_properties.select_dtypes(include=[np.number]).to_numpy().ravel(),
                    eos_comparison.select_dtypes(include=[np.number]).to_numpy().ravel(),
                    pressure_sensitivity.select_dtypes(include=[np.number]).to_numpy().ravel(),
                    api_sensitivity.select_dtypes(include=[np.number]).to_numpy().ravel(),
                ]
            )
        ).all()
    ),
}

validation_table = pd.DataFrame(
    [{"check": name, "status": "PASS" if passed else "FAIL"} for name, passed in checks.items()]
)
display(validation_table)

assert all(checks.values()), validation_table.loc[validation_table["status"] == "FAIL"]
print(f"All {len(checks)} engineering checks passed.")
# Out:
#                                        check status
# 0                  mass fractions sum to one   PASS
# 1                    boiling points increase   PASS
# 2   API gravity decreases with boiling point   PASS
# 3           API conversion round trip closes   PASS
# 4                 resolved density increases   PASS
# 5           resolved boiling point increases   PASS
# 6              resolved molar mass increases   PASS
# 7               one pseudo-component per cut   PASS
# 8                   system assay mass closes   PASS
# 9                  reconstructed mass closes   PASS
# 10                    bulk density is finite   PASS
# 11                 bulk density is plausible   PASS
# 12                  EOS densities are finite   PASS
# 13                    EOS state masses close   PASS
# 14            PR agrees with volume estimate   PASS
# 15             pressure density is monotonic   PASS
# 16                pressure sweep mass closes   PASS
# ...

# %% [markdown]
# ## Troubleshooting and limitations
#
# - Apply the assay before selecting a mixing rule so the final component list is known.
# - Use mass fractions with `withMassFraction`; do not pass percentages unless using
#   `withWeightPercent`.
# - API gravity is not density. State the reference convention and verify the round trip.
# - A broad cut is not a pure compound. Its molar mass and critical properties are correlations.
# - Do not trust phase envelopes, viscosity, wax, or asphaltene predictions without suitable light
#   ends, heavy-end calibration, physical-property models, and laboratory validation.
# - If a flash changes phase or yields an unexpected phase label, inspect density, composition, and
#   stability before interpreting the result as a product yield.
#
# The strongest validation here is analytical mass and volume closure plus expected sensitivity
# trends. No experimental benchmark is claimed.

# %% [markdown]
# ## Summary, exercises, and references
#
# An eight-cut mass assay was converted into eight NeqSim pseudo-components with exact mass closure.
# PR density was checked against an independent volume-additive estimate, and pressure, cut count,
# and API-gravity scenarios behaved in the expected direction. The workflow is reproducible and
# composable, but design use requires measured density, distillation, and phase-equilibrium data.
#
# ### Further exercises
#
# 1. Replace the synthetic table with a public assay and document its test method and license.
# 2. Add identified C1--C6 light ends, then validate saturation pressure against a measured point.
# 3. Split the residue into more cuts and test convergence of density and bubble pressure.
# 4. Compare calculated density with laboratory values before and after EOS volume tuning.
#
# ### Authoritative references
#
# - [NeqSim PVT simulation guide](https://equinor.github.io/neqsim/pvtsimulation/README.html)
# - [NeqSim oil-assay characterization source](https://github.com/equinor/neqsim/blob/master/src/main/java/neqsim/thermo/characterization/OilAssayCharacterisation.java)
# - [NeqSim thermodynamic-model guide](https://equinor.github.io/neqsim/thermo/thermodynamic_models.html)
# - [API MPMS addenda and errata](https://www.api.org/products-and-services/standards/addenda-and-errata)
