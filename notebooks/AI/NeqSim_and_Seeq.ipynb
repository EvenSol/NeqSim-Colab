# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/AI/NeqSim_and_Seeq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NeqSim and process-data analytics using Seeq
#
# [Seeq](https://www.seeq.com/) supplies industrial time-series search,
# contextualization, visualization, and deployment. NeqSim supplies thermodynamics
# and composable process equipment. Together they support physics-informed
# monitoring.
#
# <figure>
# <img src='https://github.com/EvenSol/NeqSim-Colab/blob/master/figures/neqsimseeq.png?raw=true'
#      width="300" height="300" alt="Original NeqSim and Seeq integration illustration">
# <figcaption>Original repository illustration, retained from the previous notebook.</figcaption>
# </figure>
#
# ## Learning objectives
#
# - use a search–pull–calculate–validate–push workflow;
# - configure a multistage NeqSim separation and compression process;
# - calculate soft-sensor and equipment-performance signals;
# - check units, timestamps, finite values, trends, and mass closure;
# - replace a local adapter with authenticated Seeq SPy calls; and
# - structure a bounded live-model job without storing credentials.

# %% [markdown]
# ## Bridging process analytics and process simulation
#
# Seeq connects to historians and contextualizes operational time series. NeqSim
# converts those signals into phase state, density, separator products, compressor
# power, cooler duty, and conservation diagnostics.
#
# The original workflow is preserved with a reproducible LocalSeeqAdapter:
#
# 1. search signal metadata;
# 2. pull aligned operating data;
# 3. map tags to unit-explicit inputs;
# 4. execute the NeqSim process;
# 5. compare measured and modeled performance; and
# 6. push modeled signals with metadata and provenance.
#
# Only the adapter changes in production. The model, checks, and result schema remain
# reusable.

# %% [markdown]
# ## Installation in Colab or Seeq Data Lab
#
# NeqSim is distributed through public PyPI. Colab normally provides Java. A managed
# Seeq Data Lab should provision Java centrally; installing a JDK from notebook code
# is unnecessary and makes the runtime less reproducible.
#
# The setup cell installs only public neqsim when the package is absent.

# %%
import importlib.util
import subprocess
import sys


if importlib.util.find_spec("neqsim") is None:
    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--no-cache-dir",
            "neqsim",
        ]
    )

print("NeqSim is available.")
# Out:
# NeqSim is available.

# %%
import importlib.metadata
import platform
import subprocess


neqsim_version = importlib.metadata.version("neqsim")
python_version = platform.python_version()
java_version = subprocess.run(
    ["java", "-version"],
    capture_output=True,
    check=True,
    text=True,
).stderr.splitlines()[0]

runtime_table = {
    "NeqSim": neqsim_version,
    "Python": python_version,
    "Java": java_version,
}
print(runtime_table)
# Out:
# {'NeqSim': '3.16.0', 'Python': '3.12.13', 'Java': 'openjdk version "17.0.19" 2026-04-21'}

# %% [markdown]
# ## Integration theory and data contract
#
# At timestamp $t$, the historian supplies inputs $\mathbf{u}(t)$ such as
# temperature, pressure, flow, and set points. NeqSim calculates a modeled output
# $\hat{y}(t)$. The model residual is:
#
# $$
# r(t) = y_{\mathrm{measured}}(t) - \hat{y}(t)
# $$
#
# Residuals also contain sensor uncertainty, heat loss, composition uncertainty,
# timestamp misalignment, and model-form error. They require engineering
# interpretation.
#
# The relative mass residual is:
#
# $$
# \epsilon_m = \frac{\left|\dot{m}_{\mathrm{in}} -
# \sum_j \dot{m}_{j,\mathrm{out}}\right|}
# {\max\left(\dot{m}_{\mathrm{in}}, 1\ \mathrm{kg\,h^{-1}}\right)}
# $$
#
# All mass flows are in kg/h. The example operates far above 1 kg/h.

# %% [markdown]
# ## Example: historian-driven multistage processing
#
# The original large process-model intent is retained as an executable system with
# three separation pressures, low- and medium-pressure gas recompression,
# export-gas compression and cooling, a fuel split, and export-oil pumping.
#
# The original [process-comparison notebook](https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/process/comparesimulations.ipynb)
# remains available as a related example.

# %%
from dataclasses import asdict, dataclass
from time import monotonic
from typing import Sequence

import numpy as np
import pandas as pd
from neqsim.process.processTools import (
    clearProcess,
    compressor,
    cooler,
    getProcess,
    heater,
    mixer,
    pump,
    separator,
    separator3phase,
    splitter,
    stream,
    valve,
)
from neqsim.thermo import fluid


COMPONENTS = (
    "nitrogen",
    "CO2",
    "methane",
    "ethane",
    "propane",
    "n-butane",
    "n-pentane",
    "n-hexane",
    "n-heptane",
    "n-octane",
    "nC10",
    "water",
)
BASE_COMPOSITION = (
    0.010,
    0.020,
    0.620,
    0.090,
    0.070,
    0.045,
    0.035,
    0.025,
    0.020,
    0.015,
    0.010,
    0.040,
)


@dataclass(frozen=True)
class ProcessInput:
    timestamp: pd.Timestamp
    feed_rate_kg_h: float
    inlet_temperature_C: float
    inlet_pressure_bara: float
    first_stage_pressure_bara: float
    second_stage_pressure_bara: float
    third_stage_pressure_bara: float
    export_pressure_bara: float
    compressor_efficiency_fraction: float
    molar_composition: Sequence[float] = BASE_COMPOSITION

    def __post_init__(self):
        if len(self.molar_composition) != len(COMPONENTS):
            raise ValueError("Composition length must match the component list.")
        if not np.isclose(sum(self.molar_composition), 1.0, atol=1.0e-12):
            raise ValueError("Composition must sum to one.")
        if self.feed_rate_kg_h <= 0.0:
            raise ValueError("Feed rate must be positive.")
        if not 0.5 <= self.compressor_efficiency_fraction <= 0.95:
            raise ValueError("Efficiency must be between 0.50 and 0.95.")
        if not (
            self.inlet_pressure_bara
            >= self.first_stage_pressure_bara
            > self.second_stage_pressure_bara
            > self.third_stage_pressure_bara
            > 0.0
        ):
            raise ValueError("Separator pressures must decrease by stage.")
        if self.export_pressure_bara <= self.first_stage_pressure_bara:
            raise ValueError("Export pressure must exceed first-stage pressure.")


@dataclass(frozen=True)
class ProcessOutput:
    timestamp: pd.Timestamp
    feed_rate_kg_h: float
    sales_gas_rate_kg_h: float
    fuel_gas_rate_kg_h: float
    export_oil_rate_kg_h: float
    condensate_rate_kg_h: float
    produced_water_rate_kg_h: float
    total_compressor_power_kW: float
    export_temperature_C: float
    export_pressure_bara: float
    export_gas_density_kg_m3: float
    relative_mass_residual: float
    runtime_s: float


def create_well_fluid(composition=BASE_COMPOSITION):
    well_fluid = fluid("srk")
    for name, fraction in zip(COMPONENTS, composition):
        well_fluid.addComponent(name, float(fraction))
    well_fluid.setMixingRule("classic")
    well_fluid.setMultiPhaseCheck(True)
    return well_fluid


def getprocess():
    clearProcess()
    well_stream = stream("well stream", create_well_fluid())
    well_stream.setFlowRate(8_000.0, "kg/hr")
    well_stream.setTemperature(60.0, "C")
    well_stream.setPressure(80.0, "bara")

    stage1_heater = heater("first-stage conditioning", well_stream)
    stage1_heater.setOutTemperature(45.0, "C")
    stage1_heater.setOutPressure(60.0, "bara")
    stage1 = separator3phase("first-stage separator", stage1_heater.getOutletStream())

    stage1_valve = valve("first-stage oil valve", stage1.getOilOutStream(), 20.0)
    stage2_heater = heater("second-stage heater", stage1_valve.getOutletStream())
    stage2_heater.setOutTemperature(50.0, "C")
    stage2 = separator3phase("second-stage separator", stage2_heater.getOutletStream())

    stage2_valve = valve("second-stage oil valve", stage2.getOilOutStream(), 3.0)
    stage3_heater = heater("third-stage heater", stage2_valve.getOutletStream())
    stage3_heater.setOutTemperature(60.0, "C")
    stage3 = separator3phase("third-stage separator", stage3_heater.getOutletStream())

    lp_compressor = compressor("LP compressor", stage3.getGasOutStream(), 20.0)
    lp_cooler = cooler("LP cooler", lp_compressor.getOutletStream())
    lp_cooler.setOutTemperature(35.0, "C")
    lp_scrubber = separator("LP scrubber", lp_cooler.getOutletStream())

    mp_mixer = mixer("MP gas mixer")
    mp_mixer.addStream(lp_scrubber.getGasOutStream())
    mp_mixer.addStream(stage2.getGasOutStream())
    mp_compressor = compressor("MP compressor", mp_mixer.getOutletStream(), 60.0)
    mp_cooler = cooler("MP cooler", mp_compressor.getOutletStream())
    mp_cooler.setOutTemperature(35.0, "C")
    mp_scrubber = separator("MP scrubber", mp_cooler.getOutletStream())

    hp_mixer = mixer("HP gas mixer")
    hp_mixer.addStream(mp_scrubber.getGasOutStream())
    hp_mixer.addStream(stage1.getGasOutStream())
    export_compressor = compressor(
        "export compressor",
        hp_mixer.getOutletStream(),
        120.0,
    )
    export_cooler = cooler("export aftercooler", export_compressor.getOutletStream())
    export_cooler.setOutTemperature(35.0, "C")
    export_split = splitter(
        "sales and fuel split",
        export_cooler.getOutletStream(),
        [0.97, 0.03],
    )
    export_split.getSplitStream(0).setName("sales gas")
    export_split.getSplitStream(1).setName("fuel gas")

    export_oil = pump("export oil pump", stage3.getOilOutStream(), 20.0)
    export_oil.getOutletStream().setName("export oil")

    return {
        "process": getProcess(),
        "well_stream": well_stream,
        "stage1_heater": stage1_heater,
        "stage1": stage1,
        "stage1_valve": stage1_valve,
        "stage2": stage2,
        "stage2_valve": stage2_valve,
        "stage3": stage3,
        "lp_compressor": lp_compressor,
        "lp_scrubber": lp_scrubber,
        "mp_compressor": mp_compressor,
        "mp_scrubber": mp_scrubber,
        "export_compressor": export_compressor,
        "export_cooler": export_cooler,
        "export_split": export_split,
        "export_oil": export_oil,
    }


def updateinput(bundle, operating_point):
    bundle["well_stream"].setFlowRate(operating_point.feed_rate_kg_h, "kg/hr")
    bundle["well_stream"].setTemperature(
        operating_point.inlet_temperature_C,
        "C",
    )
    bundle["well_stream"].setPressure(
        operating_point.inlet_pressure_bara,
        "bara",
    )
    bundle["stage1_heater"].setOutPressure(
        operating_point.first_stage_pressure_bara,
        "bara",
    )
    bundle["stage1_valve"].setOutletPressure(
        operating_point.second_stage_pressure_bara,
        "bara",
    )
    bundle["stage2_valve"].setOutletPressure(
        operating_point.third_stage_pressure_bara,
        "bara",
    )
    bundle["lp_compressor"].setOutletPressure(
        operating_point.second_stage_pressure_bara,
        "bara",
    )
    bundle["mp_compressor"].setOutletPressure(
        operating_point.first_stage_pressure_bara,
        "bara",
    )
    bundle["export_compressor"].setOutletPressure(
        operating_point.export_pressure_bara,
        "bara",
    )
    for unit in (
        bundle["lp_compressor"],
        bundle["mp_compressor"],
        bundle["export_compressor"],
    ):
        unit.setIsentropicEfficiency(
            operating_point.compressor_efficiency_fraction
        )


def getoutput(bundle, operating_point, runtime_s):
    feed = bundle["well_stream"].getFlowRate("kg/hr")
    sales = bundle["export_split"].getSplitStream(0)
    fuel = bundle["export_split"].getSplitStream(1)
    sales_rate = sales.getFlowRate("kg/hr")
    fuel_rate = fuel.getFlowRate("kg/hr")
    oil_rate = bundle["export_oil"].getOutletStream().getFlowRate("kg/hr")
    condensate_rate = sum(
        scrubber.getLiquidOutStream().getFlowRate("kg/hr")
        for scrubber in (bundle["lp_scrubber"], bundle["mp_scrubber"])
    )
    water_rate = sum(
        stage.getWaterOutStream().getFlowRate("kg/hr")
        for stage in (bundle["stage1"], bundle["stage2"], bundle["stage3"])
    )
    products = sales_rate + fuel_rate + oil_rate + condensate_rate + water_rate
    mass_residual = abs(feed - products) / max(feed, 1.0)
    total_power = sum(
        unit.getPower("kW")
        for unit in (
            bundle["lp_compressor"],
            bundle["mp_compressor"],
            bundle["export_compressor"],
        )
    )
    sales.getFluid().initPhysicalProperties()

    return ProcessOutput(
        timestamp=operating_point.timestamp,
        feed_rate_kg_h=feed,
        sales_gas_rate_kg_h=sales_rate,
        fuel_gas_rate_kg_h=fuel_rate,
        export_oil_rate_kg_h=oil_rate,
        condensate_rate_kg_h=condensate_rate,
        produced_water_rate_kg_h=water_rate,
        total_compressor_power_kW=total_power,
        export_temperature_C=bundle["export_cooler"].getOutletStream().getTemperature(
            "C"
        ),
        export_pressure_bara=sales.getPressure("bara"),
        export_gas_density_kg_m3=sales.getFluid().getDensity("kg/m3"),
        relative_mass_residual=mass_residual,
        runtime_s=runtime_s,
    )


def run_simulation(bundle, operating_point, timeout_seconds=30):
    updateinput(bundle, operating_point)
    start = monotonic()
    thread = bundle["process"].runAsThread()
    thread.join(int(timeout_seconds * 1_000))
    if thread.isAlive():
        thread.interrupt()
        thread.join()
        raise TimeoutError(f"Process exceeded {timeout_seconds} seconds.")
    return getoutput(bundle, operating_point, monotonic() - start)


process1 = getprocess()
print("Created the preserved multistage process workflow.")
# Out:
# Created the preserved multistage process workflow.

# %% [markdown]
# ## Read field data using the Seeq search and pull pattern
#
# The real SPy API needs an authenticated Seeq environment. Repository validation
# must not depend on private credentials, so the next cell uses deterministic,
# public synthetic signals through a local adapter.

# %%
from dataclasses import dataclass, field


@dataclass
class LocalSeeqAdapter:
    pushed_frames: list = field(default_factory=list)

    def search(self, query):
        names = [
            "Feed Rate",
            "Inlet Temperature",
            "Inlet Pressure",
            "First Stage Pressure",
            "Second Stage Pressure",
            "Third Stage Pressure",
            "Export Pressure",
            "Estimated Compressor Efficiency",
        ]
        units = [
            "kg/h",
            "degC",
            "bara",
            "bara",
            "bara",
            "bara",
            "bara",
            "fraction",
        ]
        return pd.DataFrame(
            {
                "Name": names,
                "Path": ["Demo >> Production Train"] * len(names),
                "ID": [f"LOCAL-{index:02d}" for index in range(len(names))],
                "Unit": units,
            }
        )

    def pull(self, items, start, end, grid="1h"):
        timestamps = pd.date_range(
            start=start,
            periods=24,
            freq="1h",
            tz="Europe/Oslo",
        )
        angle = np.linspace(0.0, 2.0 * np.pi, len(timestamps))
        degradation = np.linspace(0.0, 0.035, len(timestamps))
        return pd.DataFrame(
            {
                "Feed Rate": 8_000.0 + 500.0 * np.sin(angle),
                "Inlet Temperature": 58.0 + 3.0 * np.sin(angle - 0.5),
                "Inlet Pressure": 80.0 + 2.0 * np.cos(angle),
                "First Stage Pressure": 60.0 + np.cos(angle),
                "Second Stage Pressure": 20.0 + 0.4 * np.sin(angle),
                "Third Stage Pressure": 3.0 + 0.1 * np.sin(angle),
                "Export Pressure": 118.0 + 4.0 * np.sin(angle + 0.4),
                "Estimated Compressor Efficiency": 0.78 - degradation,
            },
            index=timestamps,
        )

    def push(self, data, metadata, workbook, worksheet):
        if not isinstance(data.index, pd.DatetimeIndex):
            raise TypeError("Signal data must use a DatetimeIndex.")
        if not data.index.is_monotonic_increasing:
            raise ValueError("Signal timestamps must be ordered.")
        self.pushed_frames.append(
            {
                "data": data.copy(),
                "metadata": metadata.copy(),
                "workbook": workbook,
                "worksheet": worksheet,
            }
        )
        return pd.DataFrame(
            {
                "Workbook": [workbook],
                "Worksheet": [worksheet],
                "Rows": [len(data)],
                "Signals": [len(data.columns)],
                "Mode": ["local validation adapter"],
            }
        )


spy = LocalSeeqAdapter()
signals_to_find = spy.search(
    {
        "Path": "Demo >> Production Train",
        "Name": ["Temperature", "Pressure", "Flow", "Efficiency"],
    }
)
field_data_df = spy.pull(
    items=signals_to_find,
    start="2026-01-15 00:00",
    end="2026-01-16 00:00",
    grid="1h",
)

display(signals_to_find)
display(field_data_df.head())
# Out:
#                               Name  ...      Unit
# 0                        Feed Rate  ...      kg/h
# 1                Inlet Temperature  ...      degC
# 2                   Inlet Pressure  ...      bara
# 3             First Stage Pressure  ...      bara
# 4            Second Stage Pressure  ...      bara
# 5             Third Stage Pressure  ...      bara
# 6                  Export Pressure  ...      bara
# 7  Estimated Compressor Efficiency  ...  fraction
#
# [8 rows x 4 columns]
#                              Feed Rate  ...  Estimated Compressor Efficiency
# 2026-01-15 00:00:00+01:00  8000.000000  ...                         0.780000
# 2026-01-15 01:00:00+01:00  8134.898386  ...                         0.778478
# 2026-01-15 02:00:00+01:00  8259.791975  ...                         0.776957
# 2026-01-15 03:00:00+01:00  8365.417982  ...                         0.775435
# 2026-01-15 04:00:00+01:00  8443.942609  ...                         0.773913
#
# [5 rows x 8 columns]

# %% [markdown]
# The search step resolves item metadata before data retrieval. Pull aligns
# signals to a common time grid. A production Data Lab deployment replaces the
# local adapter with from seeq import spy and uses platform-managed authentication.
# Credentials must never be committed to notebook source.

# %% [markdown]
# ## Update inputs from field data
#
# Site-specific historian tags are mapped once to stable engineering names and
# explicit units. This fixes the previous duplicated dictionary key and undefined
# row variable.

# %%
def field_row_to_process_input(timestamp, row):
    return ProcessInput(
        timestamp=timestamp,
        feed_rate_kg_h=float(row["Feed Rate"]),
        inlet_temperature_C=float(row["Inlet Temperature"]),
        inlet_pressure_bara=float(row["Inlet Pressure"]),
        first_stage_pressure_bara=float(row["First Stage Pressure"]),
        second_stage_pressure_bara=float(row["Second Stage Pressure"]),
        third_stage_pressure_bara=float(row["Third Stage Pressure"]),
        export_pressure_bara=float(row["Export Pressure"]),
        compressor_efficiency_fraction=float(
            row["Estimated Compressor Efficiency"]
        ),
    )


input_records = [
    field_row_to_process_input(timestamp, row)
    for timestamp, row in field_data_df.iterrows()
]
display(pd.DataFrame([asdict(item) for item in input_records[:3]]))
# Out:
#                   timestamp  ...                                  molar_composition
# 0 2026-01-15 00:00:00+01:00  ...  (0.01, 0.02, 0.62, 0.09, 0.07, 0.045, 0.035, 0...
# 1 2026-01-15 01:00:00+01:00  ...  (0.01, 0.02, 0.62, 0.09, 0.07, 0.045, 0.035, 0...
# 2 2026-01-15 02:00:00+01:00  ...  (0.01, 0.02, 0.62, 0.09, 0.07, 0.045, 0.035, 0...
#
# [3 rows x 10 columns]

# %%
simulation_outputs = [
    run_simulation(process1, operating_point)
    for operating_point in input_records
]
results_df = pd.DataFrame(
    [asdict(output) for output in simulation_outputs]
).set_index("timestamp")

degradation = np.linspace(0.0, 0.06, len(results_df))
sensor_variation = 0.004 * np.sin(
    np.linspace(0.0, 4.0 * np.pi, len(results_df))
)
results_df["measured_compressor_power_kW"] = results_df[
    "total_compressor_power_kW"
] * (1.0 + degradation + sensor_variation)
results_df["power_residual_kW"] = (
    results_df["measured_compressor_power_kW"]
    - results_df["total_compressor_power_kW"]
)
results_df["relative_power_residual"] = (
    results_df["power_residual_kW"]
    / results_df["total_compressor_power_kW"]
)

display(
    results_df[
        [
            "feed_rate_kg_h",
            "sales_gas_rate_kg_h",
            "export_oil_rate_kg_h",
            "total_compressor_power_kW",
            "measured_compressor_power_kW",
            "relative_mass_residual",
        ]
    ].head()
)
# Out:
#                            feed_rate_kg_h  ...  relative_mass_residual
# timestamp                                  ...
# 2026-01-15 00:00:00+01:00     8000.000000  ...            5.013590e-14
# 2026-01-15 01:00:00+01:00     8134.898386  ...            5.355297e-14
# 2026-01-15 02:00:00+01:00     8259.791975  ...            5.703754e-14
# 2026-01-15 03:00:00+01:00     8365.417982  ...            6.001387e-14
# 2026-01-15 04:00:00+01:00     8443.942609  ...            6.247164e-14
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Push historical model results back to Seeq
#
# The pushed frame has timestamped rows and stable, unit-explicit signal names. The
# local adapter records the payload without a network write.

# %%
data_to_push_df = results_df[
    [
        "total_compressor_power_kW",
        "export_gas_density_kg_m3",
        "relative_mass_residual",
        "power_residual_kW",
    ]
].copy()
data_to_push_df.columns = [
    "NeqSim Total Compressor Power [kW]",
    "NeqSim Export Gas Density [kg/m3]",
    "NeqSim Relative Mass Residual [-]",
    "Measured minus NeqSim Power [kW]",
]
metadata_df = pd.DataFrame(
    [
        {
            "Name": name,
            "Type": "Signal",
            "Source": "NeqSim validated example",
        }
        for name in data_to_push_df.columns
    ]
)
push_results = spy.push(
    data=data_to_push_df,
    metadata=metadata_df,
    workbook="Process Simulation Results",
    worksheet="Physics-informed monitoring",
)
display(push_results)
# Out:
#                      Workbook  ...                      Mode
# 0  Process Simulation Results  ...  local validation adapter
#
# [1 rows x 5 columns]

# %% [markdown]
# The audit confirms that all timestamped operating points and four modeled
# signals satisfy the Seeq-style payload contract. The data remain local until an
# authorized production adapter is supplied.

# %% [markdown]
# ## Make a bounded live process model
#
# A live model repeats pull, validation, simulation, quality checks, packaging, and
# push for the newest qualified point. The previous infinite loop is replaced with
# a bounded demonstration. Production scheduling belongs in a managed job with
# timeouts, retries, logging, and credential management.

# %%
def simulate_latest_point_from_seeq(
    bundle,
    seeq_adapter,
    field_data,
    row_position=-1,
):
    selected = field_data.iloc[[row_position]]
    operating_point = field_row_to_process_input(
        selected.index[0],
        selected.iloc[0],
    )
    output = run_simulation(bundle, operating_point)
    output_frame = pd.DataFrame([asdict(output)]).set_index("timestamp")
    output_frame.columns = [
        name.replace("_", " ")
        for name in output_frame.columns
    ]
    metadata = pd.DataFrame(
        {
            "Name": output_frame.columns,
            "Type": ["Signal"] * len(output_frame.columns),
            "Source": ["NeqSim live model"] * len(output_frame.columns),
        }
    )
    audit = seeq_adapter.push(
        data=output_frame,
        metadata=metadata,
        workbook="Process Simulation Results",
        worksheet="Live model",
    )
    return operating_point, output, audit


latest_input, latest_output, latest_push_audit = (
    simulate_latest_point_from_seeq(
        process1,
        spy,
        field_data_df,
    )
)
display(pd.DataFrame([asdict(latest_output)]))
display(latest_push_audit)
# Out:
#                   timestamp  feed_rate_kg_h  ...  relative_mass_residual  runtime_s
# 0 2026-01-15 23:00:00+01:00          8000.0  ...            5.013590e-14   0.018651
#
# [1 rows x 13 columns]
#                      Workbook   Worksheet  ...  Signals                      Mode
# 0  Process Simulation Results  Live model  ...       12  local validation adapter
#
# [1 rows x 5 columns]

# %% [markdown]
# ## Push live results and schedule safely
#
# The next cell emulates three scheduler invocations and terminates. A production
# scheduler should call the live function once per managed job invocation.

# %%
live_job_records = []
for row_position in (-3, -2, -1):
    live_input, live_output, live_push = simulate_latest_point_from_seeq(
        process1,
        spy,
        field_data_df,
        row_position=row_position,
    )
    live_job_records.append(
        {
            "timestamp": live_output.timestamp,
            "compressor_power_kW": live_output.total_compressor_power_kW,
            "mass_residual": live_output.relative_mass_residual,
            "push_rows": int(live_push.loc[0, "Rows"]),
        }
    )

live_job_df = pd.DataFrame(live_job_records).set_index("timestamp")
display(live_job_df)
print("Bounded live-model demonstration completed.")
# Out:
# Bounded live-model demonstration completed.
#                            compressor_power_kW  mass_residual  push_rows
# timestamp
# 2026-01-15 21:00:00+01:00           178.118502   1.956419e-13          1
# 2026-01-15 22:00:00+01:00           182.751051   1.988952e-13          1
# 2026-01-15 23:00:00+01:00           187.784035   5.024958e-14          1

# %% [markdown]
# ## Visual 1 — data-to-model workflow
#
# The diagram distinguishes historian operations from the reproducible engineering
# calculation and its quality gate.

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch, FancyBboxPatch


steps = [
    ("Seeq search", "Resolve tags\nand units"),
    ("Seeq pull", "Align historian\ntime series"),
    ("Validation", "Check time,\nunits, bounds"),
    ("NeqSim", "Flash and run\nprocess model"),
    ("Quality gate", "Balances and\nresiduals"),
    ("Seeq push", "Publish modeled\nsignals"),
]

figure, axis = plt.subplots(figsize=(12, 3.4))
axis.set_xlim(0.0, 12.0)
axis.set_ylim(0.0, 3.0)
axis.axis("off")

for index, (title, subtitle) in enumerate(steps):
    x_position = 0.3 + index * 1.95
    box_color = "#56B4E9" if index in (0, 1, 5) else "#009E73"
    box = FancyBboxPatch(
        (x_position, 0.75),
        1.55,
        1.45,
        boxstyle="round,pad=0.08",
        facecolor=box_color,
        edgecolor="#222222",
        linewidth=1.2,
    )
    axis.add_patch(box)
    axis.text(
        x_position + 0.775,
        1.67,
        title,
        ha="center",
        va="center",
        fontsize=10,
        fontweight="bold",
    )
    axis.text(
        x_position + 0.775,
        1.14,
        subtitle,
        ha="center",
        va="center",
        fontsize=9,
    )
    if index < len(steps) - 1:
        axis.add_patch(
            FancyArrowPatch(
                (x_position + 1.58, 1.47),
                (x_position + 1.90, 1.47),
                arrowstyle="->",
                mutation_scale=14,
                linewidth=1.5,
                color="#333333",
            )
        )

axis.set_title(
    "Seeq–NeqSim physics-informed analytics workflow",
    fontsize=14,
    pad=12,
)
plt.tight_layout()
plt.show()
# Out:
# <Figure 1: 12.0x3.4 inches>

# %% [markdown]
# The same NeqSim calculation can be used with a local adapter, Seeq
# Data Lab, or another historian connector because data access is isolated from
# model execution.

# %% [markdown]
# ## Visual 2 — operating inputs
#
# The historian-style dataset changes flow and pressure over one day. Every plotted
# signal is a real boundary condition for the process model.

# %%
figure, axes = plt.subplots(3, 1, figsize=(11, 8), sharex=True)

axes[0].plot(
    field_data_df.index,
    field_data_df["Feed Rate"],
    color="#0072B2",
    linewidth=2.2,
    label="Feed rate",
)
axes[0].set_ylabel("Feed rate [kg/h]")
axes[0].legend(loc="upper right")
axes[0].grid(alpha=0.25)

axes[1].plot(
    field_data_df.index,
    field_data_df["Inlet Pressure"],
    color="#009E73",
    linewidth=2.2,
    label="Inlet pressure",
)
axes[1].plot(
    field_data_df.index,
    field_data_df["First Stage Pressure"],
    color="#E69F00",
    linewidth=2.2,
    label="First-stage pressure",
)
axes[1].set_ylabel("Pressure [bara]")
axes[1].legend(loc="upper right")
axes[1].grid(alpha=0.25)

axes[2].plot(
    field_data_df.index,
    field_data_df["Export Pressure"],
    color="#CC79A7",
    linewidth=2.2,
    label="Export pressure",
)
axes[2].set_ylabel("Pressure [bara]")
axes[2].set_xlabel("Timestamp [Europe/Oslo]")
axes[2].legend(loc="upper right")
axes[2].grid(alpha=0.25)

figure.suptitle("Historian-style operating inputs used by NeqSim", fontsize=14)
figure.autofmt_xdate()
figure.tight_layout()
plt.show()
# Out:
# <Figure 1: 11.0x8.0 inches>

# %% [markdown]
# The pressure ordering follows the process topology. Input validation
# prevents a mismapped historian tag from silently reversing a separator or
# compressor pressure ratio.

# %% [markdown]
# ## Visual 3 — modeled power and residual
#
# The illustrative measured signal includes gradual performance loss. The
# difference from modeled power is a useful monitoring signal, but not automatic
# proof of equipment degradation.

# %%
figure, axes = plt.subplots(2, 1, figsize=(11, 7), sharex=True)

axes[0].plot(
    results_df.index,
    results_df["total_compressor_power_kW"],
    color="#0072B2",
    linewidth=2.3,
    label="NeqSim modeled power",
)
axes[0].plot(
    results_df.index,
    results_df["measured_compressor_power_kW"],
    color="#D55E00",
    linewidth=2.0,
    linestyle="--",
    label="Illustrative measured power",
)
axes[0].set_ylabel("Compressor power [kW]")
axes[0].legend(loc="upper left")
axes[0].grid(alpha=0.25)

axes[1].plot(
    results_df.index,
    100.0 * results_df["relative_power_residual"],
    color="#CC79A7",
    linewidth=2.3,
    label="Measured minus modeled",
)
axes[1].axhline(
    5.0,
    color="#E69F00",
    linestyle=":",
    linewidth=2.0,
    label="Illustrative 5% review threshold",
)
axes[1].set_ylabel("Power residual [%]")
axes[1].set_xlabel("Timestamp [Europe/Oslo]")
axes[1].legend(loc="upper left")
axes[1].grid(alpha=0.25)

figure.suptitle("Physics-based compressor monitoring with NeqSim", fontsize=14)
figure.autofmt_xdate()
figure.tight_layout()
plt.show()
# Out:
# <Figure 1: 11.0x7.0 inches>

# %% [markdown]
# The residual grows and crosses the illustrative review threshold.
# Engineers should also check composition, sensor calibration, heat loss, and time
# alignment before diagnosing equipment.

# %% [markdown]
# ## Visual 4 — export-pressure sensitivity
#
# The same process objects are reused to evaluate operating scenarios, showing how
# a worksheet can move beyond historical replay.

# %%
base_input = input_records[len(input_records) // 2]
pressure_cases = np.array([90.0, 105.0, 120.0, 135.0, 150.0])
sensitivity_records = []

for export_pressure in pressure_cases:
    case_input = ProcessInput(
        timestamp=base_input.timestamp,
        feed_rate_kg_h=base_input.feed_rate_kg_h,
        inlet_temperature_C=base_input.inlet_temperature_C,
        inlet_pressure_bara=base_input.inlet_pressure_bara,
        first_stage_pressure_bara=base_input.first_stage_pressure_bara,
        second_stage_pressure_bara=base_input.second_stage_pressure_bara,
        third_stage_pressure_bara=base_input.third_stage_pressure_bara,
        export_pressure_bara=float(export_pressure),
        compressor_efficiency_fraction=(
            base_input.compressor_efficiency_fraction
        ),
    )
    case_output = run_simulation(process1, case_input)
    sensitivity_records.append(
        {
            "export_pressure_bara": export_pressure,
            "compressor_power_kW": case_output.total_compressor_power_kW,
            "gas_density_kg_m3": case_output.export_gas_density_kg_m3,
            "relative_mass_residual": case_output.relative_mass_residual,
        }
    )

sensitivity_df = pd.DataFrame(sensitivity_records)

figure, primary_axis = plt.subplots(figsize=(10, 5.5))
primary_axis.plot(
    sensitivity_df["export_pressure_bara"],
    sensitivity_df["compressor_power_kW"],
    marker="o",
    color="#0072B2",
    linewidth=2.3,
    label="Total compressor power",
)
primary_axis.set_xlabel("Export pressure [bara]")
primary_axis.set_ylabel("Total compressor power [kW]", color="#0072B2")
primary_axis.tick_params(axis="y", labelcolor="#0072B2")
primary_axis.grid(alpha=0.25)

secondary_axis = primary_axis.twinx()
secondary_axis.plot(
    sensitivity_df["export_pressure_bara"],
    sensitivity_df["gas_density_kg_m3"],
    marker="s",
    color="#D55E00",
    linewidth=2.3,
    label="Export-gas density",
)
secondary_axis.set_ylabel("Export-gas density [kg/m3]", color="#D55E00")
secondary_axis.tick_params(axis="y", labelcolor="#D55E00")

lines = primary_axis.get_lines() + secondary_axis.get_lines()
primary_axis.legend(
    lines,
    [line.get_label() for line in lines],
    loc="upper left",
)
primary_axis.set_title("NeqSim export-pressure sensitivity")
figure.tight_layout()
plt.show()

display(sensitivity_df)
# Out:
#    export_pressure_bara  ...  relative_mass_residual
# 0                  90.0  ...            1.926333e-13
# 1                 105.0  ...            1.926333e-13
# 2                 120.0  ...            1.926333e-13
# 3                 135.0  ...            1.926333e-13
# 4                 150.0  ...            1.926333e-13
#
# [5 rows x 4 columns]
# <Figure 1: 10.0x5.5 inches>

# %% [markdown]
# Compressor power and cooled-gas density should increase with export
# pressure. This is an operating screen, not compressor-map or mechanical-design
# certification.

# %% [markdown]
# ## Engineering validation
#
# The checks cover data quality, process conservation, result finiteness, expected
# trends, payload structure, and bounded live execution.

# %%
engineering_checks = {
    "neqsim_version_recorded": bool(neqsim_version),
    "timestamps_ordered": field_data_df.index.is_monotonic_increasing,
    "timestamps_unique": field_data_df.index.is_unique,
    "field_values_finite": np.isfinite(field_data_df.to_numpy()).all(),
    "result_values_finite": np.isfinite(
        results_df.select_dtypes(include=[np.number]).to_numpy()
    ).all(),
    "mass_residual_below_1e_8": (
        results_df["relative_mass_residual"].max() < 1.0e-8
    ),
    "sales_gas_positive": results_df["sales_gas_rate_kg_h"].min() > 0.0,
    "export_oil_positive": results_df["export_oil_rate_kg_h"].min() > 0.0,
    "compressor_power_positive": (
        results_df["total_compressor_power_kW"].min() > 0.0
    ),
    "export_temperature_35_C": np.allclose(
        results_df["export_temperature_C"],
        35.0,
        atol=1.0e-6,
    ),
    "export_pressure_matches_input": np.allclose(
        results_df["export_pressure_bara"],
        field_data_df["Export Pressure"],
        atol=1.0e-6,
    ),
    "power_residual_grows": (
        results_df["relative_power_residual"].iloc[-1]
        > results_df["relative_power_residual"].iloc[0]
    ),
    "power_increases_with_pressure": (
        sensitivity_df["compressor_power_kW"].is_monotonic_increasing
    ),
    "density_increases_with_pressure": (
        sensitivity_df["gas_density_kg_m3"].is_monotonic_increasing
    ),
    "sensitivity_mass_closure": (
        sensitivity_df["relative_mass_residual"].max() < 1.0e-8
    ),
    "historic_push_complete": int(push_results.loc[0, "Rows"])
    == len(results_df),
    "three_live_jobs_complete": len(live_job_df) == 3,
    "live_push_one_row_each": live_job_df["push_rows"].eq(1).all(),
}
failed_checks = [
    name
    for name, passed in engineering_checks.items()
    if not passed
]
assert not failed_checks, f"Engineering checks failed: {failed_checks}"

validation_df = pd.DataFrame(
    {
        "Check": list(engineering_checks),
        "Passed": list(engineering_checks.values()),
    }
)
display(validation_df)
print(f"{len(engineering_checks)}/{len(engineering_checks)} checks passed.")
print(
    "Maximum relative process mass residual: "
    f"{results_df['relative_mass_residual'].max():.3e}"
)
# Out:
# 18/18 checks passed.
# Maximum relative process mass residual: 2.151e-13
#                               Check  Passed
# 0           neqsim_version_recorded    True
# 1                timestamps_ordered    True
# 2                 timestamps_unique    True
# 3               field_values_finite    True
# 4              result_values_finite    True
# 5          mass_residual_below_1e_8    True
# 6                sales_gas_positive    True
# 7               export_oil_positive    True
# 8         compressor_power_positive    True
# 9           export_temperature_35_C    True
# 10    export_pressure_matches_input    True
# 11             power_residual_grows    True
# 12    power_increases_with_pressure    True
# 13  density_increases_with_pressure    True
# 14         sensitivity_mass_closure    True
# 15           historic_push_complete    True
# 16         three_live_jobs_complete    True
# 17           live_push_one_row_each    True

# %% [markdown]
# ## Deployment guidance, limitations, and exercises
#
# ### Production checklist
#
# - provision Java and neqsim in managed Seeq Data Lab;
# - authenticate through the platform, never committed credentials;
# - map site tags to the unit-explicit ProcessInput contract;
# - reject bad, stale, interpolated, or out-of-service data;
# - version composition and thermodynamic assumptions;
# - retain model version, runtime, convergence, and balance quality fields; and
# - require engineering review before residuals trigger operating actions.
#
# ### Limitations
#
# The adapter is not Seeq and performs no network communication. Fluid and historian
# signals are synthetic. Equipment maps, heat loss, controls, uncertainty, and
# site-specific tags are outside this educational model.
#
# ### Exercises
#
# 1. Replace local pull with a CSV export without changing the input contract.
# 2. Add composition signals and quantify density uncertainty.
# 3. Require three consecutive residual exceedances before alerting.
# 4. Compare compressor results with a validated map.
# 5. Deploy the bounded function as an idempotent managed job.
#
# ### References
#
# - [NeqSim documentation](https://equinor.github.io/neqsim/)
# - [NeqSim process recipes](https://equinor.github.io/neqsim/cookbook/process-recipes.html)
# - [Seeq SPy documentation](https://python-docs.seeq.com/)
# - [Seeq Data Lab](https://www.seeq.com/product/seeq-data-lab)
