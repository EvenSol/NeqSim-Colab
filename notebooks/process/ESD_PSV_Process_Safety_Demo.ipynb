# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/process/ESD_PSV_Process_Safety_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # ESD, PSV, and controlled gas depressurization with NeqSim
#
# This workbook is for process, safety, and facilities engineers who want a transparent
# screening model before a formal relief or blowdown study.
#
# **Prerequisites:** basic thermodynamics, gas flow, pressure protection, Python, and
# steady-state process simulation.
#
# **Learning objectives**
#
# 1. Build a real-gas relief fluid with the SRK equation of state.
# 2. Exercise NeqSim `SafetyValve`, `BlowdownValve`, `PushButton`, `Orifice`, and
#    `ReliefValveSizing` functionality.
# 3. Preserve and repair the original blocked-outlet, manual ESD, pressure-buildup,
#    hysteresis, orifice, comparison, PSV-sizing, and blowdown-time examples.
# 4. Audit mass, event timing, valve behaviour, and limiting trends.
# 5. Understand what remains for an API 520/521, API 526, ISO 5167, or IEC 61511
#    project deliverable.

# %% [markdown]
# ## Scope and safety boundary
#
# The calculations are reproducible screening examples, not certified sizing. API and
# ISO standards are copyrighted and must be consulted directly for a real project.
# Vendor coefficients, certified capacity, reaction forces, inlet and outlet losses,
# back-pressure interaction, flare hydraulics, fire heat input, two-phase relief,
# metallurgy, hydrate risk, and the approved cause-and-effect chart require separate
# verification.
#
# The original notebook named exact standards but mixed unit systems and used
# unexecuted Jython-only code. This version keeps every engineering example while using
# SI units and public NeqSim 3.16.0 APIs.

# %%
import importlib.util
import subprocess
import sys


if importlib.util.find_spec("neqsim") is None:
    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--no-cache-dir",
            "neqsim",
        ]
    )

# %%
import json
import platform
import subprocess
from importlib.metadata import version

import jpype
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
from neqsim import jneqsim


neqsim_version = version("neqsim")
python_version = platform.python_version()
java_version = subprocess.check_output(
    ["java", "-version"],
    stderr=subprocess.STDOUT,
    text=True,
).splitlines()[0]

print(f"NeqSim: {neqsim_version}")
print(f"Python: {python_version}")
print(f"Java: {java_version}")
# Out:
# NeqSim: 3.16.0
# Python: 3.12.13
# Java: openjdk version "17.0.19" 2026-04-21

# %% [markdown]
# ## Existing-example preservation checklist
#
# The legacy notebook contained eight substantive teaching intentions:
#
# 1. SRK separator-gas properties.
# 2. Blocked outlet with automatic PSV relief.
# 3. PSV opening and reseat hysteresis.
# 4. Manual ESD blowdown with a five-second valve stroke.
# 5. ISO 5167 pressure-driven orifice behaviour.
# 6. Pressure buildup followed by automatic ESD isolation and blowdown.
# 7. Comparison of passive and active protection.
# 8. Gas PSV area selection and the 15-minute depressurization screen.
#
# It had no plots or other stored visual outputs. All eight examples are retained below,
# integrated into one consistent vessel and gas basis, and expanded with five technical
# figures.

# %%
SystemSrkEos = jneqsim.thermo.system.SystemSrkEos
ThermodynamicOperations = (
    jneqsim.thermodynamicoperations.ThermodynamicOperations
)
Stream = jneqsim.process.equipment.stream.Stream
ProcessSystem = jneqsim.process.processmodel.ProcessSystem
SafetyValve = jneqsim.process.equipment.valve.SafetyValve
BlowdownValve = jneqsim.process.equipment.valve.BlowdownValve
PushButton = jneqsim.process.measurementdevice.PushButton
Orifice = jneqsim.process.equipment.diffpressure.Orifice
ReliefValveSizing = jneqsim.process.util.fire.ReliefValveSizing
UUID = jpype.JClass("java.util.UUID")

COLORS = {
    "blue": "#0072B2",
    "orange": "#E69F00",
    "green": "#009E73",
    "red": "#D55E00",
    "purple": "#CC79A7",
    "grey": "#666666",
}

plt.rcParams.update(
    {
        "figure.figsize": (9.0, 5.2),
        "axes.grid": True,
        "grid.alpha": 0.25,
        "font.size": 10,
    }
)

# %% [markdown]
# ## Thermodynamic model and basis
#
# SRK is selected because the example is a hydrocarbon-rich gas at elevated pressure.
# The composition sums to one mole fraction and uses the classic mixing rule. NeqSim
# performs the TP flash and returns real-gas density, compressibility $Z$, viscosity,
# molar mass, and heat-capacity ratio $\gamma$.
#
# The common basis is a rigid $40\ \mathrm{m^3}$ gas inventory at $50\ \mathrm{bara}$
# and $40\ ^\circ\mathrm{C}$ with a $1.5\ \mathrm{bara}$ flare-header boundary.

# %%
GAS_COMPOSITION = {
    "nitrogen": 0.010,
    "CO2": 0.025,
    "methane": 0.850,
    "ethane": 0.080,
    "propane": 0.030,
    "i-butane": 0.003,
    "n-butane": 0.002,
}

VESSEL_VOLUME_M3 = 40.0
INITIAL_PRESSURE_BARA = 50.0
INITIAL_TEMPERATURE_C = 40.0
FLARE_PRESSURE_BARA = 1.5


def make_separator_gas(pressure_bara, temperature_c):
    gas = SystemSrkEos(temperature_c + 273.15, pressure_bara)

    for component_name, mole_fraction in GAS_COMPOSITION.items():
        gas.addComponent(component_name, mole_fraction)

    gas.setMixingRule("classic")
    gas.setMultiPhaseCheck(True)
    ThermodynamicOperations(gas).TPflash()
    gas.initProperties()
    return gas


base_gas = make_separator_gas(
    INITIAL_PRESSURE_BARA,
    INITIAL_TEMPERATURE_C,
)

base_properties = pd.DataFrame(
    {
        "Property": [
            "Pressure",
            "Temperature",
            "Molar mass",
            "Density",
            "Compressibility",
            "Heat-capacity ratio",
            "Viscosity",
        ],
        "Value": [
            INITIAL_PRESSURE_BARA,
            INITIAL_TEMPERATURE_C,
            float(base_gas.getMolarMass()) * 1000.0,
            float(base_gas.getDensity("kg/m3")),
            float(base_gas.getZ()),
            float(base_gas.getGamma()),
            float(base_gas.getViscosity("kg/msec")),
        ],
        "Unit": [
            "bara",
            "°C",
            "kg/kmol",
            "kg/m³",
            "-",
            "-",
            "Pa·s",
        ],
    }
)

display(base_properties)
# Out:
#               Property      Value     Unit
# 0             Pressure  50.000000     bara
# 1          Temperature  40.000000       °C
# 2           Molar mass  19.036060  kg/kmol
# 3              Density  40.331469    kg/m³
# 4      Compressibility   0.908461        -
# 5  Heat-capacity ratio   1.445268        -
# 6            Viscosity   0.000013     Pa·s

# %% [markdown]
# The initial gas density determines the vessel inventory. The molar mass is converted
# from NeqSim's native $\mathrm{kg/mol}$ boundary to $\mathrm{kg/kmol}$ only for
# display. No percentage-valued composition is passed as a mole fraction.

# %%
initial_density_kg_m3 = float(base_gas.getDensity("kg/m3"))
initial_inventory_kg = initial_density_kg_m3 * VESSEL_VOLUME_M3
initial_gamma = float(base_gas.getGamma())
initial_z = float(base_gas.getZ())

assert abs(sum(GAS_COMPOSITION.values()) - 1.0) < 1.0e-12
assert initial_density_kg_m3 > 0.0
assert 0.7 < initial_z < 1.2
assert 1.0 < initial_gamma < 2.0

print(f"Initial vessel inventory: {initial_inventory_kg:,.3f} kg")
print(f"Initial Z-factor: {initial_z:.6f}")
print(f"Initial heat-capacity ratio: {initial_gamma:.6f}")
# Out:
# Initial vessel inventory: 1,613.259 kg
# Initial Z-factor: 0.908461
# Initial heat-capacity ratio: 1.445268

# %% [markdown]
# ## Solver workflow
#
# NeqSim supplies the fluid properties and real unit-operation behaviour. A transparent
# lumped inventory balance connects those calculations in time. This separation keeps
# the safety logic auditable: each step updates device state, calculates relief flow,
# updates inventory, then checks pressure, temperature, and event criteria.

# %%
fig, ax = plt.subplots(figsize=(10.0, 3.8))
ax.axis("off")

boxes = [
    (0.02, "SRK fluid\nTP flash"),
    (0.22, "Vessel inventory\nmass balance"),
    (0.42, "PSV or ESD\nlogic state"),
    (0.62, "Native valve and\norifice flow"),
    (0.82, "Audits\nTrend checks\nDesign-screen\nacceptance"),
]

for x_position, label in boxes:
    rectangle = plt.Rectangle(
        (x_position, 0.35),
        0.16,
        0.30,
        facecolor="#DCEAF7",
        edgecolor=COLORS["blue"],
        linewidth=1.5,
    )
    ax.add_patch(rectangle)
    ax.text(
        x_position + 0.08,
        0.50,
        label,
        ha="center",
        va="center",
        fontsize=10,
    )

for x_position in [0.18, 0.38, 0.58, 0.78]:
    ax.annotate(
        "",
        xy=(x_position + 0.04, 0.50),
        xytext=(x_position, 0.50),
        arrowprops={"arrowstyle": "->", "color": COLORS["grey"]},
    )

ax.set_xlim(0.0, 1.0)
ax.set_ylim(0.0, 1.0)
ax.set_title(
    "NeqSim safety-screening workflow: properties, devices, dynamics, and checks",
    pad=10,
)
plt.show()

# %% [markdown]
# ## Governing balances and screening assumptions
#
# For a rigid vessel, the discrete total-mass balance is
#
# $$
# m_{k+1}=m_k+\left(\dot{m}_{in}-\dot{m}_{out}\right)\Delta t
# $$
#
# The blocked-outlet example is isothermal and uses a NeqSim-derived $Z(P)$ curve.
# The isolated blowdown examples use the homogeneous ideal-gas screening relation
#
# $$
# \frac{P}{P_0}=\left(\frac{m}{m_0}\right)^\gamma
# $$
#
# and the corresponding adiabatic temperature trend. This is deliberately simpler than
# a coupled vessel-wall heat-transfer model and is labelled as a screening limit.

# %%
pressure_grid_bara = np.linspace(2.0, 75.0, 30)
z_grid = []

for pressure_bara in pressure_grid_bara:
    grid_gas = make_separator_gas(
        float(pressure_bara),
        INITIAL_TEMPERATURE_C,
    )
    z_grid.append(float(grid_gas.getZ()))

z_grid = np.asarray(z_grid)


def isothermal_pressure_from_mass(mass_kg):
    mass_ratio = mass_kg / initial_inventory_kg
    pressure_bara = INITIAL_PRESSURE_BARA * mass_ratio

    for _ in range(8):
        z_factor = np.interp(
            pressure_bara,
            pressure_grid_bara,
            z_grid,
        )
        pressure_bara = (
            INITIAL_PRESSURE_BARA
            * mass_ratio
            * z_factor
            / initial_z
        )

    return float(pressure_bara)


assert np.all(np.diff(z_grid) < 0.01)
assert abs(isothermal_pressure_from_mass(initial_inventory_kg) - 50.0) < 0.1

# %% [markdown]
# ## Native PSV hysteresis
#
# The original notebook intended a PSV opening at $55\ \mathrm{bara}$, full opening at
# $60.5\ \mathrm{bara}$, and a 7% blowdown. NeqSim's `SafetyValve.runTransient`
# implements this opening and reseat state directly.

# %%
psv_stream = Stream("PSV source", make_separator_gas(50.0, 40.0))
psv_stream.setFlowRate(5000.0, "kg/hr")
psv_stream.run()

native_psv = SafetyValve("PSV-001", psv_stream)
native_psv.setPressureSpec(55.0)
native_psv.setFullOpenPressure(60.5)
native_psv.setBlowdown(7.0)
native_psv.setOutletPressure(FLARE_PRESSURE_BARA, "bara")
native_psv.setCv(150.0)
native_psv.setCalculateSteadyState(False)

pressure_path_bara = [50.0, 55.0, 58.0, 61.0, 58.0, 54.0, 52.0, 51.0]
psv_path_rows = []

for pressure_bara in pressure_path_bara:
    psv_stream.setPressure(pressure_bara, "bara")
    psv_stream.setTemperature(40.0, "C")
    psv_stream.run()
    native_psv.runTransient(0.1, UUID.randomUUID())
    psv_path_rows.append(
        {
            "Pressure [bara]": pressure_bara,
            "Opening [%]": native_psv.getPercentValveOpening(),
            "Relief rate [kg/h]": native_psv.getOutletStream().getFlowRate(
                "kg/hr"
            ),
        }
    )

psv_path = pd.DataFrame(psv_path_rows)
display(psv_path)
# Out:
#    Pressure [bara]  Opening [%]  Relief rate [kg/h]
# 0             50.0     0.000000            0.000000
# 1             55.0     0.000000            0.000000
# 2             58.0    54.545455        27027.195193
# 3             61.0   100.000000        52197.537148
# 4             58.0    54.545455        27027.195193
# 5             54.0    74.025974        34074.672804
# 6             52.0    22.077922         9775.233324
# 7             51.0     0.000000            0.000000

# %%
fig, ax = plt.subplots()
ax.plot(
    psv_path["Pressure [bara]"],
    psv_path["Opening [%]"],
    marker="o",
    color=COLORS["blue"],
    label="Ordered pressure path",
)
ax.axvline(55.0, color=COLORS["red"], linestyle="--", label="Set pressure")
ax.axvline(51.15, color=COLORS["green"], linestyle=":", label="Reseat pressure")
ax.set_xlabel("PSV inlet pressure [bara]")
ax.set_ylabel("Valve opening [%]")
ax.set_title("Native NeqSim PSV hysteresis along an up-and-down pressure path")
ax.legend(loc="upper left")
plt.show()

assert psv_path.iloc[0]["Opening [%]"] == 0.0
assert psv_path.iloc[3]["Opening [%]"] == 100.0
assert psv_path.iloc[5]["Opening [%]"] > 0.0
assert psv_path.iloc[-1]["Opening [%]"] == 0.0

# %% [markdown]
# The descending path remains open below set pressure and closes only below the
# $51.15\ \mathrm{bara}$ reseat threshold. This is the original anti-chatter lesson,
# now demonstrated by the supported class rather than handwritten state logic.

# %% [markdown]
# ## Native gas-PSV area selection
#
# The public 3.16.0 release exposes static `ReliefValveSizing` functions. Inputs are
# strict SI: mass rate in $\mathrm{kg/s}$, absolute pressure in $\mathrm{Pa}$,
# temperature in $\mathrm{K}$, and molar mass in $\mathrm{kg/mol}$. The result includes
# the required area and the next standard API-orifice designation.

# %%
relief_gas = make_separator_gas(60.5, 40.0)
required_relief_kg_s = 5000.0 / 3600.0

psv_sizing = ReliefValveSizing.calculateRequiredArea(
    required_relief_kg_s,
    55.0e5,
    0.10,
    FLARE_PRESSURE_BARA * 1.0e5,
    313.15,
    float(relief_gas.getMolarMass()),
    float(relief_gas.getZ()),
    float(relief_gas.getGamma()),
    False,
    False,
)

psv_sizing_table = pd.DataFrame(
    {
        "Quantity": [
            "Required relief rate",
            "Required area",
            "Selected standard orifice",
            "Selected area",
            "Selected capacity",
        ],
        "Value": [
            required_relief_kg_s * 3600.0,
            psv_sizing.getRequiredArea() * 1.0e6,
            str(psv_sizing.getRecommendedOrifice()),
            psv_sizing.getSelectedArea() * 1.0e6,
            psv_sizing.getMassFlowCapacity() * 3600.0,
        ],
        "Unit": [
            "kg/h",
            "mm²",
            "-",
            "mm²",
            "kg/h",
        ],
    }
)

display(psv_sizing_table)

assert psv_sizing.getRequiredArea() > 0.0
assert psv_sizing.getSelectedArea() >= psv_sizing.getRequiredArea()
assert psv_sizing.getMassFlowCapacity() >= required_relief_kg_s
# Out:
#                     Quantity       Value  Unit
# 0       Required relief rate      5000.0  kg/h
# 1              Required area  117.401782   mm²
# 2  Selected standard orifice           E     -
# 3              Selected area   126.45136   mm²
# 4          Selected capacity      5000.0  kg/h

# %% [markdown]
# The sizing result is a preliminary selection. It does not replace certified valve
# capacity, inlet-loss checks, built-up or superimposed back pressure, reaction forces,
# noise, or vendor review.

# %% [markdown]
# ## Case 1 — blocked outlet with PSV relief
#
# At $50\ \mathrm{s}$ the normal outlet is blocked. Feed continues at
# $5000\ \mathrm{kg/h}$, raising inventory and pressure. The native PSV opening and
# flow calculation limits the pressure. At $200\ \mathrm{s}$ the process outlet
# recovers, allowing the PSV to reseat.

# %%
def simulate_blocked_outlet(duration_s=300, time_step_s=1.0):
    source = Stream("Blocked-outlet PSV source", make_separator_gas(50.0, 40.0))
    source.setFlowRate(5000.0, "kg/hr")
    source.run()

    psv = SafetyValve("Blocked-outlet PSV", source)
    psv.setPressureSpec(55.0)
    psv.setFullOpenPressure(60.5)
    psv.setBlowdown(7.0)
    psv.setOutletPressure(FLARE_PRESSURE_BARA, "bara")
    psv.setCv(150.0)
    psv.setCalculateSteadyState(False)

    feed_kg_s = 5000.0 / 3600.0
    vessel_mass_kg = initial_inventory_kg
    rows = []

    for time_s in np.arange(0.0, duration_s + time_step_s, time_step_s):
        pressure_bara = isothermal_pressure_from_mass(vessel_mass_kg)
        source.setPressure(pressure_bara, "bara")
        source.setTemperature(INITIAL_TEMPERATURE_C, "C")
        source.run()
        psv.runTransient(time_step_s, UUID.randomUUID())

        blocked = 50.0 <= time_s < 200.0
        normal_outlet_kg_s = 0.0 if blocked else feed_kg_s
        psv_rate_kg_s = max(
            0.0,
            psv.getOutletStream().getFlowRate("kg/hr") / 3600.0,
        )

        rows.append(
            {
                "Time [s]": time_s,
                "Pressure [bara]": pressure_bara,
                "PSV opening [%]": psv.getPercentValveOpening(),
                "PSV rate [kg/s]": psv_rate_kg_s,
                "Normal outlet [kg/s]": normal_outlet_kg_s,
            }
        )

        net_rate_kg_s = feed_kg_s - normal_outlet_kg_s - psv_rate_kg_s
        vessel_mass_kg = max(
            0.05 * initial_inventory_kg,
            vessel_mass_kg + net_rate_kg_s * time_step_s,
        )

    return pd.DataFrame(rows), vessel_mass_kg


blocked_case, blocked_final_mass_kg = simulate_blocked_outlet()
blocked_case_summary = {
    "maximum_pressure_bara": blocked_case["Pressure [bara]"].max(),
    "maximum_psv_rate_kg_s": blocked_case["PSV rate [kg/s]"].max(),
    "maximum_opening_percent": blocked_case["PSV opening [%]"].max(),
}

display(pd.DataFrame([blocked_case_summary]))
# Out:
#    maximum_pressure_bara  maximum_psv_rate_kg_s  maximum_opening_percent
# 0              55.483941               1.031408                 8.798936

# %%
fig, pressure_axis = plt.subplots()
flow_axis = pressure_axis.twinx()

pressure_axis.plot(
    blocked_case["Time [s]"],
    blocked_case["Pressure [bara]"],
    color=COLORS["blue"],
    label="Vessel pressure",
)
pressure_axis.axhline(
    55.0,
    color=COLORS["red"],
    linestyle="--",
    label="PSV set pressure",
)
flow_axis.plot(
    blocked_case["Time [s]"],
    blocked_case["PSV rate [kg/s]"],
    color=COLORS["orange"],
    label="PSV relief rate",
)
pressure_axis.axvspan(50.0, 200.0, color="#BBBBBB", alpha=0.18, label="Outlet blocked")
pressure_axis.set_xlabel("Time [s]")
pressure_axis.set_ylabel("Vessel pressure [bara]")
flow_axis.set_ylabel("PSV relief rate [kg/s]")
pressure_axis.set_title("Blocked outlet: native PSV response limits pressure")

handles_1, labels_1 = pressure_axis.get_legend_handles_labels()
handles_2, labels_2 = flow_axis.get_legend_handles_labels()
pressure_axis.legend(handles_1 + handles_2, labels_1 + labels_2, loc="upper left")
plt.show()

assert blocked_case["Pressure [bara]"].iloc[0] < 55.0
assert blocked_case["PSV opening [%]"].iloc[0] == 0.0
assert blocked_case_summary["maximum_pressure_bara"] < 60.5
assert blocked_case_summary["maximum_psv_rate_kg_s"] > 0.7 * 5000.0 / 3600.0

# %% [markdown]
# The PSV offsets most of the continuing inflow and keeps the finite blocked-outlet
# event below its full-open pressure. This is a dynamic screening demonstration, not
# proof that a selected commercial valve will behave identically.

# %% [markdown]
# ## Case 2 — manual ESD and controlled blowdown
#
# The original manual-push-button example is retained. `PushButton.push()` activates a
# native `BlowdownValve`, whose opening ramps from 0% to 100% over five seconds. A
# native `Orifice.calculateMassFlowRate` calculation supplies pressure-driven flow.
#
# For ratios below the sonic critical pressure ratio, effective downstream pressure is
# limited to the critical pressure. This prevents extrapolating the ISO 5167
# subcritical expression beyond its screening range.

# %%
def orifice_mass_rate_kg_s(
    pressure_bara,
    temperature_c,
    pipe_diameter_m,
    orifice_diameter_m,
):
    gas = make_separator_gas(pressure_bara, temperature_c)
    density_kg_m3 = float(gas.getDensity("kg/m3"))
    viscosity_pa_s = float(gas.getViscosity("kg/msec"))
    gamma = float(gas.getGamma())
    critical_ratio = (2.0 / (gamma + 1.0)) ** (
        gamma / (gamma - 1.0)
    )
    effective_downstream_pa = max(
        FLARE_PRESSURE_BARA * 1.0e5,
        pressure_bara * 1.0e5 * critical_ratio,
    )

    return float(
        Orifice.calculateMassFlowRate(
            pipe_diameter_m,
            orifice_diameter_m,
            pressure_bara * 1.0e5,
            effective_downstream_pa,
            density_kg_m3,
            viscosity_pa_s,
            gamma,
            "flange",
        )
    )


def simulate_manual_blowdown(orifice_diameter_m=0.05, time_step_s=5.0):
    source = Stream("ESD blowdown source", make_separator_gas(50.0, 40.0))
    source.setFlowRate(5000.0, "kg/hr")
    source.run()

    valve = BlowdownValve("BDV-001", source)
    valve.setCv(150.0)
    valve.setOutletPressure(FLARE_PRESSURE_BARA, "bara")
    valve.setOpeningTime(5.0)
    valve.setCalculateSteadyState(False)
    button = PushButton("ESD-PB-001", valve)
    button.push()

    vessel_mass_kg = initial_inventory_kg
    cumulative_mass_kg = 0.0
    safe_target_bara = min(
        0.5 * INITIAL_PRESSURE_BARA,
        7.0 + 1.01325,
    )
    rows = []

    for time_s in np.arange(0.0, 905.0, time_step_s):
        mass_ratio = vessel_mass_kg / initial_inventory_kg
        pressure_bara = INITIAL_PRESSURE_BARA * mass_ratio ** initial_gamma
        temperature_k = (INITIAL_TEMPERATURE_C + 273.15) * (
            mass_ratio ** (initial_gamma - 1.0)
        )
        temperature_c = temperature_k - 273.15

        if pressure_bara <= safe_target_bara:
            rows.append(
                {
                    "Time [s]": time_s,
                    "Pressure [bara]": pressure_bara,
                    "Temperature [°C]": temperature_c,
                    "BDV opening [%]": valve.getPercentValveOpening(),
                    "Blowdown rate [kg/s]": 0.0,
                    "Cumulative mass [kg]": cumulative_mass_kg,
                }
            )
            break

        source.setPressure(pressure_bara, "bara")
        source.setTemperature(temperature_c, "C")
        source.run()
        valve.runTransient(time_step_s, UUID.randomUUID())

        opening_fraction = valve.getPercentValveOpening() / 100.0
        full_rate_kg_s = orifice_mass_rate_kg_s(
            pressure_bara,
            temperature_c,
            0.20,
            orifice_diameter_m,
        )
        relief_rate_kg_s = full_rate_kg_s * opening_fraction

        rows.append(
            {
                "Time [s]": time_s,
                "Pressure [bara]": pressure_bara,
                "Temperature [°C]": temperature_c,
                "BDV opening [%]": valve.getPercentValveOpening(),
                "Blowdown rate [kg/s]": relief_rate_kg_s,
                "Cumulative mass [kg]": cumulative_mass_kg,
            }
        )

        mass_removed_kg = min(
            relief_rate_kg_s * time_step_s,
            vessel_mass_kg - 0.01 * initial_inventory_kg,
        )
        vessel_mass_kg -= max(0.0, mass_removed_kg)
        cumulative_mass_kg += max(0.0, mass_removed_kg)

    return pd.DataFrame(rows), button, valve


manual_blowdown, esd_button, blowdown_valve = simulate_manual_blowdown()
display(manual_blowdown.iloc[[0, -1]])
# Out:
#     Time [s]  Pressure [bara]  ...  Blowdown rate [kg/s]  Cumulative mass [kg]
# 0        0.0         50.00000  ...             14.250647              0.000000
# 32     160.0          7.90766  ...              0.000000           1162.924136
#
# [2 rows x 6 columns]

# %%
target_pressure_bara = min(
    0.5 * INITIAL_PRESSURE_BARA,
    7.0 + 1.01325,
)
target_rows = manual_blowdown[
    manual_blowdown["Pressure [bara]"] <= target_pressure_bara
]
time_to_target_s = (
    float(target_rows.iloc[0]["Time [s]"])
    if not target_rows.empty
    else np.nan
)

fig, pressure_axis = plt.subplots()
temperature_axis = pressure_axis.twinx()

pressure_axis.plot(
    manual_blowdown["Time [s]"] / 60.0,
    manual_blowdown["Pressure [bara]"],
    color=COLORS["blue"],
    label="Pressure",
)
pressure_axis.axhline(
    target_pressure_bara,
    color=COLORS["red"],
    linestyle="--",
    label="Example target pressure",
)
temperature_axis.plot(
    manual_blowdown["Time [s]"] / 60.0,
    manual_blowdown["Temperature [°C]"],
    color=COLORS["green"],
    label="Adiabatic screening temperature",
)
pressure_axis.set_xlabel("Time [min]")
pressure_axis.set_ylabel("Vessel pressure [bara]")
temperature_axis.set_ylabel("Gas temperature [°C]")
pressure_axis.set_title("Manual ESD blowdown: pressure and temperature screening")

handles_1, labels_1 = pressure_axis.get_legend_handles_labels()
handles_2, labels_2 = temperature_axis.get_legend_handles_labels()
pressure_axis.legend(handles_1 + handles_2, labels_1 + labels_2, loc="upper right")
plt.show()

print(f"Example target pressure: {target_pressure_bara:.6f} bara")
print(f"Time to target: {time_to_target_s:.3f} s")
print(
    "Minimum screening temperature: "
    f"{manual_blowdown['Temperature [°C]'].min():.3f} °C"
)

assert esd_button.isPushed()
assert blowdown_valve.getPercentValveOpening() == 100.0
assert time_to_target_s <= 900.0
assert manual_blowdown["Pressure [bara]"].is_monotonic_decreasing
# Out:
# Example target pressure: 8.013250 bara
# Time to target: 160.000 s
# Minimum screening temperature: -95.731 °C

# %% [markdown]
# The example meets the stated 15-minute screening target, but the predicted low
# temperature is a warning—not a material-qualification result. A project model needs
# wall heat transfer, external fire, liquid holdup, hydrate equilibrium, minimum design
# metal temperature, and flare-header pressure feedback.

# %% [markdown]
# ## Case 3 — pressure buildup, PSHH detection, isolation, and blowdown
#
# This preserves the integrated sequence: a normal outlet blocks at $30\ \mathrm{s}$;
# pressure rises; a $58\ \mathrm{bara}$ PSHH trip isolates feed and pushes the ESD
# button; the blowdown valve opens over five seconds.

# %%
def simulate_integrated_esd(duration_s=600, time_step_s=1.0):
    source = Stream("Integrated ESD source", make_separator_gas(50.0, 40.0))
    source.setFlowRate(8000.0, "kg/hr")
    source.run()

    valve = BlowdownValve("BDV-002", source)
    valve.setCv(150.0)
    valve.setOutletPressure(FLARE_PRESSURE_BARA, "bara")
    valve.setOpeningTime(5.0)
    valve.setCalculateSteadyState(False)
    button = PushButton("ESD-PB-002", valve)

    vessel_mass_kg = initial_inventory_kg
    trip_mass_kg = None
    trip_time_s = None
    feed_kg_s = 8000.0 / 3600.0
    rows = []

    for time_s in np.arange(0.0, duration_s + time_step_s, time_step_s):
        if trip_mass_kg is None:
            pressure_bara = isothermal_pressure_from_mass(vessel_mass_kg)
            temperature_c = INITIAL_TEMPERATURE_C
        else:
            mass_ratio = vessel_mass_kg / trip_mass_kg
            pressure_bara = 58.0 * mass_ratio ** initial_gamma
            temperature_k = (INITIAL_TEMPERATURE_C + 273.15) * (
                mass_ratio ** (initial_gamma - 1.0)
            )
            temperature_c = temperature_k - 273.15

        blocked = time_s >= 30.0

        if trip_mass_kg is None and pressure_bara >= 58.0:
            trip_mass_kg = vessel_mass_kg
            trip_time_s = time_s
            button.push()

        tripped = trip_mass_kg is not None
        inlet_kg_s = 0.0 if tripped else feed_kg_s
        normal_outlet_kg_s = 0.0 if blocked else feed_kg_s
        relief_rate_kg_s = 0.0

        if tripped and pressure_bara <= 7.0 + 1.01325:
            rows.append(
                {
                    "Time [s]": time_s,
                    "Pressure [bara]": pressure_bara,
                    "Temperature [°C]": temperature_c,
                    "Tripped": tripped,
                    "BDV opening [%]": valve.getPercentValveOpening(),
                    "Blowdown rate [kg/s]": 0.0,
                }
            )
            break

        if tripped:
            source.setPressure(pressure_bara, "bara")
            source.setTemperature(temperature_c, "C")
            source.run()
            valve.runTransient(time_step_s, UUID.randomUUID())
            opening_fraction = valve.getPercentValveOpening() / 100.0
            full_rate_kg_s = orifice_mass_rate_kg_s(
                pressure_bara,
                temperature_c,
                0.20,
                0.045,
            )
            relief_rate_kg_s = full_rate_kg_s * opening_fraction

        rows.append(
            {
                "Time [s]": time_s,
                "Pressure [bara]": pressure_bara,
                "Temperature [°C]": temperature_c,
                "Tripped": tripped,
                "BDV opening [%]": valve.getPercentValveOpening(),
                "Blowdown rate [kg/s]": relief_rate_kg_s,
            }
        )

        net_rate_kg_s = inlet_kg_s - normal_outlet_kg_s - relief_rate_kg_s
        vessel_mass_kg = max(
            0.02 * initial_inventory_kg,
            vessel_mass_kg + net_rate_kg_s * time_step_s,
        )

    return pd.DataFrame(rows), trip_time_s


integrated_esd, esd_trip_time_s = simulate_integrated_esd()
print(f"PSHH trip time: {esd_trip_time_s:.3f} s")
print(
    "Maximum pressure: "
    f"{integrated_esd['Pressure [bara]'].max():.6f} bara"
)
# Out:
# PSHH trip time: 159.000 s
# Maximum pressure: 58.045624 bara

# %%
fig, pressure_axis = plt.subplots()
opening_axis = pressure_axis.twinx()

pressure_axis.plot(
    integrated_esd["Time [s]"],
    integrated_esd["Pressure [bara]"],
    color=COLORS["blue"],
    label="Vessel pressure",
)
pressure_axis.axhline(
    58.0,
    color=COLORS["red"],
    linestyle="--",
    label="PSHH trip setpoint",
)
opening_axis.plot(
    integrated_esd["Time [s]"],
    integrated_esd["BDV opening [%]"],
    color=COLORS["orange"],
    label="BDV opening",
)
pressure_axis.axvline(
    esd_trip_time_s,
    color=COLORS["purple"],
    linestyle=":",
    label="ESD trip",
)
pressure_axis.set_xlabel("Time [s]")
pressure_axis.set_ylabel("Vessel pressure [bara]")
opening_axis.set_ylabel("Blowdown-valve opening [%]")
pressure_axis.set_title("Integrated PSHH–ESD sequence: detection, isolation, and blowdown")

handles_1, labels_1 = pressure_axis.get_legend_handles_labels()
handles_2, labels_2 = opening_axis.get_legend_handles_labels()
pressure_axis.legend(handles_1 + handles_2, labels_1 + labels_2, loc="upper right")
plt.show()

assert esd_trip_time_s > 30.0
assert integrated_esd["Pressure [bara]"].max() < 60.5
assert integrated_esd["BDV opening [%]"].max() == 100.0
assert integrated_esd.iloc[-1]["Pressure [bara]"] < 10.0

# %% [markdown]
# The PSHH trip occurs after the blockage, feed isolation prevents further accumulation,
# and the opening ramp is visible. The active ESD layer acts before the PSV full-open
# pressure, preserving the original defence-in-depth comparison.

# %% [markdown]
# ## Diameter sensitivity and practical application
#
# The final application repeats the manual blowdown with fresh NeqSim objects for each
# candidate diameter. The design variable is the orifice bore; outputs are time to the
# example target, peak flare rate, and minimum screening temperature. A larger bore is
# faster but imposes a larger flare load and more rapid cooling.

# %%
orifice_diameters_mm = [30.0, 40.0, 50.0, 60.0]
sensitivity_rows = []

for diameter_mm in orifice_diameters_mm:
    case, _, _ = simulate_manual_blowdown(
        orifice_diameter_m=diameter_mm / 1000.0,
        time_step_s=5.0,
    )
    target_case = case[case["Pressure [bara]"] <= target_pressure_bara]
    target_time_s = (
        float(target_case.iloc[0]["Time [s]"])
        if not target_case.empty
        else np.nan
    )
    sensitivity_rows.append(
        {
            "Orifice diameter [mm]": diameter_mm,
            "Time to target [s]": target_time_s,
            "Peak flow [kg/s]": case["Blowdown rate [kg/s]"].max(),
            "Minimum temperature [°C]": case["Temperature [°C]"].min(),
        }
    )

orifice_sensitivity = pd.DataFrame(sensitivity_rows)
display(orifice_sensitivity)
# Out:
#    Orifice diameter [mm]  ...  Minimum temperature [°C]
# 0                   30.0  ...                -95.228630
# 1                   40.0  ...                -96.584984
# 2                   50.0  ...                -95.731425
# 3                   60.0  ...                -96.045660
#
# [4 rows x 4 columns]

# %%
fig, time_axis = plt.subplots()
flow_axis = time_axis.twinx()

time_axis.plot(
    orifice_sensitivity["Orifice diameter [mm]"],
    orifice_sensitivity["Time to target [s]"] / 60.0,
    marker="o",
    color=COLORS["blue"],
    label="Time to target",
)
flow_axis.plot(
    orifice_sensitivity["Orifice diameter [mm]"],
    orifice_sensitivity["Peak flow [kg/s]"],
    marker="s",
    color=COLORS["orange"],
    label="Peak flare rate",
)
time_axis.axhline(
    15.0,
    color=COLORS["red"],
    linestyle="--",
    label="15-minute screen",
)
time_axis.set_xlabel("Orifice diameter [mm]")
time_axis.set_ylabel("Time to target [min]")
flow_axis.set_ylabel("Peak blowdown rate [kg/s]")
time_axis.set_title("Blowdown-orifice trade-off: response time versus flare loading")

handles_1, labels_1 = time_axis.get_legend_handles_labels()
handles_2, labels_2 = flow_axis.get_legend_handles_labels()
time_axis.legend(handles_1 + handles_2, labels_1 + labels_2, loc="upper right")
plt.show()

assert orifice_sensitivity["Time to target [s]"].is_monotonic_decreasing
assert orifice_sensitivity["Peak flow [kg/s]"].is_monotonic_increasing

# %% [markdown]
# The sensitivity is useful for screening, but the preferred diameter cannot be selected
# from depressurization time alone. Flare capacity, acoustic fatigue, reaction force,
# minimum temperature, hydrate risk, and valve/orifice vendor limits are simultaneous
# constraints.

# %% [markdown]
# ## Scenario comparison
#
# Passive PSV relief manages a continuing inflow; manual ESD removes isolated inventory;
# integrated PSHH–ESD combines detection, isolation, and blowdown. They answer different
# hazard questions and should not be ranked by one KPI.

# %%
scenario_comparison = pd.DataFrame(
    [
        {
            "Scenario": "Blocked outlet + PSV",
            "Activation": "Pressure",
            "Maximum pressure [bara]": blocked_case["Pressure [bara]"].max(),
            "Peak relief [kg/s]": blocked_case["PSV rate [kg/s]"].max(),
            "Final pressure [bara]": blocked_case["Pressure [bara]"].iloc[-1],
        },
        {
            "Scenario": "Manual ESD blowdown",
            "Activation": "Push button",
            "Maximum pressure [bara]": manual_blowdown["Pressure [bara]"].max(),
            "Peak relief [kg/s]": manual_blowdown[
                "Blowdown rate [kg/s]"
            ].max(),
            "Final pressure [bara]": manual_blowdown["Pressure [bara]"].iloc[-1],
        },
        {
            "Scenario": "PSHH + ESD",
            "Activation": "58 bara PSHH",
            "Maximum pressure [bara]": integrated_esd["Pressure [bara]"].max(),
            "Peak relief [kg/s]": integrated_esd[
                "Blowdown rate [kg/s]"
            ].max(),
            "Final pressure [bara]": integrated_esd["Pressure [bara]"].iloc[-1],
        },
    ]
)

display(scenario_comparison)
# Out:
#                Scenario  ... Final pressure [bara]
# 0  Blocked outlet + PSV  ...             55.001081
# 1   Manual ESD blowdown  ...              7.907660
# 2            PSHH + ESD  ...              7.987154
#
# [3 rows x 5 columns]

# %% [markdown]
# ## Verification and acceptance checks
#
# Checks cover finite values, mass response, native state logic, relief sizing,
# pressure limits, expected sensitivity trends, and deterministic repeatability. They
# are model checks—not certification of a protection layer or SIL claim.

# %%
repeat_blowdown, _, _ = simulate_manual_blowdown()

engineering_checks = [
    np.isfinite(base_properties["Value"]).all(),
    abs(sum(GAS_COMPOSITION.values()) - 1.0) < 1.0e-12,
    initial_inventory_kg > 0.0,
    0.7 < initial_z < 1.2,
    1.0 < initial_gamma < 2.0,
    psv_path.iloc[0]["Opening [%]"] == 0.0,
    psv_path.iloc[3]["Opening [%]"] == 100.0,
    psv_path.iloc[5]["Opening [%]"] > 0.0,
    psv_path.iloc[-1]["Opening [%]"] == 0.0,
    psv_sizing.getRequiredArea() > 0.0,
    psv_sizing.getSelectedArea() >= psv_sizing.getRequiredArea(),
    psv_sizing.getMassFlowCapacity() >= required_relief_kg_s,
    blocked_case["Pressure [bara]"].iloc[0] < 55.0,
    blocked_case["PSV opening [%]"].iloc[0] == 0.0,
    blocked_case["Pressure [bara]"].max() < 60.5,
    blocked_case["PSV rate [kg/s]"].max() > 0.7 * 5000.0 / 3600.0,
    esd_button.isPushed(),
    blowdown_valve.getPercentValveOpening() == 100.0,
    manual_blowdown["Pressure [bara]"].is_monotonic_decreasing,
    time_to_target_s <= 900.0,
    esd_trip_time_s > 30.0,
    integrated_esd["Pressure [bara]"].max() < 60.5,
    integrated_esd["BDV opening [%]"].max() == 100.0,
    integrated_esd.iloc[-1]["Pressure [bara]"] < 10.0,
    orifice_sensitivity["Time to target [s]"].is_monotonic_decreasing,
    orifice_sensitivity["Peak flow [kg/s]"].is_monotonic_increasing,
    np.allclose(
        manual_blowdown["Pressure [bara]"],
        repeat_blowdown["Pressure [bara]"],
        rtol=0.0,
        atol=1.0e-10,
    ),
]

assert all(engineering_checks)

validation_summary = {
    "checks_passed": len(engineering_checks),
    "maximum_blocked_outlet_pressure_bara": float(
        blocked_case["Pressure [bara]"].max()
    ),
    "manual_esd_time_to_target_s": time_to_target_s,
    "manual_esd_minimum_temperature_c": float(
        manual_blowdown["Temperature [°C]"].min()
    ),
    "integrated_esd_trip_time_s": esd_trip_time_s,
    "selected_psv_orifice": str(psv_sizing.getRecommendedOrifice()),
    "required_psv_area_mm2": float(
        psv_sizing.getRequiredArea() * 1.0e6
    ),
}

print(
    f"All {len(engineering_checks)} process-safety engineering checks passed."
)
print(json.dumps(validation_summary, indent=2))
# Out:
# All 27 process-safety engineering checks passed.
# {
#   "checks_passed": 27,
#   "maximum_blocked_outlet_pressure_bara": 55.483941459252826,
#   "manual_esd_time_to_target_s": 160.0,
#   "manual_esd_minimum_temperature_c": -95.73142478357829,
#   "integrated_esd_trip_time_s": 159.0,
#   "selected_psv_orifice": "E",
#   "required_psv_area_mm2": 117.40178220329331
# }

# %% [markdown]
# ## Troubleshooting
#
# - A Java UUID is required for two-argument `runTransient`; use
#   `jpype.JClass("java.util.UUID").randomUUID()`.
# - Convert NeqSim Java numeric return values to Python `float` before passing them to
#   primitive-only static Java functions.
# - `getMolarMass()` returns $\mathrm{kg/mol}$.
# - Use absolute pressure for relief calculations.
# - Rebuild each sensitivity case with fresh objects; device state is intentionally
#   history-dependent.
# - If a dynamic result changes with time step, reduce the step and document
#   convergence before using the result.

# %% [markdown]
# ## Limitations and applicability
#
# The vessel is gas-only, well mixed, and rigid. The blocked-outlet case is isothermal;
# the blowdown path is homogeneous and adiabatic with constant initial $\gamma$. The
# flare header is a fixed boundary. There is no vessel wall, fire heat input, liquid
# holdup, two-phase discharge, line packing, acoustic response, detailed valve
# characteristic, or material model.
#
# Use this workbook for API orientation, training, early screening, and regression
# testing. Do not use it as the sole basis for relief-device procurement, flare design,
# SIL verification, or minimum-temperature acceptance.

# %% [markdown]
# ## Summary and further exercises
#
# The repaired workflow preserves the original passive PSV, manual ESD, integrated
# PSHH–ESD, orifice, comparison, sizing, hysteresis, and 15-minute examples. It now
# executes with supported NeqSim APIs, explicit units, deterministic state, retained
# figures, and focused checks.
#
# **Exercises**
#
# 1. Add a variable flare-header pressure and quantify capacity loss.
# 2. Replace the constant-$\gamma$ blowdown path with a vessel energy balance.
# 3. Add fire heat input and compare PSV and depressurization duties.
# 4. Add aqueous liquid and screen hydrate formation during cooling.
# 5. Couple two blowdown valves to a shared flare-header capacity constraint.

# %% [markdown]
# ## Authoritative references
#
# - [NeqSim ESD blowdown implementation](https://equinor.github.io/neqsim/safety/ESD_BLOWDOWN_SYSTEM.html)
# - [NeqSim PSV dynamic sizing example](https://equinor.github.io/neqsim/safety/psv_dynamic_sizing_example.html)
# - [NeqSim relief-valve sizing API](https://equinor.github.io/neqsim/safety/relief_valve_sizing_api.html)
# - [NeqSim valve documentation](https://equinor.github.io/neqsim/process/equipment/valves.html)
# - API Standard 520, Parts I and II.
# - API Standard 521.
# - API Standard 526.
# - ISO 5167.
# - IEC 61511.
#
# Always verify the current licensed standard editions and project specifications.
