# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/process/model_predictive_controller_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Model predictive control with NeqSim
#
# **Audience.** Process engineers, control engineers, graduate students, and NeqSim users who
# already understand steady-state process simulation and want a reproducible introduction to
# model predictive control (MPC).
#
# **Prerequisites.** Basic Python, material and energy balances, first-order dynamic models, and
# the meaning of manipulated, controlled, and measured variables. No Java coding is required.
#
# **Learning objectives.** After completing this notebook you can:
#
# 1. create an SRK natural-gas fluid, stream, heater, and temperature transmitter in NeqSim;
# 2. translate a NeqSim heater study into a first-order control model;
# 3. configure the native Java `ModelPredictiveController` through Python;
# 4. simulate constrained closed-loop temperature control and inspect its prediction horizon;
# 5. use moving-horizon estimation (MHE) and recognize when excitation is insufficient;
# 6. compare tuning scenarios and verify thermodynamic, dynamic, and controller results.
#
# All reported engineering quantities use SI or accepted SI-derived units. The case is synthetic
# and contains no proprietary plant data.

# %%
import importlib.metadata
import subprocess
import sys


try:
    installed_version = importlib.metadata.version("neqsim")
except importlib.metadata.PackageNotFoundError:
    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--quiet",
            "neqsim",
        ]
    )
    installed_version = importlib.metadata.version("neqsim")

print(f"NeqSim version: {installed_version}")
# Out:
# NeqSim version: 3.16.0

# %% [markdown]
# ## 1. Imports and reproducibility
#
# The Python package starts NeqSim's Java Virtual Machine through JPype. We use the supported
# Python helper functions for thermodynamics and unit operations, and access the native Java MPC
# and transmitter classes through `jneqsim`. A fixed synthetic case and deterministic controller
# settings make every run reproducible.

# %%
import math

import jpype
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from neqsim import jneqsim
from neqsim.process import clearProcess, heater, runProcess, stream
from neqsim.thermo import fluid


plt.style.use("seaborn-v0_8-whitegrid")
UUID = jpype.JClass("java.util.UUID")

print(f"Python version: {sys.version.split()[0]}")
print(f"Java VM running: {jpype.isJVMStarted()}")
# Out:
# Python version: 3.12.13
# Java VM running: True

# %% [markdown]
# ## 2. Thermodynamic basis and fluid model
#
# NeqSim represents the process fluid with a thermodynamic system. We select the Soave–Redlich–
# Kwong (SRK) equation of state because this dry, hydrocarbon-rich gas remains single phase over
# the 25–45 °C and 50 bara range. The classic mixing rule is adequate for this teaching case.
#
# The cubic equation of state is written as
#
# $$
# P = \frac{RT}{v-b} - \frac{a\alpha}{v(v+b)}
# $$
#
# where $P$ is pressure in Pa, $T$ is temperature in K, $v$ is molar volume in m³/mol, $R$ is the
# gas constant, and $a$, $b$, and $\alpha$ are component and mixture parameters. Water-rich,
# electrolyte, strongly associating, or near-critical cases require a more suitable model and
# additional validation.

# %%
clearProcess()

feed_fluid = fluid("srk", temperature=298.15, pressure=50.0)
feed_composition = {
    "methane": 0.880,
    "ethane": 0.070,
    "propane": 0.025,
    "n-butane": 0.010,
    "nitrogen": 0.010,
    "CO2": 0.005,
}

for component_name, mole_fraction in feed_composition.items():
    feed_fluid.addComponent(component_name, mole_fraction)

feed_fluid.setMixingRule("classic")
feed_fluid.init(3)

composition_sum = sum(feed_composition.values())
assert math.isclose(composition_sum, 1.0, rel_tol=0.0, abs_tol=1.0e-12)
print(f"Specified composition sum: {composition_sum:.6f} mol/mol")
# Out:
# Specified composition sum: 1.000000 mol/mol

# %% [markdown]
# ## 3. Streams, unit operations, and solver workflow
#
# A NeqSim `Stream` carries composition, flow, pressure, temperature, phase state, enthalpy, and
# physical properties. A `Heater` consumes the inlet stream and calculates an outlet state and
# duty. `runProcess()` executes the registered units in flowsheet order. The controller is not a
# replacement for the process model: it uses measurements and a reduced dynamic model to choose
# a manipulated signal.
#
# The workflow is therefore:
#
# **fluid → feed stream → heater → measured outlet → controller → manipulated heater signal**.

# %%
feed_stream = stream("MPC feed gas", feed_fluid)
feed_stream.setFlowRate(10_000.0, "kg/hr")
feed_stream.setTemperature(25.0, "C")
feed_stream.setPressure(50.0, "bara")

gas_heater = heater("MPC gas heater", feed_stream)
gas_heater.setOutTemperature(40.0, "C")
runProcess()

outlet_stream = gas_heater.getOutletStream()
feed_density = feed_stream.getFluid().getDensity("kg/m3")
outlet_temperature = outlet_stream.getTemperature("C")
heater_duty = gas_heater.getDuty("kW")

baseline = pd.Series(
    {
        "Feed flow [kg/h]": feed_stream.getFlowRate("kg/hr"),
        "Feed pressure [bara]": feed_stream.getPressure("bara"),
        "Feed temperature [°C]": feed_stream.getTemperature("C"),
        "Feed density [kg/m³]": feed_density,
        "Outlet temperature [°C]": outlet_temperature,
        "Heater duty [kW]": heater_duty,
    },
    name="value",
)
baseline.to_frame()
# Out:
#                                 value
# Feed flow [kg/h]         10000.000000
# Feed pressure [bara]        50.000000
# Feed temperature [°C]       25.000000
# Feed density [kg/m³]        41.757471
# Outlet temperature [°C]     40.000000
# Heater duty [kW]           104.204587

# %% [markdown]
# ## 4. Heater energy balance
#
# At steady state, with negligible kinetic and potential energy changes, the heater duty is
#
# $$
# \dot Q = \dot m\left(h_{out}-h_{in}\right)
# $$
#
# where $\dot Q$ is heat duty in kW, $\dot m$ is mass flow in kg/s, and $h$ is specific enthalpy in
# kJ/kg. NeqSim evaluates enthalpy from the selected equation of state and phase state. We sweep
# the outlet temperature instead of assuming a constant heat capacity.

# %%
temperature_targets_c = np.append(np.arange(28.0, 46.0, 2.0), 45.0)
heater_records = []

for temperature_c in temperature_targets_c:
    gas_heater.setOutTemperature(float(temperature_c), "C")
    runProcess()
    heater_records.append(
        {
            "outlet_temperature_C": temperature_c,
            "heater_duty_kW": gas_heater.getDuty("kW"),
            "outlet_density_kg_m3": (
                gas_heater.getOutletStream().getFluid().getDensity("kg/m3")
            ),
        }
    )

heater_curve = pd.DataFrame(heater_records)
heater_curve
# Out:
#    outlet_temperature_C  heater_duty_kW  outlet_density_kg_m3
# 0                  28.0       20.927822             41.134167
# 1                  30.0       34.850884             40.731677
# 2                  32.0       48.753653             40.339098
# 3                  34.0       62.638355             39.956008
# 4                  36.0       76.507096             39.582014
# 5                  38.0       90.361875             39.216745
# 6                  40.0      104.204587             38.859850
# 7                  42.0      118.037035             38.511002
# 8                  44.0      131.860935             38.169890
# 9                  45.0      138.770193             38.002142

# %% [markdown]
# ## 5. Reduced dynamic model
#
# MPC normally uses a lower-order model than the rigorous thermodynamic flowsheet. Here the
# controlled variable $y$ is outlet temperature in °C and the manipulated variable $u$ is heater
# command in percent. A first-order model is
#
# $$
# \tau\frac{dy}{dt} = y_b + K u - y
# $$
#
# where $\tau$ is the time constant in s, $K$ is the steady-state gain in °C/%, and $y_b$ is the
# zero-command temperature in °C. Forward Euler integration gives
#
# $$
# y_{k+1}=y_k+\frac{\Delta t}{\tau}\left(y_b+K u_k-y_k\right)
# $$
#
# The model is valid only near the operating region used to obtain $K$ and $\tau$. Transport delay,
# valve dynamics, sensor filtering, phase change, and heat loss are omitted.

# %%
full_scale_temperature_c = 45.0
full_scale_duty_kW = float(
    heater_curve.loc[
        heater_curve["outlet_temperature_C"] == full_scale_temperature_c,
        "heater_duty_kW",
    ].iloc[0]
)

temperature_bias_c = 25.0
process_gain_c_per_pct = (
    full_scale_temperature_c - temperature_bias_c
) / 100.0
process_time_constant_s = 45.0
sample_time_s = 1.0

reconstructed_full_scale_c = (
    temperature_bias_c + process_gain_c_per_pct * 100.0
)
assert math.isclose(
    reconstructed_full_scale_c,
    full_scale_temperature_c,
    rel_tol=0.0,
    abs_tol=1.0e-12,
)

print(f"Full-scale thermodynamic duty: {full_scale_duty_kW:.3f} kW")
print(f"Reduced-model gain: {process_gain_c_per_pct:.3f} °C/%")
print(f"Assumed time constant: {process_time_constant_s:.1f} s")
# Out:
# Full-scale thermodynamic duty: 138.770 kW
# Reduced-model gain: 0.200 °C/%
# Assumed time constant: 45.0 s

# %% [markdown]
# ## 6. Thermodynamic linearity check
#
# The command-to-temperature mapping assumes that heater duty is approximately proportional to
# temperature rise. We compare the rigorous NeqSim duty curve with a line through the zero-duty
# state and full-scale point. A small residual supports local linearization; it does not prove that
# the model is valid outside the tested range.

# %%
temperature_rise_c = heater_curve["outlet_temperature_C"] - temperature_bias_c
linear_duty_kW = full_scale_duty_kW * temperature_rise_c / 20.0
duty_residual_kW = heater_curve["heater_duty_kW"] - linear_duty_kW

maximum_relative_duty_residual = (
    duty_residual_kW.abs().max() / full_scale_duty_kW
)

fig, axes = plt.subplots(1, 2, figsize=(11, 4))
axes[0].plot(
    heater_curve["outlet_temperature_C"],
    heater_curve["heater_duty_kW"],
    "o-",
    label="NeqSim SRK",
)
axes[0].plot(
    heater_curve["outlet_temperature_C"],
    linear_duty_kW,
    "--",
    label="local linear model",
)
axes[0].set_xlabel("Outlet temperature [°C]")
axes[0].set_ylabel("Heater duty [kW]")
axes[0].legend()

axes[1].plot(
    heater_curve["outlet_temperature_C"],
    duty_residual_kW,
    "o-",
)
axes[1].axhline(0.0, color="black", linewidth=0.8)
axes[1].set_xlabel("Outlet temperature [°C]")
axes[1].set_ylabel("Duty residual [kW]")
fig.tight_layout()

print(
    "Maximum duty linearization residual: "
    f"{100.0 * maximum_relative_duty_residual:.3f}% of full scale"
)
# Out:
# Maximum duty linearization residual: 0.138% of full scale
# <Figure 1>

# %% [markdown]
# ## 7. Native NeqSim controller and measurement
#
# `TemperatureTransmitter` reads the thermodynamic stream in °C. The native Java
# `ModelPredictiveController` is configured directly through Python. The prediction horizon is
# dimensionless in samples, while gain, time constant, bias, limits, and set point retain the
# units declared for this loop.
#
# The controller minimizes a finite-horizon quadratic objective of the form
#
# $$
# J = \sum_{i=1}^{N_p}\left[w_y(r-y_i)^2 + w_{\Delta u}(\Delta u_i)^2 + w_p(u_i-u_p)^2\right]
# $$
#
# where $N_p$ is the prediction horizon, $r$ is the set point, and the three weights penalize
# tracking error, moves, and departure from a preferred command.

# %%
temperature_transmitter = (
    jneqsim.process.measurementdevice.TemperatureTransmitter(outlet_stream)
)

controller_class = jneqsim.process.controllerdevice.ModelPredictiveController
controller_method_names = {
    method.getName() for method in controller_class.class_.getMethods()
}
required_methods = {
    "setTransmitter",
    "setProcessModel",
    "setPredictionHorizon",
    "setWeights",
    "setOutputLimits",
    "runTransient",
}

assert required_methods.issubset(controller_method_names)
print("Verified native MPC API methods:")
print(sorted(required_methods))
# Out:
# Verified native MPC API methods:
# ['runTransient', 'setOutputLimits', 'setPredictionHorizon', 'setProcessModel', 'setTransmitter', 'setWeights']

# %% [markdown]
# ## 8. Closed-loop simulation helper
#
# For each sample, the helper updates the measured NeqSim stream, executes the Java MPC, clips the
# command to physical bounds, and advances the first-order plant. The thermodynamic state supplies
# the measurement context; the reduced model supplies the dynamics. This separation is common in
# online optimization, but a plant deployment must replace the synthetic model with validated
# equipment dynamics and actual signal interfaces.

# %%
def configure_mpc(
    name,
    setpoint_c,
    prediction_horizon,
    move_weight,
    enable_mhe=False,
):
    controller = controller_class(name)
    controller.setTransmitter(temperature_transmitter)
    controller.setUnit("C")
    controller.setControllerSetPoint(float(setpoint_c))
    controller.setProcessModel(
        process_gain_c_per_pct,
        process_time_constant_s,
    )
    controller.setProcessBias(temperature_bias_c)
    controller.setPredictionHorizon(int(prediction_horizon))
    controller.setWeights(1.0, float(move_weight), 0.0)
    controller.setOutputLimits(0.0, 100.0)

    if enable_mhe:
        controller.enableMovingHorizonEstimation(40)

    return controller


def run_closed_loop(
    name,
    setpoint_c=40.0,
    prediction_horizon=20,
    move_weight=0.001,
    duration_s=300,
    true_gain=process_gain_c_per_pct,
    true_time_constant_s=process_time_constant_s,
    true_bias_c=temperature_bias_c,
    enable_mhe=False,
):
    controller = configure_mpc(
        name,
        setpoint_c,
        prediction_horizon,
        move_weight,
        enable_mhe,
    )
    measured_temperature_c = float(true_bias_c)
    command_pct = 0.0
    records = []

    for time_s in range(int(duration_s)):
        sensor_fluid = outlet_stream.getFluid()
        sensor_fluid.setTemperature(measured_temperature_c, "C")
        sensor_fluid.init(2)

        controller.runTransient(
            command_pct,
            sample_time_s,
            UUID.randomUUID(),
        )
        command_pct = float(controller.getResponse())
        steady_temperature_c = true_bias_c + true_gain * command_pct
        temperature_change_c = (
            sample_time_s
            / true_time_constant_s
            * (steady_temperature_c - measured_temperature_c)
        )
        measured_temperature_c += temperature_change_c

        records.append(
            {
                "time_s": float(time_s + 1),
                "temperature_C": measured_temperature_c,
                "setpoint_C": float(setpoint_c),
                "heater_command_pct": command_pct,
            }
        )

    return pd.DataFrame(records), controller

# %% [markdown]
# ## 9. Baseline closed-loop case
#
# The baseline targets 40 °C from a 25 °C initial condition. With $K=0.20$ °C/% the ideal
# steady-state command is 75%. The 0–100% output limits mean that the largest modeled steady-state
# temperature is 45 °C. The move penalty is deliberately small so tracking is prioritized without
# producing an abrupt full-scale command.

# %%
baseline_history, baseline_controller = run_closed_loop(
    name="baseline MPC",
    setpoint_c=40.0,
    prediction_horizon=20,
    move_weight=0.001,
    duration_s=300,
)

baseline_final_temperature_c = baseline_history["temperature_C"].iloc[-1]
baseline_final_command_pct = baseline_history["heater_command_pct"].iloc[-1]
baseline_tracking_error_c = (
    baseline_final_temperature_c
    - baseline_history["setpoint_C"].iloc[-1]
)

pd.Series(
    {
        "Final temperature [°C]": baseline_final_temperature_c,
        "Final command [%]": baseline_final_command_pct,
        "Final tracking error [°C]": baseline_tracking_error_c,
    },
    name="baseline result",
).to_frame()
# Out:
#                            baseline result
# Final temperature [°C]           39.907564
# Final command [%]                74.537820
# Final tracking error [°C]        -0.092436

# %% [markdown]
# ## 10. Response interpretation
#
# The controlled temperature should approach the set point monotonically for this simplified
# first-order plant. The command must remain inside its physical limits. Real loops can show delay,
# noise, nonlinear valve characteristics, heat-exchanger inventory, and disturbances; those effects
# should be included before using the tuning for design or operation.

# %%
fig, axes = plt.subplots(2, 1, figsize=(10, 7), sharex=True)
axes[0].plot(
    baseline_history["time_s"],
    baseline_history["temperature_C"],
    label="measured outlet",
)
axes[0].plot(
    baseline_history["time_s"],
    baseline_history["setpoint_C"],
    "--",
    label="set point",
)
axes[0].set_ylabel("Temperature [°C]")
axes[0].legend()

axes[1].plot(
    baseline_history["time_s"],
    baseline_history["heater_command_pct"],
    color="tab:orange",
)
axes[1].set_xlabel("Time [s]")
axes[1].set_ylabel("Heater command [%]")
axes[1].set_ylim(-2.0, 102.0)
fig.tight_layout()
# Out:
# <Figure 1>

# %% [markdown]
# ## 11. Prediction horizon inspection
#
# The controller exposes its predicted trajectory. The values are predictions made by the internal
# reduced model, not extra rigorous NeqSim flashes. We inspect a ten-sample horizon and check that
# the returned temperatures are finite and physically plausible for the configured bounds.

# %%
prediction_samples = 10
predicted_temperature_c = np.asarray(
    baseline_controller.getPredictedTrajectory(
        prediction_samples,
        sample_time_s,
    ),
    dtype=float,
)
prediction_table = pd.DataFrame(
    {
        "prediction_step": np.arange(1, prediction_samples + 1),
        "predicted_temperature_C": predicted_temperature_c,
    }
)

assert len(prediction_table) == prediction_samples
assert np.isfinite(predicted_temperature_c).all()
prediction_table
# Out:
#    prediction_step  predicted_temperature_C
# 0                1                39.907564
# 1                2                39.907564
# 2                3                39.907564
# 3                4                39.907564
# 4                5                39.907564
# 5                6                39.907564
# 6                7                39.907564
# 7                8                39.907564
# 8                9                39.907564
# 9               10                39.907564

# %% [markdown]
# ## 12. Moving-horizon estimation
#
# MHE estimates $K$, $\tau$, and $y_b$ from a rolling data window. For the discrete model, a linear
# regression can identify coefficients in
#
# $$
# y_{k+1}=A y_k+B u_k+D
# $$
#
# and recover $\tau=\Delta t/(1-A)$, $K=B/(1-A)$, and $y_b=D/(1-A)$. Parameter estimation requires
# excitation: nearly constant temperature and command make the regression ill-conditioned. We use
# an intentionally conservative controller during the initial transient and inspect the estimate
# before the loop loses excitation.

# %%
identification_history, identification_controller = run_closed_loop(
    name="MHE identification MPC",
    setpoint_c=40.0,
    prediction_horizon=20,
    move_weight=0.1,
    duration_s=120,
    enable_mhe=True,
)

mhe_estimate = identification_controller.getLastMovingHorizonEstimate()
assert mhe_estimate is not None

mhe_results = pd.Series(
    {
        "Samples in window [-]": mhe_estimate.getSampleCount(),
        "Estimated gain [°C/%]": mhe_estimate.getProcessGain(),
        "True gain [°C/%]": process_gain_c_per_pct,
        "Estimated time constant [s]": mhe_estimate.getTimeConstant(),
        "True time constant [s]": process_time_constant_s,
        "Estimated bias [°C]": mhe_estimate.getProcessBias(),
        "True bias [°C]": temperature_bias_c,
        "Mean squared error [°C²]": mhe_estimate.getMeanSquaredError(),
    },
    name="MHE result",
)
mhe_results.to_frame()
# Out:
#                                MHE result
# Samples in window [-]        4.000000e+01
# Estimated gain [°C/%]        2.000174e-01
# True gain [°C/%]             2.000000e-01
# Estimated time constant [s]  4.500373e+01
# True time constant [s]       4.500000e+01
# Estimated bias [°C]          2.499920e+01
# True bias [°C]               2.500000e+01
# Mean squared error [°C²]     2.077615e-14

# %% [markdown]
# ## 13. Tuning sensitivity
#
# A longer horizon anticipates farther ahead; a larger move weight suppresses changes in command.
# Neither choice is universally best. We compare deterministic cases using integral absolute error
# (IAE) in °C·s and total command movement in percentage points. These metrics describe this model
# only and are not acceptance limits for an industrial loop.

# %%
tuning_cases = [
    (5, 0.001),
    (20, 0.001),
    (40, 0.001),
    (20, 0.000),
    (20, 0.010),
]
tuning_records = []

for horizon, move_weight in tuning_cases:
    case_history, _ = run_closed_loop(
        name=f"MPC h{horizon} w{move_weight}",
        prediction_horizon=horizon,
        move_weight=move_weight,
        duration_s=300,
    )
    absolute_error_c = (
        case_history["setpoint_C"] - case_history["temperature_C"]
    ).abs()
    command_movement_pct = (
        case_history["heater_command_pct"].diff().abs().fillna(0.0)
    )
    tuning_records.append(
        {
            "horizon_samples": horizon,
            "move_weight": move_weight,
            "IAE_C_s": absolute_error_c.sum() * sample_time_s,
            "total_command_movement_pct": command_movement_pct.sum(),
            "final_error_C": (
                case_history["temperature_C"].iloc[-1] - 40.0
            ),
        }
    )

tuning_results = pd.DataFrame(tuning_records)
tuning_results
# Out:
#    horizon_samples  move_weight  ...  total_command_movement_pct  final_error_C
# 0                5        0.001  ...                   30.432344  -1.086469e+00
# 1               20        0.001  ...                   25.462180  -9.243596e-02
# 2               40        0.001  ...                   25.135668  -2.714058e-02
# 3               20        0.000  ...                   25.000000  -1.621672e-10
# 4               20        0.010  ...                   29.378935  -8.757871e-01
#
# [5 rows x 5 columns]

# %% [markdown]
# ## 14. Output constraints and an infeasible target
#
# At 100% command, the reduced model can reach only 45 °C. A 48 °C request is infeasible. A sound
# simulation must reveal saturation rather than imply that the set point was achieved. In a real
# plant this result would trigger constraint management, operator guidance, or a supervisory
# optimizer—not removal of the equipment limit.

# %%
infeasible_history, _ = run_closed_loop(
    name="constrained MPC",
    setpoint_c=48.0,
    prediction_horizon=20,
    move_weight=0.001,
    duration_s=400,
)

maximum_reachable_temperature_c = (
    temperature_bias_c + process_gain_c_per_pct * 100.0
)
infeasible_final_temperature_c = (
    infeasible_history["temperature_C"].iloc[-1]
)
infeasible_final_command_pct = (
    infeasible_history["heater_command_pct"].iloc[-1]
)

pd.Series(
    {
        "Requested set point [°C]": 48.0,
        "Maximum modeled temperature [°C]": (
            maximum_reachable_temperature_c
        ),
        "Final temperature [°C]": infeasible_final_temperature_c,
        "Final command [%]": infeasible_final_command_pct,
    },
    name="constraint result",
).to_frame()
# Out:
#                                   constraint result
# Requested set point [°C]                  48.000000
# Maximum modeled temperature [°C]          45.000000
# Final temperature [°C]                    44.997505
# Final command [%]                        100.000000

# %% [markdown]
# ## 15. Command-to-duty interpretation
#
# The controller output is dimensionless percent, while equipment engineers need heat duty. For
# this locally linear case, the estimated duty is
#
# $$
# \dot Q_k = \frac{u_k}{100}\dot Q_{FS}
# $$
#
# where $\dot Q_{FS}$ is the rigorous NeqSim full-scale duty in kW. This mapping is an engineering
# interface assumption. An installed valve, electrical heater, or fired heater needs its own
# actuator characteristic, efficiency, and dynamic limits.

# %%
baseline_history["estimated_heater_duty_kW"] = (
    baseline_history["heater_command_pct"]
    / 100.0
    * full_scale_duty_kW
)

final_duty_kW = baseline_history["estimated_heater_duty_kW"].iloc[-1]
expected_steady_duty_kW = (
    (40.0 - temperature_bias_c)
    / (full_scale_temperature_c - temperature_bias_c)
    * full_scale_duty_kW
)
duty_difference_kW = final_duty_kW - expected_steady_duty_kW

pd.Series(
    {
        "Final interpreted duty [kW]": final_duty_kW,
        "Expected steady duty [kW]": expected_steady_duty_kW,
        "Duty difference [kW]": duty_difference_kW,
    },
    name="duty interpretation",
).to_frame()
# Out:
#                              duty interpretation
# Final interpreted duty [kW]           103.436277
# Expected steady duty [kW]             104.077645
# Duty difference [kW]                   -0.641368

# %% [markdown]
# ## 16. Verification and acceptance checks
#
# The assertions below check composition and phase consistency, positive equipment duty, local
# linearity, controller limits, baseline tracking, MHE accuracy during an excited transient,
# scenario completeness, and the limiting behavior of an infeasible target. They are deliberately
# independent of notebook display formatting.

# %%
assert feed_stream.getFluid().getNumberOfPhases() == 1
assert feed_density > 0.0
assert heater_duty > 0.0
assert maximum_relative_duty_residual < 0.01

assert baseline_history["heater_command_pct"].between(0.0, 100.0).all()
assert abs(baseline_tracking_error_c) < 0.25
assert abs(baseline_final_command_pct - 75.0) < 1.5

assert abs(mhe_estimate.getProcessGain() - process_gain_c_per_pct) < 0.04
assert abs(mhe_estimate.getTimeConstant() - process_time_constant_s) < 8.0
assert abs(mhe_estimate.getProcessBias() - temperature_bias_c) < 3.0
assert mhe_estimate.getMeanSquaredError() < 1.0e-6

assert len(tuning_results) == len(tuning_cases)
assert np.isfinite(tuning_results.select_dtypes(include=[float, int])).all().all()
assert math.isclose(infeasible_final_command_pct, 100.0, abs_tol=0.5)
assert abs(
    infeasible_final_temperature_c - maximum_reachable_temperature_c
) < 0.25

print("All 15 engineering verification checks passed.")
# Out:
# All 15 engineering verification checks passed.

# %% [markdown]
# ## 17. Troubleshooting and validity limits
#
# - **Java VM or import error:** run the installation cell once in a fresh Colab runtime, then run
#   cells from top to bottom. Do not restart the VM after importing NeqSim.
# - **Different results:** verify NeqSim 3.16.0, one-second sampling, SRK, classic mixing, and the
#   exact composition and flow rate used here.
# - **MHE parameters drift at steady state:** the data are insufficiently excited. Add safe set-point
#   steps or a designed test and inspect parameter covariance before trusting estimates.
# - **Controller saturates:** check whether the target is reachable from bias, gain, and limits.
# - **Multiphase outlet:** revisit the thermodynamic model, sensor meaning, and reduced dynamics;
#   this single-phase first-order example is no longer applicable.
#
# This notebook excludes dead time, disturbances, measurement noise, equipment inventory, rate
# limits, safety interlocks, actuator failure, and plant-model mismatch beyond the demonstrated
# linearization. MPC commissioning requires independent process-safety review and site procedures.

# %%
validation_summary = pd.DataFrame(
    [
        {
            "category": "thermodynamics",
            "result": "pass",
            "evidence": (
                f"single phase, duty residual "
                f"{100.0 * maximum_relative_duty_residual:.3f}%"
            ),
        },
        {
            "category": "closed-loop tracking",
            "result": "pass",
            "evidence": f"final error {baseline_tracking_error_c:.3f} °C",
        },
        {
            "category": "moving-horizon estimation",
            "result": "pass",
            "evidence": (
                f"K={mhe_estimate.getProcessGain():.3f} °C/%, "
                f"tau={mhe_estimate.getTimeConstant():.2f} s"
            ),
        },
        {
            "category": "constraint limiting case",
            "result": "pass",
            "evidence": (
                f"{infeasible_final_command_pct:.2f}% command, "
                f"{infeasible_final_temperature_c:.3f} °C"
            ),
        },
    ]
)
validation_summary
# Out:
#                     category result                            evidence
# 0             thermodynamics   pass  single phase, duty residual 0.138%
# 1       closed-loop tracking   pass               final error -0.092 °C
# 2  moving-horizon estimation   pass           K=0.200 °C/%, tau=45.00 s
# 3   constraint limiting case   pass          100.00% command, 44.998 °C

# %% [markdown]
# ## 18. Summary, further exercises, and references
#
# We connected a rigorous NeqSim SRK fluid, stream, heater, and temperature transmitter to the
# native `ModelPredictiveController`. A local first-order model translated heater command into
# temperature dynamics; closed-loop, horizon, tuning, MHE, duty, and saturation studies were then
# verified with deterministic checks.
#
# **Further exercises**
#
# 1. Add a transport delay and compare prediction horizons longer and shorter than the delay.
# 2. Add bounded sensor noise and evaluate MHE window length and parameter uncertainty.
# 3. Replace the heater with a cooler and verify controller action and sign conventions.
# 4. Fit $K$ from several NeqSim flow rates and build a gain-scheduled controller.
# 5. Extend the case to compressor discharge pressure with power and surge constraints.
#
# **Authoritative references**
#
# - NeqSim documentation: [process simulation](https://equinor.github.io/neqsim/process/)
#   and [Python process recipes](https://equinor.github.io/neqsim/cookbook/process-recipes.html).
# - NeqSim 3.16.0 package: [PyPI release](https://pypi.org/project/neqsim/3.16.0/).
# - S. J. Qin and T. A. Badgwell, “A survey of industrial model predictive control technology,”
#   *Control Engineering Practice*, 11 (2003), 733–764,
#   [doi:10.1016/S0967-0661(02)00186-7](https://doi.org/10.1016/S0967-0661(02)00186-7).
# - J. B. Rawlings, D. Q. Mayne, and M. M. Diehl, *Model Predictive Control: Theory,
#   Computation, and Design*, 2nd ed., Nob Hill Publishing, 2017.
