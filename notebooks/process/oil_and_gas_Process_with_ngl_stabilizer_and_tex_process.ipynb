# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/process/oil_and_gas_Process_with_ngl_stabilizer_and_tex_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Integrated oil stabilization, gas recompression, TEX, and NGL stabilization
#
# **Audience.** Process-engineering students and practising engineers who want to assemble a
# connected upstream processing train with current NeqSim Python APIs.
#
# **Learning objectives**
#
# 1. Replace a proprietary Eclipse-300 feed with a documented synthetic assay.
# 2. Build four-stage oil stabilization with separate HP and LP feeds.
# 3. Recompress and scrub flash gas through three pressure levels.
# 4. Combine hydrocarbon-dew-point cooling, a turboexpander (TEX), and an NGL stabilizer.
# 5. Audit products, energy, component conservation, quality, and operating scenarios.
# 6. Reuse the final workflow with explicit inputs and structured outputs.

# %% [markdown]
# ## Preservation checklist
#
# The original five-cell draft contained no plots and did not complete a calculation. Its
# substantive teaching intentions are preserved and made executable:
#
# 1. the original Colab entry point and NTNU/USN process-study reference;
# 2. a reusable input/output-oriented process model;
# 3. an HP/LP feed split derived from a reservoir-fluid description;
# 4. four-stage oil stabilization;
# 5. three-stage flash-gas recompression with cooling and scrubbing;
# 6. dew-point control and a turboexpander, called TEX in the legacy notebook;
# 7. an NGL preflash/stabilizer column and routing of a small NGL fraction to export oil;
# 8. export-gas and export-oil calculations, product quality, duties, and rotating power;
# 9. repeated operating cases with safe fresh initialization.
#
# The inaccessible `wellfluid.e300` file is replaced by a public synthetic assay while retaining
# the same fluid-characterization and process-building purpose. No previous figure existed to
# preserve; six executed engineering figures are added.

# %%
import importlib.metadata
import subprocess
import sys


try:
    neqsim_version = importlib.metadata.version("neqsim")
except importlib.metadata.PackageNotFoundError:
    subprocess.run(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--no-cache-dir",
            "neqsim",
        ],
        check=True,
    )
    neqsim_version = importlib.metadata.version("neqsim")

java_runtime = subprocess.run(
    ["java", "-version"],
    check=True,
    capture_output=True,
    text=True,
).stderr.splitlines()[0]

print(f"NeqSim package: {neqsim_version}")
print(f"Python runtime: {sys.version.split()[0]}")
print(f"Java runtime: {java_runtime}")
# Out:
# NeqSim package: 3.16.0
# Python runtime: 3.12.13
# Java runtime: openjdk version "17.0.19" 2026-04-21

# %% [markdown]
# ## Engineering context
#
# An offshore oil-and-gas train must stabilize liquid, recover flash gas, control export-gas
# hydrocarbon dew point, and handle condensed NGL. The flowsheet used here is deliberately
# integrated:
#
# `HP/LP feeds → four separators → recompression → cold section/TEX → NGL stabilizer → products`
#
# The model is educational, not a certified facility design. Pressures are absolute. Standard
# gas properties use NeqSim's stated standard-volume basis.
#
# For a steady process with no accumulation, overall mass conservation requires:
#
# $$
# \dot{m}_{HP} + \dot{m}_{LP}
# = \dot{m}_{gas} + \dot{m}_{oil} + \dot{m}_{NGL}
# $$
#
# For component $i$, the three-product balance is:
#
# $$
# \dot{n}_{i,feed}
# = \dot{n}_{i,gas} + \dot{n}_{i,oil} + \dot{n}_{i,NGL}
# $$

# %% [markdown]
# Compression and expansion use an efficiency relative to an isentropic reference:
#
# $$
# \eta_c = \frac{h_{out,s}-h_{in}}{h_{out}-h_{in}}
# $$
#
# $$
# \eta_e = \frac{h_{in}-h_{out}}{h_{in}-h_{out,s}}
# $$
#
# Here $h$ is specific enthalpy in J/kg. Compressor power is positive consumption; NeqSim
# reports expander shaft generation with a negative sign in this workflow.

# %%
from dataclasses import asdict, dataclass
import json
import math

import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch, FancyBboxPatch
import numpy as np
import pandas as pd
from neqsim import jneqsim
from neqsim.process import (
    clearProcess,
    compressor,
    cooler,
    distillationColumn,
    expander,
    getProcess,
    heater,
    mixer,
    pump,
    separator,
    separator3phase,
    splitter,
    stream,
    valve,
)
from neqsim.thermo import dewt, fluid_df


plt.style.use("seaborn-v0_8-whitegrid")
pd.set_option("display.precision", 7)

ThermodynamicOperations = (
    jneqsim.thermodynamicoperations.ThermodynamicOperations
)
MESH_RESIDUAL = (
    jneqsim.process.equipment.distillation.DistillationColumn
    .SolverType.MESH_RESIDUAL
)

# %% [markdown]
# ## Reproducible inputs and validity
#
# The synthetic fluid spans methane through C12 and represents a rich reservoir stream.
# C7–C12 are TBP fractions with documented molar mass and relative density. SRK with the
# classic mixing rule is retained because this is a hydrocarbon process-screening example.
# Project work should select and tune the property model against measured PVT, VLE, density,
# and product data.
#
# The HP/LP split is 80/20 by mass, preserving the original notebook's allocation. The base
# feed is 100,000 kg/h. Separator pressures are 70, 20, 6, and 1.7 bara.

# %%
COMPONENTS = ['nitrogen',
 'CO2',
 'methane',
 'ethane',
 'propane',
 'i-butane',
 'n-butane',
 'i-pentane',
 'n-pentane',
 'n-hexane',
 'C7',
 'C8',
 'C9',
 'C10',
 'C12']

RELATIVE_AMOUNTS = [0.5, 1.2, 35.0, 8.0, 7.0, 2.0, 3.5, 1.5, 2.0, 3.0, 5.0, 6.0, 7.0, 8.0, 10.0]

MOLAR_MASSES_KG_PER_MOL = [None,
 None,
 None,
 None,
 None,
 None,
 None,
 None,
 None,
 None,
 0.098,
 0.112,
 0.126,
 0.14,
 0.168]

RELATIVE_DENSITIES = [None,
 None,
 None,
 None,
 None,
 None,
 None,
 None,
 None,
 None,
 0.73,
 0.75,
 0.77,
 0.79,
 0.82]

feed_assay = pd.DataFrame(
    {
        "component": COMPONENTS,
        "relative molar amount": RELATIVE_AMOUNTS,
        "molar mass [kg/mol]": MOLAR_MASSES_KG_PER_MOL,
        "relative density [-]": RELATIVE_DENSITIES,
    }
)
feed_assay["mole fraction [-]"] = (
    feed_assay["relative molar amount"]
    / feed_assay["relative molar amount"].sum()
)

display(feed_assay)
print(
    "Normalized composition sum: "
    f"{feed_assay['mole fraction [-]'].sum():.12f}"
)
# Out:
#     component  relative molar amount  ...  relative density [-]  mole fraction [-]
# 0    nitrogen                    0.5  ...                   NaN          0.0050150
# 1         CO2                    1.2  ...                   NaN          0.0120361
# 2     methane                   35.0  ...                   NaN          0.3510532
# 3      ethane                    8.0  ...                   NaN          0.0802407
# 4     propane                    7.0  ...                   NaN          0.0702106
# 5    i-butane                    2.0  ...                   NaN          0.0200602
# 6    n-butane                    3.5  ...                   NaN          0.0351053
# 7   i-pentane                    1.5  ...                   NaN          0.0150451
# 8   n-pentane                    2.0  ...                   NaN          0.0200602
# 9    n-hexane                    3.0  ...                   NaN          0.0300903
# ...

# %% [markdown]
# ## Explicit input and output contracts
#
# The legacy notebook used large Pydantic input/output classes. The contracts below keep that
# useful intent while exposing only parameters that this executable notebook actually varies.
# Fixed stage conditions remain visible in the builder functions instead of being hidden in a
# partly wired configuration object.

# %%
@dataclass(frozen=True)
class ProcessInput:
    total_feed_rate_kg_per_h: float = 100_000.0
    tex_inlet_temperature_c: float = -5.0
    tex_outlet_pressure_bara: float = 50.0


@dataclass(frozen=True)
class ProcessOutput:
    export_gas_kg_per_h: float
    export_oil_kg_per_h: float
    ngl_product_kg_per_h: float
    export_compressor_mw: float
    tex_generation_mw: float
    relative_mass_residual: float


base_input = ProcessInput()
display(pd.Series(asdict(base_input), name="base process input"))
# Out:
# total_feed_rate_kg_per_h    100000.0
# tex_inlet_temperature_c         -5.0
# tex_outlet_pressure_bara        50.0
# Name: base process input, dtype: float64

# %%
def create_feed_fluid():
    composition = pd.DataFrame(
        {
            "ComponentName": COMPONENTS,
            "MolarComposition[-]": RELATIVE_AMOUNTS,
            "MolarMass[kg/mol]": MOLAR_MASSES_KG_PER_MOL,
            "RelativeDensity[-]": RELATIVE_DENSITIES,
        }
    )
    fluid = fluid_df(
        composition,
        lastIsPlusFraction=False,
    )
    fluid.setMixingRule("classic")
    fluid.setMultiPhaseCheck(True)
    return fluid

# %% [markdown]
# ## Figure 1 — integrated process and solver order
#
# The diagram separates the liquid stabilization path from the flash-gas and cold-section
# path. Every box corresponds to NeqSim unit operations created below. The small NGL-to-oil
# route preserves the legacy routing variable while most stabilized NGL remains a separate
# product.

# %%
figure, axis = plt.subplots(figsize=(14, 6.5))
axis.set_xlim(0.0, 14.0)
axis.set_ylim(0.0, 6.5)
axis.axis("off")

boxes = [
    (0.3, 4.6, "HP + LP\nsynthetic feeds"),
    (2.3, 4.6, "Four-stage\noil stabilization"),
    (5.0, 4.6, "Export oil\npump + cooler"),
    (2.3, 1.8, "Three-stage\ngas recompression"),
    (5.0, 1.8, "Dew-point\ncooler + scrubber"),
    (7.5, 1.8, "TEX\nturboexpander"),
    (10.0, 1.8, "NGL\nstabilizer"),
    (12.1, 3.8, "Export gas\ncompression"),
    (12.1, 0.6, "NGL product\n+ oil routing"),
]

for x_position, y_position, label in boxes:
    patch = FancyBboxPatch(
        (x_position, y_position),
        1.6,
        0.9,
        boxstyle="round,pad=0.08",
        facecolor="#DCEAF7",
        edgecolor="#1F4E79",
        linewidth=1.6,
    )
    axis.add_patch(patch)
    axis.text(
        x_position + 0.8,
        y_position + 0.45,
        label,
        ha="center",
        va="center",
        fontsize=10,
    )

arrows = [
    ((1.9, 5.05), (2.3, 5.05)),
    ((3.9, 5.05), (5.0, 5.05)),
    ((3.1, 4.6), (3.1, 2.7)),
    ((3.9, 2.25), (5.0, 2.25)),
    ((6.6, 2.25), (7.5, 2.25)),
    ((9.1, 2.25), (10.0, 2.25)),
    ((8.3, 2.7), (12.1, 4.25)),
    ((11.6, 2.25), (12.1, 1.05)),
    ((10.8, 2.7), (12.1, 4.25)),
]

for start, end in arrows:
    axis.add_patch(
        FancyArrowPatch(
            start,
            end,
            arrowstyle="-|>",
            mutation_scale=14,
            linewidth=1.6,
            color="#404040",
        )
    )

axis.set_title(
    "Integrated NeqSim oil, gas, TEX, and NGL workflow",
    fontsize=15,
    pad=14,
)
plt.show()

# %% [markdown]
# ## Build the preserved four-stage stabilization example
#
# The function creates independent HP and LP streams, flashes the HP stream at 70 bara,
# combines the LP stream before the 20-bara stage, and stabilizes oil through 6 and 1.7 bara.
# The final liquid is pumped to 20.8 bara and cooled to 20 °C.

# %%
def add_stabilization_section(total_feed_rate_kg_per_h):
    hp_feed = stream("HP well stream", create_feed_fluid())
    hp_feed.setFlowRate(
        0.8 * total_feed_rate_kg_per_h,
        "kg/hr",
    )
    hp_feed.setPressure(70.0, "bara")
    hp_feed.setTemperature(70.0, "C")

    lp_feed = stream("LP well stream", create_feed_fluid())
    lp_feed.setFlowRate(
        0.2 * total_feed_rate_kg_per_h,
        "kg/hr",
    )
    lp_feed.setPressure(20.0, "bara")
    lp_feed.setTemperature(65.0, "C")

    first_separator = separator3phase(
        "1st stage separator",
        hp_feed,
    )

    first_oil_valve = valve(
        "1st to 2nd stage oil valve",
        first_separator.getOilOutStream(),
        20.0,
    )
    first_oil_valve.setOutletPressure(20.0)
    second_feed_mixer = mixer("2nd stage feed mixer")
    second_feed_mixer.addStream(
        first_oil_valve.getOutletStream()
    )
    second_feed_mixer.addStream(lp_feed)
    second_heater = heater(
        "2nd stage oil heater",
        second_feed_mixer.getOutletStream(),
    )
    second_heater.setOutTemperature(65.0, "C")
    second_separator = separator3phase(
        "2nd stage separator",
        second_heater.getOutletStream(),
    )

    second_oil_valve = valve(
        "2nd to 3rd stage oil valve",
        second_separator.getOilOutStream(),
        6.0,
    )
    second_oil_valve.setOutletPressure(6.0)
    third_heater = heater(
        "3rd stage oil heater",
        second_oil_valve.getOutletStream(),
    )
    third_heater.setOutTemperature(65.0, "C")
    third_separator = separator3phase(
        "3rd stage separator",
        third_heater.getOutletStream(),
    )

    third_oil_valve = valve(
        "3rd to 4th stage oil valve",
        third_separator.getOilOutStream(),
        1.7,
    )
    third_oil_valve.setOutletPressure(1.7)
    fourth_heater = heater(
        "4th stage oil heater",
        third_oil_valve.getOutletStream(),
    )
    fourth_heater.setOutTemperature(60.0, "C")
    fourth_separator = separator3phase(
        "4th stage separator",
        fourth_heater.getOutletStream(),
    )

    export_oil_pump = pump(
        "export oil pump",
        fourth_separator.getOilOutStream(),
        20.8,
    )
    export_oil_pump.setOutletPressure(20.8)
    export_oil_cooler = cooler(
        "export oil cooler",
        export_oil_pump.getOutletStream(),
    )
    export_oil_cooler.setOutTemperature(20.0, "C")
    base_export_oil = stream(
        "base export oil",
        export_oil_cooler.getOutletStream(),
    )

    return {
        "HP feed": hp_feed,
        "LP feed": lp_feed,
        "1st separator": first_separator,
        "2nd separator": second_separator,
        "3rd separator": third_separator,
        "4th separator": fourth_separator,
        "base export oil": base_export_oil,
    }

# %% [markdown]
# ## Build the preserved flash-gas recompression example
#
# Gas from the fourth, third, and second separators is cooled, scrubbed, and compressed
# successively to 6, 20, and 70 bara. Freshly condensed liquids are pumped to the export-oil
# system later, so the overall process boundary remains closed.

# %%
def add_recompression_section(stabilization):
    fourth_separator = stabilization["4th separator"]
    third_separator = stabilization["3rd separator"]
    second_separator = stabilization["2nd separator"]
    first_separator = stabilization["1st separator"]

    first_cooler = cooler(
        "1st recompression cooler",
        fourth_separator.getGasOutStream(),
    )
    first_cooler.setOutTemperature(30.0, "C")
    first_scrubber = separator(
        "1st recompression scrubber",
        first_cooler.getOutletStream(),
    )
    recompressor_1 = compressor(
        "1st stage recompressor",
        first_scrubber.getGasOutStream(),
        6.0,
    )
    recompressor_1.setOutletPressure(6.0, "bara")
    recompressor_1.setIsentropicEfficiency(0.78)

    third_gas_mixer = mixer("3rd stage gas mixer")
    third_gas_mixer.addStream(
        recompressor_1.getOutletStream()
    )
    third_gas_mixer.addStream(
        third_separator.getGasOutStream()
    )
    second_cooler = cooler(
        "2nd recompression cooler",
        third_gas_mixer.getOutletStream(),
    )
    second_cooler.setOutTemperature(30.0, "C")
    second_scrubber = separator(
        "2nd recompression scrubber",
        second_cooler.getOutletStream(),
    )
    recompressor_2 = compressor(
        "2nd stage recompressor",
        second_scrubber.getGasOutStream(),
        20.0,
    )
    recompressor_2.setOutletPressure(20.0, "bara")
    recompressor_2.setIsentropicEfficiency(0.78)

    second_gas_mixer = mixer("2nd stage gas mixer")
    second_gas_mixer.addStream(
        recompressor_2.getOutletStream()
    )
    second_gas_mixer.addStream(
        second_separator.getGasOutStream()
    )
    third_cooler = cooler(
        "3rd recompression cooler",
        second_gas_mixer.getOutletStream(),
    )
    third_cooler.setOutTemperature(30.0, "C")
    third_scrubber = separator(
        "3rd recompression scrubber",
        third_cooler.getOutletStream(),
    )
    recompressor_3 = compressor(
        "3rd stage recompressor",
        third_scrubber.getGasOutStream(),
        70.0,
    )
    recompressor_3.setOutletPressure(70.0, "bara")
    recompressor_3.setIsentropicEfficiency(0.78)

    rich_gas_mixer = mixer("rich gas mixer")
    rich_gas_mixer.addStream(
        recompressor_3.getOutletStream()
    )
    rich_gas_mixer.addStream(
        first_separator.getGasOutStream()
    )

    return {
        "recompressor 1": recompressor_1,
        "recompressor 2": recompressor_2,
        "recompressor 3": recompressor_3,
        "scrubber 1": first_scrubber,
        "scrubber 2": second_scrubber,
        "scrubber 3": third_scrubber,
        "rich gas": rich_gas_mixer.getOutletStream(),
    }

# %% [markdown]
# ## Build the preserved dew-point, TEX, and NGL-stabilizer example
#
# The rich gas is cooled and scrubbed before 78%-efficient expansion. Liquids from both cold
# scrubbers feed a five-tray MESH-residual NGL stabilizer. Stabilizer overhead is recompressed
# before export compression. The stabilizer bottoms are split 0.1% to export oil
# and 99.9% to the NGL product, matching the original routing intent.

# %%
def add_cold_end_section(
    stabilization,
    recompression,
    tex_inlet_temperature_c,
    tex_outlet_pressure_bara,
):
    dew_point_cooler = cooler(
        "dew point cooler",
        recompression["rich gas"],
    )
    dew_point_cooler.setOutTemperature(
        tex_inlet_temperature_c,
        "C",
    )
    dew_point_scrubber = separator(
        "dew point scrubber",
        dew_point_cooler.getOutletStream(),
    )

    turbo_expander = expander(
        "TEX turboexpander",
        dew_point_scrubber.getGasOutStream(),
        tex_outlet_pressure_bara,
    )
    turbo_expander.setOutletPressure(
        tex_outlet_pressure_bara
    )
    turbo_expander.setIsentropicEfficiency(0.78)
    tex_scrubber = separator(
        "TEX outlet scrubber",
        turbo_expander.getOutletStream(),
    )

    ngl_liquid_mixer = mixer("NGL liquid mixer")
    ngl_liquid_mixer.addStream(
        dew_point_scrubber.getLiquidOutStream()
    )
    ngl_liquid_mixer.addStream(
        tex_scrubber.getLiquidOutStream()
    )
    ngl_feed_valve = valve(
        "NGL stabilizer feed valve",
        ngl_liquid_mixer.getOutletStream(),
        16.0,
    )
    ngl_feed_valve.setOutletPressure(16.0)

    ngl_stabilizer = distillationColumn(
        "NGL stabilizer",
        trays=5,
        reboil=True,
        condenser=False,
    )
    ngl_stabilizer.addFeedStream(
        ngl_feed_valve.getOutletStream(),
        5,
    )
    ngl_stabilizer.setSolverType(MESH_RESIDUAL)
    ngl_stabilizer.getReboiler().setOutTemperature(
        273.15 + 120.0
    )
    ngl_stabilizer.setTopPressure(15.0)
    ngl_stabilizer.setBottomPressure(17.0)

    stabilizer_gas_compressor = compressor(
        "stabilizer gas compressor",
        ngl_stabilizer.getGasOutStream(),
        tex_outlet_pressure_bara,
    )
    stabilizer_gas_compressor.setOutletPressure(
        tex_outlet_pressure_bara,
        "bara",
    )
    stabilizer_gas_compressor.setIsentropicEfficiency(0.75)

    export_gas_mixer = mixer("export gas mixer")
    export_gas_mixer.addStream(
        tex_scrubber.getGasOutStream()
    )
    export_gas_mixer.addStream(
        stabilizer_gas_compressor.getOutletStream()
    )
    export_compressor = compressor(
        "export gas compressor",
        export_gas_mixer.getOutletStream(),
        126.5,
    )
    export_compressor.setOutletPressure(126.5, "bara")
    export_compressor.setIsentropicEfficiency(0.78)
    export_gas_cooler = cooler(
        "export gas cooler",
        export_compressor.getOutletStream(),
    )
    export_gas_cooler.setOutTemperature(40.0, "C")
    export_gas = stream(
        "export gas",
        export_gas_cooler.getOutletStream(),
    )

    ngl_splitter = splitter(
        "NGL routing splitter",
        ngl_stabilizer.getLiquidOutStream(),
        [0.001, 0.999],
    )
    ngl_to_oil_pump = pump(
        "NGL to oil pump",
        ngl_splitter.getSplitStream(0),
        20.8,
    )
    ngl_to_oil_pump.setOutletPressure(20.8)

    liquid_pumps = []
    for index in range(1, 4):
        liquid_pump = pump(
            f"recompression liquid pump {index}",
            recompression[f"scrubber {index}"]
            .getLiquidOutStream(),
            20.8,
        )
        liquid_pump.setOutletPressure(20.8)
        liquid_pumps.append(liquid_pump)

    final_oil_mixer = mixer("final oil mixer")
    final_oil_mixer.addStream(
        stabilization["base export oil"]
    )
    final_oil_mixer.addStream(
        ngl_to_oil_pump.getOutletStream()
    )
    for liquid_pump in liquid_pumps:
        final_oil_mixer.addStream(
            liquid_pump.getOutletStream()
        )
    export_oil = stream(
        "export oil",
        final_oil_mixer.getOutletStream(),
    )
    ngl_product = stream(
        "NGL product",
        ngl_splitter.getSplitStream(1),
    )

    return {
        "dew point cooler": dew_point_cooler,
        "dew point scrubber": dew_point_scrubber,
        "TEX": turbo_expander,
        "TEX scrubber": tex_scrubber,
        "NGL stabilizer": ngl_stabilizer,
        "stabilizer gas compressor": stabilizer_gas_compressor,
        "export compressor": export_compressor,
        "export gas": export_gas,
        "export oil": export_oil,
        "NGL product": ngl_product,
    }

# %% [markdown]
# ## Compose the complete reusable process
#
# Each call starts with `clearProcess()` and creates new fluids, streams, and equipment. This
# replaces the legacy timeout thread and mutable repeated-run pattern. Independent construction
# is slower, but it makes scenario results reproducible and order-independent.

# %%
def build_integrated_process(
    tex_inlet_temperature_c=-5.0,
    tex_outlet_pressure_bara=50.0,
    total_feed_rate_kg_per_h=100_000.0,
):
    clearProcess()
    stabilization = add_stabilization_section(
        total_feed_rate_kg_per_h
    )
    recompression = add_recompression_section(
        stabilization
    )
    cold_end = add_cold_end_section(
        stabilization,
        recompression,
        tex_inlet_temperature_c,
        tex_outlet_pressure_bara,
    )
    equipment = {
        **stabilization,
        **recompression,
        **cold_end,
    }
    return getProcess(), equipment

# %% [markdown]
# ## Execute the base case
#
# The blocking `ProcessSystem.run()` returns only after all unit operations finish. The stored
# output is therefore evidence of a complete top-to-bottom calculation, not a background thread
# that may still be running.

# %%
base_process, base_equipment = build_integrated_process(
    tex_inlet_temperature_c=base_input.tex_inlet_temperature_c,
    tex_outlet_pressure_bara=base_input.tex_outlet_pressure_bara,
    total_feed_rate_kg_per_h=base_input.total_feed_rate_kg_per_h,
)
base_process.run()

print("Base integrated process completed synchronously.")
print(
    "TEX outlet temperature: "
    f"{base_equipment['TEX'].getOutletStream().getTemperature('C'):.6f} °C"
)
# Out:
# Base integrated process completed synchronously.
# TEX outlet temperature: -19.510737 °C

# %% [markdown]
# ## Process-state table
#
# The table follows the four stabilization stages, cold train, and final products. It exposes
# the actual NeqSim stream states that users would pass to downstream sizing, optimization, or
# digital-twin code.

# %%
state_streams = {
    "HP feed": base_equipment["HP feed"],
    "LP feed": base_equipment["LP feed"],
    "stage 1 gas": base_equipment["1st separator"].getGasOutStream(),
    "stage 1 oil": base_equipment["1st separator"].getOilOutStream(),
    "stage 2 gas": base_equipment["2nd separator"].getGasOutStream(),
    "stage 2 oil": base_equipment["2nd separator"].getOilOutStream(),
    "stage 3 gas": base_equipment["3rd separator"].getGasOutStream(),
    "stage 3 oil": base_equipment["3rd separator"].getOilOutStream(),
    "stage 4 gas": base_equipment["4th separator"].getGasOutStream(),
    "stage 4 oil": base_equipment["4th separator"].getOilOutStream(),
    "TEX outlet": base_equipment["TEX"].getOutletStream(),
    "export gas": base_equipment["export gas"],
    "export oil": base_equipment["export oil"],
    "NGL product": base_equipment["NGL product"],
}

state_rows = []
for stream_name, stream_object in state_streams.items():
    state_rows.append(
        {
            "stream": stream_name,
            "temperature [°C]": stream_object.getTemperature("C"),
            "pressure [bara]": stream_object.getPressure("bara"),
            "mass flow [kg/h]": stream_object.getFlowRate("kg/hr"),
        }
    )

state_table = pd.DataFrame(state_rows)
display(state_table)
# Out:
#          stream  temperature [°C]  pressure [bara]  mass flow [kg/h]
# 0       HP feed        70.0000000             70.0     80000.0000000
# 1       LP feed        65.0000000             20.0     20000.0000000
# 2   stage 1 gas        70.0000000             70.0      6035.9664847
# 3   stage 1 oil        70.0000000             70.0     73964.0335153
# 4   stage 2 gas        65.0000000             20.0      8383.7829643
# 5   stage 2 oil        65.0000000             20.0     85580.2505510
# 6   stage 3 gas        65.0000000              6.0      3073.8612711
# 7   stage 3 oil        65.0000000              6.0     82506.3892799
# 8   stage 4 gas        60.0000000              1.7      3079.8559771
# 9   stage 4 oil        60.0000000              1.7     79426.5333028
# 10   TEX outlet       -19.5107366             50.0     10931.8016339
# 11   export gas        40.0000000            126.5     16904.0770643
# 12   export oil        20.3966987             20.8     81145.1639501
# ...

# %% [markdown]
# ## Figure 2 — stabilization-stage profiles
#
# Pressure falls across the liquid train, while released gas changes with each flash condition.
# The separate axes prevent pressure and flow from being confused.

# %%
stage_names = ["stage 1", "stage 2", "stage 3", "stage 4"]
stage_pressures_bara = [70.0, 20.0, 6.0, 1.7]
stage_gas_flows_kg_per_h = [
    base_equipment[f"{index}st separator"].getGasOutStream()
    .getFlowRate("kg/hr")
    if index == 1
    else base_equipment[
        f"{index}{'nd' if index == 2 else 'rd' if index == 3 else 'th'} separator"
    ].getGasOutStream().getFlowRate("kg/hr")
    for index in range(1, 5)
]
stage_oil_flows_kg_per_h = [
    base_equipment[f"{index}st separator"].getOilOutStream()
    .getFlowRate("kg/hr")
    if index == 1
    else base_equipment[
        f"{index}{'nd' if index == 2 else 'rd' if index == 3 else 'th'} separator"
    ].getOilOutStream().getFlowRate("kg/hr")
    for index in range(1, 5)
]

figure, flow_axis = plt.subplots(figsize=(10.5, 5.8))
pressure_axis = flow_axis.twinx()
x_positions = np.arange(len(stage_names))

flow_axis.plot(
    x_positions,
    stage_gas_flows_kg_per_h,
    marker="o",
    linewidth=2.2,
    color="#0072B2",
    label="Released gas",
)
flow_axis.plot(
    x_positions,
    stage_oil_flows_kg_per_h,
    marker="s",
    linewidth=2.2,
    color="#009E73",
    label="Oil outlet",
)
pressure_axis.plot(
    x_positions,
    stage_pressures_bara,
    marker="D",
    linestyle="--",
    linewidth=2.0,
    color="#D55E00",
    label="Separator pressure",
)

flow_axis.set_xticks(x_positions, stage_names)
flow_axis.set_xlabel("Stabilization stage")
flow_axis.set_ylabel("Mass flow [kg/h]")
pressure_axis.set_ylabel("Pressure [bara]")
flow_axis.set_title("Four-stage oil stabilization profile")
flow_axis.legend(loc="center left")
pressure_axis.legend(loc="center right")
plt.show()

# %% [markdown]
# ## Rotating-equipment and thermal results
#
# The first three compressor powers quantify flash-gas recovery. TEX shaft generation offsets
# part of the export-compression demand, but no mechanical coupling efficiency or driver model
# is assumed here.

# %%
energy_rows = [
    {
        "equipment": "recompressor 1",
        "power [MW]": base_equipment["recompressor 1"].getPower("MW"),
    },
    {
        "equipment": "recompressor 2",
        "power [MW]": base_equipment["recompressor 2"].getPower("MW"),
    },
    {
        "equipment": "recompressor 3",
        "power [MW]": base_equipment["recompressor 3"].getPower("MW"),
    },
    {
        "equipment": "TEX generation",
        "power [MW]": base_equipment["TEX"].getPower("MW"),
    },
    {
        "equipment": "stabilizer overhead compressor",
        "power [MW]": (
            base_equipment["stabilizer gas compressor"].getPower("MW")
        ),
    },
    {
        "equipment": "export compressor",
        "power [MW]": base_equipment["export compressor"].getPower("MW"),
    },
]
energy_table = pd.DataFrame(energy_rows)
display(energy_table)

figure, axis = plt.subplots(figsize=(10.5, 5.8))
colors = [
    "#0072B2" if value >= 0.0 else "#009E73"
    for value in energy_table["power [MW]"]
]
axis.barh(
    energy_table["equipment"],
    energy_table["power [MW]"],
    color=colors,
    edgecolor="#333333",
)
axis.axvline(0.0, color="#333333", linewidth=1.0)
axis.set_xlabel("Shaft power [MW; consumption positive]")
axis.set_ylabel("Equipment")
axis.set_title("Recompression, TEX generation, and export power")
plt.show()
# Out:
#                         equipment  power [MW]
# 0                  recompressor 1   0.0739032
# 1                  recompressor 2   0.1610405
# 2                  recompressor 3   0.5372170
# 3                  TEX generation  -0.0584891
# 4  stabilizer overhead compressor   0.2464001
# 5               export compressor   0.5312312

# %% [markdown]
# ## Figure 4 — product composition
#
# The selected components show how the integrated train partitions light gas, stabilized oil,
# and NGL. A logarithmic scale keeps trace carry-over visible without hiding the heavy-product
# enrichment.

# %%
def stream_mole_fraction(stream_object, component_name):
    component = stream_object.getFluid().getComponent(component_name)
    return float(component.getz())


product_streams = {
    "export gas": base_equipment["export gas"],
    "export oil": base_equipment["export oil"],
    "NGL product": base_equipment["NGL product"],
}
plot_components = [
    "methane",
    "ethane",
    "propane",
    "n-butane",
    "n-pentane",
    "n-hexane",
    "C7_PC",
    "C9_PC",
    "C12_PC",
]
composition_rows = []
for component_name in plot_components:
    row = {"component": component_name}
    for product_name, product_stream in product_streams.items():
        row[product_name] = stream_mole_fraction(
            product_stream,
            component_name,
        )
    composition_rows.append(row)

composition_table = pd.DataFrame(composition_rows)
display(composition_table)

figure, axis = plt.subplots(figsize=(12, 6))
x_positions = np.arange(len(plot_components))
bar_width = 0.25
palette = ["#0072B2", "#009E73", "#D55E00"]

for series_index, product_name in enumerate(product_streams):
    axis.bar(
        x_positions + (series_index - 1) * bar_width,
        np.maximum(composition_table[product_name], 1.0e-8),
        width=bar_width,
        color=palette[series_index],
        label=product_name,
    )

axis.set_yscale("log")
axis.set_xticks(x_positions, plot_components, rotation=30, ha="right")
axis.set_xlabel("Component")
axis.set_ylabel("Product mole fraction [-], logarithmic scale")
axis.set_title("Component partitioning among export products")
axis.legend()
plt.tight_layout()
plt.show()
# Out:
#    component     export gas  export oil  NGL product
# 0    methane  6.8914592e-01   0.0023532    0.0000105
# 1     ethane  1.4986174e-01   0.0086941    0.0020792
# 2    propane  1.0182601e-01   0.0364497    0.0635876
# 3   n-butane  1.1481383e-02   0.0440314    0.4103031
# 4  n-pentane  3.9031983e-04   0.0362895    0.1326453
# 5   n-hexane  5.8807320e-05   0.0613581    0.0545908
# 6      C7_PC  4.6940593e-06   0.1055124    0.0194751
# 7      C9_PC  1.9594665e-07   0.1486488    0.0062632
# 8     C12_PC  2.7325496e-09   0.2126858    0.0014514

# %% [markdown]
# ## Overall and component conservation audit
#
# Mass and component balances use only the two inlet streams and the three final products.
# Intermediate recycles, scrubber liquids, and the NGL-to-oil route are therefore internal to
# the audited boundary.

# %%
feed_streams = [
    base_equipment["HP feed"],
    base_equipment["LP feed"],
]
final_product_streams = [
    base_equipment["export gas"],
    base_equipment["export oil"],
    base_equipment["NGL product"],
]

inlet_mass_kg_per_h = sum(
    stream_object.getFlowRate("kg/hr")
    for stream_object in feed_streams
)
product_mass_kg_per_h = sum(
    stream_object.getFlowRate("kg/hr")
    for stream_object in final_product_streams
)
mass_residual_kg_per_h = (
    inlet_mass_kg_per_h - product_mass_kg_per_h
)
relative_mass_residual = (
    mass_residual_kg_per_h / inlet_mass_kg_per_h
)


def component_molar_flow(stream_object, component_name):
    component = stream_object.getFluid().getComponent(component_name)
    return float(component.getNumberOfmoles())


resolved_components = [
    str(
        base_equipment["HP feed"]
        .getFluid()
        .getComponent(index)
        .getName()
    )
    for index in range(
        base_equipment["HP feed"].getFluid().getNumberOfComponents()
    )
]
component_balance_rows = []
for component_name in resolved_components:
    inlet_moles = sum(
        component_molar_flow(stream_object, component_name)
        for stream_object in feed_streams
    )
    product_moles = sum(
        component_molar_flow(stream_object, component_name)
        for stream_object in final_product_streams
    )
    relative_residual = (
        (product_moles - inlet_moles)
        / max(abs(inlet_moles), 1.0e-20)
    )
    component_balance_rows.append(
        {
            "component": component_name,
            "relative residual [-]": relative_residual,
        }
    )

component_balance_table = pd.DataFrame(component_balance_rows)
display(component_balance_table)
print(f"Mass residual: {mass_residual_kg_per_h:.8e} kg/h")
print(f"Relative mass residual: {relative_mass_residual:.8e}")
# Out:
#     component  relative residual [-]
# 0    nitrogen          7.9839397e-13
# 1         CO2          1.0828930e-12
# 2     methane          1.2868453e-12
# 3      ethane         -1.6651466e-14
# 4     propane         -2.1977431e-12
# 5    i-butane         -2.2398413e-12
# 6    n-butane         -1.9569854e-12
# 7   i-pentane         -1.1130190e-12
# 8   n-pentane         -9.0662850e-13
# 9    n-hexane         -4.6288154e-13
# 10      C7_PC         -4.1541025e-13
# 11      C8_PC         -4.2826402e-13
# 12      C9_PC         -4.3456570e-13
# 13     C10_PC         -4.3710098e-13
# 14     C12_PC         -4.3661896e-13
# Mass residual: 4.40195436e-08 kg/h
# Relative mass residual: 4.40195436e-13

# %% [markdown]
# ## Figure 5 — final product allocation
#
# The product-flow chart closes the material picture: most heavy feed becomes export oil,
# light components leave as gas, and the cold/stabilizer section recovers a smaller NGL stream.

# %%
product_flow_table = pd.DataFrame(
    {
        "product": list(product_streams),
        "mass flow [kg/h]": [
            product_streams[name].getFlowRate("kg/hr")
            for name in product_streams
        ],
    }
)
display(product_flow_table)

figure, axis = plt.subplots(figsize=(9.5, 5.5))
bars = axis.bar(
    product_flow_table["product"],
    product_flow_table["mass flow [kg/h]"],
    color=["#0072B2", "#009E73", "#D55E00"],
    edgecolor="#333333",
)
axis.bar_label(
    bars,
    labels=[
        f"{value:,.0f}"
        for value in product_flow_table["mass flow [kg/h]"]
    ],
    padding=4,
)
axis.set_ylabel("Mass flow [kg/h]")
axis.set_xlabel("Final product")
axis.set_title("Mass allocation across the audited product boundary")
axis.set_ylim(
    0.0,
    1.12 * product_flow_table["mass flow [kg/h]"].max(),
)
plt.show()
# Out:
#        product  mass flow [kg/h]
# 0   export gas     16904.0770643
# 1   export oil     81145.1639501
# 2  NGL product      1950.7589856

# %% [markdown]
# ## Product quality: GCV, dew point, and vapour pressure
#
# Gas gross calorific value is evaluated at 15 °C and 1.01325 bara. Hydrocarbon dew point is
# reported at export pressure. Oil and NGL true vapour pressures are calculated at 37.8 °C
# with independent cloned fluids, so the checks cannot mutate the process state.

# %%
def true_vapour_pressure_bara(product_stream, temperature_c=37.8):
    product_fluid = product_stream.getFluid().clone()
    product_fluid.setTemperature(temperature_c, "C")
    product_fluid.setPressure(1.0, "bara")
    operations = ThermodynamicOperations(product_fluid)
    operations.bubblePointPressureFlash(False)
    return float(product_fluid.getPressure("bara"))


export_gas = base_equipment["export gas"]
export_oil = base_equipment["export oil"]
ngl_product = base_equipment["NGL product"]

export_gcv_mj_per_sm3 = (
    export_gas.getGCV("J/Sm3", 15.0, 1.01325) / 1.0e6
)
export_hydrocarbon_dew_point_c = (
    dewt(export_gas.getFluid().clone()) - 273.15
)
oil_tvp_bara = true_vapour_pressure_bara(export_oil)
ngl_tvp_bara = true_vapour_pressure_bara(ngl_product)

quality_table = pd.DataFrame(
    [
        {
            "product": "export gas",
            "property": "gross calorific value",
            "value": export_gcv_mj_per_sm3,
            "unit": "MJ/Sm³",
        },
        {
            "product": "export gas",
            "property": "hydrocarbon dew point",
            "value": export_hydrocarbon_dew_point_c,
            "unit": "°C at 126.5 bara",
        },
        {
            "product": "export oil",
            "property": "true vapour pressure at 37.8 °C",
            "value": oil_tvp_bara,
            "unit": "bara",
        },
        {
            "product": "NGL product",
            "property": "true vapour pressure at 37.8 °C",
            "value": ngl_tvp_bara,
            "unit": "bara",
        },
    ]
)
display(quality_table)
# Out:
#        product                         property       value              unit
# 0   export gas            gross calorific value  48.7927339            MJ/Sm³
# 1   export gas            hydrocarbon dew point  39.1769340  °C at 126.5 bara
# 2   export oil  true vapour pressure at 37.8 °C   1.6978720              bara
# 3  NGL product  true vapour pressure at 37.8 °C   3.4721604              bara

# %% [markdown]
# ## Independent TEX-pressure scenarios
#
# Four fresh process systems are solved at TEX outlet pressures from 45 to 60 bara. This
# coupled flowsheet need not be monotonic: pressure changes expansion, condensation, stabilizer
# feed, overhead recompression, and final product partitioning simultaneously. The notebook therefore
# selects among the tested feasible cases instead of forcing an unjustified monotonic rule.

# %%
def summarize_tex_case(tex_outlet_pressure_bara):
    case_process, case_equipment = build_integrated_process(
        tex_inlet_temperature_c=-5.0,
        tex_outlet_pressure_bara=tex_outlet_pressure_bara,
        total_feed_rate_kg_per_h=100_000.0,
    )
    case_process.run()

    case_inlet_mass = (
        case_equipment["HP feed"].getFlowRate("kg/hr")
        + case_equipment["LP feed"].getFlowRate("kg/hr")
    )
    case_product_mass = sum(
        case_equipment[name].getFlowRate("kg/hr")
        for name in ["export gas", "export oil", "NGL product"]
    )
    return {
        "TEX outlet pressure [bara]": tex_outlet_pressure_bara,
        "TEX outlet temperature [°C]": (
            case_equipment["TEX"]
            .getOutletStream()
            .getTemperature("C")
        ),
        "NGL product [kg/h]": (
            case_equipment["NGL product"].getFlowRate("kg/hr")
        ),
        "export compressor power [MW]": (
            case_equipment["export compressor"].getPower("MW")
        ),
        "TEX generation [MW]": abs(
            case_equipment["TEX"].getPower("MW")
        ),
        "mass residual [kg/h]": (
            case_inlet_mass - case_product_mass
        ),
    }


scenario_pressures_bara = [45.0, 50.0, 55.0, 60.0]
scenario_table = pd.DataFrame(
    [
        summarize_tex_case(pressure_bara)
        for pressure_bara in scenario_pressures_bara
    ]
)
display(scenario_table)
# Out:
#    TEX outlet pressure [bara]  ...  mass residual [kg/h]
# 0                        45.0  ...         1.6007107e-10
# 1                        50.0  ...         4.4019544e-08
# 2                        55.0  ...         8.7442459e-08
# 3                        60.0  ...         2.5902409e-09
#
# [4 rows x 6 columns]

# %% [markdown]
# ## Figure 6 — TEX pressure, NGL recovery, and export power
#
# The two axes show the main trade-off directly. The result is a scenario screen, not a global
# optimum: a project decision must also include product specifications, exchanger feasibility,
# driver efficiency, machinery limits, and economics.

# %%
figure, ngl_axis = plt.subplots(figsize=(10.5, 5.8))
power_axis = ngl_axis.twinx()

ngl_axis.plot(
    scenario_table["TEX outlet pressure [bara]"],
    scenario_table["NGL product [kg/h]"],
    marker="o",
    linewidth=2.2,
    color="#0072B2",
    label="NGL product",
)
power_axis.plot(
    scenario_table["TEX outlet pressure [bara]"],
    scenario_table["export compressor power [MW]"],
    marker="s",
    linewidth=2.2,
    color="#D55E00",
    label="Export compressor",
)

ngl_axis.set_xlabel("TEX outlet pressure [bara]")
ngl_axis.set_ylabel("NGL product [kg/h]", color="#0072B2")
power_axis.set_ylabel(
    "Export compressor power [MW]",
    color="#D55E00",
)
ngl_axis.set_title("TEX pressure scenario: liquid recovery and export power")
ngl_axis.legend(loc="upper left")
power_axis.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Practical final application: select and serialize a case
#
# The application chooses the tested point with the highest NGL flow while requiring a closed
# mass balance and export-compressor power below 0.65 MW. It then creates a structured record
# that can be written to JSON, passed to an optimization layer, or compared with measurements.

# %%
feasible_scenarios = scenario_table.loc[
    (
        scenario_table["export compressor power [MW]"]
        < 0.65
    )
    & (
        scenario_table["mass residual [kg/h]"].abs()
        < 1.0e-4
    )
].copy()
selected_scenario = feasible_scenarios.sort_values(
    "NGL product [kg/h]",
    ascending=False,
).iloc[0]

base_output = ProcessOutput(
    export_gas_kg_per_h=export_gas.getFlowRate("kg/hr"),
    export_oil_kg_per_h=export_oil.getFlowRate("kg/hr"),
    ngl_product_kg_per_h=ngl_product.getFlowRate("kg/hr"),
    export_compressor_mw=(
        base_equipment["export compressor"].getPower("MW")
    ),
    tex_generation_mw=abs(
        base_equipment["TEX"].getPower("MW")
    ),
    relative_mass_residual=relative_mass_residual,
)

application_record = {
    "NeqSim version": neqsim_version,
    "base input": asdict(base_input),
    "base output": asdict(base_output),
    "selected TEX pressure [bara]": float(
        selected_scenario["TEX outlet pressure [bara]"]
    ),
    "selection rule": (
        "maximum tested NGL flow with mass closure "
        "and export compressor below 0.65 MW"
    ),
}

print(json.dumps(application_record, indent=2))
# Out:
# {
#   "NeqSim version": "3.16.0",
#   "base input": {
#     "total_feed_rate_kg_per_h": 100000.0,
#     "tex_inlet_temperature_c": -5.0,
#     "tex_outlet_pressure_bara": 50.0
#   },
#   "base output": {
#     "export_gas_kg_per_h": 16904.07706431818,
#     "export_oil_kg_per_h": 81145.16395008346,
#     "ngl_product_kg_per_h": 1950.7589855543522,
#     "export_compressor_mw": 0.5312312161604358,
#     "tex_generation_mw": 0.058489111170075596,
#     "relative_mass_residual": 4.4019543565809725e-13
#   },
#   "selected TEX pressure [bara]": 50.0,
#   "selection rule": "maximum tested NGL flow with mass closure and export compressor below 0.65 MW"
# }

# %% [markdown]
# ## Verification checks
#
# The checks below cover finite results, total and component balances, pressure ordering,
# rotating-equipment signs, product enrichment, quality ranges, independent scenario
# initialization, and final-case selection. They fail visibly if a future NeqSim release changes
# the behavior materially.

# %%
numeric_results = [
    inlet_mass_kg_per_h,
    product_mass_kg_per_h,
    mass_residual_kg_per_h,
    export_gcv_mj_per_sm3,
    export_hydrocarbon_dew_point_c,
    oil_tvp_bara,
    ngl_tvp_bara,
]
assert all(math.isfinite(value) for value in numeric_results)
assert abs(relative_mass_residual) < 1.0e-9
assert (
    component_balance_table["relative residual [-]"].abs().max()
    < 1.0e-8
)

assert stage_pressures_bara == sorted(
    stage_pressures_bara,
    reverse=True,
)
assert all(
    base_equipment[f"recompressor {index}"].getPower("MW") > 0.0
    for index in range(1, 4)
)
assert base_equipment["TEX"].getPower("MW") < 0.0
assert base_equipment["export compressor"].getPower("MW") > 0.0

assert (
    stream_mole_fraction(export_gas, "methane")
    > stream_mole_fraction(export_oil, "methane")
)
assert (
    stream_mole_fraction(export_oil, "C12_PC")
    > stream_mole_fraction(export_gas, "C12_PC")
)
assert ngl_tvp_bara > oil_tvp_bara > 0.0
assert 25.0 < export_gcv_mj_per_sm3 < 65.0

assert np.all(
    np.abs(scenario_table["mass residual [kg/h]"])
    < 1.0e-4
)
assert (
    scenario_table["TEX outlet pressure [bara]"].nunique()
    == len(scenario_pressures_bara)
)
assert not feasible_scenarios.empty
assert (
    selected_scenario["NGL product [kg/h]"]
    == feasible_scenarios["NGL product [kg/h]"].max()
)

print("All integrated-process engineering checks passed.")
# Out:
# All integrated-process engineering checks passed.

# %% [markdown]
# ## Interpretation and limitations
#
# - The model closes mass and component balances and demonstrates composable NeqSim equipment.
# - SRK/classic is an educational starting point; tune against laboratory and plant data.
# - Fixed separator temperatures and ideal pressure specifications omit equipment pressure drop,
#   heat-exchanger area, fouling, and control action.
# - The NGL column uses five equilibrium stages and a fixed reboiler temperature. Tray efficiency,
#   diameter, flooding, condenser design, and product specifications require further work.
# - The stabilizer-overhead arrangement is illustrative. A real recycle should be
#   solved with convergence controls and checked against the full hydrocarbon-dew-point envelope.
# - TVP is calculated thermodynamically; custody-transfer RVP methods have method-specific
#   definitions and should be selected explicitly.
# - The scenario selection is not an economic optimum or an engineering approval.

# %% [markdown]
# ## Troubleshooting
#
# - **Java startup:** the first NeqSim import starts the JVM and can take several seconds.
# - **Column convergence:** begin with the documented pressures and 120 °C reboiler target, then
#   change one variable at a time.
# - **Scenario order dependence:** always construct a fresh process for every point, as done here.
# - **Unexpected phase results:** verify composition normalization, TBP units, absolute pressure,
#   mixing rule, and `setMultiPhaseCheck(True)`.
# - **Missing outputs:** run the notebook top to bottom in one clean Colab runtime.

# %% [markdown]
# ## Summary
#
# You repaired the full intent of the original draft: a synthetic reservoir fluid enters
# separate HP and LP trains, oil is stabilized through four stages, flash gas is recompressed,
# the combined gas is cooled and expanded, NGL is stabilized, and three final products are
# audited. The final reusable workflow exposes current NeqSim `Stream`, `ThreePhaseSeparator`,
# `ThrottlingValve`, `Mixer`, `Cooler`, `Compressor`, `Expander`, `DistillationColumn`,
# `Pump`, `Splitter`, and `ProcessSystem` functionality.

# %% [markdown]
# ## Further exercises
#
# 1. Replace the synthetic assay with a licensed Eclipse-300 fluid and document provenance.
# 2. Add water, SRK-CPA, produced-water routing, and hydrate-margin checks.
# 3. Solve the stabilizer-overhead recycle with a NeqSim `Recycle` and convergence diagnostics.
# 4. Add compressor maps, stage intercooling, anti-surge constraints, and driver efficiency.
# 5. Optimize separator pressures against oil recovery, export power, TVP, and emissions.
# 6. Add mechanical sizing for separators, pumps, compressors, valves, and the NGL column.
# 7. Compare the NGL stabilizer with a rigorous deethanizer/debutanizer sequence.

# %% [markdown]
# ## Authoritative references
#
# - [NeqSim documentation](https://equinor.github.io/neqsim/)
# - [Getting started and process equipment](https://equinor.github.io/neqsim/wiki/getting_started.html)
# - [NeqSim modules and process capabilities](https://equinor.github.io/neqsim/modules.html)
# - [Process design guide](https://equinor.github.io/neqsim/process/process_design_guide)
# - [Original USN/NTNU process-study reference retained from the draft](https://openarchive.usn.no/usn-xmlui/handle/11250/2439061)
#
# All calculations are educational. They do not replace project-specific model selection,
# validation, vendor data, HAZOP/LOPA decisions, or accountable engineering approval.
