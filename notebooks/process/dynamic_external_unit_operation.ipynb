# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/process/dynamic_external_unit_operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Dynamic simulation with a custom external Python unit operation
#
# This tutorial implements a lumped electrically heated coil in Python, exposes it through
# NeqSim's unit-operation interface, connects it to NeqSim streams and a valve, and advances
# the combined model through a controlled transient.
#
# The example focuses on a reusable integration pattern, energy conservation, numerical
# stability, and transparent comparison with the analytical first-order response.

# %% [markdown]
# ## Learning outcomes
#
# After completing the notebook, you should be able to:
#
# 1. implement a Python unit operation that satisfies NeqSim's process-equipment interface;
# 2. preserve named inlet and outlet streams for connection to built-in equipment;
# 3. derive and integrate a dynamic energy balance with consistent kW, kJ, K, and s units;
# 4. orchestrate a Python proxy and Java equipment in a deterministic external time loop;
# 5. compare explicit-Euler results with the analytical first-order solution; and
# 6. test energy residuals, mass-flow continuity, pressure ordering, and time-step stability.

# %%
import importlib.util
import os
import subprocess
import sys

skip_install = os.environ.get("NEQSIM_SKIP_PIP_INSTALL") == "1"
if importlib.util.find_spec("neqsim") is None and not skip_install:
    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--no-cache-dir",
            "neqsim",
        ]
    )

from importlib.metadata import version

import json
import math

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from jpype import JClass
from jpype import JOverride

from neqsim import jneqsim
from neqsim.process.unitop import unitop

NEQSIM_VERSION = version("neqsim")
JavaUUID = JClass("java.util.UUID")
print(f"NeqSim {NEQSIM_VERSION}; Python {sys.version.split()[0]}")
# Out:
# NeqSim 3.16.0; Python 3.12.13

# %% [markdown]
# ## Dynamic model
#
# The custom unit is a perfectly mixed thermal mass. Its temperature is also used as the
# outlet-stream temperature:
#
# $$
# C \frac{dT}{dt}
# = \dot{m} c_p (T_\mathrm{in} - T)
# + Q_\mathrm{heater}
# - UA(T - T_\mathrm{amb})
# $$
#
# Here $C$ is in kJ/K, all energy-rate terms are in kW, and time is in seconds. For
# constant properties and inputs, the time constant and steady temperature are
#
# $$
# \tau = \frac{C}{\dot{m}c_p + UA}
# $$
#
# $$
# T_\mathrm{ss}
# = \frac{\dot{m}c_p T_\mathrm{in} + Q_\mathrm{heater} + UA T_\mathrm{amb}}
# {\dot{m}c_p + UA}
# $$
#
# The explicit-Euler step is suitable only when the selected time step is small relative
# to $\tau$.

# %% [markdown]
# ## 1. Case definition and thermodynamic basis
#
# The feed is a lean, single-phase SRK gas at 50 bara. NeqSim supplies the real-gas heat
# capacity, stream state, and downstream valve calculation. The custom heater supplies
# only the dynamic thermal state.

# %%
case = {
    "feed_temperature_K": 280.0,
    "feed_pressure_bara": 50.0,
    "export_pressure_bara": 45.0,
    "mass_flow_kg_per_s": 2.0,
    "thermal_mass_kJ_per_K": 5_000.0,
    "ambient_temperature_K": 295.0,
    "UA_kW_per_K": 2.0,
    "time_step_s": 5.0,
    "duration_s": 5_000.0,
}

composition = {
    "methane": 0.78,
    "ethane": 0.20,
    "n-butane": 0.02,
}

assert math.isclose(sum(composition.values()), 1.0, abs_tol=1.0e-12)
display(pd.Series(case, name="value").to_frame())
display(pd.Series(composition, name="mole fraction [-]").to_frame())
# Out:
#                         value
# feed_temperature_K      280.0
# feed_pressure_bara       50.0
# export_pressure_bara     45.0
# mass_flow_kg_per_s        2.0
# thermal_mass_kJ_per_K  5000.0
# ambient_temperature_K   295.0
# UA_kW_per_K               2.0
# time_step_s               5.0
# duration_s             5000.0
#           mole fraction [-]
# methane                0.78
# ethane                 0.20
# n-butane               0.02

# %%
feed_fluid = jneqsim.thermo.system.SystemSrkEos(
    case["feed_temperature_K"],
    case["feed_pressure_bara"],
)
for component, mole_fraction in composition.items():
    feed_fluid.addComponent(component, mole_fraction)
feed_fluid.setMixingRule("classic")
feed_fluid.setMultiPhaseCheck(True)
feed_fluid.init(0)
feed_fluid.initProperties()

feed_stream = jneqsim.process.equipment.stream.Stream(
    "dynamic heater feed",
    feed_fluid,
)
feed_stream.setFlowRate(case["mass_flow_kg_per_s"], "kg/sec")
feed_stream.setTemperature(case["feed_temperature_K"], "K")
feed_stream.setPressure(case["feed_pressure_bara"], "bara")
feed_stream.setCalculateSteadyState(False)
feed_stream.run()

feed_state = pd.Series(
    {
        "temperature [K]": feed_stream.getTemperature("K"),
        "pressure [bara]": feed_stream.getPressure("bara"),
        "mass flow [kg/s]": feed_stream.getFlowRate("kg/sec"),
        "density [kg/m3]": feed_stream.getFluid().getDensity("kg/m3"),
        "Cp [kJ/(kg K)]": feed_stream.getFluid().getCp("kJ/kgK"),
        "phases [-]": feed_stream.getFluid().getNumberOfPhases(),
    },
    name="feed",
)
display(feed_state.to_frame().round(6))
# Out:
#                         feed
# temperature [K]   280.000000
# pressure [bara]    50.000000
# mass flow [kg/s]    2.000000
# density [kg/m3]    51.723706
# Cp [kJ/(kg K)]      2.663838
# phases [-]          1.000000

# %% [markdown]
# ## 2. Implement the external unit operation
#
# The class inherits NeqSim's Python unit-operation proxy. The run method initializes the
# state for a steady process pass. The runTransient method performs one explicit-Euler
# step and updates a cloned NeqSim outlet fluid.
#
# The outlet is a normal NeqSim Stream, so Java unit operations can consume it without
# knowing the heater equations were implemented in Python.

# %%
class DynamicExternalHeater(unitop):
    def __init__(self, name):
        super().__init__()
        self.setName(name)
        self.inlet_stream = None
        self.outlet_stream = None
        self.thermal_mass_kJ_per_K = 1.0
        self.heater_power_kW = 0.0
        self.UA_kW_per_K = 0.0
        self.ambient_temperature_K = 298.15
        self.temperature_K = None
        self.last_terms = {}

    def setInputStream(self, inlet_stream):
        self.inlet_stream = inlet_stream
        outlet_name = f"{self.getName()} outlet"
        self.outlet_stream = jneqsim.process.equipment.stream.Stream(
            outlet_name,
            inlet_stream.getFluid().clone(),
        )
        self.outlet_stream.setCalculateSteadyState(False)

    def getOutputStream(self):
        return self.outlet_stream

    def setThermalMass(self, thermal_mass_kJ_per_K):
        self.thermal_mass_kJ_per_K = float(thermal_mass_kJ_per_K)

    def setHeaterPower(self, heater_power_kW):
        self.heater_power_kW = float(heater_power_kW)

    def setHeatLoss(self, UA_kW_per_K, ambient_temperature_K):
        self.UA_kW_per_K = float(UA_kW_per_K)
        self.ambient_temperature_K = float(ambient_temperature_K)

    def _update_outlet(self):
        updated_fluid = self.inlet_stream.getFluid().clone()
        updated_fluid.setTemperature(self.temperature_K, "K")
        updated_fluid.setPressure(
            self.inlet_stream.getPressure("bara"),
            "bara",
        )
        updated_fluid.initProperties()
        self.outlet_stream.setThermoSystem(updated_fluid)

    def _record_terms(
        self,
        inlet_temperature_K,
        convective_kW,
        ambient_loss_kW,
        storage_kW,
        residual_kW,
        time_step_s,
    ):
        self.last_terms = {
            "inlet temperature [K]": float(inlet_temperature_K),
            "heater temperature [K]": float(self.temperature_K),
            "heater power [kW]": float(self.heater_power_kW),
            "convective term [kW]": float(convective_kW),
            "ambient loss [kW]": float(ambient_loss_kW),
            "storage rate [kW]": float(storage_kW),
            "energy residual [kW]": float(residual_kW),
            "time step [s]": float(time_step_s),
        }

    def getLastEnergyTerms(self):
        return dict(self.last_terms)

    @JOverride
    def run(self, calculation_id=None):
        self.temperature_K = self.inlet_stream.getTemperature("K")
        self._update_outlet()
        self._record_terms(
            self.temperature_K,
            0.0,
            self.UA_kW_per_K
            * (self.temperature_K - self.ambient_temperature_K),
            0.0,
            0.0,
            0.0,
        )

    @JOverride
    def runTransient(self, time_step_s, calculation_id=None):
        time_step_s = float(time_step_s)
        inlet_temperature_K = self.inlet_stream.getTemperature("K")
        old_temperature_K = self.temperature_K
        mass_flow_kg_per_s = self.inlet_stream.getFlowRate("kg/sec")
        cp_kJ_per_kgK = self.inlet_stream.getFluid().getCp("kJ/kgK")

        convective_kW = (
            mass_flow_kg_per_s
            * cp_kJ_per_kgK
            * (inlet_temperature_K - old_temperature_K)
        )
        ambient_loss_kW = self.UA_kW_per_K * (
            old_temperature_K - self.ambient_temperature_K
        )
        net_rate_kW = (
            convective_kW
            + self.heater_power_kW
            - ambient_loss_kW
        )
        temperature_change_K = (
            net_rate_kW
            * time_step_s
            / self.thermal_mass_kJ_per_K
        )
        self.temperature_K = old_temperature_K + temperature_change_K

        storage_kW = (
            self.thermal_mass_kJ_per_K
            * temperature_change_K
            / time_step_s
        )
        residual_kW = net_rate_kW - storage_kW

        self._update_outlet()
        self._record_terms(
            inlet_temperature_K,
            convective_kW,
            ambient_loss_kW,
            storage_kW,
            residual_kW,
            time_step_s,
        )

# %% [markdown]
# ## 3. Assemble a composable process
#
# The Python heater is placed between a NeqSim feed stream and a NeqSim throttling valve.
# ProcessSystem performs the initial ordered run. The transient is then driven by an
# external loop because Python proxy objects are not Java-serializable in NeqSim 3.16.0;
# the standard ProcessSystem.runTransient path deep-copies the process.
#
# Explicit orchestration avoids that copy while retaining normal NeqSim streams and
# equipment on both sides of the custom model.

# %%
dynamic_heater = DynamicExternalHeater("external electric heater")
dynamic_heater.setInputStream(feed_stream)
dynamic_heater.setThermalMass(case["thermal_mass_kJ_per_K"])
dynamic_heater.setHeatLoss(
    case["UA_kW_per_K"],
    case["ambient_temperature_K"],
)
dynamic_heater.setHeaterPower(100.0)

export_valve = jneqsim.process.equipment.valve.ThrottlingValve(
    "export pressure valve",
    dynamic_heater.getOutputStream(),
)
export_valve.setOutletPressure(case["export_pressure_bara"], "bara")
export_valve.setCalculateSteadyState(False)

process = jneqsim.process.processmodel.ProcessSystem()
process.add(feed_stream)
process.add(dynamic_heater)
process.add(export_valve)
process.run()

initial_process_state = pd.Series(
    {
        "feed pressure [bara]": feed_stream.getPressure("bara"),
        "heater outlet pressure [bara]": (
            dynamic_heater.getOutputStream().getPressure("bara")
        ),
        "valve outlet pressure [bara]": (
            export_valve.getOutletStream().getPressure("bara")
        ),
        "feed mass flow [kg/s]": feed_stream.getFlowRate("kg/sec"),
        "heater outlet mass flow [kg/s]": (
            dynamic_heater.getOutputStream().getFlowRate("kg/sec")
        ),
    },
    name="initial process",
)
display(initial_process_state.to_frame().round(8))
# Out:
#                                 initial process
# feed pressure [bara]                       50.0
# heater outlet pressure [bara]              50.0
# valve outlet pressure [bara]               45.0
# feed mass flow [kg/s]                       2.0
# heater outlet mass flow [kg/s]              2.0

# %%
fig, ax = plt.subplots(figsize=(9.0, 2.8))
ax.axis("off")
equipment = [
    (0.08, "NeqSim\nfeed stream", "tab:blue"),
    (0.40, "Python dynamic\nheater", "tab:red"),
    (0.72, "NeqSim\nexport valve", "tab:green"),
]
for x_position, label, color in equipment:
    box = plt.Rectangle(
        (x_position, 0.34),
        0.20,
        0.32,
        facecolor=color,
        edgecolor="black",
        alpha=0.22,
    )
    ax.add_patch(box)
    ax.text(
        x_position + 0.10,
        0.50,
        label,
        ha="center",
        va="center",
        fontsize=11,
    )
for start, end in [(0.28, 0.40), (0.60, 0.72)]:
    ax.annotate(
        "",
        xy=(end, 0.50),
        xytext=(start, 0.50),
        arrowprops={"arrowstyle": "->", "linewidth": 2},
    )
ax.set_xlim(0.0, 1.0)
ax.set_ylim(0.0, 1.0)
ax.set_title("Composable external-unit integration")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Time constant and steady states
#
# The feed heat capacity is evaluated once at the fixed inlet state. The analytical
# quantities provide an independent reference for the numerical transient and make the
# time-step choice auditable.

# %%
cp_kJ_per_kgK = feed_stream.getFluid().getCp("kJ/kgK")
mass_heat_capacity_kW_per_K = (
    case["mass_flow_kg_per_s"] * cp_kJ_per_kgK
)
total_conductance_kW_per_K = (
    mass_heat_capacity_kW_per_K + case["UA_kW_per_K"]
)
time_constant_s = (
    case["thermal_mass_kJ_per_K"]
    / total_conductance_kW_per_K
)


def steady_temperature_K(heater_power_kW):
    numerator = (
        mass_heat_capacity_kW_per_K * case["feed_temperature_K"]
        + heater_power_kW
        + case["UA_kW_per_K"] * case["ambient_temperature_K"]
    )
    return numerator / total_conductance_kW_per_K


analytical_table = pd.DataFrame(
    {
        "heater power [kW]": [100.0, 300.0, 50.0],
        "steady temperature [K]": [
            steady_temperature_K(power)
            for power in [100.0, 300.0, 50.0]
        ],
    }
)
display(analytical_table.round(6))
print(f"Time constant: {time_constant_s:.3f} s")
print(
    "Time step / time constant: "
    f"{case['time_step_s'] / time_constant_s:.5f}"
)
# Out:
#    heater power [kW]  steady temperature [K]
# 0              100.0              297.740960
# 1              300.0              325.034743
# 2               50.0              290.917514
# Time constant: 682.345 s
# Time step / time constant: 0.00733

# %% [markdown]
# ## 5. Execute a scheduled transient
#
# The heater starts at 100 kW, steps to 300 kW at 600 s, and steps down to 50 kW at
# 2400 s. Each time step runs the feed, advances the Python heater, and then runs the
# downstream NeqSim valve with one shared calculation identifier.

# %%
def scheduled_power_kW(time_s):
    if time_s >= 2_400.0:
        return 50.0
    if time_s >= 600.0:
        return 300.0
    return 100.0


def record_state(time_s):
    terms = dynamic_heater.getLastEnergyTerms()
    return {
        "time [s]": time_s,
        "inlet temperature [K]": feed_stream.getTemperature("K"),
        "heater temperature [K]": dynamic_heater.temperature_K,
        "heater outlet temperature [K]": (
            dynamic_heater.getOutputStream().getTemperature("K")
        ),
        "valve outlet temperature [K]": (
            export_valve.getOutletStream().getTemperature("K")
        ),
        "heater power [kW]": dynamic_heater.heater_power_kW,
        "convective term [kW]": terms.get("convective term [kW]", 0.0),
        "ambient loss [kW]": terms.get("ambient loss [kW]", 0.0),
        "storage rate [kW]": terms.get("storage rate [kW]", 0.0),
        "energy residual [kW]": terms.get("energy residual [kW]", 0.0),
        "feed flow [kg/s]": feed_stream.getFlowRate("kg/sec"),
        "heater outlet flow [kg/s]": (
            dynamic_heater.getOutputStream().getFlowRate("kg/sec")
        ),
        "valve outlet flow [kg/s]": (
            export_valve.getOutletStream().getFlowRate("kg/sec")
        ),
        "valve outlet pressure [bara]": (
            export_valve.getOutletStream().getPressure("bara")
        ),
    }


time_step_s = case["time_step_s"]
number_of_steps = int(case["duration_s"] / time_step_s)
transient_rows = [record_state(0.0)]

for step in range(1, number_of_steps + 1):
    time_s = step * time_step_s
    dynamic_heater.setHeaterPower(scheduled_power_kW(time_s))
    calculation_id = JavaUUID.randomUUID()
    feed_stream.run(calculation_id)
    dynamic_heater.runTransient(time_step_s, calculation_id)
    export_valve.run(calculation_id)
    transient_rows.append(record_state(time_s))

transient_results = pd.DataFrame(transient_rows)
print(
    f"Executed {number_of_steps} steps to "
    f"{transient_results['time [s]'].iloc[-1]:.0f} s."
)
# Out:
# Executed 1000 steps to 5000 s.

# %%
event_times_s = [0.0, 600.0, 1_200.0, 2_400.0, 3_000.0, 5_000.0]
event_table = (
    transient_results[
        transient_results["time [s]"].isin(event_times_s)
    ][
        [
            "time [s]",
            "heater power [kW]",
            "heater outlet temperature [K]",
            "valve outlet temperature [K]",
            "energy residual [kW]",
        ]
    ]
    .reset_index(drop=True)
)
display(event_table.round(6))
# Out:
#    time [s]  heater power [kW]  heater outlet temperature [K]  valve outlet temperature [K]  energy residual [kW]
# 0       0.0              100.0                     280.000000                    276.659151                   0.0
# 1     600.0              300.0                     290.601117                    287.554006                   0.0
# 2    1200.0              300.0                     310.788760                    308.206160                   0.0
# 3    2400.0               50.0                     322.346305                    319.986421                   0.0
# 4    3000.0               50.0                     303.920328                    301.191628                   0.0
# 5    5000.0               50.0                     291.603638                    288.582306                   0.0

# %%
fig, ax_temperature = plt.subplots(figsize=(9.5, 4.8))
ax_temperature.plot(
    transient_results["time [s]"],
    transient_results["heater outlet temperature [K]"],
    color="tab:red",
    label="heater outlet temperature",
)
ax_temperature.axhline(
    case["feed_temperature_K"],
    color="tab:green",
    linestyle=":",
    label="feed temperature",
)
ax_temperature.set(
    xlabel="Time [s]",
    ylabel="Temperature [K]",
    title="Custom dynamic-heater response",
)
ax_temperature.grid(True, alpha=0.3)

ax_power = ax_temperature.twinx()
ax_power.step(
    transient_results["time [s]"],
    transient_results["heater power [kW]"],
    where="post",
    color="tab:blue",
    alpha=0.75,
    label="heater power",
)
ax_power.set_ylabel("Heater power [kW]", color="tab:blue")
ax_temperature.legend(loc="upper left")
ax_power.legend(loc="upper right")
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Analytical comparison
#
# The exact constant-coefficient solution is propagated over the same power schedule.
# The comparison isolates numerical integration error from NeqSim property and equipment
# calculations.

# %%
exact_temperatures_K = [case["feed_temperature_K"]]
for step in range(1, number_of_steps + 1):
    time_s = step * time_step_s
    target_temperature_K = steady_temperature_K(
        scheduled_power_kW(time_s)
    )
    previous_exact_K = exact_temperatures_K[-1]
    exact_temperature_K = (
        target_temperature_K
        + (previous_exact_K - target_temperature_K)
        * math.exp(-time_step_s / time_constant_s)
    )
    exact_temperatures_K.append(exact_temperature_K)

transient_results["analytical temperature [K]"] = exact_temperatures_K
transient_results["integration error [K]"] = (
    transient_results["heater outlet temperature [K]"]
    - transient_results["analytical temperature [K]"]
)

maximum_integration_error_K = transient_results[
    "integration error [K]"
].abs().max()
maximum_energy_residual_kW = transient_results[
    "energy residual [kW]"
].abs().max()

comparison_summary = pd.Series(
    {
        "maximum integration error [K]": maximum_integration_error_K,
        "maximum energy residual [kW]": maximum_energy_residual_kW,
        "final numerical temperature [K]": transient_results[
            "heater outlet temperature [K]"
        ].iloc[-1],
        "final analytical temperature [K]": transient_results[
            "analytical temperature [K]"
        ].iloc[-1],
    },
    name="comparison",
)
display(comparison_summary.to_frame().round(10))
# Out:
#                                   comparison
# maximum integration error [K]       0.056529
# maximum energy residual [kW]        0.000000
# final numerical temperature [K]   291.603638
# final analytical temperature [K]  291.612786

# %%
fig, axes = plt.subplots(2, 1, figsize=(9.5, 7.2), sharex=True)

axes[0].plot(
    transient_results["time [s]"],
    transient_results["heater outlet temperature [K]"],
    label="explicit Euler",
)
axes[0].plot(
    transient_results["time [s]"],
    transient_results["analytical temperature [K]"],
    "--",
    label="analytical",
)
axes[0].set_ylabel("Temperature [K]")
axes[0].set_title("Numerical verification")
axes[0].grid(True, alpha=0.3)
axes[0].legend()

axes[1].plot(
    transient_results["time [s]"],
    transient_results["energy residual [kW]"],
    color="tab:purple",
)
axes[1].axhline(0.0, color="black", linestyle=":")
axes[1].set(
    xlabel="Time [s]",
    ylabel="Residual [kW]",
    title="Discrete energy-balance residual",
)
axes[1].grid(True, alpha=0.3)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Thermal-inertia sensitivity
#
# The same explicit equation is evaluated for three thermal masses. Increasing thermal
# mass changes the time constant but not the final steady-state temperature.

# %%
def simulate_power_step(thermal_mass_kJ_per_K, duration_s=2_500.0):
    local_time_constant_s = (
        thermal_mass_kJ_per_K / total_conductance_kW_per_K
    )
    temperature_K = case["feed_temperature_K"]
    target_temperature_K = steady_temperature_K(300.0)
    rows = []
    steps = int(duration_s / time_step_s)
    for step in range(steps + 1):
        time_s = step * time_step_s
        rows.append(
            {
                "time [s]": time_s,
                "temperature [K]": temperature_K,
                "thermal mass [kJ/K]": thermal_mass_kJ_per_K,
                "time constant [s]": local_time_constant_s,
            }
        )
        net_rate_kW = total_conductance_kW_per_K * (
            target_temperature_K - temperature_K
        )
        temperature_K += (
            net_rate_kW
            * time_step_s
            / thermal_mass_kJ_per_K
        )
    return rows


inertia_rows = []
for thermal_mass in [2_500.0, 5_000.0, 10_000.0]:
    inertia_rows.extend(simulate_power_step(thermal_mass))
inertia_results = pd.DataFrame(inertia_rows)

fig, ax = plt.subplots(figsize=(8.5, 4.6))
for thermal_mass, group in inertia_results.groupby(
    "thermal mass [kJ/K]"
):
    ax.plot(
        group["time [s]"],
        group["temperature [K]"],
        label=f"C = {thermal_mass:.0f} kJ/K",
    )
ax.axhline(
    steady_temperature_K(300.0),
    color="black",
    linestyle=":",
    label="300 kW steady state",
)
ax.set(
    xlabel="Time [s]",
    ylabel="Temperature [K]",
    title="Thermal-mass sensitivity",
)
ax.grid(True, alpha=0.3)
ax.legend()
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Executable validation
#
# The following checks cover thermodynamic state, connection integrity, pressure ordering,
# mass-flow continuity, finite results, energy conservation, numerical agreement, response
# direction, schedule execution, and stable time-step selection.

# %%
flow_columns = [
    "feed flow [kg/s]",
    "heater outlet flow [kg/s]",
    "valve outlet flow [kg/s]",
]
maximum_flow_difference_kg_per_s = transient_results[
    flow_columns
].max(axis=1).sub(
    transient_results[flow_columns].min(axis=1)
).max()

temperature_at_600_K = event_table.loc[
    event_table["time [s]"] == 600.0,
    "heater outlet temperature [K]",
].iloc[0]
temperature_at_2400_K = event_table.loc[
    event_table["time [s]"] == 2_400.0,
    "heater outlet temperature [K]",
].iloc[0]
final_temperature_K = event_table.loc[
    event_table["time [s]"] == 5_000.0,
    "heater outlet temperature [K]",
].iloc[0]

checks = {
    "composition closes": math.isclose(
        sum(composition.values()),
        1.0,
        abs_tol=1.0e-12,
    ),
    "feed remains single phase": (
        feed_stream.getFluid().getNumberOfPhases() == 1
    ),
    "custom unit uses NeqSim unitop interface": isinstance(
        dynamic_heater,
        unitop,
    ),
    "pressure decreases across valve": (
        export_valve.getOutletStream().getPressure("bara")
        < feed_stream.getPressure("bara")
    ),
    "export pressure matches specification": math.isclose(
        export_valve.getOutletStream().getPressure("bara"),
        case["export_pressure_bara"],
        abs_tol=1.0e-9,
    ),
    "all transient temperatures are finite": np.isfinite(
        transient_results[
            [
                "heater outlet temperature [K]",
                "valve outlet temperature [K]",
            ]
        ].to_numpy()
    ).all(),
    "mass flow is continuous": (
        maximum_flow_difference_kg_per_s < 1.0e-10
    ),
    "energy balance closes": maximum_energy_residual_kW < 1.0e-8,
    "Euler result agrees with analytical model": (
        maximum_integration_error_K < 0.15
    ),
    "time step is small relative to time constant": (
        time_step_s / time_constant_s < 0.05
    ),
    "temperature rises after power increase": (
        temperature_at_2400_K > temperature_at_600_K
    ),
    "temperature falls after power reduction": (
        final_temperature_K < temperature_at_2400_K
    ),
    "power schedule contains all three levels": set(
        transient_results["heater power [kW]"].unique()
    ) == {50.0, 100.0, 300.0},
    "final state approaches 50 kW steady state": abs(
        final_temperature_K - steady_temperature_K(50.0)
    ) < 1.0,
}

for check_name, passed in checks.items():
    assert passed, check_name

display(pd.Series(checks, name="passed").to_frame())
print(f"{sum(checks.values())} engineering checks passed.")
# Out:
#                                               passed
# composition closes                              True
# feed remains single phase                       True
# custom unit uses NeqSim unitop interface        True
# pressure decreases across valve                 True
# export pressure matches specification           True
# all transient temperatures are finite           True
# mass flow is continuous                         True
# energy balance closes                           True
# Euler result agrees with analytical model       True
# time step is small relative to time constant    True
# temperature rises after power increase          True
# temperature falls after power reduction         True
# power schedule contains all three levels        True
# final state approaches 50 kW steady state       True
# 14 engineering checks passed.

# %% [markdown]
# ## 9. Reusable result object
#
# The result object records the model, schedule, numerical method, validation metrics, and
# integration limitation. It can be consumed by a larger engineering or teaching workflow.

# %%
result_object = {
    "neqsim_version": NEQSIM_VERSION,
    "model": "custom Python lumped dynamic heater",
    "thermodynamic_model": "SRK with classic mixing rule",
    "time_integration": "explicit Euler",
    "time_step_s": time_step_s,
    "time_constant_s": time_constant_s,
    "power_schedule_kW": {
        "0_to_600_s": 100.0,
        "600_to_2400_s": 300.0,
        "2400_to_5000_s": 50.0,
    },
    "maximum_integration_error_K": maximum_integration_error_K,
    "maximum_energy_residual_kW": maximum_energy_residual_kW,
    "maximum_flow_difference_kg_per_s": (
        maximum_flow_difference_kg_per_s
    ),
    "final_heater_temperature_K": final_temperature_K,
    "final_export_pressure_bara": (
        export_valve.getOutletStream().getPressure("bara")
    ),
    "checks_passed": int(sum(checks.values())),
    "integration_note": (
        "Python proxy is advanced in an external ordered loop because "
        "ProcessSystem.runTransient deep-copies Java-serializable equipment."
    ),
}
print(json.dumps(result_object, indent=2))
# Out:
# {
#   "neqsim_version": "3.16.0",
#   "model": "custom Python lumped dynamic heater",
#   "thermodynamic_model": "SRK with classic mixing rule",
#   "time_integration": "explicit Euler",
#   "time_step_s": 5.0,
#   "time_constant_s": 682.3445983335919,
#   "power_schedule_kW": {
#     "0_to_600_s": 100.0,
#     "600_to_2400_s": 300.0,
#     "2400_to_5000_s": 50.0
#   },
#   "maximum_integration_error_K": 0.05652898777429982,
#   "maximum_energy_residual_kW": 2.842170943040401e-14,
#   "maximum_flow_difference_kg_per_s": 0.0,
#   "final_heater_temperature_K": 291.6036380297689,
#   "final_export_pressure_bara": 45.0,
#   "checks_passed": 14,
#   "integration_note": "Python proxy is advanced in an external ordered loop because ProcessSystem.runTransient deep-copies Java-serializable equipment."
# }

# %% [markdown]
# ## Results and engineering interpretation
#
# The external heater preserved the NeqSim stream interface and could therefore feed a
# normal NeqSim valve. The temperature followed the scheduled duty with the expected
# first-order lag. The explicit-Euler trace agreed closely with the analytical solution,
# and mass flow and the discrete energy balance closed through the transient.
#
# Thermal mass controlled response speed, while duty, flow heat capacity, heat loss, inlet
# temperature, and ambient temperature controlled the steady value.

# %% [markdown]
# ## Limitations and applicability
#
# - The heater is a single lumped temperature; wall, fluid, and axial gradients are not resolved.
# - Feed properties are held at a fixed inlet state. Strong property variation should be
#   evaluated inside the transient model or with an implicit solver.
# - Explicit Euler requires a time-step stability and convergence study.
# - The Python proxy is not Java-serializable in NeqSim 3.16.0, so ProcessSystem.runTransient
#   cannot deep-copy this mixed process. The documented external ordered loop is used instead.
# - The example has no controller, measurement delay, actuator dynamics, or heat-source limit.
# - A production implementation should add input validation, failure states, serialization,
#   a stable public interface, regression tests, and performance profiling.

# %% [markdown]
# ## References and suggested exercises
#
# - [NeqSim Python package](https://pypi.org/project/neqsim/)
# - [NeqSim process simulation documentation](https://equinor.github.io/neqsim/process/)
# - [NeqSim source repository](https://github.com/equinor/neqsim)
#
# Exercises:
#
# 1. Replace explicit Euler with an implicit or exact first-order update and compare time steps.
# 2. Add a temperature transmitter and PI controller that manipulates heater power.
# 3. Split wall and fluid into two thermal states and identify both time constants.
# 4. Recalculate heat capacity at the evolving outlet state and quantify the nonlinearity.
# 5. Implement a serializable Java version and compare it with the Python proxy workflow.
