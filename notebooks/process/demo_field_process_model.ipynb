# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/process/demo_field_process_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Standalone field process model with separation, recompression, and gas injection
#
# **Audience.** Process, production, and field-development engineers who know basic phase
# equilibrium and want a reproducible NeqSim flowsheet that can be adapted to screening studies.
#
# **Prerequisites.** Familiarity with pressure, temperature, mass flow, separators, valves, and
# compressors. All calculations use SI-derived engineering units: bara, °C, kg/h, and MW.

# %% [markdown]
# ## Learning objectives
#
# After completing this notebook, you can:
#
# 1. define a synthetic reservoir-fluid assay with characterized heavy fractions;
# 2. connect streams, valves, heaters, separators, mixers, compressors, coolers, a pump, and a
#    splitter in a NeqSim `ProcessSystem`;
# 3. run three-stage oil stabilization and two-stage flash-gas recompression;
# 4. divide treated gas between export and reinjection services;
# 5. retrieve process results by equipment name and check pressures, mass, and every component;
# 6. vary injection fraction and field throughput using independent fresh flowsheets; and
# 7. export a compact machine-readable design snapshot for reuse.
#
# The notebook preserves the original workbook's intended examples: structured inputs, synthetic
# replacement of spreadsheet data, fluid construction, well-stream creation, separation, gas
# injection, full-process assembly, valve checks, mass balance, result export, and a process-flow
# diagram.

# %% [markdown]
# ## Colab setup
#
# The cell below installs the latest public PyPI package only when NeqSim is absent. In a clean
# Colab runtime it executes `python -m pip install --upgrade --no-cache-dir neqsim`. Java 17 or
# newer is required by current NeqSim releases.

# %%
import importlib.metadata
import subprocess
import sys


try:
    neqsim_version = importlib.metadata.version("neqsim")
except importlib.metadata.PackageNotFoundError:
    subprocess.run(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--no-cache-dir",
            "neqsim",
        ],
        check=True,
    )
    neqsim_version = importlib.metadata.version("neqsim")

java_runtime = subprocess.run(
    ["java", "-version"],
    check=True,
    capture_output=True,
    text=True,
).stderr.splitlines()[0]

print(f"NeqSim package: {neqsim_version}")
print(f"Python runtime: {sys.version.split()[0]}")
print(f"Java runtime: {java_runtime}")
# Out:
# NeqSim package: 3.16.0
# Python runtime: 3.12.13
# Java runtime: openjdk version "17.0.19" 2026-04-21

# %% [markdown]
# ## Engineering basis and governing balances
#
# A stage separator performs an equilibrium flash at its inlet pressure and temperature. Lowering
# pressure releases dissolved light components from the liquid. Recompression then returns the
# flash gas to the high-pressure gas system. The steady-state total mass balance is
#
# $$
#
# \dot{m}_{feed} = \sum_j \dot{m}_{product,j}
#
# $$
#
# and the component balance for component $i$ is
#
# $$
#
# \dot{m}_{i,feed} = \sum_j \dot{m}_{i,product,j}.
#
# $$
#
# Here $\dot{m}$ is mass flow in kg/h, $j$ identifies a boundary product, and $i$ identifies a
# chemical component or characterized pseudo-component. Separator and scrubber liquids are counted
# explicitly at the model boundary; they are not silently discarded.

# %% [markdown]
# ## Compression and routing
#
# NeqSim calculates compressor power from the thermodynamic enthalpy rise. The engineering energy
# rate is
#
# $$
#
# \dot{W} = \dot{n}(h_{out} - h_{in}),
#
# $$
#
# where $\dot{n}$ is molar flow, $h$ is molar enthalpy, and $\dot{W}$ is power. Isentropic efficiency
# is specified explicitly for every compressor.
#
# The treated gas splitter applies an injection fraction $f_{inj}$:
#
# $$
#
# \dot{m}_{inj} = f_{inj}\dot{m}_{treated}.
#
# $$
#
# This is a steady-state screening model. It does not represent wells, reservoir injectivity,
# compressor maps, anti-surge control, equipment dimensions, or dynamic inventories.

# %%
from dataclasses import asdict, dataclass
import json
import math

import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch, FancyBboxPatch
import numpy as np
import pandas as pd
from neqsim.process import (
    clearProcess,
    compressor,
    cooler,
    getProcess,
    heater,
    mixer,
    pump,
    runProcess,
    separator,
    splitter,
    stream,
    valve,
)
from neqsim.thermo import TPflash, fluid_df


plt.style.use("seaborn-v0_8-whitegrid")
pd.set_option("display.precision", 7)

# %% [markdown]
# ## Explicit case contract
#
# The original workbook had a very large, partially wired input class populated from spreadsheets.
# This compact immutable contract exposes every input varied in this tutorial. Fixed temperatures
# and efficiencies remain visible in the builder code.

# %%
@dataclass(frozen=True)
class FieldCase:
    feed_rate_kg_per_h: float = 75_000.0
    hp_pressure_bara: float = 80.0
    mp_pressure_bara: float = 20.0
    lp_pressure_bara: float = 5.0
    injection_fraction: float = 0.25
    export_pressure_bara: float = 110.0
    injection_pressure_bara: float = 160.0


base_case = FieldCase()
display(pd.Series(asdict(base_case), name="base field case"))
# Out:
# feed_rate_kg_per_h         75000.00
# hp_pressure_bara              80.00
# mp_pressure_bara              20.00
# lp_pressure_bara               5.00
# injection_fraction             0.25
# export_pressure_bara         110.00
# injection_pressure_bara      160.00
# Name: base field case, dtype: float64

# %% [markdown]
# ## Public synthetic fluid assay
#
# The legacy notebook expected a private Excel workbook and site-specific process data. Those inputs
# cannot be reproduced in Colab, so this repair uses a documented synthetic rich field fluid. C7,
# C8, C10, and C12 are characterized pseudo-components defined by molar mass and relative density.
# The values are illustrative rather than a benchmark for a real asset.

# %%
COMPONENTS = [
    "nitrogen",
    "CO2",
    "methane",
    "ethane",
    "propane",
    "i-butane",
    "n-butane",
    "i-pentane",
    "n-pentane",
    "n-hexane",
    "C7",
    "C8",
    "C10",
    "C12",
]
RELATIVE_AMOUNTS = [
    0.7,
    1.5,
    45.0,
    8.0,
    6.0,
    2.0,
    3.0,
    1.5,
    2.0,
    3.5,
    6.0,
    7.0,
    8.0,
    8.0,
]
MOLAR_MASSES_KG_PER_MOL = [
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    0.098,
    0.112,
    0.140,
    0.168,
]
RELATIVE_DENSITIES = [
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    None,
    0.73,
    0.75,
    0.79,
    0.82,
]

assay = pd.DataFrame(
    {
        "component": COMPONENTS,
        "relative molar amount": RELATIVE_AMOUNTS,
        "molar mass [kg/mol]": MOLAR_MASSES_KG_PER_MOL,
        "relative density [-]": RELATIVE_DENSITIES,
    }
)
assay["mole fraction [-]"] = (
    assay["relative molar amount"]
    / assay["relative molar amount"].sum()
)

display(assay)
print(f"Composition sum: {assay['mole fraction [-]'].sum():.12f}")
# Out:
#     component  relative molar amount  ...  relative density [-]  mole fraction [-]
# 0    nitrogen                    0.7  ...                   NaN          0.0068493
# 1         CO2                    1.5  ...                   NaN          0.0146771
# 2     methane                   45.0  ...                   NaN          0.4403131
# 3      ethane                    8.0  ...                   NaN          0.0782779
# 4     propane                    6.0  ...                   NaN          0.0587084
# 5    i-butane                    2.0  ...                   NaN          0.0195695
# 6    n-butane                    3.0  ...                   NaN          0.0293542
# 7   i-pentane                    1.5  ...                   NaN          0.0146771
# 8   n-pentane                    2.0  ...                   NaN          0.0195695
# 9    n-hexane                    3.5  ...                   NaN          0.0342466
# ...

# %%
def create_feed_fluid():
    composition = pd.DataFrame(
        {
            "ComponentName": COMPONENTS,
            "MolarComposition[-]": RELATIVE_AMOUNTS,
            "MolarMass[kg/mol]": MOLAR_MASSES_KG_PER_MOL,
            "RelativeDensity[-]": RELATIVE_DENSITIES,
        }
    )
    feed_fluid = fluid_df(
        composition,
        lastIsPlusFraction=False,
    )
    feed_fluid.setMixingRule("classic")
    feed_fluid.setMultiPhaseCheck(True)
    return feed_fluid


reference_fluid = create_feed_fluid()
reference_fluid.setTemperature(70.0, "C")
reference_fluid.setPressure(80.0, "bara")
reference_fluid.setTotalFlowRate(
    base_case.feed_rate_kg_per_h,
    "kg/hr",
)
TPflash(reference_fluid)
reference_fluid.initProperties()

assert math.isclose(
    assay["mole fraction [-]"].sum(),
    1.0,
    abs_tol=1.0e-12,
)
assert 1.0 < reference_fluid.getDensity("kg/m3") < 1000.0

print(f"Feed bulk density: {reference_fluid.getDensity('kg/m3'):.6f} kg/m³")
print(f"Feed molar mass: {reference_fluid.getMolarMass():.8f} kg/mol")
# Out:
# Feed bulk density: 301.946438 kg/m³
# Feed molar mass: 0.05864445 kg/mol

# %% [markdown]
# ## Flowsheet overview
#
# The field model is deliberately modular. The stabilization section produces export oil and three
# flash-gas streams. The gas section cools, scrubs, recompresses, mixes, and routes treated gas to
# export or reinjection. This diagram is the first technical figure and maps directly to the builder
# functions below.

# %%
figure, axis = plt.subplots(figsize=(13.0, 6.2))
axis.set_xlim(0.0, 13.0)
axis.set_ylim(0.0, 6.2)
axis.axis("off")

boxes = [
    (0.3, 4.4, "Synthetic\nwell stream"),
    (2.2, 4.4, "HP, MP, LP\nseparation"),
    (4.4, 4.4, "Oil pump\n+ cooler"),
    (2.2, 1.5, "LP + MP flash-gas\nrecompression"),
    (5.1, 1.5, "HP gas mixer\n+ scrubber"),
    (7.6, 1.5, "Gas routing\nsplitter"),
    (10.1, 3.5, "Export gas\ncompression"),
    (10.1, 0.2, "Injection gas\ncompression"),
]

for x_position, y_position, label in boxes:
    box = FancyBboxPatch(
        (x_position, y_position),
        1.7,
        0.9,
        boxstyle="round,pad=0.08",
        facecolor="#DCEAF7",
        edgecolor="#1F4E79",
        linewidth=1.6,
    )
    axis.add_patch(box)
    axis.text(
        x_position + 0.85,
        y_position + 0.45,
        label,
        ha="center",
        va="center",
        fontsize=10,
    )

arrows = [
    ((2.0, 4.85), (2.2, 4.85)),
    ((3.9, 4.85), (4.4, 4.85)),
    ((3.05, 4.4), (3.05, 2.4)),
    ((3.9, 1.95), (5.1, 1.95)),
    ((6.8, 1.95), (7.6, 1.95)),
    ((9.3, 2.2), (10.1, 3.85)),
    ((9.3, 1.7), (10.1, 0.65)),
]

for start, end in arrows:
    axis.add_patch(
        FancyArrowPatch(
            start,
            end,
            arrowstyle="-|>",
            mutation_scale=14,
            linewidth=1.6,
            color="#404040",
        )
    )

axis.set_title(
    "Standalone NeqSim field process: stabilization, recompression, and gas routing",
    fontsize=14,
    pad=12,
)
plt.show()

# %% [markdown]
# ## Build the stabilization section
#
# The well stream enters at 80 bara and 70 °C. Each lower-pressure stage releases more gas. Heating
# the MP and LP liquids to specified temperatures makes the assumptions explicit and avoids hidden
# state. The final oil is pumped to 25 bara and cooled to 25 °C.

# %%
def add_stabilization_section(case):
    well_stream = stream("well stream", create_feed_fluid())
    well_stream.setFlowRate(case.feed_rate_kg_per_h, "kg/hr")
    well_stream.setPressure(case.hp_pressure_bara, "bara")
    well_stream.setTemperature(70.0, "C")

    hp_separator = separator("HP separator", well_stream)

    hp_liquid_valve = valve(
        "HP liquid valve",
        hp_separator.getLiquidOutStream(),
        case.mp_pressure_bara,
    )
    hp_liquid_valve.setOutletPressure(
        case.mp_pressure_bara,
        "bara",
    )
    mp_heater = heater(
        "MP heater",
        hp_liquid_valve.getOutletStream(),
    )
    mp_heater.setOutTemperature(60.0, "C")
    mp_separator = separator(
        "MP separator",
        mp_heater.getOutletStream(),
    )

    mp_liquid_valve = valve(
        "MP liquid valve",
        mp_separator.getLiquidOutStream(),
        case.lp_pressure_bara,
    )
    mp_liquid_valve.setOutletPressure(
        case.lp_pressure_bara,
        "bara",
    )
    lp_heater = heater(
        "LP heater",
        mp_liquid_valve.getOutletStream(),
    )
    lp_heater.setOutTemperature(55.0, "C")
    lp_separator = separator(
        "LP separator",
        lp_heater.getOutletStream(),
    )

    oil_pump = pump(
        "oil export pump",
        lp_separator.getLiquidOutStream(),
        25.0,
    )
    oil_pump.setOutletPressure(25.0, "bara")
    oil_cooler = cooler(
        "oil export cooler",
        oil_pump.getOutletStream(),
    )
    oil_cooler.setOutTemperature(25.0, "C")
    export_oil = stream(
        "export oil",
        oil_cooler.getOutletStream(),
    )

    return {
        "feed": well_stream,
        "hp_separator": hp_separator,
        "mp_separator": mp_separator,
        "lp_separator": lp_separator,
        "hp_liquid_valve": hp_liquid_valve,
        "mp_liquid_valve": mp_liquid_valve,
        "export_oil": export_oil,
    }

# %% [markdown]
# ## Build flash-gas recompression
#
# Each compressor has an upstream cooler and scrubber. The scrubbers protect the compressor model
# from liquid carry-over. Gas from a lower-pressure stage is compressed to the next-stage pressure,
# mixed with the native gas there, and finally returned to HP pressure.

# %%
def add_recompression_section(case, stabilization):
    lp_separator = stabilization["lp_separator"]
    mp_separator = stabilization["mp_separator"]
    hp_separator = stabilization["hp_separator"]

    lp_gas_cooler = cooler(
        "LP gas cooler",
        lp_separator.getGasOutStream(),
    )
    lp_gas_cooler.setOutTemperature(30.0, "C")
    lp_scrubber = separator(
        "LP compressor scrubber",
        lp_gas_cooler.getOutletStream(),
    )
    lp_compressor = compressor(
        "LP gas compressor",
        lp_scrubber.getGasOutStream(),
        case.mp_pressure_bara,
    )
    lp_compressor.setOutletPressure(
        case.mp_pressure_bara,
        "bara",
    )
    lp_compressor.setIsentropicEfficiency(0.78)

    mp_gas_mixer = mixer("MP gas mixer")
    mp_gas_mixer.addStream(
        mp_separator.getGasOutStream()
    )
    mp_gas_mixer.addStream(
        lp_compressor.getOutletStream()
    )
    mp_gas_cooler = cooler(
        "MP gas cooler",
        mp_gas_mixer.getOutletStream(),
    )
    mp_gas_cooler.setOutTemperature(30.0, "C")
    mp_scrubber = separator(
        "MP compressor scrubber",
        mp_gas_cooler.getOutletStream(),
    )
    mp_compressor = compressor(
        "MP gas compressor",
        mp_scrubber.getGasOutStream(),
        case.hp_pressure_bara,
    )
    mp_compressor.setOutletPressure(
        case.hp_pressure_bara,
        "bara",
    )
    mp_compressor.setIsentropicEfficiency(0.78)

    hp_gas_mixer = mixer("HP gas mixer")
    hp_gas_mixer.addStream(
        hp_separator.getGasOutStream()
    )
    hp_gas_mixer.addStream(
        mp_compressor.getOutletStream()
    )
    hp_gas_cooler = cooler(
        "HP gas cooler",
        hp_gas_mixer.getOutletStream(),
    )
    hp_gas_cooler.setOutTemperature(30.0, "C")
    hp_scrubber = separator(
        "HP gas scrubber",
        hp_gas_cooler.getOutletStream(),
    )

    return {
        "lp_scrubber": lp_scrubber,
        "mp_scrubber": mp_scrubber,
        "hp_scrubber": hp_scrubber,
        "lp_compressor": lp_compressor,
        "mp_compressor": mp_compressor,
    }

# %% [markdown]
# ## Build export and injection services
#
# The treated HP gas is split after the final scrubber. Export gas is compressed to 110 bara;
# injection gas is compressed to 160 bara. Both streams are cooled to 35 °C. The split is a boundary
# condition, not a reservoir deliverability calculation.

# %%
def add_gas_routing_section(case, recompression):
    hp_scrubber = recompression["hp_scrubber"]
    gas_router = splitter(
        "gas routing splitter",
        hp_scrubber.getGasOutStream(),
        [
            1.0 - case.injection_fraction,
            case.injection_fraction,
        ],
    )

    export_compressor = compressor(
        "export gas compressor",
        gas_router.getSplitStream(0),
        case.export_pressure_bara,
    )
    export_compressor.setOutletPressure(
        case.export_pressure_bara,
        "bara",
    )
    export_compressor.setIsentropicEfficiency(0.80)
    export_gas_cooler = cooler(
        "export gas cooler",
        export_compressor.getOutletStream(),
    )
    export_gas_cooler.setOutTemperature(35.0, "C")
    export_gas = stream(
        "export gas",
        export_gas_cooler.getOutletStream(),
    )

    injection_compressor = compressor(
        "injection gas compressor",
        gas_router.getSplitStream(1),
        case.injection_pressure_bara,
    )
    injection_compressor.setOutletPressure(
        case.injection_pressure_bara,
        "bara",
    )
    injection_compressor.setIsentropicEfficiency(0.78)
    injection_gas_cooler = cooler(
        "injection gas cooler",
        injection_compressor.getOutletStream(),
    )
    injection_gas_cooler.setOutTemperature(35.0, "C")
    injection_gas = stream(
        "injection gas",
        injection_gas_cooler.getOutletStream(),
    )

    return {
        "gas_router": gas_router,
        "export_compressor": export_compressor,
        "injection_compressor": injection_compressor,
        "export_gas": export_gas,
        "injection_gas": injection_gas,
    }

# %% [markdown]
# ## Compose a reusable `ProcessSystem`
#
# `clearProcess()` prevents hidden global state between cases. The wrapper functions register each
# unit in NeqSim's current `ProcessSystem`; `getProcess()` returns that assembled system. The
# equipment dictionary gives stable Python names for retrieval and testing.

# %%
def build_field_process(case):
    clearProcess()
    stabilization = add_stabilization_section(case)
    recompression = add_recompression_section(
        case,
        stabilization,
    )
    gas_routing = add_gas_routing_section(
        case,
        recompression,
    )
    equipment = {
        **stabilization,
        **recompression,
        **gas_routing,
    }
    return getProcess(), equipment


base_process, base_equipment = build_field_process(base_case)
runProcess()

retrieved_hp_separator = base_process.getUnit("HP separator")
assert retrieved_hp_separator.getName() == "HP separator"

print(f"Process unit count: {base_process.getUnitOperations().size()}")
print(f"Retrieved unit: {retrieved_hp_separator.getName()}")
# Out:
# Process unit count: 28
# Retrieved unit: HP separator

# %% [markdown]
# ## Base-case products
#
# Important results are converted to a tidy table. Scrubber liquids are shown separately because
# their downstream stabilization is outside this compact model. Their inclusion in the boundary
# balance prevents an apparently good but incomplete mass closure.

# %%
def boundary_product_streams(equipment):
    return {
        "export oil": equipment["export_oil"],
        "export gas": equipment["export_gas"],
        "injection gas": equipment["injection_gas"],
        "LP scrubber liquid": (
            equipment["lp_scrubber"].getLiquidOutStream()
        ),
        "MP scrubber liquid": (
            equipment["mp_scrubber"].getLiquidOutStream()
        ),
        "HP scrubber liquid": (
            equipment["hp_scrubber"].getLiquidOutStream()
        ),
    }


base_products = boundary_product_streams(base_equipment)
product_rows = []

for product_name, product_stream in base_products.items():
    product_rows.append(
        {
            "product": product_name,
            "mass flow [kg/h]": product_stream.getFlowRate("kg/hr"),
            "pressure [bara]": product_stream.getPressure("bara"),
            "temperature [°C]": product_stream.getTemperature("C"),
            "bulk density [kg/m³]": (
                product_stream.getFluid().getDensity("kg/m3")
            ),
        }
    )

product_table = pd.DataFrame(product_rows)
display(product_table)
# Out:
#               product  mass flow [kg/h]  ...  temperature [°C]  bulk density [kg/m³]
# 0          export oil     57640.1008846  ...              25.0           742.3707746
# 1          export gas     12139.3332329  ...              35.0           130.1100460
# 2       injection gas      4046.4444110  ...              35.0           192.9847471
# 3  LP scrubber liquid        79.4292842  ...              30.0           670.3041741
# 4  MP scrubber liquid       333.6503216  ...              30.0           604.2779522
# 5  HP scrubber liquid       761.0418656  ...              30.0           501.3077088
#
# [6 rows x 5 columns]

# %% [markdown]
# The base case routes one quarter of treated gas to injection. Export oil is the largest mass
# product. Small scrubber-liquid streams quantify the condensation created by intercooling and must
# be routed in a detailed facility model.

# %% [markdown]
# ## Separation-stage profile
#
# The second technical figure compares released gas and remaining liquid at each separator while
# showing the pressure ladder. It explains why low-pressure flash gas requires the most pressure
# ratio to return to the HP system.

# %%
stage_names = ["HP separator", "MP separator", "LP separator"]
stage_pressures_bara = [
    base_case.hp_pressure_bara,
    base_case.mp_pressure_bara,
    base_case.lp_pressure_bara,
]
stage_gas_kg_per_h = [
    base_equipment["hp_separator"].getGasOutStream()
    .getFlowRate("kg/hr"),
    base_equipment["mp_separator"].getGasOutStream()
    .getFlowRate("kg/hr"),
    base_equipment["lp_separator"].getGasOutStream()
    .getFlowRate("kg/hr"),
]
stage_liquid_kg_per_h = [
    base_equipment["hp_separator"].getLiquidOutStream()
    .getFlowRate("kg/hr"),
    base_equipment["mp_separator"].getLiquidOutStream()
    .getFlowRate("kg/hr"),
    base_equipment["lp_separator"].getLiquidOutStream()
    .getFlowRate("kg/hr"),
]

stage_table = pd.DataFrame(
    {
        "stage": stage_names,
        "pressure [bara]": stage_pressures_bara,
        "released gas [kg/h]": stage_gas_kg_per_h,
        "liquid outlet [kg/h]": stage_liquid_kg_per_h,
    }
)
display(stage_table)
# Out:
#           stage  pressure [bara]  released gas [kg/h]  liquid outlet [kg/h]
# 0  HP separator             80.0         9587.1391709         65412.8608291
# 1  MP separator             20.0         5424.2785196         59988.5823094
# 2  LP separator              5.0         2348.4814248         57640.1008846

# %%
figure, flow_axis = plt.subplots(figsize=(10.0, 5.7))
pressure_axis = flow_axis.twinx()
x_positions = np.arange(len(stage_names))

flow_axis.plot(
    x_positions,
    stage_gas_kg_per_h,
    marker="o",
    linewidth=2.2,
    color="#0072B2",
    label="Released gas",
)
flow_axis.plot(
    x_positions,
    stage_liquid_kg_per_h,
    marker="s",
    linewidth=2.2,
    color="#009E73",
    label="Liquid outlet",
)
pressure_axis.plot(
    x_positions,
    stage_pressures_bara,
    marker="D",
    linestyle="--",
    linewidth=2.0,
    color="#D55E00",
    label="Stage pressure",
)

flow_axis.set_xticks(x_positions, stage_names)
flow_axis.set_xlabel("Separation stage")
flow_axis.set_ylabel("Mass flow [kg/h]")
pressure_axis.set_ylabel("Pressure [bara]")
flow_axis.set_title("Three-stage field separation profile")
flow_axis.legend(loc="center left")
pressure_axis.legend(loc="center right")
plt.show()

# %% [markdown]
# ## Compressor duties
#
# The recompression duties are process-wide energy consumers, while the export and injection
# compressors serve different product boundaries. A stage-by-stage view makes the effect of pressure
# ratio and routed flow visible.

# %%
compressor_names = [
    "LP gas compressor",
    "MP gas compressor",
    "export gas compressor",
    "injection gas compressor",
]
compressor_keys = [
    "lp_compressor",
    "mp_compressor",
    "export_compressor",
    "injection_compressor",
]
compressor_power_mw = [
    base_equipment[key].getPower("MW")
    for key in compressor_keys
]
power_table = pd.DataFrame(
    {
        "compressor": compressor_names,
        "power [MW]": compressor_power_mw,
    }
)
display(power_table)
print(f"Total compressor power: {sum(compressor_power_mw):.6f} MW")
# Out:
#                  compressor  power [MW]
# 0         LP gas compressor   0.0927041
# 1         MP gas compressor   0.3783862
# 2     export gas compressor   0.1240101
# 3  injection gas compressor   0.0987460
# Total compressor power: 0.693846 MW

# %%
figure, axis = plt.subplots(figsize=(9.5, 5.3))
colors = ["#0072B2", "#56B4E9", "#009E73", "#D55E00"]
bars = axis.bar(
    compressor_names,
    compressor_power_mw,
    color=colors,
    label="NeqSim compressor duty",
)
axis.bar_label(
    bars,
    fmt="%.3f MW",
    padding=3,
)
axis.set_ylabel("Power [MW]")
axis.set_xlabel("Compression service")
axis.set_title("Base-case compressor power allocation")
axis.tick_params(axis="x", rotation=18)
axis.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# The MP recompressor handles accumulated LP and MP flash gas over the largest pressure interval in
# the stabilization train, so it dominates this particular synthetic case. The result is
# case-specific and should not be transferred to another fluid or pressure basis without rerunning
# the model.

# %% [markdown]
# ## Total and component conservation audit
#
# The audit uses the feed and every boundary product. Component mass flow is reconstructed from the
# stream molar rate, overall mole fraction, and component molar mass, providing an independent check
# for every native and characterized component.

# %%
feed_mass_kg_per_h = base_equipment["feed"].getFlowRate("kg/hr")
product_mass_kg_per_h = sum(
    product_stream.getFlowRate("kg/hr")
    for product_stream in base_products.values()
)
mass_residual_kg_per_h = (
    feed_mass_kg_per_h - product_mass_kg_per_h
)
relative_mass_residual = (
    mass_residual_kg_per_h / feed_mass_kg_per_h
)

def component_mass_flow_kg_per_h(process_stream, component_name):
    fluid = process_stream.getFluid()
    component = (
        fluid.getComponent(component_name)
    )
    if component is None:
        return 0.0
    stream_molar_flow_mol_per_s = process_stream.getFlowRate(
        "mol/sec"
    )
    return (
        stream_molar_flow_mol_per_s
        * component.getz()
        * component.getMolarMass()
        * 3600.0
    )


component_rows = []
feed_fluid = base_equipment["feed"].getFluid()
fluid_component_names = [
    feed_fluid.getComponent(index).getName()
    for index in range(feed_fluid.getNumberOfComponents())
]

for component_name in fluid_component_names:
    feed_component_kg_per_h = component_mass_flow_kg_per_h(
        base_equipment["feed"],
        component_name,
    )
    product_component_kg_per_h = sum(
        component_mass_flow_kg_per_h(
            product_stream,
            component_name,
        )
        for product_stream in base_products.values()
    )
    component_rows.append(
        {
            "component": component_name,
            "feed [kg/h]": feed_component_kg_per_h,
            "products [kg/h]": product_component_kg_per_h,
            "residual [kg/h]": (
                feed_component_kg_per_h
                - product_component_kg_per_h
            ),
        }
    )

component_balance = pd.DataFrame(component_rows)
max_component_residual_kg_per_h = (
    component_balance["residual [kg/h]"].abs().max()
)

print(f"Total mass residual: {mass_residual_kg_per_h:.3e} kg/h")
print(f"Relative mass residual: {relative_mass_residual:.3e}")
print(
    "Maximum component residual: "
    f"{max_component_residual_kg_per_h:.3e} kg/h"
)
display(component_balance)
# Out:
#                       component  ...  residual [kg/h]
# 0      (n, i, t, r, o, g, e, n)  ...    1.2741452e-10
# 1                     (C, O, 2)  ...    8.1854523e-10
# 2         (m, e, t, h, a, n, e)  ...    7.5760909e-09
# 3            (e, t, h, a, n, e)  ...    2.8221621e-09
# 4         (p, r, o, p, a, n, e)  ...    1.7216735e-09
# 5      (i, -, b, u, t, a, n, e)  ...    2.2419044e-10
# 6      (n, -, b, u, t, a, n, e)  ...    4.7748472e-11
# 7   (i, -, p, e, n, t, a, n, e)  ...   -2.7762326e-10
# 8   (n, -, p, e, n, t, a, n, e)  ...   -4.4474291e-10
# 9      (n, -, h, e, x, a, n, e)  ...   -1.0618351e-09
# 10              (C, 7, _, P, C)  ...   -1.1268639e-09
# 11              (C, 8, _, P, C)  ...   -7.1122486e-10
# 12           (C, 1, 0, _, P, C)  ...   -1.7644197e-10
# 13           (C, 1, 2, _, P, C)  ...   -1.4551915e-11
#
# [14 rows x 4 columns]
# Total mass residual: 9.532e-09 kg/h
# Relative mass residual: 1.271e-13
# Maximum component residual: 7.576e-09 kg/h

# %% [markdown]
# ## Valve and physical-state checks
#
# The original workbook included valve checks. Here they are made executable: both throttling valves
# must reduce pressure, all principal product flows must be non-negative, densities must be finite,
# and all compressor powers must be positive.

# %%
hp_valve = base_equipment["hp_liquid_valve"]
mp_valve = base_equipment["mp_liquid_valve"]

valve_table = pd.DataFrame(
    {
        "valve": ["HP liquid valve", "MP liquid valve"],
        "inlet pressure [bara]": [
            hp_valve.getInletStream().getPressure("bara"),
            mp_valve.getInletStream().getPressure("bara"),
        ],
        "outlet pressure [bara]": [
            hp_valve.getOutletStream().getPressure("bara"),
            mp_valve.getOutletStream().getPressure("bara"),
        ],
    }
)
valve_table["pressure drop [bar]"] = (
    valve_table["inlet pressure [bara]"]
    - valve_table["outlet pressure [bara]"]
)

assert (valve_table["pressure drop [bar]"] > 0.0).all()
assert (product_table["mass flow [kg/h]"] >= 0.0).all()
assert np.isfinite(product_table["bulk density [kg/m³]"]).all()
assert all(power > 0.0 for power in compressor_power_mw)
assert abs(relative_mass_residual) < 1.0e-9
assert max_component_residual_kg_per_h < 1.0e-6

display(valve_table)
print("Base-case pressure, state, power, and balance checks passed.")
# Out:
#              valve  ...  pressure drop [bar]
# 0  HP liquid valve  ...                 60.0
# 1  MP liquid valve  ...                 15.0
#
# [2 rows x 4 columns]
# Base-case pressure, state, power, and balance checks passed.

# %% [markdown]
# ## Independent scenario function
#
# Every scenario constructs a fresh `ProcessSystem`. This avoids retaining an old splitter fraction,
# flow rate, or equipment state. The function returns only boundary and energy metrics needed for
# comparison.

# %%
def evaluate_field_case(case):
    process, equipment = build_field_process(case)
    runProcess()
    products = boundary_product_streams(equipment)

    feed_rate = equipment["feed"].getFlowRate("kg/hr")
    product_rate = sum(
        product.getFlowRate("kg/hr")
        for product in products.values()
    )
    compressor_keys = [
        "lp_compressor",
        "mp_compressor",
        "export_compressor",
        "injection_compressor",
    ]
    compressor_power = sum(
        equipment[key].getPower("MW")
        for key in compressor_keys
    )

    result = {
        "feed rate [kg/h]": feed_rate,
        "injection fraction [-]": case.injection_fraction,
        "export gas [kg/h]": (
            equipment["export_gas"].getFlowRate("kg/hr")
        ),
        "injection gas [kg/h]": (
            equipment["injection_gas"].getFlowRate("kg/hr")
        ),
        "export oil [kg/h]": (
            equipment["export_oil"].getFlowRate("kg/hr")
        ),
        "compressor power [MW]": compressor_power,
        "relative mass residual [-]": (
            (feed_rate - product_rate) / feed_rate
        ),
    }
    return result

# %% [markdown]
# ## Injection-fraction sensitivity
#
# The export and injection delivery pressures differ, so changing the split changes both product
# rates and total power. Five fresh cases provide the third technical figure.

# %%
injection_fractions = [0.0, 0.15, 0.25, 0.40, 0.50]
injection_results = []

for injection_fraction in injection_fractions:
    scenario = FieldCase(
        injection_fraction=injection_fraction,
    )
    injection_results.append(
        evaluate_field_case(scenario)
    )

injection_table = pd.DataFrame(injection_results)
display(injection_table)
# Out:
#    feed rate [kg/h]  ...  relative mass residual [-]
# 0           75000.0  ...               1.2708673e-13
# 1           75000.0  ...               1.2708673e-13
# 2           75000.0  ...               1.2708673e-13
# 3           75000.0  ...               1.2689270e-13
# 4           75000.0  ...               1.2708673e-13
#
# [5 rows x 7 columns]

# %%
figure, flow_axis = plt.subplots(figsize=(10.2, 5.8))
power_axis = flow_axis.twinx()

flow_axis.plot(
    100.0 * injection_table["injection fraction [-]"],
    injection_table["export gas [kg/h]"],
    marker="o",
    linewidth=2.2,
    color="#0072B2",
    label="Export gas",
)
flow_axis.plot(
    100.0 * injection_table["injection fraction [-]"],
    injection_table["injection gas [kg/h]"],
    marker="s",
    linewidth=2.2,
    color="#009E73",
    label="Injection gas",
)
power_axis.plot(
    100.0 * injection_table["injection fraction [-]"],
    injection_table["compressor power [MW]"],
    marker="D",
    linestyle="--",
    linewidth=2.0,
    color="#D55E00",
    label="Total compressor power",
)

flow_axis.set_xlabel("Treated-gas injection fraction [%]")
flow_axis.set_ylabel("Gas product flow [kg/h]")
power_axis.set_ylabel("Total compressor power [MW]")
flow_axis.set_title("Gas routing and power sensitivity")
flow_axis.legend(loc="center left")
power_axis.legend(loc="center right")
plt.show()

# %% [markdown]
# Higher injection fraction transfers gas from the 110 bara export service to the 160 bara injection
# service. Total compression power therefore rises in this case. The trend is not a reservoir
# optimization result; it is the facility consequence of the specified boundary pressures.

# %% [markdown]
# ## Throughput sensitivity
#
# The next study holds composition, pressures, temperatures, and split fixed while changing feed
# rate. It checks the expected extensive-property trend: mass products and steady compressor power
# should increase with throughput.

# %%
throughputs_kg_per_h = [
    45_000.0,
    60_000.0,
    75_000.0,
    90_000.0,
    105_000.0,
]
throughput_results = []

for throughput_kg_per_h in throughputs_kg_per_h:
    scenario = FieldCase(
        feed_rate_kg_per_h=throughput_kg_per_h,
    )
    throughput_results.append(
        evaluate_field_case(scenario)
    )

throughput_table = pd.DataFrame(throughput_results)
display(throughput_table)
# Out:
#    feed rate [kg/h]  ...  relative mass residual [-]
# 0           45000.0  ...               1.6783209e-13
# 1           60000.0  ...              -5.8692725e-14
# 2           75000.0  ...               1.2708673e-13
# 3           90000.0  ...               1.6783209e-13
# 4          105000.0  ...               1.6783209e-13
#
# [5 rows x 7 columns]

# %%
figure, gas_axis = plt.subplots(figsize=(10.2, 5.8))
power_axis = gas_axis.twinx()

gas_axis.plot(
    throughput_table["feed rate [kg/h]"] / 1000.0,
    throughput_table["export gas [kg/h]"] / 1000.0,
    marker="o",
    linewidth=2.2,
    color="#0072B2",
    label="Export gas",
)
gas_axis.plot(
    throughput_table["feed rate [kg/h]"] / 1000.0,
    throughput_table["injection gas [kg/h]"] / 1000.0,
    marker="s",
    linewidth=2.2,
    color="#009E73",
    label="Injection gas",
)
power_axis.plot(
    throughput_table["feed rate [kg/h]"] / 1000.0,
    throughput_table["compressor power [MW]"],
    marker="D",
    linestyle="--",
    linewidth=2.0,
    color="#D55E00",
    label="Total compressor power",
)

gas_axis.set_xlabel("Well-stream throughput [t/h]")
gas_axis.set_ylabel("Gas product flow [t/h]")
power_axis.set_ylabel("Total compressor power [MW]")
gas_axis.set_title("Field throughput sensitivity at fixed operating conditions")
gas_axis.legend(loc="upper left")
power_axis.legend(loc="lower right")
plt.show()

# %% [markdown]
# The nearly proportional curves are a limiting-case check for a steady equilibrium flowsheet with
# fixed intensive conditions and no equipment-capacity constraints. A real facility will depart from
# this trend when compressor maps, separator capacity, heat-transfer limits, or well performance
# become active.

# %% [markdown]
# ## Practical application: select and export an operating case
#
# Suppose an early field study requires at least 3,500 kg/h of reinjection gas while minimizing
# compression power among the evaluated splits. We filter the already validated scenario table,
# select the lowest-power feasible point, rebuild it, and export its inputs and main outputs as JSON.
# This pattern can be reused in screening tools, optimization loops, or digital-twin services.

# %%
minimum_injection_kg_per_h = 3_500.0
feasible_cases = injection_table[
    injection_table["injection gas [kg/h]"]
    >= minimum_injection_kg_per_h
].copy()
selected_row = feasible_cases.sort_values(
    "compressor power [MW]"
).iloc[0]

selected_case = FieldCase(
    injection_fraction=float(
        selected_row["injection fraction [-]"]
    )
)
selected_result = evaluate_field_case(selected_case)

application_snapshot = {
    "model": "standalone synthetic field process",
    "neqsim_version": neqsim_version,
    "inputs": asdict(selected_case),
    "outputs": {
        key: float(value)
        for key, value in selected_result.items()
    },
    "selection_rule": {
        "minimum_injection_kg_per_h": (
            minimum_injection_kg_per_h
        ),
        "objective": (
            "minimum compressor power among evaluated cases"
        ),
    },
}

print(json.dumps(application_snapshot, indent=2))
# Out:
# {
#   "model": "standalone synthetic field process",
#   "neqsim_version": "3.16.0",
#   "inputs": {
#     "feed_rate_kg_per_h": 75000.0,
#     "hp_pressure_bara": 80.0,
#     "mp_pressure_bara": 20.0,
#     "lp_pressure_bara": 5.0,
#     "injection_fraction": 0.25,
#     "export_pressure_bara": 110.0,
#     "injection_pressure_bara": 160.0
#   },
#   "outputs": {
#     "feed rate [kg/h]": 75000.00000000001,
#     "injection fraction [-]": 0.25,
#     "export gas [kg/h]": 12139.333232940699,
#     "injection gas [kg/h]": 4046.4444109802384,
#     "export oil [kg/h]": 57640.100884632826,
#     "compressor power [MW]": 0.6938464269314145,
#     "relative mass residual [-]": 1.2708672632773714e-13
#   },
#   "selection_rule": {
#     "minimum_injection_kg_per_h": 3500.0,
#     "objective": "minimum compressor power among evaluated cases"
#   }
# }

# %% [markdown]
# The selected case is a discrete screening decision, not a continuous optimum. A production study
# should add compressor envelopes, availability, injection-well pressure, separator sizing, liquid
# handling, economics, and emissions before recommending an operating target.

# %% [markdown]
# ## Final validation
#
# The final checks cover all scenario balances, routing trends, throughput trends, and the application
# constraint. They intentionally use tolerances rather than rounded displayed values.

# %%
assert (
    injection_table["relative mass residual [-]"].abs().max()
    < 1.0e-9
)
assert (
    throughput_table["relative mass residual [-]"].abs().max()
    < 1.0e-9
)
assert injection_table["export gas [kg/h]"].is_monotonic_decreasing
assert injection_table["injection gas [kg/h]"].is_monotonic_increasing
assert injection_table["compressor power [MW]"].is_monotonic_increasing
assert throughput_table["export gas [kg/h]"].is_monotonic_increasing
assert throughput_table["injection gas [kg/h]"].is_monotonic_increasing
assert throughput_table["compressor power [MW]"].is_monotonic_increasing
assert (
    selected_result["injection gas [kg/h]"]
    >= minimum_injection_kg_per_h
)
assert np.isfinite(
    throughput_table.select_dtypes(include=[np.number]).to_numpy()
).all()

print("All base-case, scenario, trend, and application checks passed.")
# Out:
# All base-case, scenario, trend, and application checks passed.

# %% [markdown]
# ## Troubleshooting
#
# - **JVM does not start:** verify Java 17+ and restart the Colab runtime after changing Java.
# - **A component name fails:** use NeqSim's component-name helpers or check the database spelling.
# - **A flash does not converge:** verify composition normalization, units, and physically reachable
#   pressure/temperature conditions; then simplify the fluid before adding heavy fractions.
# - **A scenario reuses old values:** call `build_field_process` for each case; it invokes
#   `clearProcess()` before adding equipment.
# - **Mass balance appears open:** include every scrubber liquid and every splitter outlet at the
#   chosen model boundary.
# - **Compressor result is misleading:** supply a realistic efficiency and check that the specified
#   outlet pressure exceeds inlet pressure. Add a compressor map for equipment design.

# %% [markdown]
# ## Applicability and limitations
#
# This notebook is suitable for early process configuration, teaching, code integration, and
# relative scenario screening. It is not a detailed design. The synthetic fluid is not tuned to PVT
# data; separator efficiencies are ideal equilibrium flashes; heat losses and pressure drops outside
# the valves are neglected; scrubber liquids are not routed to a stabilization system; and no
# mechanical capacity, compressor map, recycle, emissions, availability, cost, or reservoir model is
# included.

# %% [markdown]
# ## Summary and exercises
#
# You built a reproducible field-process workflow from a characterized fluid through three-stage
# stabilization, flash-gas recompression, gas scrubbing, export compression, and reinjection
# compression. You retrieved results, verified valve behavior, closed total and component balances,
# ran independent scenarios, and exported a selected design case.
#
# Further exercises:
#
# 1. add a second well stream with a different GOR and combine it in a named mixer;
# 2. route scrubber liquids back to the LP stabilization section and solve the recycle;
# 3. replace the fixed injection fraction with a pressure- or power-constrained selection;
# 4. add compressor maps and flag cases outside the operating envelope;
# 5. characterize the assay against public PVT data and compare SRK with Peng–Robinson; and
# 6. connect the process to a simple reservoir deliverability and injection-pressure model.

# %% [markdown]
# ## References
#
# - [NeqSim Python package on PyPI](https://pypi.org/project/neqsim/)
# - [NeqSim process-simulation package](https://equinor.github.io/neqsim/process/README.html)
# - [NeqSim process recipes](https://equinor.github.io/neqsim/cookbook/process-recipes.html)
# - [NeqSim getting started and equipment overview](https://equinor.github.io/neqsim/wiki/getting_started.html)
#
# The process model and numerical values in this notebook are calculated examples, not field data.
