# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/process/onlineprocesssimulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Online oil-stabilization simulation with NeqSim
#
# **Audience.** Process, production, and automation engineers who know basic phase equilibrium and
# Python and want to connect an oil-and-gas process model to changing plant data.
#
# **Prerequisites.** Familiarity with pressure, temperature, material streams, separators, valves,
# compressors, and pandas tables is helpful. All pressures are absolute (`bara`) and calculations use
# SI units unless a standard gas rate in `MSm3/day` is explicitly stated.
#
# ## Learning objectives
#
# After completing this notebook, you can:
#
# 1. build a Peng–Robinson well-fluid model with characterized heavy fractions;
# 2. compose a three-stage oil-stabilization and gas-recompression flowsheet;
# 3. update measured inputs without rebuilding the process;
# 4. calculate stable-oil true vapor pressure (TVP), gas cricondenbar, and compressor power;
# 5. validate total mass closure, recycle convergence, pressure ordering, and repeated execution; and
# 6. turn a synthetic historian table into an auditable online-simulation loop.
#
# This is an educational steady-state digital-twin pattern, not a certified control or safety system.

# %% [markdown]
# ## Existing examples preserved and repaired
#
# The original notebook contained three substantive examples, all retained here:
#
# - a base oil-stabilization process with water saturation, three separators, liquid recycle,
#   recompression, and two-stage export compression;
# - a second calculation after changing live process inputs; and
# - a historian-driven loop that repeatedly updates and solves the model.
#
# The unavailable `c:/temp/TimeseriesGasProcess.csv` input is replaced by a compact synthetic
# historian table with the same teaching purpose. The process is also repaired so medium-pressure
# separator gas joins the recompression train and the export cooler receives the second export
# compressor discharge. These connections are required for mass closure and a true 200 bara export.
#
# The original notebook had no retained figures. This revision adds five reproducible engineering
# figures: a process overview, pressure profile, base/change comparison, sensitivity plot, and online
# trend/validation chart.

# %% [markdown]
# ## 1. Clean Colab setup
#
# The setup installs the latest public PyPI release only when NeqSim is absent. It does not use a
# local checkout, unpublished JAR, or hidden data file. NeqSim 3.15 and later require Java 17 or
# newer when installed with pip.

# %%
try:
    import neqsim
except ImportError:
    # %pip install --upgrade --no-cache-dir neqsim

from importlib.metadata import version
import platform
import subprocess

import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrowPatch, FancyBboxPatch
import numpy as np
import pandas as pd
from IPython.display import display

from neqsim.thermo import fluid
from neqsim.process import (
    clearProcess,
    compressor,
    cooler,
    getProcess,
    heater,
    mixer,
    pump,
    recycle,
    saturator,
    separator,
    separator3phase,
    stream,
    valve,
)

NEQSIM_VERSION = version("neqsim")
PYTHON_VERSION = platform.python_version()
JAVA_VERSION = subprocess.check_output(
    ["java", "-version"],
    stderr=subprocess.STDOUT,
    text=True,
).splitlines()[0]

print(f"NeqSim: {NEQSIM_VERSION}")
print(f"Python: {PYTHON_VERSION}")
print(f"Java: {JAVA_VERSION}")
# Out:
# NeqSim: 3.16.0
# Python: 3.12.13
# Java: openjdk version "17.0.19" 2026-04-21

# %% [markdown]
# ## 2. Engineering model and assumptions
#
# The Peng–Robinson (PR) cubic equation of state is used because the feed is predominantly
# hydrocarbon and includes characterized heavy fractions. A classic mixing rule is adequate for this
# teaching case. Water saturation is included, but the simplified separator train does not model
# salts, emulsions, chemical injection, or detailed water treatment.
#
# For a steady process with no accumulation, total mass must close:
#
# $$
#
# \dot{m}_{\mathrm{in}} = \sum_j \dot{m}_{\mathrm{out},j}
#
# $$
#
# Here $\dot{m}$ is mass flow in kg/h and $j$ denotes stable oil, export gas, and produced-water
# outlets. Internal recycle flow is excluded from the external balance.
#
# Valves are modeled as adiabatic throttles:
#
# $$
#
# h_{\mathrm{out}} = h_{\mathrm{in}}
#
# $$
#
# where $h$ is specific enthalpy in J/kg. Separators perform equilibrium flashes at their inlet
# conditions. Compressors use an assigned isentropic efficiency:
#
# $$
#
# \eta_s = \frac{h_{2s} - h_1}{h_2 - h_1}
#
# $$
#
# where state 1 is the inlet, $2s$ is the isentropic outlet, and 2 is the actual outlet.

# %% [markdown]
# ### Base operating case
#
# The rates and conditions are representative educational inputs rather than field data. Standard
# gas rate means volume at NeqSim's standard reference state, whereas equipment calculations use the
# actual thermodynamic state.

# %%
base_case = {
    "feed_rate_msm3_day": 10.0,
    "well_pressure_bara": 180.0,
    "well_temperature_c": 100.0,
    "topside_pressure_bara": 90.0,
    "topside_temperature_c": 5.0,
    "first_stage_pressure_bara": 75.0,
    "oil_heater_temperature_c": 75.9,
    "second_stage_pressure_bara": 8.6,
    "third_stage_pressure_bara": 1.9,
    "suction_temperature_c": 25.0,
    "export_interstage_pressure_bara": 140.0,
    "export_pressure_bara": 200.0,
    "compressor_efficiency": 0.75,
}

component_amounts = {
    "nitrogen": 0.08,
    "CO2": 3.56,
    "methane": 87.36,
    "ethane": 4.02,
    "propane": 1.54,
    "i-butane": 0.20,
    "n-butane": 0.42,
    "i-pentane": 0.15,
    "n-pentane": 0.20,
}

tbp_fractions = [
    ("C6", 3.24, 84.99e-3, 695.0),
    ("C7", 1.34, 97.87e-3, 718.0),
    ("C8", 1.33, 111.54e-3, 729.0),
    ("C9", 1.19, 126.10e-3, 749.0),
    ("C10", 1.15, 140.14e-3, 760.0),
    ("C11", 1.69, 175.00e-3, 830.0),
    ("C12", 1.50, 280.00e-3, 914.0),
    ("C13", 2.103, 560.00e-3, 980.0),
]

composition_total = sum(component_amounts.values())
composition_total += sum(row[1] for row in tbp_fractions)

print(f"Characterization entries: {len(component_amounts) + len(tbp_fractions)}")
print(f"Relative input amount sum: {composition_total:.3f}")
# Out:
# Characterization entries: 17
# Relative input amount sum: 111.073

# %% [markdown]
# The component amounts are relative; NeqSim normalizes the composition. `addTBPfraction` represents
# heavy cuts by average molar mass in kg/mol and liquid density in kg/m³. Heavy-end characterization
# matters for liquid recovery and vapor-pressure predictions.

# %%
well_fluid = fluid("pr")

for component_name, amount in component_amounts.items():
    well_fluid.addComponent(component_name, amount)

for name, amount, molar_mass_kg_mol, density_kg_m3 in tbp_fractions:
    well_fluid.addTBPfraction(
        name,
        amount,
        molar_mass_kg_mol,
        density_kg_m3 / 1000.0,
    )

well_fluid.setMixingRule("classic")
well_fluid.init(0)

normalized_sum = sum(
    well_fluid.getComponent(index).getz()
    for index in range(well_fluid.getNumberOfComponents())
)

assert abs(normalized_sum - 1.0) < 1.0e-10
print(f"Normalized mole-fraction sum: {normalized_sum:.12f}")
print(f"Thermodynamic model: {well_fluid.getModelName()}")
# Out:
# Normalized mole-fraction sum: 1.000000000000
# Thermodynamic model: PR-EOS

# %% [markdown]
# ## 3. Process workflow
#
# The well fluid is water-saturated, brought to topside conditions, and flashed through high-,
# medium-, and low-pressure separators. Flash gas is recompressed to the first-stage pressure and
# mixed with the high-pressure gas. Condensed liquids return to the low-pressure separator through a
# NeqSim `Recycle`. Export gas is compressed in two stages to 200 bara.
#
# The diagram is a topology aid; arrows indicate material-flow direction, not physical layout.

# %%
fig, ax = plt.subplots(figsize=(12, 4.8))
ax.set_xlim(0, 12)
ax.set_ylim(0, 6)
ax.axis("off")

boxes = [
    (0.3, 3.8, "Well feed\n180 bara", "#4477AA"),
    (2.2, 3.8, "Conditioner\nand choke", "#66CCEE"),
    (4.2, 3.8, "HP separator\n75 bara", "#228833"),
    (4.2, 1.2, "MP / LP oil\nstabilization", "#EE6677"),
    (6.6, 1.2, "Gas\nrecompression", "#CCBB44"),
    (6.6, 3.8, "Dew-point\nscrubber", "#AA3377"),
    (9.1, 3.8, "Two-stage export\ncompression", "#BBBBBB"),
    (11.0, 3.8, "Export gas\n200 bara", "#4477AA"),
    (6.6, 0.0, "Liquid recycle", "#66CCEE"),
]

for x_pos, y_pos, label, color in boxes:
    patch = FancyBboxPatch(
        (x_pos, y_pos),
        1.5,
        0.9,
        boxstyle="round,pad=0.05",
        facecolor=color,
        edgecolor="#222222",
        alpha=0.9,
    )
    ax.add_patch(patch)
    ax.text(
        x_pos + 0.75,
        y_pos + 0.45,
        label,
        ha="center",
        va="center",
        fontsize=9,
    )

arrows = [
    ((1.8, 4.25), (2.2, 4.25)),
    ((3.7, 4.25), (4.2, 4.25)),
    ((5.7, 4.25), (6.6, 4.25)),
    ((8.1, 4.25), (9.1, 4.25)),
    ((10.6, 4.25), (11.0, 4.25)),
    ((4.95, 3.8), (4.95, 2.1)),
    ((5.7, 1.65), (6.6, 1.65)),
    ((7.35, 2.1), (7.35, 3.8)),
    ((7.35, 1.2), (7.35, 0.9)),
    ((6.6, 0.45), (5.15, 1.2)),
]

for start, end in arrows:
    ax.add_patch(
        FancyArrowPatch(
            start,
            end,
            arrowstyle="-|>",
            mutation_scale=12,
            linewidth=1.5,
            color="#333333",
        )
    )

ax.set_title(
    "Online oil-stabilization model: NeqSim equipment and material connections",
    fontsize=13,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Build the feed conditioning and oil-stabilization train
#
# The Python convenience functions create Java-backed NeqSim equipment and add it to the active
# `ProcessSystem`. Named objects are retained so their setpoints can be updated later. The recycle
# placeholder starts with a negligible flow and is overwritten by the converged liquid recycle.

# %%
clearProcess()

well_stream = stream("dry well stream", well_fluid)
well_stream.setFlowRate(base_case["feed_rate_msm3_day"], "MSm3/day")
well_stream.setTemperature(base_case["well_temperature_c"], "C")
well_stream.setPressure(base_case["well_pressure_bara"], "bara")

water_saturator = saturator("water saturator", well_stream)
water_saturated_feed = stream(
    "water saturated feed gas",
    water_saturator.getOutStream(),
)

inlet_conditioner = heater("inlet TP setter", water_saturated_feed)
inlet_conditioner.setOutPressure(base_case["topside_pressure_bara"], "bara")
inlet_conditioner.setOutTemperature(base_case["topside_temperature_c"], "C")

inlet_choke = valve(
    "inlet choke",
    inlet_conditioner.getOutStream(),
    base_case["first_stage_pressure_bara"],
)
hp_separator = separator3phase(
    "1st stage separator",
    inlet_choke.getOutStream(),
)

oil_heater = heater(
    "oil heater second stage",
    hp_separator.getOilOutStream(),
)
oil_heater.setOutTemperature(base_case["oil_heater_temperature_c"], "C")

oil_valve_1 = valve(
    "valve oil from first stage",
    oil_heater.getOutStream(),
    base_case["second_stage_pressure_bara"],
)
mp_separator = separator3phase(
    "2nd stage separator",
    oil_valve_1.getOutStream(),
)

oil_valve_2 = valve(
    "valve oil from second stage",
    mp_separator.getOilOutStream(),
    base_case["third_stage_pressure_bara"],
)
lp_separator = separator3phase(
    "3rd stage separator",
    oil_valve_2.getOutStream(),
)

recycle_oil = well_stream.clone()
recycle_oil.setName("recycle oil")
recycle_oil.setFlowRate(1.0e-6, "kg/hr")
lp_separator.addStream(recycle_oil)

stable_oil = stream("stable oil", lp_separator.getOilOutStream())
stable_oil_pump = pump("stable oil pump", stable_oil, 15.0)

# %% [markdown]
# ## 5. Build gas recompression, recycle, and export compression
#
# Low-pressure flash gas is compressed to the medium-pressure separator pressure. It is then mixed
# with medium-pressure flash gas before the second recompression stage. This connection fixes the
# missing outlet in the original model. The export cooler is connected to the second export
# compressor, so the published export stream is actually at 200 bara.

# %%
lp_gas_cooler = cooler("1st stage cooler", lp_separator.getGasOutStream())
lp_gas_cooler.setOutTemperature(base_case["suction_temperature_c"], "C")
lp_scrubber = separator("1st stage scrubber", lp_gas_cooler.getOutStream())

lp_compressor = compressor(
    "1st stage compressor",
    lp_scrubber.getGasOutStream(),
    base_case["second_stage_pressure_bara"],
)
lp_compressor.setIsentropicEfficiency(base_case["compressor_efficiency"])

mp_gas_mixer = mixer("medium-pressure gas mixer")
mp_gas_mixer.addStream(lp_compressor.getOutStream())
mp_gas_mixer.addStream(mp_separator.getGasOutStream())

mp_gas_cooler = cooler("2nd stage cooler", mp_gas_mixer.getOutStream())
mp_gas_cooler.setOutTemperature(base_case["suction_temperature_c"], "C")
mp_scrubber = separator("2nd stage scrubber", mp_gas_cooler.getOutStream())

mp_compressor = compressor(
    "2nd stage compressor",
    mp_scrubber.getGasOutStream(),
    base_case["first_stage_pressure_bara"],
)
mp_compressor.setIsentropicEfficiency(base_case["compressor_efficiency"])

rich_gas_mixer = mixer("rich gas mixer")
rich_gas_mixer.addStream(mp_compressor.getOutStream())
rich_gas_mixer.addStream(hp_separator.getGasOutStream())

dew_point_cooler = cooler("dew point cooler", rich_gas_mixer.getOutStream())
dew_point_cooler.setOutTemperature(base_case["suction_temperature_c"], "C")
dew_point_scrubber = separator(
    "dew point scrubber",
    dew_point_cooler.getOutStream(),
)

liquid_mixer = mixer("LP liquid mixer")
liquid_mixer.addStream(lp_scrubber.getLiquidOutStream())
liquid_mixer.addStream(mp_scrubber.getLiquidOutStream())
liquid_mixer.addStream(dew_point_scrubber.getLiquidOutStream())

liquid_recycle = recycle("LP liquid recycle", liquid_mixer.getOutStream())
liquid_recycle.setOutletStream(recycle_oil)
liquid_recycle.setTolerance(1.0e-6)

export_compressor_1 = compressor(
    "export 1st stage",
    dew_point_scrubber.getGasOutStream(),
    base_case["export_interstage_pressure_bara"],
)
export_compressor_1.setIsentropicEfficiency(
    base_case["compressor_efficiency"]
)

export_intercooler = cooler(
    "export interstage cooler",
    export_compressor_1.getOutStream(),
)
export_intercooler.setOutTemperature(base_case["suction_temperature_c"], "C")

export_compressor_2 = compressor(
    "export 2nd stage",
    export_intercooler.getOutStream(),
    base_case["export_pressure_bara"],
)
export_compressor_2.setIsentropicEfficiency(
    base_case["compressor_efficiency"]
)

export_cooler = cooler(
    "export cooler",
    export_compressor_2.getOutStream(),
)
export_cooler.setOutTemperature(base_case["suction_temperature_c"], "C")
export_gas = stream("export gas", export_cooler.getOutStream())

oil_process = getProcess()
print(f"Process equipment count: {oil_process.getUnitOperations().size()}")
# Out:
# Process equipment count: 30

# %% [markdown]
# ## 6. Base-case execution
#
# `ProcessSystem.run()` executes units in sequence and iterates the liquid recycle. A successful call
# does not by itself prove engineering validity, so the next sections extract KPIs and perform
# independent checks.

# %%
oil_process.run()

assert liquid_recycle.solved()
assert abs(export_gas.getPressure("bara") - 200.0) < 1.0e-8

print("Base process solved.")
print(f"Liquid recycle: {liquid_recycle.getOutletStream().getFlowRate('kg/hr'):.1f} kg/h")
print(f"Export pressure: {export_gas.getPressure('bara'):.1f} bara")
# Out:
# Base process solved.
# Liquid recycle: 5870.6 kg/h
# Export pressure: 200.0 bara

# %% [markdown]
# ### KPI extraction
#
# TVP is calculated at 20 °C for the stabilized oil. Cricondenbar is the maximum pressure on the
# gas phase envelope. These are thermodynamic indicators, not contractual product specifications;
# real projects must apply the correct test standard, sampling basis, and compositional uncertainty.

# %%
compressors = {
    "LP recompressor": lp_compressor,
    "MP recompressor": mp_compressor,
    "Export stage 1": export_compressor_1,
    "Export stage 2": export_compressor_2,
}


def collect_kpis(label):
    power_mw = {
        name: unit.getPower() / 1.0e6
        for name, unit in compressors.items()
    }
    return {
        "case": label,
        "feed rate [MSm3/day]": well_stream.getFlowRate("MSm3/day"),
        "stable oil [kg/h]": stable_oil.getFlowRate("kg/hr"),
        "export gas [kg/h]": export_gas.getFlowRate("kg/hr"),
        "oil TVP at 20 C [bara]": stable_oil.TVP(20.0, "C"),
        "gas cricondenbar [bara]": export_gas.CCB("bara"),
        "total compressor power [MW]": sum(power_mw.values()),
        "export pressure [bara]": export_gas.getPressure("bara"),
    }


base_kpis = collect_kpis("Base")
base_kpi_table = pd.DataFrame([base_kpis]).round(4)
display(base_kpi_table)
# Out:
#    case  ...  export pressure [bara]
# 0  Base  ...                   200.0
#
# [1 rows x 8 columns]

# %% [markdown]
# The base result should have positive oil and gas product rates, TVP below the low-pressure
# separator pressure, positive compressor power, and an export pressure equal to the assigned
# boundary condition.

# %% [markdown]
# ### Pressure path
#
# Pressure drops through the oil stabilization train as volatile components are flashed. Gas pressure
# increases through recompression and export compression. A line plot makes accidental bypasses or
# wrong equipment connections visible.

# %%
oil_path = pd.DataFrame(
    {
        "location": [
            "Well",
            "Topside",
            "HP sep",
            "MP sep",
            "LP sep",
            "Oil pump",
        ],
        "pressure_bara": [
            well_stream.getPressure("bara"),
            inlet_conditioner.getOutletStream().getPressure("bara"),
            hp_separator.getGasOutStream().getPressure("bara"),
            mp_separator.getOilOutStream().getPressure("bara"),
            lp_separator.getOilOutStream().getPressure("bara"),
            stable_oil_pump.getOutletStream().getPressure("bara"),
        ],
    }
)

gas_path = pd.DataFrame(
    {
        "location": [
            "LP sep",
            "LP comp",
            "MP comp",
            "Export 1",
            "Export 2",
            "Export",
        ],
        "pressure_bara": [
            lp_separator.getGasOutStream().getPressure("bara"),
            lp_compressor.getOutletStream().getPressure("bara"),
            mp_compressor.getOutletStream().getPressure("bara"),
            export_compressor_1.getOutletStream().getPressure("bara"),
            export_compressor_2.getOutletStream().getPressure("bara"),
            export_gas.getPressure("bara"),
        ],
    }
)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(
    oil_path["location"],
    oil_path["pressure_bara"],
    marker="o",
    linewidth=2,
    color="#EE6677",
    label="Oil stabilization path",
)
ax.plot(
    gas_path["location"],
    gas_path["pressure_bara"],
    marker="s",
    linewidth=2,
    color="#4477AA",
    label="Gas compression path",
)
ax.set_title("Base-case process pressure paths")
ax.set_xlabel("Process location")
ax.set_ylabel("Pressure [bara]")
ax.grid(alpha=0.3)
ax.legend()
plt.xticks(rotation=25, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# The oil path falls from 180 bara to 1.9 bara before the product pump. The gas path rises in
# physically ordered steps to 200 bara. The oil-pump point is a product-delivery condition and is not
# part of the flashing sequence.

# %% [markdown]
# ## 7. Engineering validation
#
# The water saturator adds water to the dry well stream. Therefore, the correct external feed for the
# mass balance is the water-saturated stream. External outlets are stable oil, export gas, and the
# three separator water streams. Internal recycle must not be counted as a new feed or product.

# %%
feed_mass_kg_h = water_saturated_feed.getFlowRate("kg/hr")
product_mass_kg_h = stable_oil.getFlowRate("kg/hr")
product_mass_kg_h += export_gas.getFlowRate("kg/hr")
product_mass_kg_h += hp_separator.getWaterOutStream().getFlowRate("kg/hr")
product_mass_kg_h += mp_separator.getWaterOutStream().getFlowRate("kg/hr")
product_mass_kg_h += lp_separator.getWaterOutStream().getFlowRate("kg/hr")

mass_residual_kg_h = product_mass_kg_h - feed_mass_kg_h
relative_mass_residual = abs(mass_residual_kg_h) / feed_mass_kg_h

validation_rows = [
    ("Normalized composition", abs(normalized_sum - 1.0), 1.0e-10),
    ("Relative mass residual", relative_mass_residual, 1.0e-5),
    (
        "Export pressure error [bar]",
        abs(export_gas.getPressure("bara") - 200.0),
        1.0e-8,
    ),
]

validation_table = pd.DataFrame(
    validation_rows,
    columns=["check", "value", "limit"],
)
validation_table["passed"] = validation_table["value"] <= validation_table["limit"]

assert validation_table["passed"].all()
assert liquid_recycle.solved()
assert 0.0 < base_kpis["oil TVP at 20 C [bara]"] < 1.9
assert base_kpis["gas cricondenbar [bara]"] < 200.0
assert base_kpis["total compressor power [MW]"] > 0.0

print(f"Mass residual: {mass_residual_kg_h:.6f} kg/h")
print(f"Relative mass residual: {relative_mass_residual:.3e}")
display(validation_table)
# Out:
# Mass residual: -0.094443 kg/h
# Relative mass residual: 1.297e-07
#                          check         value         limit  passed
# 0       Normalized composition  2.220446e-16  1.000000e-10    True
# 1       Relative mass residual  1.296580e-07  1.000000e-05    True
# 2  Export pressure error [bar]  0.000000e+00  1.000000e-08    True

# %% [markdown]
# The relative mass residual is compared with a scale-aware tolerance. This check would have exposed
# the original missing medium-pressure gas connection. A balance alone cannot prove that every
# connection is correct, which is why pressure ordering and export boundary checks are also retained.

# %% [markdown]
# ## 8. Preserve the original “new parameters” calculation
#
# The original second example increased the well rate from 10.0 to 11.1 MSm³/day and changed topside
# pressure from 90 to 91 bara. The helper below updates named equipment setpoints in place, retaining
# the same process objects and recycle topology.

# %%
def update_online_inputs(
    feed_rate_msm3_day,
    well_temperature_c,
    topside_pressure_bara,
    topside_temperature_c,
    oil_heater_temperature_c,
):
    well_stream.setFlowRate(feed_rate_msm3_day, "MSm3/day")
    well_stream.setTemperature(well_temperature_c, "C")
    inlet_conditioner.setOutPressure(topside_pressure_bara, "bara")
    inlet_conditioner.setOutTemperature(topside_temperature_c, "C")
    oil_heater.setOutTemperature(oil_heater_temperature_c, "C")


changed_case = {
    "feed_rate_msm3_day": 11.1,
    "well_temperature_c": 100.0,
    "topside_pressure_bara": 91.0,
    "topside_temperature_c": 5.0,
    "oil_heater_temperature_c": 75.9,
}

update_online_inputs(**changed_case)
oil_process.run()
changed_kpis = collect_kpis("Changed inputs")

assert liquid_recycle.solved()
assert changed_kpis["feed rate [MSm3/day]"] > base_kpis["feed rate [MSm3/day]"]

comparison = pd.DataFrame([base_kpis, changed_kpis])
display(comparison.round(4))
# Out:
#              case  ...  export pressure [bara]
# 0            Base  ...                   200.0
# 1  Changed inputs  ...                   200.0
#
# [2 rows x 8 columns]

# %% [markdown]
# At fixed pressure and temperature setpoints, compressor power and product mass rates should
# increase with feed rate. TVP and cricondenbar depend mainly on composition and equilibrium
# conditions, so they should change much less than throughput.

# %%
comparison_plot = comparison.set_index("case")[
    [
        "stable oil [kg/h]",
        "export gas [kg/h]",
        "total compressor power [MW]",
    ]
].copy()

normalized_plot = comparison_plot / comparison_plot.iloc[0]
normalized_plot.columns = [
    "Stable oil mass rate",
    "Export gas mass rate",
    "Compressor power",
]

fig, ax = plt.subplots(figsize=(9, 5))
normalized_plot.plot(
    kind="bar",
    ax=ax,
    color=["#228833", "#4477AA", "#CCBB44"],
)
ax.set_title("Effect of the original online input change")
ax.set_xlabel("Simulation case")
ax.set_ylabel("Result relative to base case [-]")
ax.axhline(1.0, color="#333333", linewidth=1)
ax.grid(axis="y", alpha=0.3)
ax.legend()
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# The similar normalized change in mass rates and power is expected for a fixed-composition
# throughput increase. The plot is a useful online-model sanity check: a large discontinuity would
# suggest non-convergence, a phase-regime transition, or bad input data.

# %% [markdown]
# ## 9. Sensitivity to oil-heater temperature
#
# Heating before the medium-pressure flash releases more light components from the liquid. The
# expected trend is lower stable-oil TVP at higher heater temperature, balanced against additional
# heat duty and possible liquid-yield loss. This short sweep tests model behavior around the base
# case; it is not an optimizer.

# %%
heater_temperatures_c = np.array([65.0, 70.0, 75.9, 80.0, 85.0])
sensitivity_rows = []

for heater_temperature_c in heater_temperatures_c:
    update_online_inputs(
        feed_rate_msm3_day=10.0,
        well_temperature_c=100.0,
        topside_pressure_bara=90.0,
        topside_temperature_c=5.0,
        oil_heater_temperature_c=heater_temperature_c,
    )
    oil_process.run()
    sensitivity_rows.append(
        {
            "heater temperature [C]": heater_temperature_c,
            "oil TVP at 20 C [bara]": stable_oil.TVP(20.0, "C"),
            "stable oil [kg/h]": stable_oil.getFlowRate("kg/hr"),
            "heater duty [MW]": oil_heater.getDuty() / 1.0e6,
        }
    )

sensitivity = pd.DataFrame(sensitivity_rows)

assert liquid_recycle.solved()
assert sensitivity["oil TVP at 20 C [bara]"].is_monotonic_decreasing
assert sensitivity["heater duty [MW]"].is_monotonic_increasing

display(sensitivity.round(4))
# Out:
#    heater temperature [C]  ...  heater duty [MW]
# 0                    65.0  ...           17.1938
# 1                    70.0  ...           18.6239
# 2                    75.9  ...           20.3264
# 3                    80.0  ...           21.5193
# 4                    85.0  ...           22.9850
#
# [5 rows x 4 columns]

# %%
fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))

axes[0].plot(
    sensitivity["heater temperature [C]"],
    sensitivity["oil TVP at 20 C [bara]"],
    marker="o",
    color="#AA3377",
    label="Stable-oil TVP",
)
axes[0].set_title("Oil stability response")
axes[0].set_xlabel("Oil-heater temperature [°C]")
axes[0].set_ylabel("TVP at 20 °C [bara]")
axes[0].grid(alpha=0.3)
axes[0].legend()

axes[1].plot(
    sensitivity["heater temperature [C]"],
    sensitivity["heater duty [MW]"],
    marker="s",
    color="#CCBB44",
    label="Heater duty",
)
axes[1].set_title("Thermal cost of stabilization")
axes[1].set_xlabel("Oil-heater temperature [°C]")
axes[1].set_ylabel("Heater duty [MW]")
axes[1].grid(alpha=0.3)
axes[1].legend()

fig.suptitle("Oil-heater sensitivity: product quality and energy")
plt.tight_layout()
plt.show()

# %% [markdown]
# The calculated TVP decreases as heater temperature rises, while duty increases. This illustrates a
# real operating trade-off. The selected range remains an educational neighborhood; exchanger
# limits, fouling, salt precipitation, corrosion, and oil specifications must be added for design.

# %% [markdown]
# ## 10. Historian-driven online calculation
#
# The original notebook proposed reading a local CSV and left placeholder tags. For a reproducible
# Colab example, the table below mimics six timestamped historian records. In a plant deployment,
# replace this table with validated data from a historian client such as TagReader, while preserving
# tag mapping, units, timestamp quality, and audit logging.
#
# This is repeated steady-state reconciliation. It does not model vessel inventory, controller
# dynamics, transport delay, or transient compressor behavior.

# %%
historian_data = pd.DataFrame(
    {
        "timestamp": pd.date_range(
            "2026-07-25 00:00",
            periods=6,
            freq="15min",
            tz="UTC",
        ),
        "feed_rate_msm3_day": [9.8, 10.1, 10.5, 10.2, 10.8, 11.0],
        "well_temperature_c": [99.5, 100.0, 100.4, 100.1, 100.8, 101.0],
        "topside_pressure_bara": [89.5, 90.0, 90.8, 90.3, 91.0, 91.2],
        "topside_temperature_c": [5.0, 5.2, 5.4, 5.1, 5.6, 5.8],
        "oil_heater_temperature_c": [75.5, 75.8, 76.0, 75.7, 76.2, 76.4],
    }
)

display(historian_data)
# Out:
#                   timestamp  ...  oil_heater_temperature_c
# 0 2026-07-25 00:00:00+00:00  ...                      75.5
# 1 2026-07-25 00:15:00+00:00  ...                      75.8
# 2 2026-07-25 00:30:00+00:00  ...                      76.0
# 3 2026-07-25 00:45:00+00:00  ...                      75.7
# 4 2026-07-25 01:00:00+00:00  ...                      76.2
# 5 2026-07-25 01:15:00+00:00  ...                      76.4
#
# [6 rows x 6 columns]

# %% [markdown]
# Each row is validated before use. The example rejects impossible or out-of-scope measurements
# rather than silently clipping them. A production implementation should also inspect bad-quality
# flags, stale timestamps, rate-of-change limits, and unit metadata.

# %%
def validate_measurements(row):
    checks = {
        "feed rate": 5.0 <= row["feed_rate_msm3_day"] <= 15.0,
        "well temperature": 50.0 <= row["well_temperature_c"] <= 130.0,
        "topside pressure": 50.0 <= row["topside_pressure_bara"] <= 120.0,
        "topside temperature": -10.0 <= row["topside_temperature_c"] <= 30.0,
        "heater temperature": 50.0 <= row["oil_heater_temperature_c"] <= 100.0,
    }
    failed = [name for name, passed in checks.items() if not passed]
    if failed:
        raise ValueError(f"Historian range check failed: {failed}")


online_rows = []

for _, measurement in historian_data.iterrows():
    validate_measurements(measurement)
    update_online_inputs(
        feed_rate_msm3_day=measurement["feed_rate_msm3_day"],
        well_temperature_c=measurement["well_temperature_c"],
        topside_pressure_bara=measurement["topside_pressure_bara"],
        topside_temperature_c=measurement["topside_temperature_c"],
        oil_heater_temperature_c=measurement["oil_heater_temperature_c"],
    )
    oil_process.run()
    result = collect_kpis(str(measurement["timestamp"]))
    result["timestamp"] = measurement["timestamp"]
    result["recycle solved"] = bool(liquid_recycle.solved())
    online_rows.append(result)

online_results = pd.DataFrame(online_rows)

assert online_results["recycle solved"].all()
assert np.isfinite(
    online_results.select_dtypes(include=[np.number]).to_numpy()
).all()

online_summary = online_results[
    [
        "timestamp",
        "feed rate [MSm3/day]",
        "oil TVP at 20 C [bara]",
        "total compressor power [MW]",
        "recycle solved",
    ]
].copy()

online_numeric_columns = [
    "feed rate [MSm3/day]",
    "oil TVP at 20 C [bara]",
    "total compressor power [MW]",
]
online_summary[online_numeric_columns] = online_summary[
    online_numeric_columns
].round(4)

display(online_summary)
# Out:
#                   timestamp  ...  recycle solved
# 0 2026-07-25 00:00:00+00:00  ...            True
# 1 2026-07-25 00:15:00+00:00  ...            True
# 2 2026-07-25 00:30:00+00:00  ...            True
# 3 2026-07-25 00:45:00+00:00  ...            True
# 4 2026-07-25 01:00:00+00:00  ...            True
# 5 2026-07-25 01:15:00+00:00  ...            True
#
# [6 rows x 5 columns]

# %% [markdown]
# ### Online trends and virtual-sensor interpretation
#
# TVP is a model-derived virtual sensor. Compressor power is also calculated from the reconciled
# thermodynamic state. These values should be compared with laboratory data and calibrated equipment
# measurements before operational use.

# %%
fig, axes = plt.subplots(2, 1, figsize=(11, 7), sharex=True)

axes[0].plot(
    online_results["timestamp"],
    online_results["feed rate [MSm3/day]"],
    marker="o",
    color="#4477AA",
    label="Historian feed rate",
)
axes[0].set_title("Online input and calculated process response")
axes[0].set_ylabel("Feed rate [MSm³/day]")
axes[0].grid(alpha=0.3)
axes[0].legend()

power_line = axes[1].plot(
    online_results["timestamp"],
    online_results["total compressor power [MW]"],
    marker="s",
    color="#CCBB44",
    label="Calculated compressor power",
)
tvp_axis = axes[1].twinx()
tvp_line = tvp_axis.plot(
    online_results["timestamp"],
    online_results["oil TVP at 20 C [bara]"],
    marker="^",
    color="#AA3377",
    label="Calculated oil TVP at 20 °C",
)
axes[1].set_xlabel("Historian timestamp [UTC]")
axes[1].set_ylabel("Total compressor power [MW]")
tvp_axis.set_ylabel("Oil TVP at 20 °C [bara]")
axes[1].grid(alpha=0.3)
trend_lines = power_line + tvp_line
trend_labels = [line.get_label() for line in trend_lines]
axes[1].legend(trend_lines, trend_labels, loc="best")

plt.xticks(rotation=20, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# The calculated power follows the throughput trend, while TVP remains comparatively stable because
# composition and separator setpoints change only slightly. A real online model should alarm on
# non-convergence or invalid input quality before publishing virtual-sensor values.

# %% [markdown]
# ## 11. Repeatability and final application gate
#
# An online workflow reuses the same process many times, so repeated execution must be deterministic
# for unchanged inputs. The final cell reruns the last historian state and compares key outputs. It
# also performs all principal engineering assertions in one auditable gate.

# %%
last_before_repeat = collect_kpis("Before repeat")
oil_process.run()
last_after_repeat = collect_kpis("After repeat")

repeat_power_error_mw = abs(
    last_after_repeat["total compressor power [MW]"]
    - last_before_repeat["total compressor power [MW]"]
)
repeat_tvp_error_bara = abs(
    last_after_repeat["oil TVP at 20 C [bara]"]
    - last_before_repeat["oil TVP at 20 C [bara]"]
)

final_checks = {
    "all historian rows solved": bool(online_results["recycle solved"].all()),
    "finite online values": bool(
        np.isfinite(
            online_results.select_dtypes(include=[np.number]).to_numpy()
        ).all()
    ),
    "base mass closure": relative_mass_residual < 1.0e-5,
    "export pressure is 200 bara": (
        abs(export_gas.getPressure("bara") - 200.0) < 1.0e-8
    ),
    "heater duty rises with temperature": bool(
        sensitivity["heater duty [MW]"].is_monotonic_increasing
    ),
    "TVP falls with heater temperature": bool(
        sensitivity["oil TVP at 20 C [bara]"].is_monotonic_decreasing
    ),
    "repeat power stable": repeat_power_error_mw < 1.0e-8,
    "repeat TVP stable": repeat_tvp_error_bara < 1.0e-8,
}

assert all(final_checks.values())

print("FINAL VALIDATION: all checks passed")
print(f"Checks passed: {sum(final_checks.values())}/{len(final_checks)}")
print(f"Repeat power error: {repeat_power_error_mw:.3e} MW")
print(f"Repeat TVP error: {repeat_tvp_error_bara:.3e} bara")
display(pd.Series(final_checks, name="passed").to_frame())
# Out:
# FINAL VALIDATION: all checks passed
# Checks passed: 8/8
# Repeat power error: 0.000e+00 MW
# Repeat TVP error: 0.000e+00 bara
#                                     passed
# all historian rows solved             True
# finite online values                  True
# base mass closure                     True
# export pressure is 200 bara           True
# heater duty rises with temperature    True
# TVP falls with heater temperature     True
# repeat power stable                   True
# repeat TVP stable                     True

# %% [markdown]
# ## 12. Troubleshooting
#
# - **JVM or import failure:** confirm Java 17+ and rerun the setup cell in a fresh runtime.
# - **Recycle does not solve:** inspect feed validity and initialize near the previous operating
#   point; do not publish virtual sensors from a failed solve.
# - **Mass balance fails:** count only external streams and verify that every separator gas, oil, and
#   water outlet is connected or explicitly reported.
# - **Unexpected export pressure:** trace the compressor and cooler inlet streams; a downstream unit
#   connected to the wrong compressor can silently bypass a stage.
# - **TVP changes abruptly:** verify temperature, pressure, composition, heavy-end characterization,
#   phase presence, and measurement units before tuning the model.
# - **Historian integration fails:** validate tag names, timestamps, quality flags, and units outside
#   the simulation loop. Never substitute the last good value without recording that decision.

# %% [markdown]
# ## 13. Limitations and applicability
#
# This notebook is suitable for teaching process composition, repeated steady-state execution, and
# virtual-sensor validation. It is not a dynamic model and does not represent vessel holdup,
# controller action, compressor maps, anti-surge control, heat-exchanger UA, piping pressure drop,
# saltwater chemistry, wax/asphaltene behavior, emissions, equipment capacity, or relief design.
#
# PR with classic mixing is appropriate for hydrocarbon phase behavior in this example, but model
# selection and heavy-end characterization must be validated against laboratory PVT and separator
# data for engineering decisions. Online deployment additionally requires cybersecurity, versioned
# configuration, input-quality handling, observability, fail-safe behavior, and independent plant
# testing.

# %% [markdown]
# ## 14. Summary
#
# The notebook now demonstrates a complete online-model workflow:
#
# `fluid definition → process construction → recycle solve → KPI extraction → validation → input update → historian loop`
#
# The original oil-stabilization, parameter-update, and live-data examples remain present. The
# repaired flowsheet closes mass, reaches the intended 200 bara export pressure, and exposes named
# NeqSim streams and equipment that can be reused in a larger application.

# %% [markdown]
# ## 15. Further exercises
#
# 1. Add measured export-gas flow and compressor power, then calculate normalized residuals.
# 2. Add a bad-quality historian row and implement an explicit skip-and-log policy.
# 3. Vary second- and third-stage pressures and map TVP, oil yield, and total power.
# 4. Add compressor-map constraints and flag cases outside the valid operating envelope.
# 5. Replace the synthetic table with TagReader while retaining the same validation interface.
# 6. Compare PR with another justified equation of state using laboratory separator data.

# %% [markdown]
# ## References
#
# - [NeqSim documentation](https://equinor.github.io/neqsim/)
# - [NeqSim project homepage](https://equinor.github.io/neqsimhome/)
# - [NeqSim Python package and current release](https://pypi.org/project/neqsim/)
# - [NeqSim Java API](https://equinor.github.io/neqsimhome/javadoc/site/apidocs/index.html)
# - [TagReader Python repository](https://github.com/equinor/tagreader-python)
#
# Accessed 25 July 2026. Always review the current API and package release notes before deploying an
# online model.
