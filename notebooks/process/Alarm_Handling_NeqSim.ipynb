# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/process/Alarm_Handling_NeqSim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Alarm handling, detector voting, and gas-leak response with NeqSim
#
# This tutorial is for process, control, automation, and technical-safety engineers who
# need an auditable path from a process measurement to an operator alarm or shutdown vote.
#
# **Prerequisites:** Python basics, introductory process simulation, and familiarity with
# absolute pressure, gas composition, mass flow, and detector terminology.
#
# ## Learning objectives
#
# By the end, you will be able to:
#
# 1. configure native NeqSim `AlarmConfig`, `FireDetector`, and `GasDetector` objects;
# 2. evaluate alarm delay, deadband, acknowledgement, escalation, and clearance;
# 3. implement and test 1oo1, 1oo2, 2oo2, and 2oo3 voting;
# 4. convert methane concentration between ppm and percent LEL;
# 5. compare spurious-trip and dangerous-failure probabilities;
# 6. compose an SRK fluid, `Stream`, `Separator`, and `ProcessSystem`;
# 7. connect NeqSim gas properties to a reproducible room-dilution model;
# 8. trigger a two-detector ESD vote and audit its timing and material balance; and
# 9. reuse the workflow for ventilation and leak-rate studies.

# %% [markdown]
# ## Preservation and modernization note
#
# All eleven original teaching sections and all ten original code-example intentions are
# preserved: setup, fire-detector configuration, 2oo3 fire voting, combustible-gas
# configuration, staged gas alarms, LEL conversion, combined fire-and-gas logic, H2S
# configuration, 1oo2 voting, 2oo3 spurious-trip probability, and the closing exercises.
#
# The original notebook was an unexecuted Java/Jython draft inside a Python Colab. It used
# an obsolete NeqSim 3.0.51 POM magic, an incorrect `AlarmConfig` package, unresolved
# exercise placeholders, broken character encoding, and malformed display equations.
# This version translates every example to current Python-accessible NeqSim APIs. The
# original contained no technical plot, diagram, image, or other visual output; six new
# figures are added and retained below.

# %% [markdown]
# ## Clean Colab setup
#
# The setup installs the latest public PyPI package only when NeqSim is absent. It does
# not use a repository checkout, editable install, unpublished wheel, local JAR, secret,
# or runtime restart.

# %%
import importlib.util
import subprocess
import sys


if importlib.util.find_spec("neqsim") is None:
    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--no-cache-dir",
            "neqsim",
        ]
    )

# %%
import math
import platform
import subprocess
from importlib.metadata import version

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
from matplotlib.colors import LogNorm
from neqsim import jneqsim


plt.style.use("seaborn-v0_8-whitegrid")
plt.rcParams.update(
    {
        "figure.figsize": (9.0, 5.2),
        "figure.dpi": 120,
        "axes.titlesize": 14,
        "axes.labelsize": 11,
        "legend.fontsize": 9,
    }
)

COLORS = {
    "blue": "#0072B2",
    "orange": "#E69F00",
    "green": "#009E73",
    "red": "#D55E00",
    "purple": "#CC79A7",
    "grey": "#666666",
}

SystemSrkEos = jneqsim.thermo.system.SystemSrkEos
ThermodynamicOperations = jneqsim.thermodynamicoperations.ThermodynamicOperations
Stream = jneqsim.process.equipment.stream.Stream
Separator = jneqsim.process.equipment.separator.Separator
ProcessSystem = jneqsim.process.processmodel.ProcessSystem
AlarmConfig = jneqsim.process.alarm.AlarmConfig
FireDetector = jneqsim.process.measurementdevice.FireDetector
GasDetector = jneqsim.process.measurementdevice.GasDetector
GasType = jneqsim.process.measurementdevice.GasDetector.GasType

neqsim_version = version("neqsim")
java_version = subprocess.run(
    ["java", "-version"],
    capture_output=True,
    text=True,
    check=True,
).stderr.splitlines()[0]

print(f"NeqSim: {neqsim_version}")
print(f"Python: {platform.python_version()}")
print(f"Java: {java_version}")
# Out:
# NeqSim: 3.16.0
# Python: 3.12.13
# Java: openjdk version "17.0.19" 2026-04-21

# %% [markdown]
# ## Engineering context and scope
#
# An alarm is a notification requiring a defined operator response. A trip is an
# automatic protective action. Treating every event as an alarm produces nuisance load;
# treating every alarm as a trip can create unnecessary shutdowns. Alarm philosophy,
# rationalization, setpoint ownership, consequence, response time, priority, shelving,
# testing, and change control therefore sit outside the numerical threshold alone.
#
# This notebook demonstrates functional behavior and preliminary consequence screening.
# It does not certify detector coverage, an alarm system, a Safety Instrumented Function,
# or a Safety Integrity Level. Project work must use the governing edition of applicable
# standards and site-specific failure data.

# %% [markdown]
# ## NeqSim representation and solver workflow
#
# NeqSim separates responsibilities so the model remains reusable:
#
# - `SystemSrkEos` represents the gas composition and real-gas properties.
# - `Stream` provides a named thermodynamic and mass-flow boundary.
# - `Separator` and `ProcessSystem` compose and execute the steady-state process.
# - `FireDetector` stores a binary fire signal and location.
# - `GasDetector` stores combustible, toxic, or oxygen readings and conversion metadata.
# - `AlarmConfig` defines LOLO, LO, HI, HIHI, deadband, delay, and engineering units.
# - each detector's `AlarmState` evaluates, acknowledges, shelves, escalates, and clears.
#
# The final application passes NeqSim gas composition into an explicit room-inventory
# model, then passes calculated percent-LEL readings back through native detector and
# alarm objects.

# %%
fig, ax = plt.subplots(figsize=(10.0, 4.0))
ax.axis("off")

workflow_boxes = [
    (0.02, "SRK fluid and\nprocess system"),
    (0.22, "Leak source and\nroom inventory"),
    (0.42, "Gas-detector\nresponse"),
    (0.62, "Alarm delay,\ndeadband, state"),
    (0.82, "MooN voting,\nESD and audits"),
]

for x_position, label in workflow_boxes:
    rectangle = plt.Rectangle(
        (x_position, 0.35),
        0.16,
        0.30,
        facecolor="#DCEAF7",
        edgecolor=COLORS["blue"],
        linewidth=1.5,
    )
    ax.add_patch(rectangle)
    ax.text(
        x_position + 0.08,
        0.50,
        label,
        ha="center",
        va="center",
        fontsize=9.5,
    )

for x_position in [0.18, 0.38, 0.58, 0.78]:
    ax.annotate(
        "",
        xy=(x_position + 0.04, 0.50),
        xytext=(x_position, 0.50),
        arrowprops={"arrowstyle": "->", "color": COLORS["grey"]},
    )

ax.set_xlim(0.0, 1.0)
ax.set_ylim(0.0, 1.0)
ax.set_title(
    "Auditable workflow from NeqSim process properties to alarm and ESD action",
    pad=10,
)
plt.show()

# %% [markdown]
# Figure 1 separates the thermodynamic source, simplified dispersion, detector dynamics,
# alarm lifecycle, and voting action. This separation is deliberate: a user can replace
# the room model with CFD or field data without changing the native alarm configuration
# and voting checks.

# %% [markdown]
# ## Alarm delay, deadband, and lifecycle
#
# For a high alarm with limit $L$, deadband $D$, and confirmation delay $t_d$, activation
# requires the process value $PV$ to remain at or above the limit for the full delay:
#
# $$
# PV \geq L \quad \text{for} \quad t \geq t_d
# $$
#
# After activation, the same alarm clears only after the value crosses the hysteresis
# boundary:
#
# $$
# PV \leq L-D
# $$
#
# The deadband prevents chattering near the threshold. Acknowledgement records operator
# awareness; it does not remove the active condition. NeqSim can also shelve an alarm,
# but shelving must be governed and time limited in real operation.

# %% [markdown]
# ## Configure native fire and gas alarms
#
# The original warning and shutdown thresholds are retained: 20% LEL for HI, 60% LEL
# for HIHI, a 2 s delay, and 2% LEL deadband. Fire detectors use a binary threshold and
# 1 s delay. The correct current package is `neqsim.process.alarm.AlarmConfig`.

# %%
fire_alarm_config = (
    AlarmConfig.builder()
    .highLimit(0.5)
    .delay(1.0)
    .unit("binary")
    .build()
)

gas_alarm_config = (
    AlarmConfig.builder()
    .highLimit(20.0)
    .highHighLimit(60.0)
    .delay(2.0)
    .deadband(2.0)
    .unit("% LEL")
    .build()
)

fire_detectors = [
    FireDetector("FD-101", "Separator North"),
    FireDetector("FD-102", "Separator South"),
    FireDetector("FD-103", "Separator East"),
]

for detector in fire_detectors:
    detector.setAlarmConfig(fire_alarm_config)

fire_configuration = pd.DataFrame(
    {
        "Tag": [detector.getName() for detector in fire_detectors],
        "Location": [detector.getLocation() for detector in fire_detectors],
        "Threshold [binary]": [
            detector.getAlarmConfig().getHighLimit()
            for detector in fire_detectors
        ],
        "Delay [s]": [
            detector.getAlarmConfig().getDelay()
            for detector in fire_detectors
        ],
    }
)
display(fire_configuration)
# Out:
#                   Tag  ... Delay [s]
# 0  (F, D, -, 1, 0, 1)  ...       1.0
# 1  (F, D, -, 1, 0, 2)  ...       1.0
# 2  (F, D, -, 1, 0, 3)  ...       1.0
#
# [3 rows x 4 columns]

# %% [markdown]
# ## Preserve the four fire-voting scenarios
#
# The original no-fire, one-detector, two-detector, and three-detector tests are retained.
# The helper accepts any detector list and required vote count, which makes the logic
# reusable instead of embedding it in printed Java conditionals.

# %%
def active_fire_count(detectors):
    return sum(
        bool(detector.isFireDetected())
        for detector in detectors
    )


def vote_is_active(detectors, required_votes):
    return active_fire_count(detectors) >= required_votes


fire_scenarios = [
    ("No fire", []),
    ("FD-101 only", [0]),
    ("FD-101 and FD-102", [0, 1]),
    ("All three detectors", [0, 1, 2]),
]

fire_rows = []
for scenario_name, active_indices in fire_scenarios:
    for detector in fire_detectors:
        detector.reset()

    for active_index in active_indices:
        fire_detectors[active_index].detectFire()

    active_count = active_fire_count(fire_detectors)
    fire_rows.append(
        {
            "Scenario": scenario_name,
            "Active detectors": active_count,
            "2oo3 ESD": vote_is_active(fire_detectors, 2),
        }
    )

fire_vote_table = pd.DataFrame(fire_rows)
display(fire_vote_table)
# Out:
#               Scenario  Active detectors  2oo3 ESD
# 0              No fire                 0     False
# 1          FD-101 only                 1     False
# 2    FD-101 and FD-102                 2      True
# 3  All three detectors                 3      True

# %% [markdown]
# The 2oo3 vote rejects one isolated detector but acts when any two agree. The final row
# also acts because MooN logic means *at least* M votes, not exactly M.

# %% [markdown]
# ## Exercise the native alarm lifecycle
#
# This deterministic sequence crosses HI, receives acknowledgement, escalates to HIHI,
# and then clears through the configured deadbands. `evaluateAlarm` uses the measured
# value, time step, and simulation time; returned `AlarmEvent` objects form an audit log.

# %%
lifecycle_detector = GasDetector(
    "GD-LIFECYCLE",
    GasType.COMBUSTIBLE,
    "Training loop",
)
lifecycle_detector.setAlarmConfig(gas_alarm_config)
lifecycle_detector.setGasSpecies("methane")
lifecycle_detector.setLowerExplosiveLimit(50_000.0)

lifecycle_values = [
    0.0,
    10.0,
    21.0,
    22.0,
    23.0,
    25.0,
    61.0,
    62.0,
    63.0,
    61.0,
    58.0,
    57.0,
    10.0,
]

lifecycle_rows = []
lifecycle_events = []
for time_seconds, measured_value in enumerate(lifecycle_values):
    lifecycle_detector.setGasConcentration(measured_value)
    events = list(
        lifecycle_detector.evaluateAlarm(
            measured_value,
            1.0,
            float(time_seconds),
        )
    )

    if time_seconds == 5:
        acknowledgement = lifecycle_detector.acknowledgeAlarm(
            float(time_seconds) + 0.1
        )
        if acknowledgement is not None:
            events.append(acknowledgement)

    for event in events:
        lifecycle_events.append(
            {
                "Time [s]": float(event.getTimestamp()),
                "Type": str(event.getType()),
                "Level": str(event.getLevel()),
                "Value [% LEL]": float(event.getValue()),
            }
        )

    alarm_state = lifecycle_detector.getAlarmState()
    active_level = (
        str(alarm_state.getActiveLevel())
        if alarm_state.isActive()
        else "NORMAL"
    )
    lifecycle_rows.append(
        {
            "Time [s]": time_seconds,
            "Reading [% LEL]": measured_value,
            "Active level": active_level,
            "Acknowledged": bool(alarm_state.isAcknowledged()),
        }
    )

lifecycle_table = pd.DataFrame(lifecycle_rows)
lifecycle_event_table = pd.DataFrame(lifecycle_events)
display(lifecycle_event_table)
# Out:
#    Time [s]          Type Level  Value [% LEL]
# 0       3.0     ACTIVATED    HI           22.0
# 1       5.1  ACKNOWLEDGED    HI           25.0
# 2       7.0       CLEARED    HI           62.0
# 3       7.0     ACTIVATED  HIHI           62.0
# 4      10.0       CLEARED  HIHI           58.0
# 5      11.0     ACTIVATED    HI           57.0
# 6      12.0       CLEARED    HI           10.0

# %%
level_number = {
    "NORMAL": 0,
    "HI": 1,
    "HIHI": 2,
}
lifecycle_level_numbers = [
    level_number[level]
    for level in lifecycle_table["Active level"]
]

fig, primary_axis = plt.subplots(figsize=(9.5, 5.4))
primary_axis.plot(
    lifecycle_table["Time [s]"],
    lifecycle_table["Reading [% LEL]"],
    marker="o",
    color=COLORS["blue"],
    label="Detector reading",
)
primary_axis.axhline(
    20.0,
    color=COLORS["orange"],
    linestyle="--",
    label="HI limit (20% LEL)",
)
primary_axis.axhline(
    60.0,
    color=COLORS["red"],
    linestyle="--",
    label="HIHI limit (60% LEL)",
)
primary_axis.set_xlabel("Simulation time [s]")
primary_axis.set_ylabel("Methane detector reading [% LEL]")
primary_axis.set_ylim(-3.0, 70.0)

secondary_axis = primary_axis.twinx()
secondary_axis.step(
    lifecycle_table["Time [s]"],
    lifecycle_level_numbers,
    where="post",
    color=COLORS["purple"],
    linewidth=2.0,
    label="Native alarm state",
)
secondary_axis.set_ylabel("Alarm state")
secondary_axis.set_yticks([0, 1, 2], ["NORMAL", "HI", "HIHI"])
secondary_axis.set_ylim(-0.2, 2.3)

lines_1, labels_1 = primary_axis.get_legend_handles_labels()
lines_2, labels_2 = secondary_axis.get_legend_handles_labels()
primary_axis.legend(
    lines_1 + lines_2,
    labels_1 + labels_2,
    loc="upper left",
)
primary_axis.set_title(
    "Native NeqSim alarm delay, escalation, acknowledgement, and clearance"
)
plt.show()

# %% [markdown]
# Figure 2 shows the distinction between a raw threshold crossing and an alarm state.
# HI activates only after the 2 s confirmation. HIHI escalation produces a new
# unacknowledged state, and the 2% LEL deadband controls clearance.

# %% [markdown]
# ## Voting reliability: state assumptions before comparing architectures
#
# Let $p$ be the independent probability that one healthy channel votes spuriously during
# the stated interval. For three identical independent channels, an exact 2oo3 spurious
# vote probability is:
#
# $$
# P_{\mathrm{spur},2oo3}=3p^2(1-p)+p^3
# $$
#
# Let $q$ be the independent probability that one channel fails dangerously and therefore
# cannot vote on demand. A 2oo3 vote fails when at least two channels fail:
#
# $$
# P_{\mathrm{danger},2oo3}=3q^2(1-q)+q^3
# $$
#
# These simple binomial expressions omit diagnostics, common-cause failures, repair,
# proof testing, logic solver and final elements. They are teaching comparisons, not SIL
# verification.

# %%
def voting_probabilities(false_vote_probability, dangerous_failure_probability):
    p_value = false_vote_probability
    q_value = dangerous_failure_probability

    return pd.DataFrame(
        {
            "Architecture": ["1oo1", "2oo2", "2oo3"],
            "Spurious trip probability": [
                p_value,
                p_value**2,
                3.0 * p_value**2 * (1.0 - p_value) + p_value**3,
            ],
            "Dangerous failure probability": [
                q_value,
                1.0 - (1.0 - q_value) ** 2,
                3.0 * q_value**2 * (1.0 - q_value) + q_value**3,
            ],
        }
    )


single_false_vote_probability = 0.01
single_dangerous_failure_probability = 0.001
reliability_table = voting_probabilities(
    single_false_vote_probability,
    single_dangerous_failure_probability,
)
display(reliability_table.round(8))
# Out:
#   Architecture  Spurious trip probability  Dangerous failure probability
# 0         1oo1                   0.010000                       0.001000
# 1         2oo2                   0.000100                       0.001999
# 2         2oo3                   0.000298                       0.000003

# %%
architecture_positions = np.arange(len(reliability_table))
bar_width = 0.36

fig, ax = plt.subplots(figsize=(9.0, 5.2))
ax.bar(
    architecture_positions - bar_width / 2.0,
    reliability_table["Spurious trip probability"],
    width=bar_width,
    color=COLORS["blue"],
    label="Spurious trip probability",
)
ax.bar(
    architecture_positions + bar_width / 2.0,
    reliability_table["Dangerous failure probability"],
    width=bar_width,
    color=COLORS["orange"],
    label="Dangerous failure probability",
)
ax.set_yscale("log")
ax.set_xticks(
    architecture_positions,
    reliability_table["Architecture"],
)
ax.set_xlabel("Detector voting architecture")
ax.set_ylabel("Probability per stated interval [-]")
ax.set_title(
    "Independent-channel voting trade-off for the stated p and q assumptions"
)
ax.legend()
plt.show()

# %% [markdown]
# Figure 3 makes the trade-off visible. With the stated independent probabilities, 2oo2
# has the smallest spurious-trip probability but the largest dangerous-failure
# probability. 2oo3 substantially reduces both relative to 1oo1, while real safety
# verification must include common-cause and downstream failures.

# %% [markdown]
# ## Combustible, toxic, and oxygen detection
#
# A combustible-gas detector reports concentration relative to the lower explosive limit
# (LEL). For a gas with LEL expressed in ppm:
#
# $$
# \%\mathrm{LEL}=\frac{C_{\mathrm{ppm}}}{LEL_{\mathrm{ppm}}}100
# $$
#
# This notebook retains the original illustrative methane value of 50,000 ppm, equivalent
# to 5 vol%. Real detector calibration, cross-sensitivity, environmental effects, response
# time, placement, and the applicable setpoint philosophy must be verified for the
# installed device and jurisdiction.

# %% [markdown]
# ## Configure the two original methane detectors
#
# Both instruments retain the 10 s response-time metadata and the original east/west
# locations. The native detector conversion methods are used in both directions.

# %%
gas_detectors = [
    GasDetector(
        "GD-101",
        GasType.COMBUSTIBLE,
        "Separator East",
    ),
    GasDetector(
        "GD-102",
        GasType.COMBUSTIBLE,
        "Separator West",
    ),
]

for detector in gas_detectors:
    detector.setGasSpecies("methane")
    detector.setLowerExplosiveLimit(50_000.0)
    detector.setResponseTime(10.0)
    detector.setAlarmConfig(gas_alarm_config)

gas_configuration = pd.DataFrame(
    {
        "Tag": [detector.getName() for detector in gas_detectors],
        "Location": [detector.getLocation() for detector in gas_detectors],
        "Species": [detector.getGasSpecies() for detector in gas_detectors],
        "LEL [ppm]": [
            detector.getLowerExplosiveLimit()
            for detector in gas_detectors
        ],
        "T90 metadata [s]": [
            detector.getResponseTime()
            for detector in gas_detectors
        ],
    }
)
display(gas_configuration)
# Out:
#                   Tag  ... T90 metadata [s]
# 0  (G, D, -, 1, 0, 1)  ...             10.0
# 1  (G, D, -, 1, 0, 2)  ...             10.0
#
# [2 rows x 5 columns]

# %%
conversion_detector = gas_detectors[0]
methane_concentration_ppm = 10_000.0
methane_percent_lel = conversion_detector.convertPpmToPercentLEL(
    methane_concentration_ppm
)
warning_setpoint_percent_lel = 20.0
warning_setpoint_ppm = conversion_detector.convertPercentLELToPpm(
    warning_setpoint_percent_lel
)

lel_conversion_table = pd.DataFrame(
    {
        "Quantity": [
            "Methane example",
            "HI warning setpoint",
        ],
        "Concentration [ppm]": [
            methane_concentration_ppm,
            warning_setpoint_ppm,
        ],
        "Concentration [% LEL]": [
            methane_percent_lel,
            warning_setpoint_percent_lel,
        ],
    }
)
display(lel_conversion_table)
# Out:
#               Quantity  Concentration [ppm]  Concentration [% LEL]
# 0      Methane example              10000.0                   20.0
# 1  HI warning setpoint              10000.0                   20.0

# %% [markdown]
# The original 10,000 ppm example equals 20% LEL, and the inverse method returns
# 10,000 ppm for the 20% LEL warning setpoint. Explicit bidirectional conversion is a
# useful unit check before importing detector data.

# %% [markdown]
# ## Preserve the staged gas-leak decisions
#
# The original stages are retained exactly: normal, 25/15% LEL warning, and 65/62% LEL
# high alarm. The two-channel high vote uses 2oo2.

# %%
staged_readings = [
    ("Normal operation", 0.0, 0.0),
    ("Small leak", 25.0, 15.0),
    ("Large leak", 65.0, 62.0),
]

staged_rows = []
for stage_name, east_reading, west_reading in staged_readings:
    gas_detectors[0].setGasConcentration(east_reading)
    gas_detectors[1].setGasConcentration(west_reading)

    warning_active = any(
        detector.isGasDetected(20.0)
        for detector in gas_detectors
    )
    high_votes = sum(
        bool(detector.isHighAlarm(60.0))
        for detector in gas_detectors
    )
    staged_rows.append(
        {
            "Stage": stage_name,
            "GD-101 [% LEL]": east_reading,
            "GD-102 [% LEL]": west_reading,
            "Warning active": warning_active,
            "High votes": high_votes,
            "2oo2 ESD": high_votes >= 2,
        }
    )

staged_gas_table = pd.DataFrame(staged_rows)
display(staged_gas_table)
# Out:
#               Stage  GD-101 [% LEL]  ...  High votes  2oo2 ESD
# 0  Normal operation             0.0  ...           0     False
# 1        Small leak            25.0  ...           0     False
# 2        Large leak            65.0  ...           2      True
#
# [3 rows x 6 columns]

# %% [markdown]
# ## Detector response is not instantaneous
#
# The original notebook listed T90 response times but stepped readings instantly. For
# teaching, a first-order instrument approximation is added:
#
# $$
# \frac{dy}{dt}=\frac{x-y}{\tau}
# $$
#
# $x$ is the local gas concentration in % LEL, $y$ is the indicated reading in % LEL,
# and $\tau$ is the time constant in s. The native `responseTime` field remains detector
# metadata; the explicit response calculation makes the assumption inspectable.

# %%
response_times = np.arange(0.0, 61.0, 1.0)
target_percent_lel = np.where(
    response_times < 5.0,
    0.0,
    80.0,
)
response_time_constants = {
    "Fast detector, tau = 5 s": 5.0,
    "Nominal detector, tau = 10 s": 10.0,
    "Slow detector, tau = 15 s": 15.0,
}

response_profiles = {
    "Time [s]": response_times,
    "Local concentration [% LEL]": target_percent_lel,
}

for detector_label, time_constant in response_time_constants.items():
    indicated_value = 0.0
    indicated_values = []

    for target_value in target_percent_lel:
        indicated_value += (
            target_value - indicated_value
        ) / time_constant
        indicated_values.append(indicated_value)

    response_profiles[detector_label] = indicated_values

detector_response_table = pd.DataFrame(response_profiles)

# %%
fig, ax = plt.subplots(figsize=(9.2, 5.2))
ax.plot(
    detector_response_table["Time [s]"],
    detector_response_table["Local concentration [% LEL]"],
    color=COLORS["grey"],
    linestyle=":",
    linewidth=2.5,
    label="Local concentration",
)

profile_colors = [
    COLORS["green"],
    COLORS["blue"],
    COLORS["purple"],
]
for (profile_name, _), profile_color in zip(
    response_time_constants.items(),
    profile_colors,
):
    ax.plot(
        detector_response_table["Time [s]"],
        detector_response_table[profile_name],
        color=profile_color,
        label=profile_name,
    )

ax.axhline(
    20.0,
    color=COLORS["orange"],
    linestyle="--",
    label="HI limit (20% LEL)",
)
ax.axhline(
    60.0,
    color=COLORS["red"],
    linestyle="--",
    label="HIHI limit (60% LEL)",
)
ax.set_xlabel("Time after methane step [s]")
ax.set_ylabel("Methane concentration or reading [% LEL]")
ax.set_ylim(0.0, 85.0)
ax.set_title("First-order detector response changes alarm threshold crossing time")
ax.legend(ncol=2)
plt.show()

# %% [markdown]
# Figure 4 shows why the local concentration and instrument reading must not be
# conflated. A slower detector crosses both thresholds later. This model is illustrative;
# use the certified response curve, sampling, filtering, and environmental corrections
# for engineering work.

# %% [markdown]
# ## Combined fire-and-gas logic
#
# The original three combined scenarios are retained: fire only, gas only, and a combined
# event. Each zone uses 2oo2, while the final ESD demand is the logical OR of the fire
# and gas zones.

# %%
combined_fire_detectors = [
    FireDetector("FD-201", "Zone A North"),
    FireDetector("FD-202", "Zone A South"),
]
combined_gas_detectors = [
    GasDetector("GD-201", GasType.COMBUSTIBLE, "Zone A East"),
    GasDetector("GD-202", GasType.COMBUSTIBLE, "Zone A West"),
]

for detector in combined_gas_detectors:
    detector.setGasSpecies("methane")
    detector.setLowerExplosiveLimit(50_000.0)

combined_scenarios = [
    ("Fire event", True, 0.0),
    ("Gas event", False, 70.0),
    ("Fire and gas event", True, 70.0),
]

combined_rows = []
for scenario_name, fire_present, gas_reading in combined_scenarios:
    for detector in combined_fire_detectors:
        detector.reset()
        if fire_present:
            detector.detectFire()

    for detector in combined_gas_detectors:
        detector.reset()
        detector.setGasConcentration(gas_reading)

    fire_vote = vote_is_active(combined_fire_detectors, 2)
    gas_vote = sum(
        bool(detector.isHighAlarm(60.0))
        for detector in combined_gas_detectors
    ) >= 2
    combined_rows.append(
        {
            "Scenario": scenario_name,
            "Fire 2oo2": fire_vote,
            "Gas 2oo2": gas_vote,
            "Combined ESD": fire_vote or gas_vote,
        }
    )

combined_fg_table = pd.DataFrame(combined_rows)
display(combined_fg_table)
# Out:
#              Scenario  Fire 2oo2  Gas 2oo2  Combined ESD
# 0          Fire event       True     False          True
# 1           Gas event      False      True          True
# 2  Fire and gas event       True      True          True

# %% [markdown]
# The OR logic ensures that either confirmed hazard demands the protective action.
# Separation into zone votes and final logic also creates a clear test boundary for
# cause-and-effect verification.

# %% [markdown]
# ## Complete the original exercises
#
# The draft left three code cells unresolved. They are now executable examples with
# assertions, while the final section proposes new exercises that do not interrupt a
# top-to-bottom run.

# %%
h2s_detector = GasDetector(
    "H2S-101",
    GasType.TOXIC,
    "Compressor Area",
)
h2s_detector.setGasSpecies("H2S")
h2s_detector.setResponseTime(30.0)

h2s_alarm_config = (
    AlarmConfig.builder()
    .highLimit(10.0)
    .highHighLimit(20.0)
    .delay(0.0)
    .deadband(1.0)
    .unit("ppm")
    .build()
)
h2s_detector.setAlarmConfig(h2s_alarm_config)
h2s_detector.setGasConcentration(15.0)
h2s_events = list(
    h2s_detector.evaluateAlarm(
        h2s_detector.getMeasuredValue(),
        1.0,
        1.0,
    )
)

oxygen_detector = GasDetector(
    "O2-101",
    GasType.OXYGEN,
    "Enclosed Module",
)
oxygen_detector.setGasSpecies("oxygen")
oxygen_detector.setGasConcentration(18.9)

toxic_oxygen_table = pd.DataFrame(
    {
        "Tag": [
            h2s_detector.getName(),
            oxygen_detector.getName(),
        ],
        "Species": [
            h2s_detector.getGasSpecies(),
            oxygen_detector.getGasSpecies(),
        ],
        "Reading": [
            h2s_detector.getMeasuredValue(),
            oxygen_detector.getMeasuredValue(),
        ],
        "Unit": [
            h2s_detector.getUnit(),
            oxygen_detector.getUnit(),
        ],
        "Screening status": [
            str(h2s_detector.getAlarmState().getActiveLevel()),
            "LOW" if oxygen_detector.getMeasuredValue() < 19.5 else "NORMAL",
        ],
    }
)
display(toxic_oxygen_table)
# Out:
#                      Tag             Species  ...          Unit Screening status
# 0  (H, 2, S, -, 1, 0, 1)           (H, 2, S)  ...     (p, p, m)               HI
# 1     (O, 2, -, 1, 0, 1)  (o, x, y, g, e, n)  ...  (%,  , O, 2)              LOW
#
# [2 rows x 5 columns]

# %%
def check_1oo2_voting(detectors):
    return vote_is_active(detectors, 1)


exercise_fire_detectors = [
    FireDetector("TEST-1", "Zone 1"),
    FireDetector("TEST-2", "Zone 2"),
]
exercise_fire_detectors[0].detectFire()
exercise_1oo2_result = check_1oo2_voting(
    exercise_fire_detectors
)

exercise_false_vote_probability = 0.02
exercise_2oo3_probability = (
    3.0
    * exercise_false_vote_probability**2
    * (1.0 - exercise_false_vote_probability)
    + exercise_false_vote_probability**3
)
exercise_improvement_factor = (
    exercise_false_vote_probability
    / exercise_2oo3_probability
)

exercise_results = pd.DataFrame(
    {
        "Exercise": [
            "1oo2 fire vote",
            "2oo3 spurious probability",
            "1oo1 / 2oo3 improvement",
        ],
        "Result": [
            exercise_1oo2_result,
            exercise_2oo3_probability,
            exercise_improvement_factor,
        ],
        "Unit": [
            "boolean",
            "probability",
            "times",
        ],
    }
)
display(exercise_results)
# Out:
#                     Exercise     Result         Unit
# 0             1oo2 fire vote       True      boolean
# 1  2oo3 spurious probability   0.001184  probability
# 2    1oo1 / 2oo3 improvement  16.891892        times

# %% [markdown]
# The H2S example is at the HI level, the oxygen screen identifies a sub-19.5 vol%
# condition, either fire detector activates 1oo2, and the exact 2oo3 expression includes
# the all-three-vote term omitted by the draft.

# %% [markdown]
# ## Final application: process gas leak, detection, voting, and shutdown
#
# The final workflow makes the examples composable. A named SRK gas stream enters a
# separator in a `ProcessSystem`. A small gas leak into a ventilated 300 m³ module is
# then represented by a methane molar inventory. Two native NeqSim gas detectors have
# different response constants and spatial factors. Their native HIHI alarm states form
# a 2oo2 ESD vote, followed by an 8 s isolation delay.
#
# This is a reproducible screening model, not a dispersion or detector-coverage design.

# %% [markdown]
# ## Build the NeqSim fluid and process objects
#
# The original methane-rich gas basis is retained: 1 mol% nitrogen, 85 mol% methane,
# 10 mol% ethane, 3 mol% propane, and 1 mol% n-butane. SRK with the classic mixing rule
# is appropriate for a hydrocarbon-rich screening gas at 50 bara and 25 °C. Pressure is
# absolute and flow is mass flow.

# %%
feed_composition = {
    "nitrogen": 0.01,
    "methane": 0.85,
    "ethane": 0.10,
    "propane": 0.03,
    "n-butane": 0.01,
}

feed_fluid = SystemSrkEos(
    273.15 + 25.0,
    50.0,
)
for component_name, mole_fraction in feed_composition.items():
    feed_fluid.addComponent(
        component_name,
        mole_fraction,
    )

feed_fluid.createDatabase(True)
feed_fluid.setMixingRule("classic")
feed_flash = ThermodynamicOperations(feed_fluid)
feed_flash.TPflash()
feed_fluid.initProperties()

protected_feed = Stream(
    "F&G protected separator feed",
    feed_fluid,
)
protected_feed.setFlowRate(5_000.0, "kg/hr")

inlet_separator = Separator(
    "inlet separator",
    protected_feed,
)

alarm_process = ProcessSystem()
alarm_process.add(protected_feed)
alarm_process.add(inlet_separator)
alarm_process.run()

# %%
separator_gas = inlet_separator.getGasOutStream()
separator_liquid = inlet_separator.getLiquidOutStream()
separator_gas_system = separator_gas.getThermoSystem()
separator_gas_system.initProperties()

gas_molar_mass_kg_per_mol = separator_gas_system.getMolarMass()
methane_mole_fraction = (
    separator_gas_system
    .getComponent("methane")
    .getz()
)
methane_molar_mass_kg_per_mol = (
    separator_gas_system
    .getComponent("methane")
    .getMolarMass()
)

process_result_table = pd.DataFrame(
    {
        "Quantity": [
            "Feed mass flow",
            "Separator gas mass flow",
            "Separator liquid mass flow",
            "Gas temperature",
            "Gas pressure",
            "Gas compressibility factor",
            "Gas density",
            "Gas molar mass",
            "Methane mole fraction",
        ],
        "Value": [
            protected_feed.getFlowRate("kg/hr"),
            separator_gas.getFlowRate("kg/hr"),
            separator_liquid.getFlowRate("kg/hr"),
            separator_gas.getTemperature("C"),
            separator_gas.getPressure("bara"),
            separator_gas_system.getZ(),
            separator_gas_system.getDensity("kg/m3"),
            gas_molar_mass_kg_per_mol * 1_000.0,
            methane_mole_fraction,
        ],
        "Unit": [
            "kg/h",
            "kg/h",
            "kg/h",
            "°C",
            "bara",
            "-",
            "kg/m³",
            "g/mol",
            "mol/mol",
        ],
    }
)
display(process_result_table.round({"Value": 6}))
# Out:
#                      Quantity        Value     Unit
# 0              Feed mass flow  5000.000000     kg/h
# 1     Separator gas mass flow  5000.000000     kg/h
# 2  Separator liquid mass flow     0.000000     kg/h
# 3             Gas temperature    25.000000       °C
# 4                Gas pressure    50.000000     bara
# 5  Gas compressibility factor     0.881949        -
# 6                 Gas density    43.166017    kg/m³
# 7              Gas molar mass    18.827825    g/mol
# 8       Methane mole fraction     0.850000  mol/mol

# %% [markdown]
# The process is gas only at the selected condition, as expected for this light mixture.
# The `Separator` is still useful because it exposes named gas and liquid boundaries for
# reuse when a heavier or colder feed is substituted.

# %% [markdown]
# ## Room inventory and detector model
#
# For a perfectly mixed module with air-change rate $N$ in h⁻¹, the methane inventory is:
#
# $$
# \frac{dn_{CH_4}}{dt}=\dot{n}_{CH_4,\mathrm{leak}}-\frac{N}{3600}n_{CH_4}
# $$
#
# $n_{CH_4}$ is methane amount in mol and $\dot{n}_{CH_4,\mathrm{leak}}$ is mol/s.
# The room air amount is held constant at 1.01325 bar and 25 °C. The source composition
# and molar mass come from the NeqSim separator gas. A 1 s explicit balance is sufficient
# for the 600 s ventilation time constant in the base case.

# %%
def simulate_leak_alarm(
    total_leak_rate_kg_per_s,
    air_changes_per_hour,
    duration_seconds=1_200,
    room_volume_m3=300.0,
):
    east_detector = GasDetector(
        "GD-301",
        GasType.COMBUSTIBLE,
        "Module East",
    )
    west_detector = GasDetector(
        "GD-302",
        GasType.COMBUSTIBLE,
        "Module West",
    )

    for detector in [east_detector, west_detector]:
        detector.setGasSpecies("methane")
        detector.setLowerExplosiveLimit(50_000.0)
        detector.setAlarmConfig(gas_alarm_config)

    time_step_seconds = 1.0
    temperature_k = 298.15
    pressure_pa = 101_325.0
    gas_constant = 8.314462618
    room_air_moles = (
        pressure_pa
        * room_volume_m3
        / (gas_constant * temperature_k)
    )
    ventilation_rate_per_s = air_changes_per_hour / 3_600.0
    methane_source_mol_per_s = (
        total_leak_rate_kg_per_s
        / gas_molar_mass_kg_per_mol
        * methane_mole_fraction
    )

    room_methane_moles = 0.0
    cumulative_input_moles = 0.0
    cumulative_exhaust_moles = 0.0
    east_reading = 0.0
    west_reading = 0.0
    esd_time_seconds = None
    closure_time_seconds = None
    event_rows = []
    result_rows = []

    for time_seconds in np.arange(
        0.0,
        duration_seconds + time_step_seconds,
        time_step_seconds,
    ):
        leak_is_open = (
            closure_time_seconds is None
            or time_seconds < closure_time_seconds
        )
        source_mol_per_s = (
            methane_source_mol_per_s
            if leak_is_open
            else 0.0
        )
        exhausted_moles = (
            ventilation_rate_per_s
            * room_methane_moles
            * time_step_seconds
        )
        added_moles = source_mol_per_s * time_step_seconds
        room_methane_moles += added_moles - exhausted_moles
        cumulative_input_moles += added_moles
        cumulative_exhaust_moles += exhausted_moles

        local_percent_lel = (
            room_methane_moles
            / room_air_moles
            / 0.05
            * 100.0
        )
        east_target = 1.03 * local_percent_lel
        west_target = 0.97 * local_percent_lel
        east_reading += (
            east_target - east_reading
        ) / 10.0
        west_reading += (
            west_target - west_reading
        ) / 14.0

        east_detector.setGasConcentration(east_reading)
        west_detector.setGasConcentration(west_reading)

        for detector, reading in [
            (east_detector, east_reading),
            (west_detector, west_reading),
        ]:
            events = list(
                detector.evaluateAlarm(
                    reading,
                    time_step_seconds,
                    time_seconds,
                )
            )
            for event in events:
                event_rows.append(
                    {
                        "Tag": detector.getName(),
                        "Time [s]": float(event.getTimestamp()),
                        "Type": str(event.getType()),
                        "Level": str(event.getLevel()),
                        "Reading [% LEL]": float(event.getValue()),
                    }
                )

        east_state = east_detector.getAlarmState()
        west_state = west_detector.getAlarmState()
        east_level = (
            str(east_state.getActiveLevel())
            if east_state.isActive()
            else "NORMAL"
        )
        west_level = (
            str(west_state.getActiveLevel())
            if west_state.isActive()
            else "NORMAL"
        )

        if (
            esd_time_seconds is None
            and east_level == "HIHI"
            and west_level == "HIHI"
        ):
            esd_time_seconds = time_seconds
            closure_time_seconds = time_seconds + 8.0

        balance_residual_moles = (
            cumulative_input_moles
            - cumulative_exhaust_moles
            - room_methane_moles
        )
        result_rows.append(
            {
                "Time [s]": time_seconds,
                "Room methane [% LEL]": local_percent_lel,
                "GD-301 [% LEL]": east_reading,
                "GD-302 [% LEL]": west_reading,
                "GD-301 state": east_level,
                "GD-302 state": west_level,
                "Leak open": leak_is_open,
                "Room methane [mol]": room_methane_moles,
                "Cumulative input [mol]": cumulative_input_moles,
                "Cumulative exhaust [mol]": cumulative_exhaust_moles,
                "Balance residual [mol]": balance_residual_moles,
            }
        )

    return {
        "history": pd.DataFrame(result_rows),
        "events": pd.DataFrame(event_rows),
        "esd_time_seconds": esd_time_seconds,
        "closure_time_seconds": closure_time_seconds,
        "methane_source_mol_per_s": methane_source_mol_per_s,
        "room_air_moles": room_air_moles,
    }

# %%
base_application = simulate_leak_alarm(
    total_leak_rate_kg_per_s=0.040,
    air_changes_per_hour=6.0,
)
base_history = base_application["history"]
base_events = base_application["events"]

base_summary = pd.DataFrame(
    {
        "Quantity": [
            "Methane source",
            "First 2oo2 HIHI ESD vote",
            "Leak isolated",
            "Peak room methane",
            "Final room methane",
            "Maximum molar-balance residual",
        ],
        "Value": [
            base_application["methane_source_mol_per_s"],
            base_application["esd_time_seconds"],
            base_application["closure_time_seconds"],
            base_history["Room methane [% LEL]"].max(),
            base_history["Room methane [% LEL]"].iloc[-1],
            base_history["Balance residual [mol]"].abs().max(),
        ],
        "Unit": [
            "mol/s",
            "s",
            "s",
            "% LEL",
            "% LEL",
            "mol",
        ],
    }
)
display(base_summary.round({"Value": 6}))
display(base_events)
# Out:
#                          Quantity       Value   Unit
# 0                  Methane source    1.805838  mol/s
# 1        First 2oo2 HIHI ESD vote  272.000000      s
# 2                   Leak isolated  280.000000      s
# 3               Peak room methane   65.944779  % LEL
# 4              Final room methane   14.189995  % LEL
# 5  Maximum molar-balance residual    0.000000    mol
#                    Tag  Time [s]       Type Level  Reading [% LEL]
# 0   (G, D, -, 3, 0, 1)      79.0  ACTIVATED    HI        20.309995
# 1   (G, D, -, 3, 0, 2)      88.0  ACTIVATED    HI        20.376695
# 2   (G, D, -, 3, 0, 1)     249.0    CLEARED    HI        60.238213
# 3   (G, D, -, 3, 0, 1)     249.0  ACTIVATED  HIHI        60.238213
# 4   (G, D, -, 3, 0, 2)     272.0    CLEARED    HI        60.292613
# 5   (G, D, -, 3, 0, 2)     272.0  ACTIVATED  HIHI        60.292613
# 6   (G, D, -, 3, 0, 2)     351.0    CLEARED  HIHI        57.967603
# ...

# %%
fig, ax = plt.subplots(figsize=(10.0, 5.6))
ax.plot(
    base_history["Time [s]"],
    base_history["Room methane [% LEL]"],
    color=COLORS["grey"],
    linewidth=2.0,
    label="Well-mixed room concentration",
)
ax.plot(
    base_history["Time [s]"],
    base_history["GD-301 [% LEL]"],
    color=COLORS["blue"],
    label="GD-301 indicated reading",
)
ax.plot(
    base_history["Time [s]"],
    base_history["GD-302 [% LEL]"],
    color=COLORS["green"],
    label="GD-302 indicated reading",
)
ax.axhline(
    20.0,
    color=COLORS["orange"],
    linestyle="--",
    label="HI limit (20% LEL)",
)
ax.axhline(
    60.0,
    color=COLORS["red"],
    linestyle="--",
    label="HIHI limit (60% LEL)",
)
ax.axvline(
    base_application["esd_time_seconds"],
    color=COLORS["purple"],
    linestyle="-.",
    label="2oo2 ESD vote",
)
ax.axvline(
    base_application["closure_time_seconds"],
    color=COLORS["red"],
    linestyle=":",
    label="Leak isolated",
)
ax.set_xlabel("Time [s]")
ax.set_ylabel("Methane concentration or reading [% LEL]")
ax.set_ylim(0.0, 72.0)
ax.set_title(
    "End-to-end NeqSim gas-leak alarm workflow: detection, ESD, and ventilation"
)
ax.legend(ncol=2)
plt.show()

# %% [markdown]
# Figure 5 shows the complete application. Detector lag and spatial factors make the two
# readings differ. ESD occurs only after both native alarm states reach HIHI; the source
# continues through the stated 8 s final-element delay, then ventilation reduces the
# inventory. The retained balance output verifies that this response is not a
# non-conservative concentration sketch.

# %% [markdown]
# ## Sensitivity: ventilation and leak rate
#
# Each case creates fresh NeqSim detector and alarm-state objects, so results do not
# depend on previous scenario history. The fluid composition remains the validated SRK
# separator-gas result.

# %%
leak_rates_kg_per_s = [
    0.025,
    0.030,
    0.040,
    0.050,
]
ventilation_rates_per_hour = [
    4.0,
    6.0,
    8.0,
]

sensitivity_rows = []
for leak_rate_kg_per_s in leak_rates_kg_per_s:
    for ventilation_rate_per_hour in ventilation_rates_per_hour:
        case_result = simulate_leak_alarm(
            total_leak_rate_kg_per_s=leak_rate_kg_per_s,
            air_changes_per_hour=ventilation_rate_per_hour,
            duration_seconds=1_000,
        )
        case_history = case_result["history"]
        sensitivity_rows.append(
            {
                "Leak rate [kg/s]": leak_rate_kg_per_s,
                "Ventilation [1/h]": ventilation_rate_per_hour,
                "ESD time [s]": case_result["esd_time_seconds"],
                "Peak methane [% LEL]": (
                    case_history["Room methane [% LEL]"].max()
                ),
                "Max balance residual [mol]": (
                    case_history["Balance residual [mol]"].abs().max()
                ),
            }
        )

sensitivity_table = pd.DataFrame(sensitivity_rows)
display(
    sensitivity_table.round(
        {
            "Leak rate [kg/s]": 3,
            "Ventilation [1/h]": 1,
            "ESD time [s]": 1,
            "Peak methane [% LEL]": 3,
            "Max balance residual [mol]": 12,
        }
    )
)
# Out:
#     Leak rate [kg/s]  ...  Max balance residual [mol]
# 0              0.025  ...                5.000000e-12
# 1              0.025  ...                4.000000e-12
# 2              0.025  ...                5.000000e-12
# 3              0.030  ...                3.000000e-12
# 4              0.030  ...                4.000000e-12
# 5              0.030  ...                3.000000e-12
# 6              0.040  ...                3.000000e-12
# 7              0.040  ...                5.000000e-12
# 8              0.040  ...                5.000000e-12
# 9              0.050  ...                2.000000e-12
# 10             0.050  ...                2.000000e-12
# 11             0.050  ...                2.000000e-12
#
# [12 rows x 5 columns]

# %%
trip_time_grid = (
    sensitivity_table
    .pivot(
        index="Ventilation [1/h]",
        columns="Leak rate [kg/s]",
        values="ESD time [s]",
    )
)

fig, ax = plt.subplots(figsize=(9.0, 4.8))
image = ax.imshow(
    trip_time_grid.to_numpy(),
    cmap="viridis",
    aspect="auto",
    origin="lower",
)
colorbar = fig.colorbar(image, ax=ax)
colorbar.set_label("2oo2 HIHI ESD vote time [s]")

ax.set_xticks(
    np.arange(len(trip_time_grid.columns)),
    [f"{value:.3f}" for value in trip_time_grid.columns],
)
ax.set_yticks(
    np.arange(len(trip_time_grid.index)),
    [f"{value:.1f}" for value in trip_time_grid.index],
)
ax.set_xlabel("Total process-gas leak rate [kg/s]")
ax.set_ylabel("Ventilation rate [air changes/h]")
ax.set_title("Alarm-time sensitivity to leak rate and module ventilation")

for row_index in range(trip_time_grid.shape[0]):
    for column_index in range(trip_time_grid.shape[1]):
        trip_time_value = trip_time_grid.iloc[
            row_index,
            column_index,
        ]
        ax.text(
            column_index,
            row_index,
            f"{trip_time_value:.0f} s",
            ha="center",
            va="center",
            color="white",
            fontsize=9,
        )

plt.show()

# %% [markdown]
# Figure 6 confirms the expected trends within the tested range: a larger leak reaches
# the two-detector HIHI vote sooner, while more ventilation delays it. These trends are
# validation evidence for the inventory and detector coupling, not permission to credit
# ventilation as an independent protection layer without a formal assessment.

# %% [markdown]
# ## Engineering validation
#
# The final checks cover APIs, all preserved examples, alarm lifecycle, unit conversion,
# voting logic, SRK properties, process mass closure, methane inventory closure, event
# timing, and sensitivity trends. Finite results and physical bounds are required.

# %%
validation_checks = {}

validation_checks["composition sums to one"] = math.isclose(
    sum(feed_composition.values()),
    1.0,
    rel_tol=0.0,
    abs_tol=1.0e-12,
)
validation_checks["all fire examples preserved"] = (
    len(fire_vote_table) == 4
)
validation_checks["fire 2oo3 rejects one"] = (
    not fire_vote_table.loc[1, "2oo3 ESD"]
)
validation_checks["fire 2oo3 accepts two"] = (
    fire_vote_table.loc[2, "2oo3 ESD"]
)
validation_checks["fire 2oo3 accepts three"] = (
    fire_vote_table.loc[3, "2oo3 ESD"]
)
validation_checks["lifecycle includes HI"] = (
    "HI" in set(lifecycle_event_table["Level"])
)
validation_checks["lifecycle includes HIHI"] = (
    "HIHI" in set(lifecycle_event_table["Level"])
)
validation_checks["lifecycle activates"] = (
    "ACTIVATED" in set(lifecycle_event_table["Type"])
)
validation_checks["lifecycle acknowledges"] = (
    "ACKNOWLEDGED" in set(lifecycle_event_table["Type"])
)
validation_checks["lifecycle clears"] = (
    "CLEARED" in set(lifecycle_event_table["Type"])
)
validation_checks["LEL forward conversion"] = math.isclose(
    methane_percent_lel,
    20.0,
    rel_tol=0.0,
    abs_tol=1.0e-12,
)
validation_checks["LEL inverse conversion"] = math.isclose(
    warning_setpoint_ppm,
    10_000.0,
    rel_tol=0.0,
    abs_tol=1.0e-12,
)
validation_checks["three gas stages preserved"] = (
    len(staged_gas_table) == 3
)
validation_checks["large gas stage trips"] = (
    staged_gas_table.loc[2, "2oo2 ESD"]
)
validation_checks["three combined cases preserved"] = (
    len(combined_fg_table) == 3
)
validation_checks["all combined cases trip"] = (
    combined_fg_table["Combined ESD"].all()
)
validation_checks["H2S exercise reaches HI"] = (
    str(h2s_detector.getAlarmState().getActiveLevel()) == "HI"
)
validation_checks["oxygen exercise detects low"] = (
    oxygen_detector.getMeasuredValue() < 19.5
)
validation_checks["1oo2 exercise solved"] = (
    exercise_1oo2_result
)
validation_checks["2oo3 exercise finite"] = (
    0.0 < exercise_2oo3_probability < exercise_false_vote_probability
)
validation_checks["separator is effectively gas only"] = (
    separator_liquid.getFlowRate("kg/hr") < 1.0e-6
)
validation_checks["SRK compressibility plausible"] = (
    0.5 < separator_gas_system.getZ() < 1.2
)
validation_checks["SRK density plausible"] = (
    1.0 < separator_gas_system.getDensity("kg/m3") < 200.0
)
process_mass_residual_kg_per_h = (
    protected_feed.getFlowRate("kg/hr")
    - separator_gas.getFlowRate("kg/hr")
    - separator_liquid.getFlowRate("kg/hr")
)
validation_checks["process mass balance closes"] = (
    abs(process_mass_residual_kg_per_h) < 1.0e-6
)
validation_checks["base ESD occurs"] = (
    base_application["esd_time_seconds"] is not None
)
validation_checks["base ESD time plausible"] = (
    200.0 < base_application["esd_time_seconds"] < 400.0
)
validation_checks["isolation delay retained"] = math.isclose(
    (
        base_application["closure_time_seconds"]
        - base_application["esd_time_seconds"]
    ),
    8.0,
    rel_tol=0.0,
    abs_tol=1.0e-12,
)
validation_checks["room balance closes"] = (
    base_history["Balance residual [mol]"].abs().max() < 1.0e-8
)
validation_checks["base exceeds HIHI"] = (
    base_history["Room methane [% LEL]"].max() > 60.0
)
validation_checks["ventilation recovers below HI"] = (
    base_history["Room methane [% LEL]"].iloc[-1] < 20.0
)
validation_checks["all sensitivity cases trip"] = (
    sensitivity_table["ESD time [s]"].notna().all()
)
validation_checks["sensitivity balances close"] = (
    sensitivity_table["Max balance residual [mol]"].max() < 1.0e-8
)

for leak_rate_kg_per_s in leak_rates_kg_per_s:
    fixed_leak_cases = (
        sensitivity_table[
            sensitivity_table["Leak rate [kg/s]"]
            == leak_rate_kg_per_s
        ]
        .sort_values("Ventilation [1/h]")
    )
    validation_checks[
        f"ventilation delays trip at {leak_rate_kg_per_s:.3f} kg/s"
    ] = fixed_leak_cases["ESD time [s]"].is_monotonic_increasing

for ventilation_rate_per_hour in ventilation_rates_per_hour:
    fixed_ventilation_cases = (
        sensitivity_table[
            sensitivity_table["Ventilation [1/h]"]
            == ventilation_rate_per_hour
        ]
        .sort_values("Leak rate [kg/s]")
    )
    validation_checks[
        f"leak rate advances trip at {ventilation_rate_per_hour:.1f} 1/h"
    ] = fixed_ventilation_cases["ESD time [s]"].is_monotonic_decreasing

failed_checks = [
    check_name
    for check_name, passed in validation_checks.items()
    if not bool(passed)
]
assert not failed_checks, failed_checks

validation_table = pd.DataFrame(
    {
        "Engineering check": list(validation_checks),
        "Passed": list(validation_checks.values()),
    }
)
display(validation_table)
print(
    f"All {len(validation_checks)} alarm-handling engineering checks passed."
)
print(
    "Evidence level: conservation, native state-machine behavior, "
    "limiting logic, and expected nearby-case trends."
)
# Out:
# All 39 alarm-handling engineering checks passed.
# Evidence level: conservation, native state-machine behavior, limiting logic, and expected nearby-case trends.
#                         Engineering check  Passed
# 0                 composition sums to one    True
# 1             all fire examples preserved    True
# 2                   fire 2oo3 rejects one    True
# 3                   fire 2oo3 accepts two    True
# 4                 fire 2oo3 accepts three    True
# 5                   lifecycle includes HI    True
# 6                 lifecycle includes HIHI    True
# 7                     lifecycle activates    True
# 8                  lifecycle acknowledges    True
# 9                        lifecycle clears    True
# 10                 LEL forward conversion    True
# 11                 LEL inverse conversion    True
# 12             three gas stages preserved    True
# 13                  large gas stage trips    True
# 14         three combined cases preserved    True
# ...

# %% [markdown]
# ## Troubleshooting and practical limitations
#
# - **Import error:** run the setup cell, then imports, in the same runtime.
# - **No alarm event:** check the correct engineering unit, confirm the value remains over
#   the limit for the full delay, and use fresh alarm-state objects for independent cases.
# - **Alarm will not clear:** account for deadband; HI at 20% LEL clears at or below
#   18% LEL with the current configuration.
# - **Unexpected voting:** distinguish *at least M of N* from exactly M votes.
# - **Concentration mismatch:** distinguish ppm, volume percent, and percent LEL.
# - **Different trip time:** verify time step, detector response constant, spatial factor,
#   ventilation, and final-element delay.
# - **Real facility design:** replace the well-mixed room with validated dispersion,
#   detector mapping, and certified response data. Include common-cause failures,
#   diagnostics, proof testing, logic solver, final elements, human response, and the
#   applicable standard editions.

# %% [markdown]
# ## Summary
#
# The notebook now executes a complete chain:
#
# `SRK fluid -> Stream -> Separator -> room inventory -> GasDetector -> AlarmState -> 2oo2 ESD`
#
# It also preserves the original fire voting, gas stages, LEL conversion, combined F&G,
# toxic/oxygen examples, reliability comparison, and exercises. Native NeqSim alarm
# events provide an auditable lifecycle, while explicit mass balance and sensitivity
# tests provide engineering evidence beyond successful execution.

# %% [markdown]
# ## Further exercises
#
# 1. Add a third gas detector and compare 2oo3 ESD timing with one biased channel.
# 2. Use `shelveAlarm(reason, expiryTime)` during a simulated maintenance interval and
#    verify automatic expiry.
# 3. Replace the well-mixed model with validated time-series detector inputs.
# 4. Add a common-cause term to the voting probability comparison.
# 5. Substitute a heavier process gas and inspect separator phase split before repeating
#    the alarm study.
# 6. Connect the ESD vote to a NeqSim blowdown valve and flare model in a dynamic study.

# %% [markdown]
# ## References
#
# - [NeqSim documentation](https://equinor.github.io/neqsim/)
# - [NeqSim Google Colab quickstart](https://equinor.github.io/neqsim/quickstart/colab-quickstart.html)
# - [NeqSim getting-started and process-safety index](https://equinor.github.io/neqsim/wiki/getting_started.html)
# - [NeqSim process simulation package](https://equinor.github.io/neqsim/process/README.html)
# - [Current `AlarmConfig` source](https://github.com/equinor/neqsim/blob/master/src/main/java/neqsim/process/alarm/AlarmConfig.java)
# - [Current `AlarmState` source](https://github.com/equinor/neqsim/blob/master/src/main/java/neqsim/process/alarm/AlarmState.java)
# - [Current `FireDetector` source](https://github.com/equinor/neqsim/blob/master/src/main/java/neqsim/process/measurementdevice/FireDetector.java)
# - [Current `GasDetector` source](https://github.com/equinor/neqsim/blob/master/src/main/java/neqsim/process/measurementdevice/GasDetector.java)
# - [ISA-18 series overview](https://www.isa.org/standards-and-publications/isa-standards/isa-18-series-of-standards)
#
# Consult purchased or controlled copies of applicable standards and project requirements;
# this tutorial does not reproduce or replace their normative content.
