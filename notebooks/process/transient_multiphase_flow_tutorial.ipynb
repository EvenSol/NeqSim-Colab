# %% [markdown]
# <a href="https://colab.research.google.com/github/EvenSol/NeqSim-Colab/blob/master/notebooks/process/transient_multiphase_flow_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Transient multiphase flow with NeqSim's drift-flux model
#
# **Audience.** Flow-assurance engineers, process engineers, and graduate students who know basic
# thermodynamics and pressure-drop calculations.
#
# **Prerequisites.** Comfortable Python, SI units, gas-liquid phase behavior, and the distinction
# between actual and superficial velocity. No local files or credentials are needed.
#
# This tutorial uses the released `TransientPipe` implementation in NeqSim. It preserves the four
# applications in the original notebook: a horizontal flowline, a terrain low point, slug tracking,
# and a vertical riser. It also adds a reproducible flow-step application connected to a receiving
# separator.

# %% [markdown]
# ## Learning objectives
#
# After completing the notebook, you can:
#
# 1. Build an SRK gas-condensate fluid and a NeqSim material stream.
# 2. Configure geometry, terrain, mesh, boundary conditions, and simulation time.
# 3. Interpret pressure, temperature, holdup, phase velocity, and flow-regime profiles.
# 4. Inspect the released drift-flux closure parameters $C_0$ and $v_d$.
# 5. Track terrain accumulation and exercise the Lagrangian slug-diagnostic API.
# 6. Advance a pipe incrementally after a flow-rate change and connect its outlet to a separator.
# 7. Apply numerical and physical checks before treating a transient result as engineering evidence.

# %% [markdown]
# ## 1. Clean Colab setup
#
# The cell installs the current public PyPI package only when NeqSim is absent. A runtime restart is
# not required. The tutorial imports Java classes through NeqSim's supported `jneqsim` bridge because
# the drift-flux pipe is an advanced process-equipment class rather than a small Python wrapper.

# %%
import importlib.util
import subprocess
import sys

if importlib.util.find_spec("neqsim") is None:
    subprocess.check_call(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--no-cache-dir",
            "neqsim",
        ]
    )

# %%
from collections import Counter
from importlib.metadata import version
import platform

import matplotlib.pyplot as plt
from matplotlib.patches import FancyBboxPatch
import numpy as np
import pandas as pd

from neqsim import jneqsim, jpype
from neqsim.thermo import fluid


NEQSIM_VERSION = version("neqsim")
PYTHON_VERSION = platform.python_version()
JAVA_VERSION = str(
    jpype.JClass("java.lang.System").getProperty("java.version")
)

Stream = jneqsim.process.equipment.stream.Stream
Separator = jneqsim.process.equipment.separator.Separator
ProcessSystem = jneqsim.process.processmodel.ProcessSystem
TransientPipe = (
    jneqsim.process.equipment.pipeline.twophasepipe.TransientPipe
)
DriftFluxModel = (
    jneqsim.process.equipment.pipeline.twophasepipe.DriftFluxModel
)
SlugCharacteristics = (
    jneqsim.process.equipment.pipeline.twophasepipe
    .LiquidAccumulationTracker.SlugCharacteristics
)
UUID = jpype.JClass("java.util.UUID")

print(f"NeqSim version: {NEQSIM_VERSION}")
print(f"Python version: {PYTHON_VERSION}")
print(f"Java version: {JAVA_VERSION}")
# Out:
# NeqSim version: 3.16.0
# Python version: 3.12.13
# Java version: 17.0.19

# %% [markdown]
# ## 2. How the NeqSim workflow fits together
#
# The thermodynamic system stores composition and the SRK equation of state. A `Stream` adds flow,
# temperature, and pressure. `TransientPipe` discretizes the geometry into `PipeSection` objects,
# flashes the inlet fluid to initialize phase properties, advances conserved variables, applies
# drift-flux closure, and exposes profiles. A downstream `Separator` consumes the pipe outlet stream.
#
# The final application steps the pipe explicitly so the inlet schedule, solver call, result
# retrieval, checks, and separator update are visible.

# %%
figure, axis = plt.subplots(figsize=(12, 3.8))
axis.set_xlim(0.0, 12.0)
axis.set_ylim(0.0, 4.0)
axis.axis("off")

blocks = [
    (0.4, "SRK fluid\ncomposition + phases"),
    (3.2, "Material stream\nflow, T, P"),
    (6.0, "TransientPipe\nmesh + drift flux"),
    (8.8, "Separator\nphase products"),
]

for x_position, label in blocks:
    box = FancyBboxPatch(
        (x_position, 1.25),
        2.2,
        1.4,
        boxstyle="round,pad=0.08",
        facecolor="#D6EAF8",
        edgecolor="#1F4E79",
        linewidth=1.5,
    )
    axis.add_patch(box)
    axis.text(
        x_position + 1.1,
        1.95,
        label,
        ha="center",
        va="center",
        fontsize=10,
    )

for x_position in [2.65, 5.45, 8.25]:
    axis.annotate(
        "",
        xy=(x_position + 0.45, 1.95),
        xytext=(x_position, 1.95),
        arrowprops={"arrowstyle": "->", "color": "#333333", "lw": 1.8},
    )

axis.text(
    6.0,
    0.45,
    "configure → initialize → advance → retrieve → verify → interpret",
    ha="center",
    color="#333333",
    fontsize=11,
)
axis.set_title(
    "NeqSim workflow for a transient multiphase calculation",
    fontsize=13,
    pad=12,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Engineering model
#
# ### Conservation equations
#
# For phase $k$, the one-dimensional mass balance is
#
# $$
# \frac{\partial(\alpha_k \rho_k)}{\partial t}
# + \frac{\partial(\alpha_k \rho_k v_k)}{\partial x} = 0
# $$
#
# Here $\alpha_k$ is phase holdup in $1$, $\rho_k$ is density in $\mathrm{kg/m^3}$,
# $v_k$ is actual phase velocity in $\mathrm{m/s}$, $x$ is distance in $\mathrm{m}$, and $t$ is
# time in $\mathrm{s}$. Gas and liquid holdups satisfy $\alpha_G+\alpha_L=1$.
#
# The mixture momentum balance contains acceleration, pressure, gravity, and wall friction:
#
# $$
# \frac{\partial(\rho_m u_m)}{\partial t}
# + \frac{\partial(\rho_m u_m^2 + P)}{\partial x}
# = -\rho_m g \sin\theta - \frac{f \rho_m u_m |u_m|}{2D}
# $$
#
# $P$ is pressure in $\mathrm{Pa}$, $g$ is $9.81\ \mathrm{m/s^2}$, $\theta$ is inclination,
# $f$ is the Darcy friction factor, and $D$ is internal diameter in $\mathrm{m}$.

# %% [markdown]
# ### Drift-flux closure
#
# The solver closes the relative motion with the Zuber-Findlay relation
#
# $$
# v_G = C_0 j + v_d
# $$
#
# $j=j_G+j_L$ is total superficial velocity in $\mathrm{m/s}$, $C_0$ is a dimensionless
# distribution coefficient, and $v_d$ is drift velocity in $\mathrm{m/s}$. NeqSim selects the
# closure from the local regime and inclination. The actual gas velocity differs from superficial
# gas velocity because $v_G=j_G/\alpha_G$.
#
# `TransientPipe` uses a finite-volume, AUSM+-type flux calculation and adaptive CFL-controlled
# substeps. The requested time increment is therefore not necessarily the internal numerical step.

# %% [markdown]
# ### Assumptions, units, and validity limits
#
# - One-dimensional pipe-centerline flow with cross-section-averaged states.
# - Gas and liquid share pressure; phase slip is represented by the drift-flux closure.
# - The SRK model supplies equilibrium phase properties at selected update intervals.
# - Oil and water, if both present, are represented by volume-weighted liquid properties.
# - SI units are used internally; pressure plots use bara for readability.
# - Flow-regime boundaries and individual slug trajectories are model diagnostics, not universal
#   truth. Validate them against field or laboratory data for design.
# - Cell-scale alternating profiles can be physical waves or numerical resolution effects. Always
#   check mesh, CFL number, timestep, boundaries, and conservation before interpretation.

# %% [markdown]
# ## 4. Build and inspect the gas-condensate fluid
#
# The original tutorial used 80 mol% methane and 20 mol% n-pentane. That synthetic composition is
# retained because it gives a reproducible gas-liquid state without proprietary data. SRK with the
# classic mixing rule is appropriate for this non-polar hydrocarbon teaching case.

# %%
def make_gas_condensate(temperature_k=300.0, pressure_bara=50.0):
    model = fluid(
        name="srk",
        temperature=temperature_k,
        pressure=pressure_bara,
    )
    model.addComponent("methane", 0.80)
    model.addComponent("n-pentane", 0.20)
    model.setMixingRule("classic")
    model.setMultiPhaseCheck(True)

    operations = jneqsim.thermodynamicoperations.ThermodynamicOperations(
        model
    )
    operations.TPflash()
    model.initProperties()
    return model


base_fluid = make_gas_condensate()

phase_rows = []
for phase_name in ["gas", "oil", "aqueous"]:
    if base_fluid.hasPhaseType(phase_name):
        phase = base_fluid.getPhase(phase_name)
        phase_rows.append(
            {
                "phase": phase_name,
                "phase mole fraction (-)": float(phase.getBeta()),
                "density (kg/m³)": float(phase.getDensity("kg/m3")),
                "viscosity (Pa·s)": float(
                    phase.getViscosity("kg/msec")
                ),
            }
        )

phase_table = pd.DataFrame(phase_rows)
phase_table
# Out:
# Out[0]:
#   phase  phase mole fraction (-)  density (kg/m³)  viscosity (Pa·s)
# 0   gas                 0.770105        39.844121          0.000012
# 1   oil                 0.229895       571.669342          0.000164
#   phase  phase mole fraction (-)  density (kg/m³)  viscosity (Pa·s)
# 0   gas                 0.770105        39.844121          0.000012
# 1   oil                 0.229895       571.669342          0.000164

# %%
assert base_fluid.hasPhaseType("gas")
assert base_fluid.hasPhaseType("oil")
assert base_fluid.getNumberOfPhases() == 2
assert np.all(np.isfinite(phase_table["density (kg/m³)"]))
assert np.all(phase_table["density (kg/m³)"] > 0.0)

print(
    "Verified a two-phase gas-oil state at "
    f"{base_fluid.getTemperature():.2f} K and "
    f"{base_fluid.getPressure():.2f} bara."
)
# Out:
# Verified a two-phase gas-oil state at 300.00 K and 50.00 bara.

# %% [markdown]
# ## 5. Example 1 — horizontal flowline
#
# The first preserved example uses a 1000 m flowline with 0.20 m internal diameter, 50 µm absolute
# roughness, and 5.0 kg/s feed. Fifty cells retain the original spatial resolution. `run()` advances
# from its internally constructed initial state to the requested 10 s transient snapshot.

# %%
horizontal_inlet = Stream(
    "horizontal inlet",
    base_fluid.clone(),
)
horizontal_inlet.setFlowRate(5.0, "kg/sec")
horizontal_inlet.setTemperature(300.0, "K")
horizontal_inlet.setPressure(50.0, "bara")
horizontal_inlet.run()

horizontal_inlet_table = pd.DataFrame(
    {
        "quantity": ["mass flow", "temperature", "pressure"],
        "value": [
            horizontal_inlet.getFlowRate("kg/sec"),
            horizontal_inlet.getTemperature("K"),
            horizontal_inlet.getPressure("bara"),
        ],
        "unit": ["kg/s", "K", "bara"],
    }
)
horizontal_inlet_table
# Out:
# Out[0]:
#       quantity  value  unit
# 0    mass flow    5.0  kg/s
# 1  temperature  300.0     K
# 2     pressure   50.0  bara
#       quantity  value  unit
# 0    mass flow    5.0  kg/s
# 1  temperature  300.0     K
# 2     pressure   50.0  bara

# %%
horizontal_pipe = TransientPipe(
    "horizontal drift-flux pipe",
    horizontal_inlet,
)
horizontal_pipe.setLength(1000.0)
horizontal_pipe.setDiameter(0.20)
horizontal_pipe.setRoughness(0.00005)
horizontal_pipe.setNumberOfSections(50)
horizontal_pipe.setMaxSimulationTime(10.0)
horizontal_pipe.setCflNumber(0.5)
horizontal_pipe.setThermodynamicUpdateInterval(10)
horizontal_pipe.run()

print(
    f"Advanced to {horizontal_pipe.getSimulationTime():.3f} s "
    f"in {horizontal_pipe.getTotalTimeSteps()} adaptive steps."
)
# Out:
# Advanced to 10.009 s in 371 adaptive steps.

# %% [markdown]
# The profile arrays are returned at cell centers. Pressure is converted from Pa to bara; the other
# quantities remain in SI units. A transient run reaching its requested end time is not the same as
# a converged steady-state solve, so physical assertions are more useful here than the
# `isConverged()` flag.

# %%
horizontal_pressure_bar = np.asarray(
    horizontal_pipe.getPressureProfile(),
    dtype=float,
) / 1.0e5
horizontal_temperature_k = np.asarray(
    horizontal_pipe.getTemperatureProfile(),
    dtype=float,
)
horizontal_holdup = np.asarray(
    horizontal_pipe.getLiquidHoldupProfile(),
    dtype=float,
)
horizontal_gas_velocity = np.asarray(
    horizontal_pipe.getGasVelocityProfile(),
    dtype=float,
)
horizontal_liquid_velocity = np.asarray(
    horizontal_pipe.getLiquidVelocityProfile(),
    dtype=float,
)
horizontal_position_m = np.linspace(
    0.0,
    horizontal_pipe.getLength(),
    horizontal_pressure_bar.size,
)

horizontal_summary = pd.DataFrame(
    {
        "metric": [
            "inlet pressure",
            "outlet pressure",
            "pressure drop",
            "mean liquid holdup",
            "maximum gas velocity",
            "maximum liquid velocity",
        ],
        "value": [
            horizontal_pressure_bar[0],
            horizontal_pressure_bar[-1],
            horizontal_pressure_bar[0] - horizontal_pressure_bar[-1],
            horizontal_holdup.mean(),
            horizontal_gas_velocity.max(),
            horizontal_liquid_velocity.max(),
        ],
        "unit": ["bara", "bara", "bar", "-", "m/s", "m/s"],
    }
)
horizontal_summary
# Out:
# Out[0]:
#                     metric      value  unit
# 0           inlet pressure  50.215594  bara
# 1          outlet pressure  49.895872  bara
# 2            pressure drop   0.319721   bar
# 3       mean liquid holdup   0.021588     -
# 4     maximum gas velocity   3.548074   m/s
# 5  maximum liquid velocity   3.548074   m/s
#                     metric      value  unit
# 0           inlet pressure  50.215594  bara
# 1          outlet pressure  49.895872  bara
# 2            pressure drop   0.319721   bar
# 3       mean liquid holdup   0.021588     -
# 4     maximum gas velocity   3.548074   m/s
# 5  maximum liquid velocity   3.548074   m/s

# %%
horizontal_checks = {
    "pressure finite": np.all(np.isfinite(horizontal_pressure_bar)),
    "pressure positive": np.all(horizontal_pressure_bar > 1.0),
    "positive endpoint pressure drop": (
        horizontal_pressure_bar[0] > horizontal_pressure_bar[-1]
    ),
    "temperature finite": np.all(np.isfinite(horizontal_temperature_k)),
    "holdup bounded": np.all(
        (horizontal_holdup >= 0.0) & (horizontal_holdup <= 1.0)
    ),
    "gas velocity finite": np.all(
        np.isfinite(horizontal_gas_velocity)
    ),
    "liquid velocity finite": np.all(
        np.isfinite(horizontal_liquid_velocity)
    ),
    "solver validation": bool(horizontal_pipe.isSimulationValid()),
}

assert all(horizontal_checks.values())
pd.Series(horizontal_checks, name="passed")
# Out:
# Out[0]:
# pressure finite                    True
# pressure positive                  True
# positive endpoint pressure drop    True
# temperature finite                 True
# holdup bounded                     True
# gas velocity finite                True
# liquid velocity finite             True
# solver validation                  True
# Name: passed, dtype: bool
# pressure finite                    True
# pressure positive                  True
# positive endpoint pressure drop    True
# temperature finite                 True
# holdup bounded                     True
# gas velocity finite                True
# liquid velocity finite             True
# solver validation                  True
# Name: passed, dtype: bool

# %%
figure, axes = plt.subplots(2, 2, figsize=(13, 8))

axes[0, 0].plot(
    horizontal_position_m,
    horizontal_pressure_bar,
    color="#0072B2",
    linewidth=2.0,
    label="Pressure",
)
axes[0, 0].set_ylabel("Pressure (bara)")
axes[0, 0].set_title("Horizontal flowline pressure")
axes[0, 0].legend()

axes[0, 1].plot(
    horizontal_position_m,
    horizontal_temperature_k,
    color="#D55E00",
    linewidth=2.0,
    label="Temperature",
)
axes[0, 1].set_ylabel("Temperature (K)")
axes[0, 1].set_title("Horizontal flowline temperature")
axes[0, 1].legend()

axes[1, 0].plot(
    horizontal_position_m,
    horizontal_holdup,
    color="#009E73",
    linewidth=2.0,
    label="Liquid holdup",
)
axes[1, 0].set_ylabel("Liquid holdup (-)")
axes[1, 0].set_ylim(0.0, 1.0)
axes[1, 0].set_title("Horizontal flowline liquid holdup")
axes[1, 0].legend()

axes[1, 1].plot(
    horizontal_position_m,
    horizontal_gas_velocity,
    color="#0072B2",
    linewidth=2.0,
    label="Gas",
)
axes[1, 1].plot(
    horizontal_position_m,
    horizontal_liquid_velocity,
    color="#D55E00",
    linewidth=2.0,
    linestyle="--",
    label="Liquid",
)
axes[1, 1].set_ylabel("Actual phase velocity (m/s)")
axes[1, 1].set_title("Horizontal flowline phase velocities")
axes[1, 1].legend()

for axis in axes.flat:
    axis.set_xlabel("Distance from inlet (m)")
    axis.grid(alpha=0.25)

figure.suptitle(
    "Drift-flux profiles after 10 s: 1000 m horizontal flowline",
    fontsize=14,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# The pressure decreases between the endpoints and every displayed state remains finite. Gas and
# liquid velocities are actual phase velocities. In an annular or nearly homogeneous local closure,
# the two curves may coincide; that is a model result rather than evidence that slip is disabled
# globally.

# %% [markdown]
# ## 6. Flow-regime and drift-flux diagnostics
#
# Each `PipeSection` contains a mechanistic regime label. `DriftFluxModel.calculateDriftFlux()`
# returns the closure used for that local state. This public API replaces the original notebook's
# nonexistent top-level `pipeline.DriftFluxModel`.

# %%
horizontal_sections = list(horizontal_pipe.getSections())
horizontal_regimes = [
    str(section.getFlowRegime())
    for section in horizontal_sections
]
regime_counts = Counter(horizontal_regimes)

drift_model = DriftFluxModel()
drift_rows = []
for section in horizontal_sections:
    parameters = drift_model.calculateDriftFlux(section)
    drift_rows.append(
        {
            "position (m)": float(section.getPosition()),
            "regime": str(section.getFlowRegime()),
            "C0 (-)": float(parameters.C0),
            "drift velocity (m/s)": float(
                parameters.driftVelocity
            ),
            "void fraction (-)": float(parameters.voidFraction),
            "slip ratio (-)": float(parameters.slipRatio),
        }
    )

horizontal_drift_table = pd.DataFrame(drift_rows)
print("Regime counts:", dict(regime_counts))
horizontal_drift_table.iloc[[0, len(horizontal_drift_table) // 2, -1]]
# Out:
# Regime counts: {'ANNULAR': 50}
# Out[0]:
#     position (m)   regime  ...  void fraction (-)  slip ratio (-)
# 0            0.0  ANNULAR  ...           0.947234             1.0
# 25         500.0  ANNULAR  ...           0.979618             1.0
# 49         980.0  ANNULAR  ...           0.979618             1.0
#
# [3 rows x 6 columns]
#     position (m)   regime  ...  void fraction (-)  slip ratio (-)
# 0            0.0  ANNULAR  ...           0.947234             1.0
# 25         500.0  ANNULAR  ...           0.979618             1.0
# 49         980.0  ANNULAR  ...           0.979618             1.0
#
# [3 rows x 6 columns]

# %%
figure, axes = plt.subplots(1, 2, figsize=(12, 4.2))

axes[0].plot(
    horizontal_drift_table["position (m)"],
    horizontal_drift_table["C0 (-)"],
    color="#0072B2",
    linewidth=2.0,
    label="$C_0$",
)
axes[0].set_xlabel("Distance from inlet (m)")
axes[0].set_ylabel("Distribution coefficient (-)")
axes[0].set_title("Drift-flux distribution coefficient")
axes[0].legend()
axes[0].grid(alpha=0.25)

axes[1].plot(
    horizontal_drift_table["position (m)"],
    horizontal_drift_table["drift velocity (m/s)"],
    color="#CC79A7",
    linewidth=2.0,
    label="$v_d$",
)
axes[1].set_xlabel("Distance from inlet (m)")
axes[1].set_ylabel("Drift velocity (m/s)")
axes[1].set_title("Regime-dependent drift velocity")
axes[1].legend()
axes[1].grid(alpha=0.25)

figure.suptitle(
    "Local drift-flux closure in the horizontal flowline",
    fontsize=14,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Example 2 — terrain low point
#
# The preserved terrain application is retained with a gentler public synthetic profile: a 1000 m
# line descends 5 m and climbs back to its original elevation. This reduces numerical shock while
# still testing low-point detection, liquid accumulation, gravity, regime changes, and transient
# spatial waves. The profile contains 20 cell-center elevations because that is what the released
# setter expects.

# %%
terrain_position_m = np.linspace(0.0, 1000.0, 20)
terrain_elevation_m = np.interp(
    terrain_position_m,
    [0.0, 250.0, 500.0, 750.0, 1000.0],
    [0.0, 0.0, -5.0, 0.0, 0.0],
)

figure, axis = plt.subplots(figsize=(11, 3.5))
axis.plot(
    terrain_position_m,
    terrain_elevation_m,
    color="#6B4C3B",
    linewidth=2.5,
    label="Pipe centerline",
)
axis.fill_between(
    terrain_position_m,
    terrain_elevation_m,
    terrain_elevation_m.min() - 1.5,
    color="#D9B99B",
    alpha=0.45,
)
axis.set_xlabel("Distance from inlet (m)")
axis.set_ylabel("Elevation (m)")
axis.set_title("Synthetic terrain profile with one low point")
axis.legend()
axis.grid(alpha=0.25)
plt.tight_layout()
plt.show()

# %%
terrain_inlet = Stream(
    "terrain inlet",
    make_gas_condensate(300.0, 60.0),
)
terrain_inlet.setFlowRate(3.0, "kg/sec")
terrain_inlet.setTemperature(300.0, "K")
terrain_inlet.setPressure(60.0, "bara")
terrain_inlet.run()

terrain_pipe = TransientPipe(
    "terrain drift-flux pipe",
    terrain_inlet,
)
terrain_pipe.setLength(1000.0)
terrain_pipe.setDiameter(0.25)
terrain_pipe.setRoughness(0.00005)
terrain_pipe.setNumberOfSections(20)
terrain_pipe.setElevationProfile(terrain_elevation_m.tolist())
terrain_pipe.setMaxSimulationTime(2.0)
terrain_pipe.setCflNumber(0.3)
terrain_pipe.run()

terrain_pressure_bar = np.asarray(
    terrain_pipe.getPressureProfile(),
    dtype=float,
) / 1.0e5
terrain_holdup = np.asarray(
    terrain_pipe.getLiquidHoldupProfile(),
    dtype=float,
)
terrain_regimes = [
    str(section.getFlowRegime())
    for section in terrain_pipe.getSections()
]

# %%
accumulation_tracker = terrain_pipe.getAccumulationTracker()
accumulation_zones = list(
    accumulation_tracker.getAccumulationZones()
)

zone_rows = []
for zone_index, zone in enumerate(accumulation_zones, start=1):
    zone_rows.append(
        {
            "zone": zone_index,
            "start position (m)": float(zone.startPosition),
            "end position (m)": float(zone.endPosition),
            "liquid volume (m³)": float(zone.liquidVolume),
            "maximum volume (m³)": float(zone.maxVolume),
            "net inflow (m³/s)": float(zone.netInflowRate),
            "overflowing": bool(zone.isOverflowing),
        }
    )

accumulation_table = pd.DataFrame(zone_rows)
accumulation_table
# Out:
# Out[0]:
#    zone  start position (m)  ...  net inflow (m³/s)  overflowing
# 0     1               250.0  ...           0.000901         True
#
# [1 rows x 7 columns]
#    zone  start position (m)  ...  net inflow (m³/s)  overflowing
# 0     1               250.0  ...           0.000901         True
#
# [1 rows x 7 columns]

# %%
terrain_checks = {
    "one or more low-point zones": len(accumulation_zones) >= 1,
    "nominal low point covered": any(
        zone.startPosition <= 500.0 <= zone.endPosition
        for zone in accumulation_zones
    ),
    "pressure finite": np.all(np.isfinite(terrain_pressure_bar)),
    "pressure above 1 bara": np.all(terrain_pressure_bar > 1.0),
    "holdup bounded": np.all(
        (terrain_holdup >= 0.0) & (terrain_holdup <= 1.0)
    ),
    "accumulated volume nonnegative": (
        accumulation_tracker.getTotalAccumulatedVolume() >= 0.0
    ),
    "solver validation": bool(terrain_pipe.isSimulationValid()),
}

assert all(terrain_checks.values())
pd.Series(terrain_checks, name="passed")
# Out:
# Out[0]:
# one or more low-point zones       True
# nominal low point covered         True
# pressure finite                   True
# pressure above 1 bara             True
# holdup bounded                    True
# accumulated volume nonnegative    True
# solver validation                 True
# Name: passed, dtype: bool
# one or more low-point zones       True
# nominal low point covered         True
# pressure finite                   True
# pressure above 1 bara             True
# holdup bounded                    True
# accumulated volume nonnegative    True
# solver validation                 True
# Name: passed, dtype: bool

# %%
figure, axes = plt.subplots(3, 1, figsize=(12, 9), sharex=True)

axes[0].plot(
    terrain_position_m,
    terrain_elevation_m,
    color="#6B4C3B",
    linewidth=2.0,
    label="Elevation",
)
axes[0].set_ylabel("Elevation (m)")
axes[0].set_title("Terrain geometry")
axes[0].legend()

axes[1].plot(
    terrain_position_m,
    terrain_pressure_bar,
    color="#0072B2",
    linewidth=2.0,
    marker="o",
    markersize=3.5,
    label="2 s pressure snapshot",
)
axes[1].set_ylabel("Pressure (bara)")
axes[1].set_title("Transient pressure profile")
axes[1].legend()

axes[2].plot(
    terrain_position_m,
    terrain_holdup,
    color="#009E73",
    linewidth=2.0,
    marker="o",
    markersize=3.5,
    label="Liquid holdup",
)
axes[2].set_xlabel("Distance from inlet (m)")
axes[2].set_ylabel("Liquid holdup (-)")
axes[2].set_ylim(0.0, 1.0)
axes[2].set_title("Transient liquid distribution")
axes[2].legend()

for zone in accumulation_zones:
    for axis in axes:
        axis.axvspan(
            zone.startPosition,
            zone.endPosition,
            color="#E69F00",
            alpha=0.12,
        )

for axis in axes:
    axis.grid(alpha=0.25)

figure.suptitle(
    "Terrain-induced accumulation diagnostics after 2 s",
    fontsize=14,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# The orange band is the region identified by NeqSim's accumulation tracker. The pressure curve is
# a transient cell-center snapshot, not a steady pressure traverse. Alternating values near the
# low point must therefore be checked against smaller timesteps and finer meshes before using local
# peaks for design. The robust conclusions here are bounded pressure, bounded holdup, and correct
# low-point identification.

# %% [markdown]
# ## 8. Example 3 — controlled slug-tracker diagnostic
#
# Flow-regime classification and individual slug tracking answer different questions. A section can
# be classified as `SLUG` before the Lagrangian tracker has generated a discrete slug. To preserve
# the original slug API lesson reproducibly, this cell inserts one documented 50 m diagnostic slug
# into the terrain sections and advances it by 0.5 s.
#
# This is an API and bookkeeping check, not a prediction of field slug frequency.

# %%
slug_tracker = terrain_pipe.getSlugTracker()
automatic_slug_count = int(slug_tracker.getSlugCount())

controlled_slug = SlugCharacteristics()
controlled_slug.frontPosition = 400.0
controlled_slug.tailPosition = 350.0
controlled_slug.length = 50.0
controlled_slug.holdup = 0.85
controlled_slug.velocity = 2.0
controlled_slug.volume = 1.0
controlled_slug.isTerrainInduced = True

slug_unit = slug_tracker.initializeTerrainSlug(
    controlled_slug,
    terrain_pipe.getSections(),
)
front_before_m = float(slug_unit.frontPosition)
tail_before_m = float(slug_unit.tailPosition)

slug_tracker.setReferenceVelocity(2.0)
slug_tracker.advanceSlugs(
    terrain_pipe.getSections(),
    0.5,
)

slug_diagnostic = pd.DataFrame(
    {
        "marker": ["front", "tail"],
        "before (m)": [front_before_m, tail_before_m],
        "after 0.5 s (m)": [
            float(slug_unit.frontPosition),
            float(slug_unit.tailPosition),
        ],
        "velocity (m/s)": [
            float(slug_unit.frontVelocity),
            float(slug_unit.tailVelocity),
        ],
    }
)
slug_diagnostic
# Out:
# Out[0]:
#   marker  before (m)  after 0.5 s (m)  velocity (m/s)
# 0  front       400.0       401.445268        2.890537
# 1   tail       350.0       351.445268        2.890537
#   marker  before (m)  after 0.5 s (m)  velocity (m/s)
# 0  front       400.0       401.445268        2.890537
# 1   tail       350.0       351.445268        2.890537

# %%
slug_checks = {
    "controlled slug active": slug_tracker.getSlugCount() >= 1,
    "front moved downstream": (
        slug_unit.frontPosition > front_before_m
    ),
    "tail moved downstream": slug_unit.tailPosition > tail_before_m,
    "front velocity positive": slug_unit.frontVelocity > 0.0,
    "tail velocity positive": slug_unit.tailVelocity > 0.0,
    "bookkeeping error negligible": abs(
        slug_tracker.getMassConservationError()
    ) < 1.0e-9,
}

assert all(slug_checks.values())
print(f"Automatic active slugs before injection: {automatic_slug_count}")
print(slug_tracker.getStatisticsString())
pd.Series(slug_checks, name="passed")
# Out:
# Automatic active slugs before injection: 0
# Slug Statistics:
#   Active slugs: 1
#   Total generated: 1
#   Total merged: 0
#   Frequency: 0.000 Hz
#   Avg length: 50.0 m
#   Max length: 50.0 m
#   Mass borrowed: 559.784 kg
#   Mass returned: 0.000 kg
#   Mass conservation error: 0.000000 kg
#
# Out[0]:
# controlled slug active          True
# front moved downstream          True
# tail moved downstream           True
# front velocity positive         True
# tail velocity positive          True
# bookkeeping error negligible    True
# Name: passed, dtype: bool
# controlled slug active          True
# front moved downstream          True
# tail moved downstream           True
# front velocity positive         True
# tail velocity positive          True
# bookkeeping error negligible    True
# Name: passed, dtype: bool

# %%
figure, axis = plt.subplots(figsize=(11, 3.5))

axis.hlines(
    y=0.0,
    xmin=0.0,
    xmax=1000.0,
    color="#666666",
    linewidth=3.0,
    label="Pipeline",
)
axis.plot(
    [tail_before_m, front_before_m],
    [0.15, 0.15],
    color="#E69F00",
    linewidth=8.0,
    solid_capstyle="round",
    label="Slug before step",
)
axis.plot(
    [slug_unit.tailPosition, slug_unit.frontPosition],
    [-0.15, -0.15],
    color="#0072B2",
    linewidth=8.0,
    solid_capstyle="round",
    label="Slug after 0.5 s",
)
axis.set_xlim(300.0, 470.0)
axis.set_ylim(-0.5, 0.5)
axis.set_xlabel("Distance from inlet (m)")
axis.set_yticks([])
axis.set_title("Controlled Lagrangian slug-tracker advancement")
axis.legend(loc="upper left")
axis.grid(axis="x", alpha=0.25)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Example 4 — vertical riser initialization
#
# The preserved riser is 200 m high, 0.15 m in diameter, and carries 8.0 kg/s at 80 bara.
# `runTransient(0.0, id)` initializes the thermodynamic and hydraulic state without advancing an
# unqualified startup transient. This cleanly demonstrates the hydrostatic direction and keeps the
# example within a validated operating state.
#
# A full riser startup requires boundary pressures, initial inventory, timestep, and convergence
# studies specific to the facility. It should not be inferred from a generic default initialization.

# %%
riser_inlet = Stream(
    "riser inlet",
    make_gas_condensate(300.0, 80.0),
)
riser_inlet.setFlowRate(8.0, "kg/sec")
riser_inlet.setTemperature(300.0, "K")
riser_inlet.setPressure(80.0, "bara")
riser_inlet.run()

riser_position_m = np.linspace(0.0, 200.0, 40)
riser_pipe = TransientPipe(
    "vertical riser",
    riser_inlet,
)
riser_pipe.setLength(200.0)
riser_pipe.setDiameter(0.15)
riser_pipe.setRoughness(0.00005)
riser_pipe.setNumberOfSections(40)
riser_pipe.setElevationProfile(riser_position_m.tolist())
riser_pipe.setCflNumber(0.3)
riser_pipe.runTransient(0.0, UUID.randomUUID())

riser_pressure_bar = np.asarray(
    riser_pipe.getPressureProfile(),
    dtype=float,
) / 1.0e5
riser_holdup = np.asarray(
    riser_pipe.getLiquidHoldupProfile(),
    dtype=float,
)

# %%
riser_sections = list(riser_pipe.getSections())
riser_mixture_density = np.mean(
    [
        float(section.getMixtureDensity())
        for section in riser_sections
    ]
)
riser_hydrostatic_estimate_bar = (
    riser_mixture_density
    * 9.81
    * (riser_position_m[-1] - riser_position_m[0])
    / 1.0e5
)
riser_pressure_drop_bar = (
    riser_pressure_bar[0] - riser_pressure_bar[-1]
)

riser_summary = pd.DataFrame(
    {
        "quantity": [
            "bottom pressure",
            "top pressure",
            "initialized pressure drop",
            "mixture hydrostatic estimate",
            "mean liquid holdup",
        ],
        "value": [
            riser_pressure_bar[0],
            riser_pressure_bar[-1],
            riser_pressure_drop_bar,
            riser_hydrostatic_estimate_bar,
            riser_holdup.mean(),
        ],
        "unit": ["bara", "bara", "bar", "bar", "-"],
    }
)
riser_summary
# Out:
# Out[0]:
#                        quantity      value  unit
# 0               bottom pressure  80.000000  bara
# 1                  top pressure  78.132783  bara
# 2     initialized pressure drop   1.867217   bar
# 3  mixture hydrostatic estimate   1.741736   bar
# 4            mean liquid holdup   0.046323     -
#                        quantity      value  unit
# 0               bottom pressure  80.000000  bara
# 1                  top pressure  78.132783  bara
# 2     initialized pressure drop   1.867217   bar
# 3  mixture hydrostatic estimate   1.741736   bar
# 4            mean liquid holdup   0.046323     -

# %%
riser_checks = {
    "pressure finite": np.all(np.isfinite(riser_pressure_bar)),
    "holdup finite": np.all(np.isfinite(riser_holdup)),
    "pressure decreases upward": riser_pressure_drop_bar > 0.0,
    "holdup bounded": np.all(
        (riser_holdup >= 0.0) & (riser_holdup <= 1.0)
    ),
    "hydrostatic magnitude consistent": (
        0.5
        < riser_pressure_drop_bar / riser_hydrostatic_estimate_bar
        < 1.5
    ),
    "solver validation": bool(riser_pipe.isSimulationValid()),
}

assert all(riser_checks.values())
pd.Series(riser_checks, name="passed")
# Out:
# Out[0]:
# pressure finite                     True
# holdup finite                       True
# pressure decreases upward           True
# holdup bounded                      True
# hydrostatic magnitude consistent    True
# solver validation                   True
# Name: passed, dtype: bool
# pressure finite                     True
# holdup finite                       True
# pressure decreases upward           True
# holdup bounded                      True
# hydrostatic magnitude consistent    True
# solver validation                   True
# Name: passed, dtype: bool

# %%
figure, axes = plt.subplots(1, 2, figsize=(11, 6), sharey=True)

axes[0].plot(
    riser_pressure_bar,
    riser_position_m,
    color="#0072B2",
    linewidth=2.5,
    label="Initialized pressure",
)
axes[0].set_xlabel("Pressure (bara)")
axes[0].set_ylabel("Height above riser base (m)")
axes[0].set_title("Vertical-riser pressure")
axes[0].legend()

axes[1].plot(
    riser_holdup,
    riser_position_m,
    color="#009E73",
    linewidth=2.5,
    label="Liquid holdup",
)
axes[1].set_xlabel("Liquid holdup (-)")
axes[1].set_xlim(0.0, 1.0)
axes[1].set_title("Vertical-riser liquid holdup")
axes[1].legend()

for axis in axes:
    axis.grid(alpha=0.25)

figure.suptitle(
    "Validated initial state for a 200 m vertical riser",
    fontsize=14,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Spatial-resolution sensitivity
#
# Mesh sensitivity is more informative than timing one deliberately coarse run. The next helper
# repeats the horizontal case with 15, 30, and 60 sections for the same 3 s snapshot. Pressure drop
# and mean holdup should remain finite and retain their engineering direction. Differences quantify
# discretization sensitivity for this short transient, not formal grid convergence.

# %%
def run_horizontal_resolution(number_of_sections):
    sensitivity_inlet = Stream(
        f"mesh inlet {number_of_sections}",
        base_fluid.clone(),
    )
    sensitivity_inlet.setFlowRate(5.0, "kg/sec")
    sensitivity_inlet.setTemperature(300.0, "K")
    sensitivity_inlet.setPressure(50.0, "bara")
    sensitivity_inlet.run()

    sensitivity_pipe = TransientPipe(
        f"mesh pipe {number_of_sections}",
        sensitivity_inlet,
    )
    sensitivity_pipe.setLength(1000.0)
    sensitivity_pipe.setDiameter(0.20)
    sensitivity_pipe.setRoughness(0.00005)
    sensitivity_pipe.setNumberOfSections(number_of_sections)
    sensitivity_pipe.setMaxSimulationTime(3.0)
    sensitivity_pipe.setCflNumber(0.3)
    sensitivity_pipe.run()

    pressure_bar = np.asarray(
        sensitivity_pipe.getPressureProfile(),
        dtype=float,
    ) / 1.0e5
    holdup = np.asarray(
        sensitivity_pipe.getLiquidHoldupProfile(),
        dtype=float,
    )
    return {
        "sections (-)": number_of_sections,
        "cell length (m)": 1000.0 / number_of_sections,
        "pressure drop (bar)": pressure_bar[0] - pressure_bar[-1],
        "mean liquid holdup (-)": holdup.mean(),
        "adaptive steps (-)": sensitivity_pipe.getTotalTimeSteps(),
        "finite": bool(
            np.all(np.isfinite(pressure_bar))
            and np.all(np.isfinite(holdup))
        ),
    }


mesh_table = pd.DataFrame(
    [
        run_horizontal_resolution(number_of_sections)
        for number_of_sections in [15, 30, 60]
    ]
)
mesh_table
# Out:
# Out[0]:
#    sections (-)  cell length (m)  ...  adaptive steps (-)  finite
# 0            15        66.666667  ...                  56    True
# 1            30        33.333333  ...                 112    True
# 2            60        16.666667  ...                 223    True
#
# [3 rows x 6 columns]
#    sections (-)  cell length (m)  ...  adaptive steps (-)  finite
# 0            15        66.666667  ...                  56    True
# 1            30        33.333333  ...                 112    True
# 2            60        16.666667  ...                 223    True
#
# [3 rows x 6 columns]

# %%
assert mesh_table["finite"].all()
assert np.all(mesh_table["pressure drop (bar)"] > 0.0)
assert np.all(
    (mesh_table["mean liquid holdup (-)"] >= 0.0)
    & (mesh_table["mean liquid holdup (-)"] <= 1.0)
)

figure, axes = plt.subplots(1, 2, figsize=(11, 4.2))

axes[0].plot(
    mesh_table["cell length (m)"],
    mesh_table["pressure drop (bar)"],
    color="#0072B2",
    marker="o",
    linewidth=2.0,
    label="Pressure drop",
)
axes[0].set_xlabel("Cell length (m)")
axes[0].set_ylabel("Pressure drop (bar)")
axes[0].set_title("Pressure-drop mesh sensitivity")
axes[0].legend()

axes[1].plot(
    mesh_table["cell length (m)"],
    mesh_table["mean liquid holdup (-)"],
    color="#009E73",
    marker="o",
    linewidth=2.0,
    label="Mean holdup",
)
axes[1].set_xlabel("Cell length (m)")
axes[1].set_ylabel("Mean liquid holdup (-)")
axes[1].set_title("Holdup mesh sensitivity")
axes[1].legend()

for axis in axes:
    axis.grid(alpha=0.25)
    axis.invert_xaxis()

figure.suptitle(
    "Three-mesh comparison for an identical 3 s transient",
    fontsize=14,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 11. Final application — flow step into a receiving separator
#
# This end-to-end application composes a fluid, inlet stream, transient flowline, outlet stream,
# receiving separator, and `ProcessSystem`. The calculation is stepped explicitly in 0.5 s
# increments:
#
# - 0–2 s: 3.0 kg/s baseline,
# - 2–4 s: 5.0 kg/s high-rate period,
# - 4–6 s: return to 3.0 kg/s.
#
# The pipe rereads the inlet stream on every `runTransient()` call. The receiver then flashes the
# updated pipe outlet and exposes gas and liquid product flows.

# %%
dynamic_inlet = Stream(
    "dynamic inlet",
    make_gas_condensate(300.0, 50.0),
)
dynamic_inlet.setFlowRate(3.0, "kg/sec")
dynamic_inlet.setTemperature(300.0, "K")
dynamic_inlet.setPressure(50.0, "bara")
dynamic_inlet.run()

dynamic_pipe = TransientPipe(
    "dynamic drift-flux flowline",
    dynamic_inlet,
)
dynamic_pipe.setLength(300.0)
dynamic_pipe.setDiameter(0.20)
dynamic_pipe.setRoughness(0.00005)
dynamic_pipe.setNumberOfSections(20)
dynamic_pipe.setCflNumber(0.3)
dynamic_pipe.runTransient(0.0, UUID.randomUUID())

receiving_separator = Separator(
    "receiving separator",
    dynamic_pipe.getOutletStream(),
)

process_system = ProcessSystem("flowline and receiver")
process_system.add(dynamic_inlet)
process_system.add(dynamic_pipe)
process_system.add(receiving_separator)

print(
    "Connected equipment: dynamic inlet → "
    "dynamic drift-flux flowline → receiving separator"
)
# Out:
# Connected equipment: dynamic inlet → dynamic drift-flux flowline → receiving separator

# %%
flow_schedule_kg_s = [3.0] * 4 + [5.0] * 4 + [3.0] * 4
dynamic_records = []

for requested_flow_kg_s in flow_schedule_kg_s:
    dynamic_inlet.setFlowRate(requested_flow_kg_s, "kg/sec")
    dynamic_inlet.run()

    dynamic_pipe.runTransient(0.5, UUID.randomUUID())
    receiving_separator.run()

    pressure_bar = np.asarray(
        dynamic_pipe.getPressureProfile(),
        dtype=float,
    ) / 1.0e5
    holdup = np.asarray(
        dynamic_pipe.getLiquidHoldupProfile(),
        dtype=float,
    )
    pipe_outlet_flow_kg_s = dynamic_pipe.getOutletStream().getFlowRate(
        "kg/sec"
    )
    gas_product_kg_s = (
        receiving_separator.getGasOutStream().getFlowRate("kg/sec")
    )
    liquid_product_kg_s = (
        receiving_separator.getLiquidOutStream().getFlowRate("kg/sec")
    )

    dynamic_records.append(
        {
            "time (s)": float(dynamic_pipe.getSimulationTime()),
            "requested inlet flow (kg/s)": requested_flow_kg_s,
            "inlet pressure (bara)": pressure_bar[0],
            "outlet pressure (bara)": pressure_bar[-1],
            "mean liquid holdup (-)": holdup.mean(),
            "pipe outlet flow (kg/s)": pipe_outlet_flow_kg_s,
            "gas product (kg/s)": gas_product_kg_s,
            "liquid product (kg/s)": liquid_product_kg_s,
        }
    )

dynamic_table = pd.DataFrame(dynamic_records)
dynamic_table
# Out:
# Out[0]:
#     time (s)  ...  liquid product (kg/s)
# 0        0.5  ...               1.486414
# 1        1.0  ...               1.486414
# 2        1.5  ...               1.486414
# 3        2.0  ...               1.486414
# 4        2.5  ...               2.477357
# 5        3.0  ...               2.477357
# 6        3.5  ...               2.477357
# 7        4.0  ...               2.477357
# 8        4.5  ...               1.486414
# 9        5.0  ...               1.486414
# 10       5.5  ...               1.486414
# 11       6.0  ...               1.486414
#
# [12 rows x 8 columns]
#     time (s)  ...  liquid product (kg/s)
# 0        0.5  ...               1.486414
# 1        1.0  ...               1.486414
# 2        1.5  ...               1.486414
# 3        2.0  ...               1.486414
# 4        2.5  ...               2.477357
# 5        3.0  ...               2.477357
# 6        3.5  ...               2.477357
# 7        4.0  ...               2.477357
# ...

# %%
product_sum_kg_s = (
    dynamic_table["gas product (kg/s)"]
    + dynamic_table["liquid product (kg/s)"]
)
separator_mass_residual_kg_s = (
    product_sum_kg_s
    - dynamic_table["pipe outlet flow (kg/s)"]
)

baseline_pressure_bar = dynamic_table.loc[
    dynamic_table["time (s)"] <= 2.0,
    "inlet pressure (bara)",
].mean()
high_rate_pressure_bar = dynamic_table.loc[
    (dynamic_table["time (s)"] > 2.0)
    & (dynamic_table["time (s)"] <= 4.0),
    "inlet pressure (bara)",
].mean()

application_checks = {
    "all results finite": bool(
        np.all(
            np.isfinite(
                dynamic_table.select_dtypes(include=[np.number])
            )
        )
    ),
    "pressures above 1 bara": bool(
        np.all(dynamic_table["inlet pressure (bara)"] > 1.0)
        and np.all(dynamic_table["outlet pressure (bara)"] > 1.0)
    ),
    "holdup bounded": bool(
        np.all(dynamic_table["mean liquid holdup (-)"] >= 0.0)
        and np.all(dynamic_table["mean liquid holdup (-)"] <= 1.0)
    ),
    "high-rate inlet pressure response": (
        high_rate_pressure_bar > baseline_pressure_bar
    ),
    "separator mass balance": bool(
        np.max(np.abs(separator_mass_residual_kg_s)) < 1.0e-8
    ),
    "simulation time reached 6 s": (
        dynamic_table["time (s)"].iloc[-1] >= 6.0 - 1.0e-9
    ),
}

assert all(application_checks.values())
pd.Series(application_checks, name="passed")
# Out:
# Out[0]:
# all results finite                   True
# pressures above 1 bara               True
# holdup bounded                       True
# high-rate inlet pressure response    True
# separator mass balance               True
# simulation time reached 6 s          True
# Name: passed, dtype: bool
# all results finite                   True
# pressures above 1 bara               True
# holdup bounded                       True
# high-rate inlet pressure response    True
# separator mass balance               True
# simulation time reached 6 s          True
# Name: passed, dtype: bool

# %%
figure, axes = plt.subplots(3, 1, figsize=(12, 9), sharex=True)

axes[0].step(
    dynamic_table["time (s)"],
    dynamic_table["requested inlet flow (kg/s)"],
    where="post",
    color="#000000",
    linewidth=2.0,
    label="Requested inlet flow",
)
axes[0].plot(
    dynamic_table["time (s)"],
    dynamic_table["gas product (kg/s)"],
    color="#0072B2",
    marker="o",
    label="Separator gas",
)
axes[0].plot(
    dynamic_table["time (s)"],
    dynamic_table["liquid product (kg/s)"],
    color="#D55E00",
    marker="s",
    label="Separator liquid",
)
axes[0].set_ylabel("Mass flow (kg/s)")
axes[0].set_title("Scheduled feed and receiving-separator products")
axes[0].legend(ncol=3)

axes[1].plot(
    dynamic_table["time (s)"],
    dynamic_table["inlet pressure (bara)"],
    color="#0072B2",
    marker="o",
    label="Pipe inlet",
)
axes[1].plot(
    dynamic_table["time (s)"],
    dynamic_table["outlet pressure (bara)"],
    color="#CC79A7",
    marker="s",
    label="Pipe outlet",
)
axes[1].set_ylabel("Pressure (bara)")
axes[1].set_title("Pressure response to the flow-rate step")
axes[1].legend()

axes[2].plot(
    dynamic_table["time (s)"],
    dynamic_table["mean liquid holdup (-)"],
    color="#009E73",
    marker="o",
    linewidth=2.0,
    label="Mean liquid holdup",
)
axes[2].set_xlabel("Simulation time (s)")
axes[2].set_ylabel("Mean liquid holdup (-)")
axes[2].set_ylim(0.0, 0.06)
axes[2].set_title("Flowline inventory response")
axes[2].legend()

for axis in axes:
    axis.grid(alpha=0.25)

figure.suptitle(
    "End-to-end transient flowline and receiving-separator application",
    fontsize=14,
)
plt.tight_layout()
plt.show()

# %% [markdown]
# The high-rate interval raises the average inlet pressure relative to the baseline while the outlet
# boundary remains nearly fixed. The small holdup change is physically plausible for a gas-rich
# fluid over only six seconds. Separator gas and liquid flows close exactly to the pipe outlet flow
# within numerical precision.
#
# Reuse this workflow by replacing composition, geometry, schedule, and receiver conditions with
# documented project inputs, then extending the time horizon only after timestep and mesh checks.

# %% [markdown]
# ## 12. Consolidated verification
#
# The checks below combine thermodynamic state, horizontal flow, terrain accumulation, controlled
# slug motion, riser hydrostatics, mesh sensitivity, and process mass balance. They are intentionally
# focused on invariants and expected trends rather than an invented benchmark.

# %%
all_check_groups = {
    "horizontal": horizontal_checks,
    "terrain": terrain_checks,
    "slug diagnostic": slug_checks,
    "riser": riser_checks,
    "application": application_checks,
}

verification_rows = []
for group_name, check_group in all_check_groups.items():
    for check_name, passed in check_group.items():
        verification_rows.append(
            {
                "group": group_name,
                "check": check_name,
                "passed": bool(passed),
            }
        )

verification_table = pd.DataFrame(verification_rows)
assert verification_table["passed"].all()

print(
    f"All {len(verification_table)} engineering checks passed "
    f"with NeqSim {NEQSIM_VERSION}."
)
verification_table
# Out:
# All 33 engineering checks passed with NeqSim 3.16.0.
# Out[0]:
#               group                              check  passed
# 0        horizontal                    pressure finite    True
# 1        horizontal                  pressure positive    True
# 2        horizontal    positive endpoint pressure drop    True
# 3        horizontal                 temperature finite    True
# 4        horizontal                     holdup bounded    True
# 5        horizontal                gas velocity finite    True
# 6        horizontal             liquid velocity finite    True
# 7        horizontal                  solver validation    True
# 8           terrain        one or more low-point zones    True
# 9           terrain          nominal low point covered    True
# 10          terrain                    pressure finite    True
# 11          terrain              pressure above 1 bara    True
# 12          terrain                     holdup bounded    True
# ...

# %% [markdown]
# ## Troubleshooting
#
# - **Import error:** rerun the setup cell; do not combine a local JAR with the PyPI wheel.
# - **No liquid phase:** lower temperature, raise heavy-component fraction, or inspect the TP flash
#   before constructing the pipe.
# - **NaN, negative pressure, or holdup outside 0–1:** reject the run. Reduce requested time
#   increments and CFL number, refine the mesh, and verify boundary conditions.
# - **Alternating cell values:** compare multiple meshes and timesteps. Do not label a
#   grid-scale oscillation as a physical slug frequency.
# - **No automatic slug objects:** a `SLUG` regime label does not guarantee that the Lagrangian
#   tracker has released an individual slug.
# - **Riser pressure increases upward:** stop. Check elevation sign, pressure boundaries, initial
#   inventory, and the transient duration.
# - **Slow execution:** reduce scenario count first. Increasing the thermodynamic update interval
#   can improve speed, but validate temperature and phase behavior afterward.

# %% [markdown]
# ## Practical limitations and applicability
#
# This tutorial is appropriate for API learning, screening, scenario comparison, and diagnosing
# transient trends. It is not a substitute for qualification against controlled experiments or field
# data. The one-dimensional drift-flux model cannot resolve cross-sectional waves, detailed slug
# shape, droplets, bend-scale three-dimensional effects, or facility-specific control logic.
#
# Individual slug-arrival statistics are especially sensitive to initialization and grid choice.
# Treat the controlled slug example as a software-function demonstration. For design, document
# uncertainty against another qualified model and measured pressure, holdup, or arrival data.

# %% [markdown]
# ## Summary
#
# - `TransientPipe` is the released NeqSim drift-flux process unit.
# - The SRK fluid, stream, geometry, mesh, terrain, and time stepping are explicit.
# - The original horizontal, terrain, slug, and riser learning goals are preserved.
# - Nine technical figures show workflow, principal profiles, closure parameters, terrain,
#   controlled slug motion, riser hydrostatics, mesh sensitivity, and the final process response.
# - Physical bounds, trend checks, hydrostatic scale, numerical sensitivity, and separator mass
#   balance are release gates for the notebook.

# %% [markdown]
# ## Further exercises
#
# 1. Replace n-pentane with a C3–C10 synthetic condensate and compare phase split and holdup.
# 2. Add water with an appropriate thermodynamic model and inspect volume-weighted liquid
#    properties.
# 3. Repeat the terrain case with CFL values 0.15, 0.30, and 0.50.
# 4. Extend the flow-step duration and test whether the pressure and holdup response settles.
# 5. Compare the horizontal pressure drop with `PipeBeggsAndBrills` using identical fluid,
#    geometry, and boundary conditions.
# 6. Add a downstream pressure controller only after documenting the boundary-condition strategy.

# %% [markdown]
# ## Authoritative references
#
# 1. Zuber, N. and Findlay, J. A. (1965), *Average Volumetric Concentration in Two-Phase Flow
#    Systems*, Journal of Heat Transfer, 87(4), 453–468.
# 2. Taitel, Y. and Dukler, A. E. (1976), *A Model for Predicting Flow Regime Transitions in
#    Horizontal and Near Horizontal Gas-Liquid Flow*, AIChE Journal, 22(1), 47–55.
# 3. Barnea, D. (1987), *A Unified Model for Predicting Flow-Pattern Transitions for the Whole
#    Range of Pipe Inclinations*, International Journal of Multiphase Flow, 13(1), 1–12.
# 4. Bendiksen, K. H. (1984), *An Experimental Investigation of the Motion of Long Bubbles in
#    Inclined Tubes*, International Journal of Multiphase Flow, 10(4), 467–483.
# 5. [NeqSim repository](https://github.com/equinor/neqsim)
# 6. [NeqSim Python package](https://pypi.org/project/neqsim/)
# 7. [Released `TransientPipe` source](https://github.com/equinor/neqsim/blob/master/src/main/java/neqsim/process/equipment/pipeline/twophasepipe/TransientPipe.java)
